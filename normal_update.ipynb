# %% [markdown]
# # Normal Weekly Updates

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import numpy as np
from geopy.geocoders import Nominatim

# %% [markdown]
# ## 1. Update ATP Ranking

# %% [markdown]
# ### Single Date Update - Last: 2023-06-12

# %%
# load txt files
def load_txt(file):
    with open(file, 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    f.close()
    return df

# %%
def scrape_a_date_rank(date, previous):
    # scrape a particular date
    prefix = 'https://www.atptour.com/en/rankings/singles?rankRange=0-100&rankDate='
    img_pre = 'https://www.atptour.com'

    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)

    # get url
    driver.get(prefix + date)
    driver.refresh()

    # get content
    print('Start scraping:', date)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    trs = soup.find('table', {'id':'player-rank-detail-ajax'}).find_all('tr')

    # set attrs
    attrs = ['Date', 'Rank', 'Country', 'Image', 'Player', 'Points']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # date
    dict['Date'] = [date for i in range(len(trs) - 1)]

    for tr in trs[1:]:
        tds = tr.find_all('td')
        # rank
        dict['Rank'].append(tds[0].text.strip())
        # country
        dict['Country'].append(tds[2].img.attrs.get('alt', None))
        # image
        dict['Image'].append(img_pre + tds[2].img.attrs.get('src', None))
        # player
        dict['Player'].append(tds[3].text.strip())
        # points
        dict['Points'].append(tds[5].text.strip().replace(',', ''))

    # save to txt
    df = pd.DataFrame(dict)
    df.to_csv('m/rank/dates/' + date + '.txt', index = False, sep = ',', encoding='utf-8-sig')
    print('Finished:', date)

    # open the ranking file
    dict_r = load_txt('m/rank/atpranking_20000110_'+previous.replace('-', '')+'.txt').to_dict('list')
    dict_r[date] = []

    # first get points for existing players
    for p in dict_r['Player']:
        found = False
        for i in range(len(dict['Player'])):
            if p == dict['Player'][i]:
                # add new point
                dict_r[date].append(dict['Points'][i])
                found = True
                break
        if not found:
            dict_r[date].append(0)

    # add new player if any
    for p in dict['Player']:
        if p not in dict_r['Player']:
            # add player
            dict_r['Player'].append(p)
            for i in range(len(dict['Player'])):
                if p == dict['Player'][i]:
                    # add country
                    dict_r['Country'].append(dict['Country'][i])
                    # add image
                    dict_r['Country_Image'].append(dict['Image'][i])
                    # add point
                    dict_r[date].append(dict['Points'][i])
                    break
            # add previous points, all 0
            for d in [key for key in dict_r.keys()][3:-1]:
                dict_r[d].append(0)

    # save to txt
    df_new = pd.DataFrame(dict_r)
    df_new.to_csv('m/rank/atpranking_20000110_'+date.replace('-', '')+'.txt', index = False, sep = ',', encoding='utf-8-sig')

# %%
scrape_a_date_rank('2023-06-12', '2023-05-29')
# Out:
# Start scraping: 2023-06-12
# Finished: 2023-06-12

# %% [markdown]
# Remember to add the new dates to dates.txt

# %% [markdown]
# ## 2. Update ATP Links According to New Ranks - Last: 2023-06-12

# %%
def update_link_by_new_rank(dates):
    '''
    dates: a list of dates text
    '''
    prefix = 'https://www.atptour.com/en/rankings/singles?rankRange=0-100&rankDate='
    head = 'https://www.atptour.com'

    # open txt
    df = load_txt('m/basics/atpprofilebasics.txt')
    pl = [p for p in df['Player']]

    with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
        links = [line[:-1] for line in f]
    f.close()

    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=100, height=200)

    # date list, MODIFY DATE HERE!!!
    for date in dates:
        driver.get(prefix + date)
        driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        trs = soup.find('table', {'id':'player-rank-detail-ajax'}).find_all('tr')
        for tr in trs[1:]:
            tds = tr.find_all('td')
            if tds[3].text.strip().replace('-', ' ') not in pl:
                # add new link
                links.append(head+tds[3].a.get('href'))
                pl.append(tds[3].text.strip().replace('-', ' '))
                print('Found:', tds[3].text.strip().replace('-', ' '))
        print('Finish:', date)
    f.close()

    # update links
    with open('m/basics/atpprofilelinks.txt', 'w', encoding='utf-8-sig') as f:
        for link in set(links):
            if link != '':
                f.write(link)
                f.write('\n')
    f.close()

# %%
update_link_by_new_rank(["2023-06-12"])
# Out:
# Finish: 2023-06-12

# %% [markdown]
# Remember to update rank file in Flourish

# %% [markdown]
# ## 3. Update ATP Profile Information - Last: 2023-05-29

# %%
# UPDATE new basics based on new links in atprofilelinks

with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
    links = [line[:-1] for line in f]
f.close()

dict = load_txt('m/basics/atpprofilebasics.txt').to_dict('list')

chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)

for i, link in enumerate(links):
    if link not in dict['ATP Link']:
        driver.get(link)
        driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        # add name
        try:
            dict['Player'].append(soup.find('div', {'class': 'first-name'}).text.strip().replace('-', ' ') 
                                  + ' ' + soup.find('div', {'class': 'last-name'}).text.strip().replace('-', ' '))
        except:
            print(link, 'not found')
            break
        # add link
        dict['ATP Link'].append(link)
        # add birthday
        try:
            txt = soup.find('span', {'class': 'table-birthday'}).text.split('.')
            birthday = txt[0][-4:] + '-' + txt[1] + '-' + txt[2][:2]
        except:
            birthday = ''
        dict['Birthday'].append(birthday)
        # add birthplace, plays
        try:
            birthplace_plays = soup.find_all('div', {'class': 'table-value'})
            dict['Birthplace'].append(birthplace_plays[0].text.strip('\n ').replace(',', ' -'))
            dict['Plays'].append(birthplace_plays[1].text.strip().replace(',', ' -'))
        except:
            dict['Birthplace'].append('')
            dict['Plays'].append('')
        # add turned pro
        try:
            dict['Turned Pro'].append(soup.find_all('div', {'class': 'table-big-value'})[1].text.strip())
        except:
            dict['Turned Pro'].append('')
        # add weight, height
        try:
            dict['Weight (kg)'].append(soup.find('span', {'class': 'table-weight-kg-wrapper'}).text.strip('()kg'))
        except:
            dict['Weight (kg)'].append('')
        try:
            dict['Height (cm)'].append(soup.find('span', {'class': 'table-height-cm-wrapper'}).text.strip('()cm'))
        except:
            dict['Height (cm)'].append('')
        print('Finished:', i+1)
        # add birthplace details, matched region, lat, lon
        place = birthplace_plays[0].text.strip('\n ')
        geolocator = Nominatim(user_agent='tennis-vis')
        try:
            location = geolocator.geocode(place)
            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
            dict['Birthplace_lat'].append(location.latitude)
            dict['Birthplace_lon'].append(location.longitude)
            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
        except:
            try:
                location = geolocator.geocode(place.split(',')[0]+','+place.split(',')[1])
                dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                dict['Birthplace_lat'].append(location.latitude)
                dict['Birthplace_lon'].append(location.longitude)
                print(location.address.replace(',', ' -'), location.latitude, location.longitude)
            except:
                try:
                    location = geolocator.geocode(place.split(',')[0])
                    dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                    dict['Birthplace_lat'].append(location.latitude)
                    dict['Birthplace_lon'].append(location.longitude)
                    print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                except:
                    try:
                        location = geolocator.geocode(place.split(',')[1])
                        dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                        dict['Birthplace_lat'].append(location.latitude)
                        dict['Birthplace_lon'].append(location.longitude)
                        print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                    except:
                        try:
                            location = geolocator.geocode(place.split(',')[2])
                            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                            dict['Birthplace_lat'].append(location.latitude)
                            dict['Birthplace_lon'].append(location.longitude)
                            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                        except:
                            dict['Birthplace_matched'].append('')
                            dict['Birthplace_lat'].append('')
                            dict['Birthplace_lon'].append('')
                            print('','','')

df = pd.DataFrame(dict)
df.to_csv('m/basics/atpprofilebasics.txt', index = False, sep = ',', encoding='utf-8-sig')
# Out:
# Finished: 1777
# France 46.603354 1.8883335

# %% [markdown]
# ## 4. Update ATP TOP 100 Distribution - Last: 2023-06-12

# %%
def update_geo_atp100(date,num):
    # get basics
    df_basics = load_txt('m/basics/atpprofilebasics.txt')

    # set basic dict
    attrs = ['Start', 'End', 'Player', 'Rank', 'Points', 'Birthplace', 'Lat', 'Lon']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # get dates
    dates = []
    with open('m/rank/dates.txt', 'r') as f:
        for date in f:
            dates.append(date[:-1])
    f.close()

    # MODIFY HOW MANY DATES TO CONSIDER FROM 2000-01-10, E.G., 2023-02-20 (num=1117)
    for k, date in enumerate([dates[num - i - 1] for i in range(num)]):
        df_rank = load_txt('m/rank/dates/'+date+'.txt')
        for i, p in enumerate(df_rank['Player']):
            for j, r in enumerate(df_basics['Player']):
                if p.replace('-', ' ') == r and k != (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append(dates[num - k - 2])
                    except:
                        pass
                    break
                if p.replace('-', ' ') == r and k == (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append('')
                    except:
                        pass
                    break

        print('Finished:', date)

    df = pd.DataFrame(dict)

    # MODIFY FILE NAME!!!!
    df.to_csv('m/rank/atp100geo20000110_'+date.replace("-","")+'.txt', index = False, sep = ',', encoding = 'utf-8-sig')

# %%
# 2023-06-12 (num=1128)
update_geo_atp100("2023-06-12",1128)
# Out:
# Finished: 2000-01-10
# Finished: 2000-01-17
# Finished: 2000-01-24
# Finished: 2000-01-31
# Finished: 2000-02-07
# Finished: 2000-02-14
# Finished: 2000-02-21
# Finished: 2000-02-28
# Finished: 2000-03-06
# Finished: 2000-03-13
# Finished: 2000-03-20
# Finished: 2000-03-27
# Finished: 2000-04-03
# Finished: 2000-04-10
# Finished: 2000-04-17
# Finished: 2000-04-24
# Finished: 2000-05-01
# Finished: 2000-05-08
# Finished: 2000-05-15
# Finished: 2000-05-22
# Finished: 2000-05-29
# Finished: 2000-06-05
# Finished: 2000-06-12
# Finished: 2000-06-19
# Finished: 2000-06-26
# Finished: 2000-07-03
# Finished: 2000-07-10
# Finished: 2000-07-17
# Finished: 2000-07-24
# Finished: 2000-07-31
# Finished: 2000-08-07
# Finished: 2000-08-14
# Finished: 2000-08-21
# Finished: 2000-08-28
# Finished: 2000-09-04
# Finished: 2000-09-11
# Finished: 2000-09-18
# Finished: 2000-09-25
# Finished: 2000-10-02
# Finished: 2000-10-09
# Finished: 2000-10-16
# Finished: 2000-10-23
# Finished: 2000-10-30
# Finished: 2000-11-06
# Finished: 2000-11-13
# Finished: 2000-11-20
# Finished: 2000-11-27
# Finished: 2000-12-04
# Finished: 2000-12-11
# Finished: 2000-12-18
# Finished: 2000-12-25
# Finished: 2001-01-01
# Finished: 2001-01-08
# Finished: 2001-01-15
# Finished: 2001-01-22
# Finished: 2001-01-29
# Finished: 2001-02-05
# Finished: 2001-02-12
# Finished: 2001-02-19
# Finished: 2001-02-26
# Finished: 2001-03-05
# Finished: 2001-03-12
# Finished: 2001-03-19
# Finished: 2001-03-26
# Finished: 2001-04-02
# Finished: 2001-04-09
# Finished: 2001-04-16
# Finished: 2001-04-23
# Finished: 2001-04-30
# Finished: 2001-05-07
# Finished: 2001-05-14
# Finished: 2001-05-21
# Finished: 2001-05-28
# Finished: 2001-06-04
# Finished: 2001-06-11
# Finished: 2001-06-18
# Finished: 2001-06-25
# Finished: 2001-07-02
# Finished: 2001-07-09
# Finished: 2001-07-16
# Finished: 2001-07-23
# Finished: 2001-07-30
# Finished: 2001-08-06
# Finished: 2001-08-13
# Finished: 2001-08-20
# Finished: 2001-08-27
txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    else:
        with open('mwplayerlist_processed.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    return names

# define a function to scrape for a single man player's matches
def scrape_matches(name, driver):
    try:
        # set attributes
        attributes_m = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'TP', 'Aces', 'DFs', 'SP', 
                        '1SP', '2SP', 'vA', 'Time']

        attributes_w = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'Time']

        # get cleaned name
        sex = name[1]
        name_cleaned = name[4:].replace(' ', '')

        # set url prefix and types of webpages
        if sex == 'M':
            url = "https://www.tennisabstract.com/cgi-bin/player-classic.cgi?p=" 
        #   types = ["&f=ACareerqq", "&f=ACareerqqr1", "&f=ACareerqqw1"]
        else:
            url = "https://www.tennisabstract.com/cgi-bin/wplayer-classic.cgi?p="

        # Start of Scraping
        print('Start Scraping:', name[4:])
        
        # man and woman pages are different
        if sex == 'M':

            # for man players
            # set dictionary
            dic = {}
            for attr in attributes_m:
                dic[attr] = []

            # for serve page
            driver.get(url + name_cleaned.replace(' ', '') + "&f=ACareerqq")
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
        #   driver.quit()

            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # for return page
                show_return = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Return"]')))
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[1])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # for raw page
                show_raw = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Raw"]')))
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[2])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

            else:

                # serve page
                driver.get(url + name_cleaned.replace(' ', ''))
                driver.refresh()
                # show career
                try:
                    show_career = driver.find_element(By.ID, 'careerclick')
                except:
                    return None
                show_career.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # return page
                show_return = driver.find_element(By.XPATH, '//span[text()="Return"]')
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # raw page
                show_raw = driver.find_element(By.XPATH, '//span[text()="Raw"]')
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
              # driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

        else:

            # for woman players
            # set dictionary
            dic = {}
            for attr in attributes_w:
                dic[attr] = []

            # for serve page
            driver.get(url + name_cleaned.replace(' ', '') + '&f=ACareerqq')
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')

            for match in matches[2:]:
                tds = match.find_all('td')
                # first check if it is ongoing match
                spans = tds[6].find_all('span')
                if spans[3].text != 'vs':
                    # date, contain special character
                    date = tds[0].text.split('‑')
                    dic[attributes_w[0]].append('-'.join(date))
                    # tournament
                    dic[attributes_w[1]].append(tds[1].text)
                    # sets
                    dic[attributes_w[2]].append(3)
                    # surface
                    dic[attributes_w[3]].append(tds[2].text)
                    # round
                    dic[attributes_w[4]].append(tds[3].text)
                    # rank
                    dic[attributes_w[5]].append(tds[4].text)
                    # opponent rank
                    dic[attributes_w[6]].append(tds[5].text)
                    # win?, tournament rank, opponent tournament rank, winner, loser
                    if spans[1].text in name:
                        # win?
                        dic[attributes_w[7]].append(1)
                        # winner
                        dic[attributes_w[10]].append(name[4:])
                        # loser
                        dic[attributes_w[11]].append(spans[6].text)
                        # tRk
                        if spans[0].text != '':
                            dic[attributes_w[8]].append(spans[0].text[1:-1])
                        else:
                            dic[attributes_w[8]].append('')
                        # vtRk
                        if spans[5].text != '':
                            dic[attributes_w[9]].append(spans[5].text[1:-1])
                        else:
                            dic[attributes_w[9]].append('')
                    else:
                        # win?
                        dic[attributes_w[7]].append(0)
                        # winner
                        dic[attributes_w[10]].append(spans[1].text)
                        # loser
                        dic[attributes_w[11]].append(name[4:])
                        # tRk
                        if spans[6].text != '':
                            dic[attributes_w[8]].append(spans[6].text[1:-1])
                        else:
                            dic[attributes_w[8]].append('')
                        # vtRk
                        if spans[0].text != '':
                            dic[attributes_w[9]].append(spans[0].text[1:-1])
                        else:
                            dic[attributes_w[9]].append('')
                    # score
                    dic[attributes_w[12]].append(tds[7].text)
                    # DR
                    dic[attributes_w[13]].append(tds[8].text)
                    # A%
                    dic[attributes_w[14]].append(tds[9].text)
                    # DF%
                    dic[attributes_w[15]].append(tds[10].text)
                    # 1stIn
                    dic[attributes_w[16]].append(tds[11].text)
                    # 1st%
                    dic[attributes_w[17]].append(tds[12].text)
                    # 2rd%
                    dic[attributes_w[18]].append(tds[13].text)
                    # BPSvd
                    dic[attributes_w[19]].append(tds[14].text)

            print('Serve Page:', len(dic['Date']))

            # for return page
            page_return = driver.find_element(By.XPATH, '//span[text()="Show Return Stats"]')
            page_return.click()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
        #   driver.quit()

            for match in matches[2:]:
                tds = match.find_all('td')
                # first check if it is ongoing match
                spans = tds[6].find_all('span')
                if spans[3].text != 'vs':
                    # TPW
                    dic[attributes_w[20]].append(tds[9].text)
                    # RPW
                    dic[attributes_w[21]].append(tds[10].text)
                    # vA%
                    dic[attributes_w[22]].append(tds[11].text)
                    # v1st%
                    dic[attributes_w[23]].append(tds[12].text)
                    # v2rd%
                    dic[attributes_w[24]].append(tds[13].text)
                    # BPCvt
                    dic[attributes_w[25]].append(tds[14].text)
                    # Time
                    dic[attributes_w[26]].append(tds[15].text)

            print('Return Page:', len(dic['TPW']))

        # save to text, separated by gender
        df = pd.DataFrame(dic)
        df.to_csv(sex.lower() + '/matches/txt/' + name[4:] + '.txt', index = False, sep = ',', encoding='utf-8-sig')

    except (IndexError, AttributeError) as e:
        pass
    
# define a loop function to scrape players from a given index
def scrape_from(idx, sex, driver):
    names = get_names(sex)
    for i in range(idx, len(names)):
        scrape_matches(names[i], driver)
        print('Finish Scraping', i + 1, 'players.')
        print(len(names) - (i + 1), 'players remaining.')
        print('\n')
        
# load txt files
def load_txt(name):
    with open(name[1].lower() + '/matches/txt/' + name[4:] + '.txt', 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    return df

# %%
# UPDATE MATCHES DATA!!!
# set up chromdriver
chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)
scrape_from(23869, 'm', driver)
# Out:
# Start Scraping: Marco Jaeger
# Finish Scraping 23870 players.
# 2718 players remaining.
#
#
# Start Scraping: Tobias Schade
# Finish Scraping 23871 players.
# 2717 players remaining.
#
#
# Start Scraping: Luis Carlos Albuquerque Cabrejo
# Finish Scraping 23872 players.
# 2716 players remaining.
#
#
# Start Scraping: Juan Jose Torres Zea
# Finish Scraping 23873 players.
# 2715 players remaining.
#
#
# Start Scraping: Mateus Camasmie
# Finish Scraping 23874 players.
# 2714 players remaining.
#
#
# Start Scraping: Sebastian Yllera
# Finish Scraping 23875 players.
# 2713 players remaining.
#
#
# Start Scraping: Ibian Hodgson
# Finish Scraping 23876 players.
# 2712 players remaining.
#
#
# Start Scraping: Fernando Benitez
# Finish Scraping 23877 players.
# 2711 players remaining.
#
#
# Start Scraping: Sergei Avdeyev
# Finish Scraping 23878 players.
# 2710 players remaining.
#
#
# Start Scraping: Zach Nichols
# Finish Scraping 23879 players.
# 2709 players remaining.
#
#
# Start Scraping: Benjamin Tapia
# Finish Scraping 23880 players.
# 2708 players remaining.
#
#
# Start Scraping: Cesar Salazar
# Finish Scraping 23881 players.
# 2707 players remaining.
#
#
# Start Scraping: Eduardo Torres
# Finish Scraping 23882 players.
# 2706 players remaining.
#
#
# Start Scraping: Guillermo Catalina
# Finish Scraping 23883 players.
# 2705 players remaining.
#
#
# Start Scraping: Richard Doverspike
# Finish Scraping 23884 players.
# 2704 players remaining.
#
#
# Start Scraping: Ahmadjon Muhammad
# Finish Scraping 23885 players.
# 2703 players remaining.
#
#
# Start Scraping: Timur Isaev
# Finish Scraping 23886 players.
# 2702 players remaining.
#
#
# Start Scraping: Tomas Willis
# Finish Scraping 23887 players.
# 2701 players remaining.
#
#
# Start Scraping: Sandro Salvi
# Finish Scraping 23888 players.
# 2700 players remaining.
#
#
# Start Scraping: Juan Carlos De Pedro
# Finish Scraping 23889 players.
# 2699 players remaining.
#
#
# Start Scraping: Ebrahim Khazaee
# Finish Scraping 23890 players.
# 2698 players remaining.
#
#
# Start Scraping: Michel Monteiro
# Finish Scraping 23891 players.
# 2697 players remaining.
#
#
# Start Scraping: Edwin Yahya Tear Tjahjana
# Finish Scraping 23892 players.
# 2696 players remaining.
#
#
# Start Scraping: David Wardhana
# Finish Scraping 23893 players.
# 2695 players remaining.
#
#
# Start Scraping: Ibrahim Unggullaga
# Finish Scraping 23894 players.
# 2694 players remaining.
#
#
# Start Scraping: Dimitar Ristovski
# Finish Scraping 23895 players.
# 2693 players remaining.
#
#
# Start Scraping: Stefan Trifonov
# Finish Scraping 23896 players.
# 2692 players remaining.
#
#
# Start Scraping: Valentim Goncalves Junior
# Finish Scraping 23897 players.
# 2691 players remaining.
#
#
# Start Scraping: Ramon Simonetti
# Finish Scraping 23898 players.
# 2690 players remaining.
#
#
# Start Scraping: Ziyu Zhang
# Finish Scraping 23899 players.
# 2689 players remaining.
#
#
# Start Scraping: Junjie Wei
# Finish Scraping 23900 players.
# 2688 players remaining.
#
#
# Start Scraping: Jia Li
# Finish Scraping 23901 players.
# 2687 players remaining.
#
#
# Start Scraping: Robert Dubuque
# Finish Scraping 23902 players.
# 2686 players remaining.
#
#
# Start Scraping: Maximillian Littlejohn
# Finish Scraping 23903 players.
# 2685 players remaining.
#
#
# Start Scraping: Devin Nerenberg
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 23904 players.
# 2684 players remaining.
#
#
# Start Scraping: Gregory Scott
# Finish Scraping 23905 players.
# 2683 players remaining.
#
#
# Start Scraping: Georgy Tchoukhleb
# Finish Scraping 23906 players.
# 2682 players remaining.
#
#
# Start Scraping: Javier Mizzi Rama
# Finish Scraping 23907 players.
# 2681 players remaining.
#
#
# Start Scraping: Taras Motsny
# Finish Scraping 23908 players.
# 2680 players remaining.
#
#
# Start Scraping: Inigo Landaluce
# Finish Scraping 23909 players.
# 2679 players remaining.
#
#
# Start Scraping: Teodor Valentin Anghel
# Finish Scraping 23910 players.
# 2678 players remaining.
#
#
# Start Scraping: Tetsuro Yamagishi
# Finish Scraping 23911 players.
# 2677 players remaining.
#
#
# Start Scraping: Daisuke Suzuki
# Finish Scraping 23912 players.
# 2676 players remaining.
#
#
# Start Scraping: Paolo Volpicelli
# Finish Scraping 23913 players.
# 2675 players remaining.
#
#
# Start Scraping: Valerio Russo
# Finish Scraping 23914 players.
# 2674 players remaining.
#
#
# Start Scraping: Prateek Kumar
# Finish Scraping 23915 players.
# 2673 players remaining.
#
#
# Start Scraping: Rohit Bisht
# Finish Scraping 23916 players.
# 2672 players remaining.
#
#
# Start Scraping: Alex Golding
# Finish Scraping 23917 players.
# 2671 players remaining.
#
#
# Start Scraping: Hendrik Bertrams
# Finish Scraping 23918 players.
# 2670 players remaining.
#
#
# Start Scraping: Dennis Lengsfeld
# Finish Scraping 23919 players.
# 2669 players remaining.
#
#
# Start Scraping: Tim Kueckelhaus
# Finish Scraping 23920 players.
# 2668 players remaining.
#
#
# Start Scraping: Benjamin Marty
# Finish Scraping 23921 players.
# 2667 players remaining.
#
#
# Start Scraping: Marten Lai
# Finish Scraping 23922 players.
# 2666 players remaining.
#
#
# Start Scraping: Timmy Williams
# Finish Scraping 23923 players.
# 2665 players remaining.
#
#
# Start Scraping: Jun Takanashi
# Finish Scraping 23924 players.
# 2664 players remaining.
#
#
# Start Scraping: Denis Porcic
# Finish Scraping 23925 players.
# 2663 players remaining.
#
#
# Start Scraping: Wkwesi Williams
# Finish Scraping 23926 players.
# 2662 players remaining.
#
#
# Start Scraping: Mateus Brisot Silva
# Finish Scraping 23927 players.
# 2661 players remaining.
#
#
# Start Scraping: Hector Yamil Serur De La Torre
# Finish Scraping 23928 players.
# 2660 players remaining.
#
#
# Start Scraping: Isaac Saldana Reyes
# Finish Scraping 23929 players.
# 2659 players remaining.
#
#
# Start Scraping: Christiaan Botha
# Finish Scraping 23930 players.
# 2658 players remaining.
#
#
# Start Scraping: Christopher Walker
# Finish Scraping 23931 players.
# 2657 players remaining.
#
#
# Start Scraping: Jarryd Sauer
# Finish Scraping 23932 players.
# 2656 players remaining.
#
#
# Start Scraping: Christiaan Van Der Burgh
# Finish Scraping 23933 players.
# 2655 players remaining.
#
#
# Start Scraping: Musawenkosi Sandile Mpondi
# Finish Scraping 23934 players.
# 2654 players remaining.
#
#
# Start Scraping: Ju Shan Sun
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 23935 players.
# 2653 players remaining.
#
#
# Start Scraping: Serban Stefan Rotariu
# Finish Scraping 23936 players.
# 2652 players remaining.
#
#
# Start Scraping: Sebastian Erimicioiu
# Finish Scraping 23937 players.
# 2651 players remaining.
#
#
# Start Scraping: Tomas Prokop
# Finish Scraping 23938 players.
# 2650 players remaining.
#
#
# Start Scraping: Akmal Isakov
# Finish Scraping 23939 players.
# 2649 players remaining.
#
#
# Start Scraping: Amal Yuldashev
# Finish Scraping 23940 players.
# 2648 players remaining.
#
#
# Start Scraping: Jin Tae Kim
# Finish Scraping 23941 players.
# 2647 players remaining.
#
#
# Start Scraping: Ram Tepper
# Finish Scraping 23942 players.
# 2646 players remaining.
#
#
# Start Scraping: Emre Ozlen
# Finish Scraping 23943 players.
# 2645 players remaining.
#
#
# Start Scraping: Amine Mansour
# Finish Scraping 23944 players.
# 2644 players remaining.
#
#
# Start Scraping: Johan Ljungdahl
# Finish Scraping 23945 players.
# 2643 players remaining.
#
#
# Start Scraping: Baris Sipal
# Finish Scraping 23946 players.
# 2642 players remaining.
#
#
# Start Scraping: Gokhan Sahiner
# Finish Scraping 23947 players.
# 2641 players remaining.
#
#
# Start Scraping: Juan Obeid
# Finish Scraping 23948 players.
# 2640 players remaining.
#
#
# Start Scraping: Eugenio Romero
# Finish Scraping 23949 players.
# 2639 players remaining.
#
#
# Start Scraping: Ajay Yadav
# Finish Scraping 23950 players.
# 2638 players remaining.
#
#
# Start Scraping: Antonio Vega Cayuela
# Finish Scraping 23951 players.
# 2637 players remaining.
#
#
# Start Scraping: Alexey Eliseev
# Finish Scraping 23952 players.
# 2636 players remaining.
#
#
# Start Scraping: Kirill Lazutin
# Finish Scraping 23953 players.
# 2635 players remaining.
#
#
# Start Scraping: Ryouhei Takahasi
# Finish Scraping 23954 players.
# 2634 players remaining.
#
#
# Start Scraping: Filippo Sacco
# Finish Scraping 23955 players.
# 2633 players remaining.
#
#
# Start Scraping: Arvind Singh
# Finish Scraping 23956 players.
# 2632 players remaining.
#
#
# Start Scraping: Raul Mendez
# Finish Scraping 23957 players.
# 2631 players remaining.
#
#
# Start Scraping: Israel Morales Hernandez
# Finish Scraping 23958 players.
# 2630 players remaining.
#
#
# Start Scraping: Lucas Okita
# Finish Scraping 23959 players.
# 2629 players remaining.
#
#
# Start Scraping: Eric Fleming
# Finish Scraping 23960 players.
# 2628 players remaining.
#
#
# Start Scraping: Francisco Mendieta
# Finish Scraping 23961 players.
# 2627 players remaining.
#
#
# Start Scraping: Eduardo Cabrera
# Finish Scraping 23962 players.
# 2626 players remaining.
#
#
# Start Scraping: Justin Robinson
# Finish Scraping 23963 players.
# 2625 players remaining.
#
#
# Start Scraping: Ivan Luka Sablic
# Finish Scraping 23964 players.
# 2624 players remaining.
#
#
# Start Scraping: Cristian Batlle Rodriguez
# Finish Scraping 23965 players.
# 2623 players remaining.
#
#
# Start Scraping: Ignacio Huertas Barrantes
# Finish Scraping 23966 players.
# 2622 players remaining.
#
#
# Start Scraping: Arthur Pain
# Finish Scraping 23967 players.
# 2621 players remaining.
#
#
# Start Scraping: Joao Batista De Pontes
# Finish Scraping 23968 players.
# 2620 players remaining.
#
#
# Start Scraping: Francesc Manresa Canabate
# Finish Scraping 23969 players.
# 2619 players remaining.
#
#
# Start Scraping: Nelson Luis Barbosa Dos Santos
# Finish Scraping 23970 players.
# 2618 players remaining.
#
#
# Start Scraping: Yasier Estrada
# Finish Scraping 23971 players.
# 2617 players remaining.
#
#
# Start Scraping: Pavel Liska
# Finish Scraping 23972 players.
# 2616 players remaining.
#
#
# Start Scraping: Daniel De La Cruz
# Finish Scraping 23973 players.
# 2615 players remaining.
#
#
# Start Scraping: Jose Miguel Marquez Perez
# Finish Scraping 23974 players.
# 2614 players remaining.
#
#
# Start Scraping: Jorge Limonta Maceo
# Finish Scraping 23975 players.
# 2613 players remaining.
#
#
# Start Scraping: Abdullah Giha
# Finish Scraping 23976 players.
# 2612 players remaining.
#
#
# Start Scraping: Mohamed Noraldeen
# Finish Scraping 23977 players.
# 2611 players remaining.
#
#
# Start Scraping: Brendan Zackey
# Finish Scraping 23978 players.
# 2610 players remaining.
#
#
# Start Scraping: Antonio Reynoso
# Finish Scraping 23979 players.
# 2609 players remaining.
#
#
# Start Scraping: Ricardo Groenewold
# Finish Scraping 23980 players.
# 2608 players remaining.
#
#
# Start Scraping: Martin Augusto Miranda
# Finish Scraping 23981 players.
# 2607 players remaining.
#
#
# Start Scraping: Carlos Lopez Villa
# Finish Scraping 23982 players.
# 2606 players remaining.
#
#
# Start Scraping: Gilles De Gouy
# Finish Scraping 23983 players.
# 2605 players remaining.
#
#
# Start Scraping: Warwick Foy
# Finish Scraping 23984 players.
# 2604 players remaining.
#
#
# Start Scraping: Stefan Williams
# Finish Scraping 23985 players.
# 2603 players remaining.
#
#
# Start Scraping: Javier Anegon
# Finish Scraping 23986 players.
# 2602 players remaining.
#
#
# Start Scraping: Daniel Fossi
# Finish Scraping 23987 players.
# 2601 players remaining.
#
#
# Start Scraping: Vitaya Lasavady
# Finish Scraping 23988 players.
# 2600 players remaining.
#
#
# Start Scraping: Alejandro Ariel Saulo
# Finish Scraping 23989 players.
# 2599 players remaining.
#
#
# Start Scraping: Luis Carlos Pujol
# Finish Scraping 23990 players.
# 2598 players remaining.
#
#
# Start Scraping: Juan Ignacio Huber
# Finish Scraping 23991 players.
# 2597 players remaining.
#
#
# Start Scraping: Jose Carlos Tolentino
# Finish Scraping 23992 players.
# 2596 players remaining.
#
#
# Start Scraping: Kaan Senolsun
# Finish Scraping 23993 players.
# 2595 players remaining.
#
#
# Start Scraping: Robert A Allan
# Finish Scraping 23994 players.
# 2594 players remaining.
#
#
# Start Scraping: Bastian Parada
# Finish Scraping 23995 players.
# 2593 players remaining.
#
#
# Start Scraping: Rodrigo Encinas
# Finish Scraping 23996 players.
# 2592 players remaining.
#
#
# Start Scraping: Jacobo Gonzalez Tarrio
# Finish Scraping 23997 players.
# 2591 players remaining.
#
#
# Start Scraping: Eamon Soulsby
# Finish Scraping 23998 players.
# 2590 players remaining.
#
#
# Start Scraping: Fabio Assuncao
# Finish Scraping 23999 players.
# 2589 players remaining.
#
#
# Start Scraping: Nobuaki Tadaki
# Finish Scraping 24000 players.
# 2588 players remaining.
#
#
# Start Scraping: Ekanem Etin
# Finish Scraping 24001 players.
# 2587 players remaining.
#
#
# Start Scraping: Marc Houngbo
# Finish Scraping 24002 players.
# 2586 players remaining.
#
#
# Start Scraping: Ramazan Yernaruly
# Finish Scraping 24003 players.
# 2585 players remaining.
#
#
# Start Scraping: Pedro Dalfre
# Finish Scraping 24004 players.
# 2584 players remaining.
#
#
# Start Scraping: Rafael Ferreira
# Finish Scraping 24005 players.
# 2583 players remaining.
#
#
# Start Scraping: Nicolas Beaune
# Finish Scraping 24006 players.
# 2582 players remaining.
#
#
# Start Scraping: Mohammad Al Shatti
# Finish Scraping 24007 players.
# 2581 players remaining.
#
#
# Start Scraping: Mansour Bohamad
# Finish Scraping 24008 players.
# 2580 players remaining.
#
#
# Start Scraping: Ahmed Al Barwani
# Finish Scraping 24009 players.
# 2579 players remaining.
#
#
# Start Scraping: Abdullah Bouhamad
# Finish Scraping 24010 players.
# 2578 players remaining.
#
#
# Start Scraping: Spartak Rahachou
# Finish Scraping 24011 players.
# 2577 players remaining.
#
#
# Start Scraping: Kaue Pereira
# Finish Scraping 24012 players.
# 2576 players remaining.
#
#
# Start Scraping: Antonio Lastre
# Finish Scraping 24013 players.
# 2575 players remaining.
#
#
# Start Scraping: Axel Lagerlof
# Finish Scraping 24014 players.
# 2574 players remaining.
#
#
# Start Scraping: Wu De Liu
# Finish Scraping 24015 players.
# 2573 players remaining.
#
#
# Start Scraping: Henry Muyanja
# Finish Scraping 24016 players.
# 2572 players remaining.
#
#
# Start Scraping: Nami Malek
# Finish Scraping 24017 players.
# 2571 players remaining.
#
#
# Start Scraping: Rod Mehrtash
# Finish Scraping 24018 players.
# 2570 players remaining.
#
#
# Start Scraping: Luis Morett
# Finish Scraping 24019 players.
# 2569 players remaining.
#
#
# Start Scraping: Andrew Eklov
# Finish Scraping 24020 players.
# 2568 players remaining.
#
#
# Start Scraping: Jesus Alberto Reyes
# Finish Scraping 24021 players.
# 2567 players remaining.
#
#
# Start Scraping: Jorge Lora Prado
# Finish Scraping 24022 players.
# 2566 players remaining.
#
#
# Start Scraping: Alejandro Molina Lamelas
# Finish Scraping 24023 players.
# 2565 players remaining.
#
#
# Start Scraping: Walter Garcia
# Finish Scraping 24024 players.
# 2564 players remaining.
#
#
# Start Scraping: Mohamed Said Chaki
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 24025 players.
# 2563 players remaining.
#
#
# Start Scraping: Filippo Ghio
# Finish Scraping 24026 players.
# 2562 players remaining.
#
#
# Start Scraping: Mehdi Bourassi
# Finish Scraping 24027 players.
# 2561 players remaining.
#
#
# Start Scraping: Mattla Campus
# Finish Scraping 24028 players.
# 2560 players remaining.
#
#
# Start Scraping: Agris Kolomicevs
# Finish Scraping 24029 players.
# 2559 players remaining.
#
#
# Start Scraping: Leonardo Gasparini
# Finish Scraping 24030 players.
# 2558 players remaining.
#
#
# Start Scraping: Theodore Voegt
# Finish Scraping 24031 players.
# 2557 players remaining.
#
#
# Start Scraping: Ignacio Gonzalez Muniz
# Finish Scraping 24032 players.
# 2556 players remaining.
#
#
# Start Scraping: Eldar Sebastian Rosianu
# Finish Scraping 24033 players.
# 2555 players remaining.
#
#
# Start Scraping: Nikola Telkedzhiev
# Finish Scraping 24034 players.
# 2554 players remaining.
#
#
# Start Scraping: Michael Hole
# Finish Scraping 24035 players.
# 2553 players remaining.
#
#
# Start Scraping: Ksystof Gulbinovic
# Finish Scraping 24036 players.
# 2552 players remaining.
#
#
# Start Scraping: Jaroslaw Bienkowski
# Finish Scraping 24037 players.
# 2551 players remaining.
#
#
# Start Scraping: Mathias Oliver Rast
# Finish Scraping 24038 players.
# 2550 players remaining.
#
#
# Start Scraping: Andro Zunic
# Finish Scraping 24039 players.
# 2549 players remaining.
#
#
# Start Scraping: Michael Ess
# Finish Scraping 24040 players.
# 2548 players remaining.
#
#
# Start Scraping: Marcus Vinicius Marques Correa Meyer
# Finish Scraping 24041 players.
# 2547 players remaining.
#
#
# Start Scraping: Julio Benegas
# Finish Scraping 24042 players.
# 2546 players remaining.
#
#
# Start Scraping: Djordje Jocic
# Finish Scraping 24043 players.
# 2545 players remaining.
#
#
# Start Scraping: Danylo Psarov
# Finish Scraping 24044 players.
# 2544 players remaining.
#
#
# Start Scraping: David Virabian
# Finish Scraping 24045 players.
# 2543 players remaining.
#
#
# Start Scraping: Evgeny Khomenko
# Finish Scraping 24046 players.
# 2542 players remaining.
#
#
# Start Scraping: Fabian Nickel
# Finish Scraping 24047 players.
# 2541 players remaining.
#
#
# Start Scraping: Mario Barros
# Finish Scraping 24048 players.
# 2540 players remaining.
#
#
# Start Scraping: Drew Courtney
# Finish Scraping 24049 players.
# 2539 players remaining.
#
#
# Start Scraping: Daniel Vladut Caravan
# Finish Scraping 24050 players.
# 2538 players remaining.
#
#
# Start Scraping: Giacomo Tartarini
# Finish Scraping 24051 players.
# 2537 players remaining.
#
#
# Start Scraping: Laureano Agullo Juan
# Finish Scraping 24052 players.
# 2536 players remaining.
#
#
# Start Scraping: Constantin Lefter
# Finish Scraping 24053 players.
# 2535 players remaining.
#
#
# Start Scraping: Daniel Leitner
# Finish Scraping 24054 players.
# 2534 players remaining.
#
#
# Start Scraping: Markel Lorono Bilbao
# Finish Scraping 24055 players.
# 2533 players remaining.
#
#
# Start Scraping: Sebastian Curtis
# Finish Scraping 24056 players.
# 2532 players remaining.
#
#
# Start Scraping: Sami Dagou
# Finish Scraping 24057 players.
# 2531 players remaining.
#
#
# Start Scraping: Fernando Agustin Ordonez
# Finish Scraping 24058 players.
# 2530 players remaining.
#
#
# Start Scraping: Yi Chen Li
# Finish Scraping 24059 players.
# 2529 players remaining.
#
#
# Start Scraping: August Iwdal
# Finish Scraping 24060 players.
# 2528 players remaining.
#
#
# Start Scraping: Marc Leimbach
# Finish Scraping 24061 players.
# 2527 players remaining.
#
#
# Start Scraping: Danny Kubasik
# Finish Scraping 24062 players.
# 2526 players remaining.
#
#
# Start Scraping: Roger Muri
# Finish Scraping 24063 players.
# 2525 players remaining.
#
#
# Start Scraping: Antonio Garcia Gonzalez
# Finish Scraping 24064 players.
# 2524 players remaining.
#
#
# Start Scraping: Gael Courbard
# Finish Scraping 24065 players.
# 2523 players remaining.
#
#
# Start Scraping: Nicholas K Lopez
# Finish Scraping 24066 players.
# 2522 players remaining.
#
#
# Start Scraping: Vicente Costagliola
# Finish Scraping 24067 players.
# 2521 players remaining.
#
#
# Start Scraping: Gijs Linders
# Finish Scraping 24068 players.
# 2520 players remaining.
#
#
# Start Scraping: Maurice Van Alem
# Finish Scraping 24069 players.
# 2519 players remaining.
#
#
# Start Scraping: Ji Hoon Heo
# Finish Scraping 24070 players.
# 2518 players remaining.
#
#
# Start Scraping: Franklin Sherrill
# Finish Scraping 24071 players.
# 2517 players remaining.
#
#
# Start Scraping: Samuel Holland Smith
# Finish Scraping 24072 players.
# 2516 players remaining.
#
#
# Start Scraping: Justin Dugan
# Finish Scraping 24073 players.
# 2515 players remaining.
#
#
# Start Scraping: Jakub Kowalski
# Finish Scraping 24074 players.
# 2514 players remaining.
#
#
# Start Scraping: Jacopo Locatelli
# Finish Scraping 24075 players.
# 2513 players remaining.
#
#
# Start Scraping: Jurgen De Jager
# Finish Scraping 24076 players.
# 2512 players remaining.
#
#
# Start Scraping: Maik Ulrich
# Finish Scraping 24077 players.
# 2511 players remaining.
#
#
# Start Scraping: Gabriel Barbosa
# Finish Scraping 24078 players.
# 2510 players remaining.
#
#
# Start Scraping: Sai Kartik Nakireddi
# Finish Scraping 24079 players.
# 2509 players remaining.
#
#
# Start Scraping: Blake Davis
# Finish Scraping 24080 players.
# 2508 players remaining.
#
#
# Start Scraping: Luca Fondi
# Finish Scraping 24081 players.
# 2507 players remaining.
#
#
# Start Scraping: Stephen Gort
# Finish Scraping 24082 players.
# 2506 players remaining.
#
#
# Start Scraping: Jeong Woo Choi
# Finish Scraping 24083 players.
# 2505 players remaining.
#
#
# Start Scraping: Jae Young Han
# Finish Scraping 24084 players.
# 2504 players remaining.
#
#
# Start Scraping: Yasuteru Ishii
# Finish Scraping 24085 players.
# 2503 players remaining.
#
#
# Start Scraping: Marcos Ignacio Taccone
# Finish Scraping 24086 players.
# 2502 players remaining.
#
#
# Start Scraping: Francisco Huber
# Finish Scraping 24087 players.
# 2501 players remaining.
#
#
# Start Scraping: Abhishek Sv
# Finish Scraping 24088 players.
# 2500 players remaining.
#
#
# Start Scraping: Mandeep Singh Gill
# Finish Scraping 24089 players.
# 2499 players remaining.
#
#
# Start Scraping: Fengming Wan
# Finish Scraping 24090 players.
# 2498 players remaining.
#
#
# Start Scraping: Max Hertl
# Finish Scraping 24091 players.
# 2497 players remaining.
#
#
# Start Scraping: Jose Moncada
# Finish Scraping 24092 players.
# 2496 players remaining.
#
#
# Start Scraping: David Gaissert
# Finish Scraping 24093 players.
# 2495 players remaining.
#
#
# Start Scraping: Jose Carranza Jones
# Finish Scraping 24094 players.
# 2494 players remaining.
#
#
# Start Scraping: Askold Kuznetsov
# Finish Scraping 24095 players.
# 2493 players remaining.
#
#
# Start Scraping: Vincenzo Ciccone
# Finish Scraping 24096 players.
# 2492 players remaining.
#
#
# Start Scraping: Martin Muadi
# Finish Scraping 24097 players.
# 2491 players remaining.
#
#
# Start Scraping: Javier Waase
# Finish Scraping 24098 players.
# 2490 players remaining.
#
#
# Start Scraping: Nathan Carvalho
# Finish Scraping 24099 players.
# 2489 players remaining.
#
#
# Start Scraping: Alexandros Baier
# Finish Scraping 24100 players.
# 2488 players remaining.
#
#
# Start Scraping: Ignacio Hernandez
# Finish Scraping 24101 players.
# 2487 players remaining.
#
#
# Start Scraping: Pablo Mora
# Finish Scraping 24102 players.
# 2486 players remaining.
#
#
# Start Scraping: Fabian Balmaceda
# Finish Scraping 24103 players.
# 2485 players remaining.
#
#
# Start Scraping: Gerry De Campos
# Finish Scraping 24104 players.
# 2484 players remaining.
#
#
# Start Scraping: Jan Van Kwikkelberghe
# Finish Scraping 24105 players.
# 2483 players remaining.
#
#
# Start Scraping: Rafael Reyes Salmeron
# Finish Scraping 24106 players.
# 2482 players remaining.
#
#
# Start Scraping: Andres Devletian
# Finish Scraping 24107 players.
# 2481 players remaining.
#
#
# Start Scraping: Aaron May
# Finish Scraping 24108 players.
# 2480 players remaining.
#
#
# Start Scraping: Trenton Hagan
# Finish Scraping 24109 players.
# 2479 players remaining.
#
#
# Start Scraping: Nutthavit Likitkumchorn
# Finish Scraping 24110 players.
# 2478 players remaining.
#
#
# Start Scraping: Ehsan Nourzade
# Finish Scraping 24111 players.
# 2477 players remaining.
#
#
# Start Scraping: Yasuhito Kudo
# Finish Scraping 24112 players.
# 2476 players remaining.
#
#
# Start Scraping: Masato Yuhara
# Finish Scraping 24113 players.
# 2475 players remaining.
#
#
# Start Scraping: Guillermo Barron
# Finish Scraping 24114 players.
# 2474 players remaining.
#
#
# Start Scraping: Martin Parra
# Finish Scraping 24115 players.
# 2473 players remaining.
#
#
# Start Scraping: Diego Alberto Maronna
# Finish Scraping 24116 players.
# 2472 players remaining.
#
#
# Start Scraping: Andre Tavares
# Finish Scraping 24117 players.
# 2471 players remaining.
#
#
# Start Scraping: Victor Begara
# Finish Scraping 24118 players.
# 2470 players remaining.
#
#
# Start Scraping: Marcos Chiaretti
# Finish Scraping 24119 players.
# 2469 players remaining.
#
#
# Start Scraping: Lucas Pigossi
# Finish Scraping 24120 players.
# 2468 players remaining.
#
#
# Start Scraping: Anton Rabinov
# Finish Scraping 24121 players.
# 2467 players remaining.
#
#
# Start Scraping: Vedran Ljubicic
# Finish Scraping 24122 players.
# 2466 players remaining.
#
#
# Start Scraping: Fotis Triantis
# Finish Scraping 24123 players.
# 2465 players remaining.
#
#
# Start Scraping: David Hubbard
# Finish Scraping 24124 players.
# 2464 players remaining.
#
#
# Start Scraping: Jerome Palaz
# Finish Scraping 24125 players.
# 2463 players remaining.
#
#
# Start Scraping: Carlos Manuel Flores Albiac
# Finish Scraping 24126 players.
# 2462 players remaining.
#
#
# Start Scraping: Ariovaldo Custodio
# Finish Scraping 24127 players.
# 2461 players remaining.
#
#
# Start Scraping: Leandro Faria Da Cunha
# Finish Scraping 24128 players.
# 2460 players remaining.
#
#
# Start Scraping: Mike Tarkowski
# Finish Scraping 24129 players.
# 2459 players remaining.
#
#
# Start Scraping: Robson Nunes
# Finish Scraping 24130 players.
# 2458 players remaining.
#
#
# Start Scraping: Vinicius Botelho
# Finish Scraping 24131 players.
# 2457 players remaining.
#
#
# Start Scraping: Dennis Ochieng
# Finish Scraping 24132 players.
# 2456 players remaining.
#
#
# Start Scraping: Facundo Exequiel Cosma Miranda
# Finish Scraping 24133 players.
# 2455 players remaining.
#
#
# Start Scraping: Gaston Brizuela
# Finish Scraping 24134 players.
# 2454 players remaining.
#
#
# Start Scraping: Ali Ibshara
# Finish Scraping 24135 players.
# 2453 players remaining.
#
#
# Start Scraping: Filippo Ribacchi
# Finish Scraping 24136 players.
# 2452 players remaining.
#
#
# Start Scraping: Gabriel Ruiz Auad
# Finish Scraping 24137 players.
# 2451 players remaining.
#
#
# Start Scraping: Thomas Ackerknecht
# Finish Scraping 24138 players.
# 2450 players remaining.
#
#
# Start Scraping: Hector Sanabria
# Finish Scraping 24139 players.
# 2449 players remaining.
#
#
# Start Scraping: Rafael Bugiga
# Finish Scraping 24140 players.
# 2448 players remaining.
#
#
# Start Scraping: Flavio Malagutti
# Finish Scraping 24141 players.
# 2447 players remaining.
#
#
# Start Scraping: Carlos Alfredo Suppa
# Finish Scraping 24142 players.
# 2446 players remaining.
#
#
# Start Scraping: Marcelo Herrera
# Finish Scraping 24143 players.
# 2445 players remaining.
#
#
# Start Scraping: Francisco Aparicio
# Finish Scraping 24144 players.
# 2444 players remaining.
#
#
# Start Scraping: Alexander Vydmysh
# Finish Scraping 24145 players.
# 2443 players remaining.
#
#
# Start Scraping: Arda Coskunol
# Finish Scraping 24146 players.
# 2442 players remaining.
#
#
# Start Scraping: Muharrem Eroglu
# Finish Scraping 24147 players.
# 2441 players remaining.
#
#
# Start Scraping: Vidhan Vyas
# Finish Scraping 24148 players.
# 2440 players remaining.
#
#
# Start Scraping: Christoph Drechsler
# Finish Scraping 24149 players.
# 2439 players remaining.
#
#
# Start Scraping: Frederic Novas
# Finish Scraping 24150 players.
# 2438 players remaining.
#
#
# Start Scraping: Diego Soto Gonzalez
# Finish Scraping 24151 players.
# 2437 players remaining.
#
#
# Start Scraping: Joel Akerberg
# Finish Scraping 24152 players.
# 2436 players remaining.
#
#
# Start Scraping: Nicolas Pinones Haltenhoff
# Finish Scraping 24153 players.
# 2435 players remaining.
#
#
# Start Scraping: Nikita Rudenko
# Finish Scraping 24154 players.
# 2434 players remaining.
#
#
# Start Scraping: Eran Hecht
# Finish Scraping 24155 players.
# 2433 players remaining.
#
#
# Start Scraping: Michael Trebuhov
# Finish Scraping 24156 players.
# 2432 players remaining.
#
#
# Start Scraping: Steven Gallacher
# Finish Scraping 24157 players.
# 2431 players remaining.
#
#
# Start Scraping: Rogan Egerton
# Finish Scraping 24158 players.
# 2430 players remaining.
#
#
# Start Scraping: Alexandre Spoerri
# Finish Scraping 24159 players.
# 2429 players remaining.
#
#
# Start Scraping: Glen Kuma Mintah
# Finish Scraping 24160 players.
# 2428 players remaining.
#
#
# Start Scraping: Giovanni Bottai
# Finish Scraping 24161 players.
# 2427 players remaining.
#
#
# Start Scraping: Perica Josic
# Finish Scraping 24162 players.
# 2426 players remaining.
#
#
# Start Scraping: Alexander Seeger
# Finish Scraping 24163 players.
# 2425 players remaining.
#
#
# Start Scraping: Bob Huuskes
# Finish Scraping 24164 players.
# 2424 players remaining.
#
#
# Start Scraping: Ricard Tubert
# Finish Scraping 24165 players.
# 2423 players remaining.
#
#
# Start Scraping: George Alexandru Tatomir
# Finish Scraping 24166 players.
# 2422 players remaining.
#
#
# Start Scraping: Adam Fabik
# Finish Scraping 24167 players.
# 2421 players remaining.
#
#
# Start Scraping: Sergio Sanchez Moruno
# Finish Scraping 24168 players.
# 2420 players remaining.
#
#
# Start Scraping: Simon Blomberg
# Finish Scraping 24169 players.
# 2419 players remaining.
#
#
# Start Scraping: Karl Erik Paaro
# Finish Scraping 24170 players.
# 2418 players remaining.
#
#
# Start Scraping: Septimiu Fratila
# Finish Scraping 24171 players.
# 2417 players remaining.
#
#
# Start Scraping: Davit Minasyan
# Finish Scraping 24172 players.
# 2416 players remaining.
#
#
# Start Scraping: Torgom Asatryan
# Finish Scraping 24173 players.
# 2415 players remaining.
#
#
# Start Scraping: Ruben Alapont Rubio
# Finish Scraping 24174 players.
# 2414 players remaining.
#
#
# Start Scraping: Gabriel Maril Beltran
# Finish Scraping 24175 players.
# 2413 players remaining.
#
#
# Start Scraping: Armel Collinot
# Finish Scraping 24176 players.
# 2412 players remaining.
#
#
# Start Scraping: Giann Franco Meletto
# Finish Scraping 24177 players.
# 2411 players remaining.
#
#
# Start Scraping: Daniel Pazos
# Finish Scraping 24178 players.
# 2410 players remaining.
#
#
# Start Scraping: Juan Pablo Ramirez
# Finish Scraping 24179 players.
# 2409 players remaining.
#
#
# Start Scraping: Mario Correa
# Finish Scraping 24180 players.
# 2408 players remaining.
#
#
# Start Scraping: Thiago Aguiar
# Finish Scraping 24181 players.
# 2407 players remaining.
#
#
# Start Scraping: Lester Hippen
# Finish Scraping 24182 players.
# 2406 players remaining.
#
#
# Start Scraping: Nick Savage Pollock
# Finish Scraping 24183 players.
# 2405 players remaining.
#
#
# Start Scraping: William Humphreys
# Finish Scraping 24184 players.
# 2404 players remaining.
#
#
# Start Scraping: Adam Morgan
# Finish Scraping 24185 players.
# 2403 players remaining.
#
#
# Start Scraping: Nihal Kapoor
# Finish Scraping 24186 players.
# 2402 players remaining.
#
#
# Start Scraping: Bhishma Desai
# Finish Scraping 24187 players.
# 2401 players remaining.
#
#
# Start Scraping: Aziz Yuldashev
# Finish Scraping 24188 players.
# 2400 players remaining.
#
#
# Start Scraping: Nikita Soifer
# Finish Scraping 24189 players.
# 2399 players remaining.
#
#
# Start Scraping: Sam Kazemi
# Finish Scraping 24190 players.
# 2398 players remaining.
#
#
# Start Scraping: Ahmed Borai
# Finish Scraping 24191 players.
# 2397 players remaining.
#
#
# Start Scraping: Rafik Zaher
# Finish Scraping 24192 players.
# 2396 players remaining.
#
#
# Start Scraping: Kevin Soriano Lladser
# Finish Scraping 24193 players.
# 2395 players remaining.
#
#
# Start Scraping: Miguel Angel Lopez
# Finish Scraping 24194 players.
# 2394 players remaining.
#
#
# Start Scraping: Baligh Ellouze
# Finish Scraping 24195 players.
# 2393 players remaining.
#
#
# Start Scraping: Karim Sallemi
# Finish Scraping 24196 players.
# 2392 players remaining.
#
#
# Start Scraping: Guillaume Crasson
# Finish Scraping 24197 players.
# 2391 players remaining.
#
#
# Start Scraping: Gabriel Marcolino
# Finish Scraping 24198 players.
# 2390 players remaining.
#
#
# Start Scraping: Miroslav Stengl
# Finish Scraping 24199 players.
# 2389 players remaining.
#
#
# Start Scraping: Victor Acurcio Machado
# Finish Scraping 24200 players.
# 2388 players remaining.
#
#
# Start Scraping: Federico Iraola
# Finish Scraping 24201 players.
# 2387 players remaining.
#
#
# Start Scraping: Orlando Puleo
# Finish Scraping 24202 players.
# 2386 players remaining.
#
#
# Start Scraping: Eric Roberson
# Finish Scraping 24203 players.
# 2385 players remaining.
#
#
# Start Scraping: Zachary Ganger
# Finish Scraping 24204 players.
# 2384 players remaining.
#
#
# Start Scraping: Erick Eduardo Martinez Torres
# Finish Scraping 24205 players.
# 2383 players remaining.
#
#
# Start Scraping: Roope Kailaheimo
# Finish Scraping 24206 players.
# 2382 players remaining.
#
#
# Start Scraping: Kirill Kokhanov
# Finish Scraping 24207 players.
# 2381 players remaining.
#
#
# Start Scraping: Alessandro Lorenzon
# Finish Scraping 24208 players.
# 2380 players remaining.
#
#
# Start Scraping: Mattia Errico
# Finish Scraping 24209 players.
# 2379 players remaining.
#
#
# Start Scraping: Marlon Van Ingen
# Finish Scraping 24210 players.
# 2378 players remaining.
#
#
# Start Scraping: Andrea Bortolon
# Finish Scraping 24211 players.
# 2377 players remaining.
#
#
# Start Scraping: Ivan Petrov
# Finish Scraping 24212 players.
# 2376 players remaining.
#
#
# Start Scraping: Slavi Delchev
# Finish Scraping 24213 players.
# 2375 players remaining.
#
#
# Start Scraping: Angel Mirchev
# Finish Scraping 24214 players.
# 2374 players remaining.
#
#
# Start Scraping: Tin Horvatinovic
# Finish Scraping 24215 players.
# 2373 players remaining.
#
#
# Start Scraping: Kouhei Maeda
# Finish Scraping 24216 players.
# 2372 players remaining.
#
#
# Start Scraping: Tatsuya Sawada
# Finish Scraping 24217 players.
# 2371 players remaining.
#
#
# Start Scraping: Kentaro Kamata
# Finish Scraping 24218 players.
# 2370 players remaining.
#
#
# Start Scraping: Ryutaro Ueki
# Finish Scraping 24219 players.
# 2369 players remaining.
#
#
# Start Scraping: Yang Li
# Finish Scraping 24220 players.
# 2368 players remaining.
#
#
# Start Scraping: Tianchao Mei
# Finish Scraping 24221 players.
# 2367 players remaining.
#
#
# Start Scraping: Minu Lee
# Finish Scraping 24222 players.
# 2366 players remaining.
#
#
# Start Scraping: Man Hyo Lee
# Finish Scraping 24223 players.
# 2365 players remaining.
#
#
# Start Scraping: Xavi Torres
# Finish Scraping 24224 players.
# 2364 players remaining.
#
#
# Start Scraping: Daniel Steinbrenner
# Finish Scraping 24225 players.
# 2363 players remaining.
#
#
# Start Scraping: Jorge Alejandro Suarez Zuleta
# Finish Scraping 24226 players.
# 2362 players remaining.
#
#
# Start Scraping: Juan Paul Bastiaans Minguillon
# Finish Scraping 24227 players.
# 2361 players remaining.
#
#
# Start Scraping: Olivier Lemaitre
# Finish Scraping 24228 players.
# 2360 players remaining.
#
#
# Start Scraping: Lassine Kone
# Finish Scraping 24229 players.
# 2359 players remaining.
#
#
# Start Scraping: Brett Cromwell
# Finish Scraping 24230 players.
# 2358 players remaining.
#
#
# Start Scraping: Federico Waidlich Chaves
# Finish Scraping 24231 players.
# 2357 players remaining.
#
#
# Start Scraping: Canyo Dagum
# Finish Scraping 24232 players.
# 2356 players remaining.
#
#
# Start Scraping: Cristian Bohorquez
# Finish Scraping 24233 players.
# 2355 players remaining.
#
#
# Start Scraping: Kosho Shiono
# Finish Scraping 24234 players.
# 2354 players remaining.
#
#
# Start Scraping: Alfonso Gallo
# Finish Scraping 24235 players.
# 2353 players remaining.
#
#
# Start Scraping: Jean Ayissi Etele
# Finish Scraping 24236 players.
# 2352 players remaining.
#
#
# Start Scraping: Simon Samardzic
# Finish Scraping 24237 players.
# 2351 players remaining.
#
#
# Start Scraping: Jordan Mcculloch
# Finish Scraping 24238 players.
# 2350 players remaining.
#
#
# Start Scraping: Jose Carlos Fernandes
# Finish Scraping 24239 players.
# 2349 players remaining.
#
#
# Start Scraping: Sergey Tuskov
# Finish Scraping 24240 players.
# 2348 players remaining.
#
#
# Start Scraping: Garret Brasseaux
# Finish Scraping 24241 players.
# 2347 players remaining.
#
#
# Start Scraping: Alessandro Sarra
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 24242 players.
# 2346 players remaining.
#
#
# Start Scraping: Carlos Antonio Tavarez Rodriguez
# Finish Scraping 24243 players.
# 2345 players remaining.
#
#
# Start Scraping: Marlon Dal Pont
# Finish Scraping 24244 players.
# 2344 players remaining.
#
#
# Start Scraping: Sergio Martinez
# Finish Scraping 24245 players.
# 2343 players remaining.
#
#
# Start Scraping: Ki Soo Lee
# Finish Scraping 24246 players.
# 2342 players remaining.
#
#
# Start Scraping: Ernesto Arguello
# Finish Scraping 24247 players.
# 2341 players remaining.
#
#
# Start Scraping: Michael Rehrl
# Finish Scraping 24248 players.
# 2340 players remaining.
#
#
# Start Scraping: Elliot Keyser
# Finish Scraping 24249 players.
# 2339 players remaining.
#
#
# Start Scraping: Ozren Damjanovski
# Finish Scraping 24250 players.
# 2338 players remaining.
#
#
# Start Scraping: Marco Jager
# Finish Scraping 24251 players.
# 2337 players remaining.
#
#
# Start Scraping: Fahad Ali
# Finish Scraping 24252 players.
# 2336 players remaining.
#
#
# Start Scraping: Mandeep Yadav
# Finish Scraping 24253 players.
# 2335 players remaining.
#
#
# Start Scraping: Lucas Marin
# Finish Scraping 24254 players.
# 2334 players remaining.
#
#
# Start Scraping: Michael Cressevich
# Finish Scraping 24255 players.
# 2333 players remaining.
#
#
# Start Scraping: Sergio Barrera
# Finish Scraping 24256 players.
# 2332 players remaining.
#
#
# Start Scraping: Claudio Acevedo
# Finish Scraping 24257 players.
# 2331 players remaining.
#
#
# Start Scraping: Javier Andres Liu Rivas
# Finish Scraping 24258 players.
# 2330 players remaining.
#
#
# Start Scraping: Thomas Zamora Fuentes
# Finish Scraping 24259 players.
# 2329 players remaining.
#
#
# Start Scraping: Cedric Babu
# Finish Scraping 24260 players.
# 2328 players remaining.
#
#
# Start Scraping: Mussa Hakizimana
# Finish Scraping 24261 players.
# 2327 players remaining.
#
#
# Start Scraping: Diego Carrion
# Finish Scraping 24262 players.
# 2326 players remaining.
#
#
# Start Scraping: Francisco Vaca
# Finish Scraping 24263 players.
# 2325 players remaining.
#
#
# Start Scraping: Malandro Ayala
# Finish Scraping 24264 players.
# 2324 players remaining.
#
#
# Start Scraping: Guilheme Canineo R
# Finish Scraping 24265 players.
# 2323 players remaining.
#
#
# Start Scraping: Miguel Alves
# Finish Scraping 24266 players.
# 2322 players remaining.
#
#
# Start Scraping: Orion Modebe
# Finish Scraping 24267 players.
# 2321 players remaining.
#
#
# Start Scraping: Luke Mcdonald
# Finish Scraping 24268 players.
# 2320 players remaining.
#
#
# Start Scraping: Prateek Bhambri
# Finish Scraping 24269 players.
# 2319 players remaining.
#
#
# Start Scraping: Kujtim Bajrami
# Finish Scraping 24270 players.
# 2318 players remaining.
#
#
# Start Scraping: Kittibodee Singnil
# Finish Scraping 24271 players.
# 2317 players remaining.
#
#
# Start Scraping: Somboon Prasanwan
# Finish Scraping 24272 players.
# 2316 players remaining.
#
#
# Start Scraping: Kriangkrai Prajoubphansri
# Finish Scraping 24273 players.
# 2315 players remaining.
#
#
# Start Scraping: Kevin Andersson
# Finish Scraping 24274 players.
# 2314 players remaining.
#
#
# Start Scraping: Javier Ottaviani
# Finish Scraping 24275 players.
# 2313 players remaining.
#
#
# Start Scraping: Horacio Giussani
# Finish Scraping 24276 players.
# 2312 players remaining.
#
#
# Start Scraping: Jean Gandonou
# Finish Scraping 24277 players.
# 2311 players remaining.
#
#
# Start Scraping: Demba Sow
# Finish Scraping 24278 players.
# 2310 players remaining.
#
#
# Start Scraping: Karim Karrit
# Finish Scraping 24279 players.
# 2309 players remaining.
#
#
# Start Scraping: Clive Wright
# Finish Scraping 24280 players.
# 2308 players remaining.
#
#
# Start Scraping: Charles Graham
# Finish Scraping 24281 players.
# 2307 players remaining.
#
#
# Start Scraping: Austin Klores
# Finish Scraping 24282 players.
# 2306 players remaining.
#
#
# Start Scraping: Charles Weber
# Finish Scraping 24283 players.
# 2305 players remaining.
#
#
# Start Scraping: Giampaolo Zulli
# Finish Scraping 24284 players.
# 2304 players remaining.
#
#
# Start Scraping: Juan Diego Luzardo
# Finish Scraping 24285 players.
# 2303 players remaining.
#
#
# Start Scraping: Lawrence Harradine
# Finish Scraping 24286 players.
# 2302 players remaining.
#
#
# Start Scraping: Michael Tjuatjadarma
# Finish Scraping 24287 players.
# 2301 players remaining.
#
#
# Start Scraping: Andre Guzman
# Finish Scraping 24288 players.
# 2300 players remaining.
#
#
# Start Scraping: Maximiliano Gurmandi
# Finish Scraping 24289 players.
# 2299 players remaining.
#
#
# Start Scraping: Manoel Barbosa Andrade Neto
# Finish Scraping 24290 players.
# 2298 players remaining.
#
#
# Start Scraping: Adolfo Aires
# Finish Scraping 24291 players.
# 2297 players remaining.
#
#
# Start Scraping: Thiago Mastroianni
# Finish Scraping 24292 players.
# 2296 players remaining.
#
#
# Start Scraping: Marcelo Mazzetto
# Finish Scraping 24293 players.
# 2295 players remaining.
#
#
# Start Scraping: Fernando Mussolini
# Finish Scraping 24294 players.
# 2294 players remaining.
#
#
# Start Scraping: Bruno Bertolucci
# Finish Scraping 24295 players.
# 2293 players remaining.
#
#
# Start Scraping: Federico Visioli
# Finish Scraping 24296 players.
# 2292 players remaining.
#
#
# Start Scraping: William Ursule
# Finish Scraping 24297 players.
# 2291 players remaining.
#
#
# Start Scraping: James Turbervill
# Finish Scraping 24298 players.
# 2290 players remaining.
#
#
# Start Scraping: Alexander Pumpyanskiy
# Finish Scraping 24299 players.
# 2289 players remaining.
#
#
# Start Scraping: Hristosko Atanasov
# Finish Scraping 24300 players.
# 2288 players remaining.
#
#
# Start Scraping: Daniel Winnewisser
# Finish Scraping 24301 players.
# 2287 players remaining.
#
#
# Start Scraping: Daniil Lunev
# Finish Scraping 24302 players.
# 2286 players remaining.
#
#
# Start Scraping: Ramiro Arias Moreno
# Finish Scraping 24303 players.
# 2285 players remaining.
#
#
# Start Scraping: Gianmarco Velez
# Finish Scraping 24304 players.
# 2284 players remaining.
#
#
# Start Scraping: Mihail Gochev
# Finish Scraping 24305 players.
# 2283 players remaining.
#
#
# Start Scraping: Ronald Tijvelijn
# Finish Scraping 24306 players.
# 2282 players remaining.
#
#
# Start Scraping: David Veza
# Finish Scraping 24307 players.
# 2281 players remaining.
#
#
# Start Scraping: Andrei Dumitrascu
# Finish Scraping 24308 players.
# 2280 players remaining.
#
#
# Start Scraping: Presiyan Koev
# Finish Scraping 24309 players.
# 2279 players remaining.
#
#
# Start Scraping: Konstantin Lazarov
# Finish Scraping 24310 players.
# 2278 players remaining.
#
#
# Start Scraping: Vinko Ojdanic
# Finish Scraping 24311 players.
# 2277 players remaining.
#
#
# Start Scraping: Bostjan Repansek
# Finish Scraping 24312 players.
# 2276 players remaining.
#
#
# Start Scraping: Phillip Schulz
# Finish Scraping 24313 players.
# 2275 players remaining.
#
#
# Start Scraping: Christian Matic
# Finish Scraping 24314 players.
# 2274 players remaining.
#
#
# Start Scraping: Jan Plewinski
# Finish Scraping 24315 players.
# 2273 players remaining.
#
#
# Start Scraping: Emilio Misas
# Finish Scraping 24316 players.
# 2272 players remaining.
#
#
# Start Scraping: Aleksander Klenar
# Finish Scraping 24317 players.
# 2271 players remaining.
#
#
# Start Scraping: Andrea Dallasta
# Finish Scraping 24318 players.
# 2270 players remaining.
#
#
# Start Scraping: Victor Tiberiu Benea
# Finish Scraping 24319 players.
# 2269 players remaining.
#
#
# Start Scraping: Alexandru Florin Giurca
# Finish Scraping 24320 players.
# 2268 players remaining.
#
#
# Start Scraping: Phillip Mohr
# Finish Scraping 24321 players.
# 2267 players remaining.
#
#
# Start Scraping: Christopher Enser Boenisch
# Finish Scraping 24322 players.
# 2266 players remaining.
#
#
# Start Scraping: Andrey Daniluk
# Finish Scraping 24323 players.
# 2265 players remaining.
#
#
# Start Scraping: Valentin Dima
# Finish Scraping 24324 players.
# 2264 players remaining.
#
#
# Start Scraping: Callum Lloyd
# Finish Scraping 24325 players.
# 2263 players remaining.
#
#
# Start Scraping: Alexander Malko
# Finish Scraping 24326 players.
# 2262 players remaining.
#
#
# Start Scraping: Krunoslav Sven Lupis
# Finish Scraping 24327 players.
# 2261 players remaining.
#
#
# Start Scraping: Javier Peris Inigo
# Finish Scraping 24328 players.
# 2260 players remaining.
#
#
# Start Scraping: Ryan Horgan
# Finish Scraping 24329 players.
# 2259 players remaining.
#
#
# Start Scraping: Eldar Artemiev
# Finish Scraping 24330 players.
# 2258 players remaining.
#
#
# Start Scraping: Rustam Hajiyev
# Finish Scraping 24331 players.
# 2257 players remaining.
#
#
# Start Scraping: Mehmet Nafiz Duru
# Finish Scraping 24332 players.
# 2256 players remaining.
#
#
# Start Scraping: Morteza Jamshidi
# Finish Scraping 24333 players.
# 2255 players remaining.
#
#
# Start Scraping: Joshua Ayala
# Finish Scraping 24334 players.
# 2254 players remaining.
#
#
# Start Scraping: Domenico Sano
# Finish Scraping 24335 players.
# 2253 players remaining.
#
#
# Start Scraping: Jonathan Martinez Galvan
# Finish Scraping 24336 players.
# 2252 players remaining.
#
#
# Start Scraping: Ricardo Andrei Campos Contreras
# Finish Scraping 24337 players.
# 2251 players remaining.
#
#
# Start Scraping: Daniel Serur De La Torre
# Finish Scraping 24338 players.
# 2250 players remaining.
#
#
# Start Scraping: Asser Al Nokaly
# Finish Scraping 24339 players.
# 2249 players remaining.
#
#
# Start Scraping: Muhammad Waqas Malak
# Finish Scraping 24340 players.
# 2248 players remaining.
#
#
# Start Scraping: Ki Hun Jung
# Finish Scraping 24341 players.
# 2247 players remaining.
#
#
# Start Scraping: Jung Hyo Lee
# Finish Scraping 24342 players.
# 2246 players remaining.
#
#
# Start Scraping: Davey Sandgren
# Finish Scraping 24343 players.
# 2245 players remaining.
#
#
# Start Scraping: Casey Watt
# Finish Scraping 24344 players.
# 2244 players remaining.
#
#
# Start Scraping: Aba Omodele Lucien
# Finish Scraping 24345 players.
# 2243 players remaining.
#
#
# Start Scraping: Rhett Rollyson
# Finish Scraping 24346 players.
# 2242 players remaining.
#
#
# Start Scraping: Fabio Tsuchiya
# Finish Scraping 24347 players.
# 2241 players remaining.
#
#
# Start Scraping: Lucas Gordilho
# Finish Scraping 24348 players.
# 2240 players remaining.
#
#
# Start Scraping: Matias Vittori
# Finish Scraping 24349 players.
# 2239 players remaining.
#
#
# Start Scraping: Mircea Dimofte
# Finish Scraping 24350 players.
# 2238 players remaining.
#
#
# Start Scraping: Jose Luis Hernandez Davo
# Finish Scraping 24351 players.
# 2237 players remaining.
#
#
# Start Scraping: Ura Mukovoz
# Finish Scraping 24352 players.
# 2236 players remaining.
#
#
# Start Scraping: David Vukasinec
# Finish Scraping 24353 players.
# 2235 players remaining.
#
#
# Start Scraping: Michael Nuesslein
# Finish Scraping 24354 players.
# 2234 players remaining.
#
#
# Start Scraping: Johannes Pulsfort
# Finish Scraping 24355 players.
# 2233 players remaining.
#
#
# Start Scraping: Ola Rorvik Bakke
# Finish Scraping 24356 players.
# 2232 players remaining.
#
#
# Start Scraping: Pierre Clad
# Finish Scraping 24357 players.
# 2231 players remaining.
#
#
# Start Scraping: Juan Pablo De Paiz Ferrer
# Finish Scraping 24358 players.
# 2230 players remaining.
#
#
# Start Scraping: Pablo Romero Alvarez
# Finish Scraping 24359 players.
# 2229 players remaining.
#
#
# Start Scraping: Davide Cannone
# Finish Scraping 24360 players.
# 2228 players remaining.
#
#
# Start Scraping: Jovan Milic
# Finish Scraping 24361 players.
# 2227 players remaining.
#
#
# Start Scraping: Rares Georgescu
# Finish Scraping 24362 players.
# 2226 players remaining.
#
#
# Start Scraping: Razvan Lazarenco
# Finish Scraping 24363 players.
# 2225 players remaining.
#
#
# Start Scraping: Njal Foss Stene
# Finish Scraping 24364 players.
# 2224 players remaining.
#
#
# Start Scraping: Alexandru Oichea
# Finish Scraping 24365 players.
# 2223 players remaining.
#
#
# Start Scraping: Ignacio Arroyo Cologan
# Finish Scraping 24366 players.
# 2222 players remaining.
#
#
# Start Scraping: Lukas Michl
# Finish Scraping 24367 players.
# 2221 players remaining.
#
#
# Start Scraping: Jan Gattiker
# Finish Scraping 24368 players.
# 2220 players remaining.
#
#
# Start Scraping: Luka Starc
# Finish Scraping 24369 players.
# 2219 players remaining.
#
#
# Start Scraping: Roman Rohacek
# Finish Scraping 24370 players.
# 2218 players remaining.
#
#
# Start Scraping: Blagovest Naidenov
# Finish Scraping 24371 players.
# 2217 players remaining.
#
#
# Start Scraping: Davide Zucchini
# Finish Scraping 24372 players.
# 2216 players remaining.
#
#
# Start Scraping: Roman Chmelik
# Finish Scraping 24373 players.
# 2215 players remaining.
#
#
# Start Scraping: Christopher Prutsch
# Finish Scraping 24374 players.
# 2214 players remaining.
#
#
# Start Scraping: Calum Gee
# Finish Scraping 24375 players.
# 2213 players remaining.
#
#
# Start Scraping: Adria Mercadal Berenguer
# Finish Scraping 24376 players.
# 2212 players remaining.
#
#
# Start Scraping: Alistair Felton
# Finish Scraping 24377 players.
# 2211 players remaining.
#
#
# Start Scraping: David Florez Cohen
# Finish Scraping 24378 players.
# 2210 players remaining.
#
#
# Start Scraping: Claudio Masci
# Finish Scraping 24379 players.
# 2209 players remaining.
#
#
# Start Scraping: Mathieu Monleau
# Finish Scraping 24380 players.
# 2208 players remaining.
#
#
# Start Scraping: Yuriy Maslov
# Finish Scraping 24381 players.
# 2207 players remaining.
#
#
# Start Scraping: Anton Sevastyanov
# Finish Scraping 24382 players.
# 2206 players remaining.
#
#
# Start Scraping: Justin Jendruch
# Finish Scraping 24383 players.
# 2205 players remaining.
#
#
# Start Scraping: Nathaniel Gery
# Finish Scraping 24384 players.
# 2204 players remaining.
#
#
# Start Scraping: Carlos Guerrero Pancorbo
# Finish Scraping 24385 players.
# 2203 players remaining.
#
#
# Start Scraping: Evan Specht
# Finish Scraping 24386 players.
# 2202 players remaining.
#
#
# Start Scraping: Hannay Carbonell
# Finish Scraping 24387 players.
# 2201 players remaining.
#
#
# Start Scraping: Ken Endo
# Finish Scraping 24388 players.
# 2200 players remaining.
#
#
# Start Scraping: Hermand De Bruin
# Finish Scraping 24389 players.
# 2199 players remaining.
#
#
# Start Scraping: Bryce Durham
# Finish Scraping 24390 players.
# 2198 players remaining.
#
#
# Start Scraping: Alessio Abbondanzieri
# Finish Scraping 24391 players.
# 2197 players remaining.
#
#
# Start Scraping: Thomas Flury
# Finish Scraping 24392 players.
# 2196 players remaining.
#
#
# Start Scraping: Tim Matthewson
# Finish Scraping 24393 players.
# 2195 players remaining.
#
#
# Start Scraping: Nicolas Ebran
# Finish Scraping 24394 players.
# 2194 players remaining.
#
#
# Start Scraping: Javier Alfonso Roman
# Finish Scraping 24395 players.
# 2193 players remaining.
#
#
# Start Scraping: Fabricio Moncada
# Finish Scraping 24396 players.
# 2192 players remaining.
#
#
# Start Scraping: Rigoberto Estrada
# Finish Scraping 24397 players.
# 2191 players remaining.
#
#
# Start Scraping: Victor Martins
# Finish Scraping 24398 players.
# 2190 players remaining.
#
#
# Start Scraping: Henrique Boturao
# Finish Scraping 24399 players.
# 2189 players remaining.
#
#
# Start Scraping: Mohammed Abbas
# Finish Scraping 24400 players.
# 2188 players remaining.
#
#
# Start Scraping: John Oyet
# Finish Scraping 24401 players.
# 2187 players remaining.
#
#
# Start Scraping: Charles Senyanga
# Finish Scraping 24402 players.
# 2186 players remaining.
#
#
# Start Scraping: Alexander Farron Mahon
# Finish Scraping 24403 players.
# 2185 players remaining.
#
#
# Start Scraping: Cekina Niyonshuti
# ...
#
#
# Start Scraping: Jose Fernandez
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26430 players.
# 158 players remaining.
#
#
# Start Scraping: Jose Delafuente
# Finish Scraping 26431 players.
# 157 players remaining.
#
#
# Start Scraping: Jorge Cano
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26432 players.
# 156 players remaining.
#
#
# Start Scraping: Johnies Sauer
# Finish Scraping 26433 players.
# 155 players remaining.
#
#
# Start Scraping: John Werner
# Finish Scraping 26434 players.
# 154 players remaining.
#
#
# Start Scraping: John Kapakoglu
# Finish Scraping 26435 players.
# 153 players remaining.
#
#
# Start Scraping: Johan Sjogren
# Finish Scraping 26436 players.
# 152 players remaining.
#
#
# Start Scraping: Johan Milbrimk
# Finish Scraping 26437 players.
# 151 players remaining.
#
#
# Start Scraping: Joe Shaheen
# Finish Scraping 26438 players.
# 150 players remaining.
#
#
# Start Scraping: Joao Guedes
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26439 players.
# 149 players remaining.
#
#
# Start Scraping: Joao Coutinho
# Finish Scraping 26440 players.
# 148 players remaining.
#
#
# Start Scraping: Jin So Lee
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26441 players.
# 147 players remaining.
#
#
# Start Scraping: Jim Somerville
# Finish Scraping 26442 players.
# 146 players remaining.
#
#
# Start Scraping: Jeremy Grubi
# Finish Scraping 26443 players.
# 145 players remaining.
#
#
# Start Scraping: Jeff Player
# Finish Scraping 26444 players.
# 144 players remaining.
#
#
# Start Scraping: Jeff Crowne
# Finish Scraping 26445 players.
# 143 players remaining.
#
#
# Start Scraping: Jean Francois Blain
# Finish Scraping 26446 players.
# 142 players remaining.
#
#
# Start Scraping: Javier Duarte
# Finish Scraping 26447 players.
# 141 players remaining.
#
#
# Start Scraping: Jason Wilkie
# Finish Scraping 26448 players.
# 140 players remaining.
#
#
# Start Scraping: James Ilako
# Finish Scraping 26449 players.
# 139 players remaining.
#
#
# Start Scraping: Jacques Bonnemaison
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26450 players.
# 138 players remaining.
#
#
# Start Scraping: J Spinnenweber
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26451 players.
# 137 players remaining.
#
#
# Start Scraping: J Potgieter
# Finish Scraping 26452 players.
# 136 players remaining.
#
#
# Start Scraping: Ian Duvenhage
# Finish Scraping 26453 players.
# 135 players remaining.
#
#
# Start Scraping: Ian Bersin
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26454 players.
# 134 players remaining.
#
#
# Start Scraping: Horacio Marin
# Finish Scraping 26455 players.
# 133 players remaining.
#
#
# Start Scraping: Holger Trahn
# Finish Scraping 26456 players.
# 132 players remaining.
#
#
# Start Scraping: Hiroshi Ito
# Finish Scraping 26457 players.
# 131 players remaining.
#
#
# Start Scraping: Herve Bardot
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26458 players.
# 130 players remaining.
#
#
# Start Scraping: Hernan Valenzuela
# Finish Scraping 26459 players.
# 129 players remaining.
#
#
# Start Scraping: Harvey Becker
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26460 players.
# 128 players remaining.
#
#
# Start Scraping: H Hsu
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26461 players.
# 127 players remaining.
#
#
# Start Scraping: Gustavo Merbilhaa
# Finish Scraping 26462 players.
# 126 players remaining.
#
#
# Start Scraping: Gustavo Espinosa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26463 players.
# 125 players remaining.
#
#
# Start Scraping: Gulio Melchiorre
# Finish Scraping 26464 players.
# 124 players remaining.
#
#
# Start Scraping: Guido Possamai
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26465 players.
# 123 players remaining.
#
#
# Start Scraping: Greg Muller
# Finish Scraping 26466 players.
# 122 players remaining.
#
#
# Start Scraping: Greg Ewansky
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26467 players.
# 121 players remaining.
#
#
# Start Scraping: Graziano Risi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26468 players.
# 120 players remaining.
#
#
# Start Scraping: Graham Epsley Jones
# Finish Scraping 26469 players.
# 119 players remaining.
#
#
# Start Scraping: Gerardo Hernandez
# Finish Scraping 26470 players.
# 118 players remaining.
#
#
# Start Scraping: George Obidiegwu
# Finish Scraping 26471 players.
# 117 players remaining.
#
#
# Start Scraping: George Goncalves
# Finish Scraping 26472 players.
# 116 players remaining.
#
#
# Start Scraping: Gavin Hewson
# Finish Scraping 26473 players.
# 115 players remaining.
#
#
# Start Scraping: Gary Seymour
# Finish Scraping 26474 players.
# 114 players remaining.
#
#
# Start Scraping: Frank Apecehea
# Finish Scraping 26475 players.
# 113 players remaining.
#
#
# Start Scraping: Francis Ikosa
# Finish Scraping 26476 players.
# 112 players remaining.
#
#
# Start Scraping: Fernando Souza
# Finish Scraping 26477 players.
# 111 players remaining.
#
#
# Start Scraping: Evgeni Zhelyazkov
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26478 players.
# 110 players remaining.
#
#
# Start Scraping: Enno Van Veggel
# Finish Scraping 26479 players.
# 109 players remaining.
#
#
# Start Scraping: Emmanuel Brard
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26480 players.
# 108 players remaining.
#
#
# Start Scraping: Emeka Igbinebor
# Finish Scraping 26481 players.
# 107 players remaining.
#
#
# Start Scraping: Eduardo Bricio
# Finish Scraping 26482 players.
# 106 players remaining.
#
#
# Start Scraping: Eddie Siegenthaler
# Finish Scraping 26483 players.
# 105 players remaining.
#
#
# Start Scraping: Donald England
# Finish Scraping 26484 players.
# 104 players remaining.
#
#
# Start Scraping: Didier Frantz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26485 players.
# 103 players remaining.
#
#
# Start Scraping: Delroy Reid
# Finish Scraping 26486 players.
# 102 players remaining.
#
#
# Start Scraping: Davn Santiago
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26487 players.
# 101 players remaining.
#
#
# Start Scraping: David Leveaux
# Finish Scraping 26488 players.
# 100 players remaining.
#
#
# Start Scraping: David Kacharava
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26489 players.
# 99 players remaining.
#
#
# Start Scraping: David Culley
# Finish Scraping 26490 players.
# 98 players remaining.
#
#
# Start Scraping: David Betous
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26491 players.
# 97 players remaining.
#
#
# Start Scraping: Daryl Greeves
# Finish Scraping 26492 players.
# 96 players remaining.
#
#
# Start Scraping: Darren Cole
# Finish Scraping 26493 players.
# 95 players remaining.
#
#
# Start Scraping: Daniel Garcia
# Finish Scraping 26494 players.
# 94 players remaining.
#
#
# Start Scraping: Dan Rastland
# Finish Scraping 26495 players.
# 93 players remaining.
#
#
# Start Scraping: Curtis Hollinger
# Finish Scraping 26496 players.
# 92 players remaining.
#
#
# Start Scraping: Cristofer Leberth
# Finish Scraping 26497 players.
# 91 players remaining.
#
#
# Start Scraping: Cris Herman
# Finish Scraping 26498 players.
# 90 players remaining.
#
#
# Start Scraping: Corey Wittenberg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26499 players.
# 89 players remaining.
#
#
# Start Scraping: Claudio Semmelmann
# Finish Scraping 26500 players.
# 88 players remaining.
#
#
# Start Scraping: Claudio Menna
# Finish Scraping 26501 players.
# 87 players remaining.
#
#
# Start Scraping: Claudio Fava
# Finish Scraping 26502 players.
# 86 players remaining.
#
#
# Start Scraping: Christopher Wolff
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26503 players.
# 85 players remaining.
#
#
# Start Scraping: Christoph Geukens
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26504 players.
# 84 players remaining.
#
#
# Start Scraping: Chris Vermeeren
# Finish Scraping 26505 players.
# 83 players remaining.
#
#
# Start Scraping: Chris Ellis
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26506 players.
# 82 players remaining.
#
#
# Start Scraping: Chip Tolleson
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26507 players.
# 81 players remaining.
#
#
# Start Scraping: Carlos Stocker
# Finish Scraping 26508 players.
# 80 players remaining.
#
#
# Start Scraping: Carlo Zugarelli
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26509 players.
# 79 players remaining.
#
#
# Start Scraping: Carl Williams
# Finish Scraping 26510 players.
# 78 players remaining.
#
#
# Start Scraping: Carey Brading
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26511 players.
# 77 players remaining.
#
#
# Start Scraping: Bunge Nahor
# Finish Scraping 26512 players.
# 76 players remaining.
#
#
# Start Scraping: Brett Hibbert
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26513 players.
# 75 players remaining.
#
#
# Start Scraping: Brendan Sharp
# Finish Scraping 26514 players.
# 74 players remaining.
#
#
# Start Scraping: Bosko Simundsa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26515 players.
# 73 players remaining.
#
#
# Start Scraping: Bob Deller
# Finish Scraping 26516 players.
# 72 players remaining.
#
#
# Start Scraping: Bjorn Wahlstrom
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26517 players.
# 71 players remaining.
#
#
# Start Scraping: Bernardo Padilha
# Finish Scraping 26518 players.
# 70 players remaining.
#
#
# Start Scraping: Babatunde Akinola
# Finish Scraping 26519 players.
# 69 players remaining.
#
#
# Start Scraping: B Hochstadter
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26520 players.
# 68 players remaining.
#
#
# Start Scraping: Archie Adams
# Finish Scraping 26521 players.
# 67 players remaining.
#
#
# Start Scraping: Antti Eranne
# Finish Scraping 26522 players.
# 66 players remaining.
#
#
# Start Scraping: Antonio Zampieri
# Finish Scraping 26523 players.
# 65 players remaining.
#
#
# Start Scraping: Anthony Burke
# Finish Scraping 26524 players.
# 64 players remaining.
#
#
# Start Scraping: Andreas Fink
# Finish Scraping 26525 players.
# 63 players remaining.
#
#
# Start Scraping: Anders Rolfsen
# Finish Scraping 26526 players.
# 62 players remaining.
#
#
# Start Scraping: Alberto Kulmann
# Finish Scraping 26527 players.
# 61 players remaining.
#
#
# Start Scraping: Alan Tunik
# Finish Scraping 26528 players.
# 60 players remaining.
#
#
# Start Scraping: Alan Douglas
# Finish Scraping 26529 players.
# 59 players remaining.
#
#
# Start Scraping: A Noffat
# Finish Scraping 26530 players.
# 58 players remaining.
#
#
# Start Scraping: A Hall
# Serve Page: 882
# Return Page: 882
# Raw Page: 882
# Finish Scraping 26531 players.
# 57 players remaining.
#
#
# Start Scraping: Arkadiusz Kocyla Kd20
# Finish Scraping 26532 players.
# 56 players remaining.
#
#
# Start Scraping: Yoann Re
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 26533 players.
# 55 players remaining.
#
#
# Start Scraping: Antonio Ruiz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26534 players.
# 54 players remaining.
#
#
# Start Scraping: Ravishankar Pathanjali
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26535 players.
# 53 players remaining.
#
#
# Start Scraping: Eduardo Magadan
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26536 players.
# 52 players remaining.
#
#
# Start Scraping: Will Farah
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26537 players.
# 51 players remaining.
#
#
# Start Scraping: Juri Margotto
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26538 players.
# 50 players remaining.
#
#
# Start Scraping: Emmanuel Marmillod
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26539 players.
# 49 players remaining.
#
#
# Start Scraping: Juan Olivert
# Finish Scraping 26540 players.
# 48 players remaining.
#
#
# Start Scraping: David Franco
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26541 players.
# 47 players remaining.
#
#
# Start Scraping: Alexander Lindholm L174
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26542 players.
# 46 players remaining.
#
#
# Start Scraping: Adi Kremer
# Finish Scraping 26543 players.
# 45 players remaining.
#
#
# Start Scraping: Paul Lord
# Finish Scraping 26544 players.
# 44 players remaining.
#
#
# Start Scraping: Alberto Gutierrez G230
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26545 players.
# 43 players remaining.
#
#
# Start Scraping: Glenn Dickerson
# Finish Scraping 26546 players.
# 42 players remaining.
#
#
# Start Scraping: Jochen Wolff
# Finish Scraping 26547 players.
# 41 players remaining.
#
#
# Start Scraping: Yann Drieux
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26548 players.
# 40 players remaining.
#
#
# Start Scraping: Jeff Brown
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 26549 players.
# 39 players remaining.
#
#
# Start Scraping: Peter Herrmann
# Finish Scraping 26550 players.
# 38 players remaining.
#
#
# Start Scraping: Trey Carter
# Finish Scraping 26551 players.
# 37 players remaining.
#
#
# Start Scraping: Doug Pielet
# Finish Scraping 26552 players.
# 36 players remaining.
#
#
# Start Scraping: Eric Rosenfeld
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26553 players.
# 35 players remaining.
#
#
# Start Scraping: Bill Stanley
# Finish Scraping 26554 players.
# 34 players remaining.
#
#
# Start Scraping: Dave Richmond
# Finish Scraping 26555 players.
# 33 players remaining.
#
#
# Start Scraping: Peter Smith
# Serve Page: 882
# Return Page: 882
# Raw Page: 882
# Finish Scraping 26556 players.
# 32 players remaining.
#
#
# Start Scraping: Jim Sharton
# Finish Scraping 26557 players.
# 31 players remaining.
#
#
# Start Scraping: Martin Fortun
# Finish Scraping 26558 players.
# 30 players remaining.
#
#
# Start Scraping: Tom Fontana
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26559 players.
# 29 players remaining.
#
#
# Start Scraping: Kai Niemi
# Finish Scraping 26560 players.
# 28 players remaining.
#
#
# Start Scraping: Rob Mitchell
# Finish Scraping 26561 players.
# 27 players remaining.
#
#
# Start Scraping: Hans Fredborg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26562 players.
# 26 players remaining.
#
#
# Start Scraping: Leighton Alfred
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26563 players.
# 25 players remaining.
#
#
# Start Scraping: Fred Viancos
# Finish Scraping 26564 players.
# 24 players remaining.
#
#
# Start Scraping: Jean Luc Cotard
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26565 players.
# 23 players remaining.
#
#
# Start Scraping: Steven Matthews
# Finish Scraping 26566 players.
# 22 players remaining.
#
#
# Start Scraping: John Losito
# Finish Scraping 26567 players.
# 21 players remaining.
#
#
# Start Scraping: Darcy Carroll
# Finish Scraping 26568 players.
# 20 players remaining.
#
#
# Start Scraping: Mark Pinchoff
# Finish Scraping 26569 players.
# 19 players remaining.
#
#
# Start Scraping: Tracy Fenelon
# Finish Scraping 26570 players.
# 18 players remaining.
#
#
# Start Scraping: Tim Robson
# Finish Scraping 26571 players.
# 17 players remaining.
#
#
# Start Scraping: Tim Downey
# Finish Scraping 26572 players.
# 16 players remaining.
#
#
# Start Scraping: James Rubin
# Finish Scraping 26573 players.
# 15 players remaining.
#
#
# Start Scraping: Andy Gordon
# Finish Scraping 26574 players.
# 14 players remaining.
#
#
# Start Scraping: Larry Barnett
# Finish Scraping 26575 players.
# 13 players remaining.
#
#
# Start Scraping: Eduard Pana
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26576 players.
# 12 players remaining.
#
#
# Start Scraping: Tom Caine
# Finish Scraping 26577 players.
# 11 players remaining.
#
#
# Start Scraping: Doug Adler
# Finish Scraping 26578 players.
# 10 players remaining.
#
#
# Start Scraping: Renald Etienne
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26579 players.
# 9 players remaining.
#
#
# Start Scraping: Jochen Hierl
# Finish Scraping 26580 players.
# 8 players remaining.
#
#
# Start Scraping: Robert Baumgartner
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26581 players.
# 7 players remaining.
#
#
# Start Scraping: David Parker
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26582 players.
# 6 players remaining.
#
#
# Start Scraping: George Glowa
# Finish Scraping 26583 players.
# 5 players remaining.
#
#
# Start Scraping: Zdenek Slizek
# Finish Scraping 26584 players.
# 4 players remaining.
#
#
# Start Scraping: Grant Golden
# Serve Page: 67
# Return Page: 67
# Raw Page: 67
# Finish Scraping 26585 players.
# 3 players remaining.
#
#
# Start Scraping: Jeff Sackmann
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 26586 players.
# 2 players remaining.
#
#
# Start Scraping: Carl Bialik
# Serve Page: 18
# Return Page: 18
# Raw Page: 18
# Finish Scraping 26587 players.
# 1 players remaining.
#
#
# Start Scraping: Edoardo Salvati
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26588 players.
# 0 players remaining.
