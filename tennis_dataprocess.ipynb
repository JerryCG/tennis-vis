# %% [markdown]
# # Tennis Player Analysis

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %% [markdown]
# ## 2. Process Names

# %%
# load name list
# https://www.tennisabstract.com/mwplayerlist.js?_=1668453288068
with open("mwplayerlist.txt", 'r') as f:
    names = f.read()
f.close()

# %%
# process name list and save to a new text file
names = names[17:-5].split("\", \"")
with open("mwplayerlist_processed.txt", "w") as f:
    for name in names:
        f.write(name)
        f.write('\n')
f.close()

# %% [markdown]
# ## 3. Scraper All Matches Player by Player

# %%
# headers = {
#   'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:55.0) Gecko/20100101 Firefox/55.0',
#}

# %%
# define functions to get all players' names
def get_names(sex = ''):
    names = []
    if sex == 'm':
        with open('mp.txt', 'r') as f:
            for line in f:
                names.append(line[:-1])
    elif sex == 'w':
        with open('wp.txt', 'r') as f:
            for line in f:
                names.append(line[:-1])
    else:
        with open('mwplayerlist_processed.txt', 'r') as f:
            for line in f:
                names.append(line[:-1])
    return names

# define a function to scrape for a single man player's matches
def scrape_matches(name, driver):
    try:
        # set attributes
        attributes_m = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'TP', 'Aces', 'DFs', 'SP', 
                        '1SP', '2SP', 'vA', 'Time']

        attributes_w = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'Time']

        # get cleaned name
        sex = name[1]
        name_cleaned = name[4:].replace(' ', '')

        # set url prefix and types of webpages
        if sex == 'M':
            url = "https://www.tennisabstract.com/cgi-bin/player-classic.cgi?p=" 
        #   types = ["&f=ACareerqq", "&f=ACareerqqr1", "&f=ACareerqqw1"]
        else:
            url = "https://www.tennisabstract.com/cgi-bin/wplayer-classic.cgi?p="

        # Start of Scraping
        print('Start Scraping:', name[4:])
        
        # man and woman pages are different
        if sex == 'M':

            # for man players
            # set dictionary
            dic = {}
            for attr in attributes_m:
                dic[attr] = []

            # for serve page
            driver.get(url + name_cleaned.replace(' ', '') + "&f=ACareerqq")
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
        #   driver.quit()

            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # for return page
                show_return = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Return"]')))
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[1])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # for raw page
                show_raw = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Raw"]')))
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[2])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

            else:

                # serve page
                driver.get(url + name_cleaned.replace(' ', ''))
                driver.refresh()
                # show career
                try:
                    show_career = driver.find_element(By.ID, 'careerclick')
                except:
                    return None
                show_career.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # return page
                show_return = driver.find_element(By.XPATH, '//span[text()="Return"]')
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # raw page
                show_raw = driver.find_element(By.XPATH, '//span[text()="Raw"]')
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
              # driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

        else:

            # for woman players
            # set dictionary
            dic = {}
            for attr in attributes_w:
                dic[attr] = []

            # for serve page
            driver.get(url + name_cleaned.replace(' ', '') + '&f=ACareerqq')
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')

            for match in matches[2:]:
                tds = match.find_all('td')
                # first check if it is ongoing match
                spans = tds[6].find_all('span')
                if spans[3].text != 'vs':
                    # date, contain special character
                    date = tds[0].text.split('‑')
                    dic[attributes_w[0]].append('-'.join(date))
                    # tournament
                    dic[attributes_w[1]].append(tds[1].text)
                    # sets
                    dic[attributes_w[2]].append(3)
                    # surface
                    dic[attributes_w[3]].append(tds[2].text)
                    # round
                    dic[attributes_w[4]].append(tds[3].text)
                    # rank
                    dic[attributes_w[5]].append(tds[4].text)
                    # opponent rank
                    dic[attributes_w[6]].append(tds[5].text)
                    # win?, tournament rank, opponent tournament rank, winner, loser
                    if spans[1].text in name:
                        # win?
                        dic[attributes_w[7]].append(1)
                        # winner
                        dic[attributes_w[10]].append(name[4:])
                        # loser
                        dic[attributes_w[11]].append(spans[6].text)
                        # tRk
                        if spans[0].text != '':
                            dic[attributes_w[8]].append(spans[0].text[1:-1])
                        else:
                            dic[attributes_w[8]].append('')
                        # vtRk
                        if spans[5].text != '':
                            dic[attributes_w[9]].append(spans[5].text[1:-1])
                        else:
                            dic[attributes_w[9]].append('')
                    else:
                        # win?
                        dic[attributes_w[7]].append(0)
                        # winner
                        dic[attributes_w[10]].append(spans[1].text)
                        # loser
                        dic[attributes_w[11]].append(name[4:])
                        # tRk
                        if spans[6].text != '':
                            dic[attributes_w[8]].append(spans[6].text[1:-1])
                        else:
                            dic[attributes_w[8]].append('')
                        # vtRk
                        if spans[0].text != '':
                            dic[attributes_w[9]].append(spans[0].text[1:-1])
                        else:
                            dic[attributes_w[9]].append('')
                    # score
                    dic[attributes_w[12]].append(tds[7].text)
                    # DR
                    dic[attributes_w[13]].append(tds[8].text)
                    # A%
                    dic[attributes_w[14]].append(tds[9].text)
                    # DF%
                    dic[attributes_w[15]].append(tds[10].text)
                    # 1stIn
                    dic[attributes_w[16]].append(tds[11].text)
                    # 1st%
                    dic[attributes_w[17]].append(tds[12].text)
                    # 2rd%
                    dic[attributes_w[18]].append(tds[13].text)
                    # BPSvd
                    dic[attributes_w[19]].append(tds[14].text)

            print('Serve Page:', len(dic['Date']))

            # for return page
            page_return = driver.find_element(By.XPATH, '//span[text()="Show Return Stats"]')
            page_return.click()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
        #   driver.quit()

            for match in matches[2:]:
                tds = match.find_all('td')
                # first check if it is ongoing match
                spans = tds[6].find_all('span')
                if spans[3].text != 'vs':
                    # TPW
                    dic[attributes_w[20]].append(tds[9].text)
                    # RPW
                    dic[attributes_w[21]].append(tds[10].text)
                    # vA%
                    dic[attributes_w[22]].append(tds[11].text)
                    # v1st%
                    dic[attributes_w[23]].append(tds[12].text)
                    # v2rd%
                    dic[attributes_w[24]].append(tds[13].text)
                    # BPCvt
                    dic[attributes_w[25]].append(tds[14].text)
                    # Time
                    dic[attributes_w[26]].append(tds[15].text)

            print('Return Page:', len(dic['TPW']))

        # save to text, separated by gender
        df = pd.DataFrame(dic)
        df.to_csv(sex.lower() + '/matches/txt/' + name[4:] + '.txt', index = False, sep = ',')

    except (IndexError, AttributeError) as e:
        pass
    
# define a loop function to scrape players from a given index
def scrape_from(idx, sex, driver):
    names = get_names(sex)
    for i in range(idx, len(names)):
        scrape_matches(names[i], driver)
        print('Finish Scraping', i + 1, 'players.')
        print(len(names) - (i + 1), 'players remaining.')
        print('\n')
        
# load txt files
def load_txt(name):
    with open(name[1].lower() + '/matches/txt/' + name[4:] + '.txt', 'r') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    return df

# %%
# separate women and men
names = get_names()
mp = []
wp = []
for name in names:
    if name[1] == 'M':
        mp.append(name)
    elif name[1] == 'W':
        wp.append(name)

with open('mp.txt', 'w') as f:
    for name in mp:
        f.write(name)
        f.write('\n')
f.close()

with open('wp.txt', 'w') as f:
    for name in wp:
        f.write(name)
        f.write('\n')
f.close()

# %%
# scraping begins
# set up chromdriver
chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)
scrape_from(2030, 'm', driver)
# Out:
# Start Scraping: James Lemke
# Finish Scraping 2031 players.
# 24557 players remaining.
#
#
# Start Scraping: Ervin Eleskovic
# Serve Page: 59
# Return Page: 59
# Raw Page: 59
# Finish Scraping 2032 players.
# 24556 players remaining.
#
#
# Start Scraping: Bogdan Leonte
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 2033 players.
# 24555 players remaining.
#
#
# Start Scraping: Hector Ruiz Cadenas
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 2034 players.
# 24554 players remaining.
#
#
# Start Scraping: John Paul Fruttero
# Serve Page: 308
# Return Page: 308
# Raw Page: 308
# Finish Scraping 2035 players.
# 24553 players remaining.
#
#
# Start Scraping: Kirill Ivanov Smolensky
# Serve Page: 75
# Return Page: 75
# Raw Page: 75
# Finish Scraping 2036 players.
# 24552 players remaining.
#
#
# Start Scraping: Colin Dowdeswell
# Serve Page: 316
# Return Page: 316
# Raw Page: 316
# Finish Scraping 2037 players.
# 24551 players remaining.
#
#
# Start Scraping: Juan Sebastian Cabal
# Serve Page: 313
# Return Page: 313
# Raw Page: 313
# Finish Scraping 2038 players.
# 24550 players remaining.
#
#
# Start Scraping: Jorge Montero
# Serve Page: 312
# Return Page: 312
# Raw Page: 312
# Finish Scraping 2039 players.
# 24549 players remaining.
#
#
# Start Scraping: Daniel Lustig
# Serve Page: 313
# Return Page: 313
# Raw Page: 313
# Finish Scraping 2040 players.
# 24548 players remaining.
#
#
# Start Scraping: Peng Sun
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 2041 players.
# 24547 players remaining.
#
#
# Start Scraping: Petr Luxa
# Serve Page: 233
# Return Page: 233
# Raw Page: 233
# Finish Scraping 2042 players.
# 24546 players remaining.
#
#
# Start Scraping: Massimo Cierro
# Serve Page: 129
# Return Page: 129
# Raw Page: 129
# Finish Scraping 2043 players.
# 24545 players remaining.
#
#
# Start Scraping: Marko Ostoja
# Serve Page: 312
# Return Page: 312
# Raw Page: 312
# Finish Scraping 2044 players.
# 24544 players remaining.
#
#
# Start Scraping: Antonio Zugarelli
# Serve Page: 313
# Return Page: 313
# Raw Page: 313
# Finish Scraping 2045 players.
# 24543 players remaining.
#
#
# Start Scraping: Sergey Fomin
# Serve Page: 170
# Return Page: 170
# Raw Page: 170
# Finish Scraping 2046 players.
# 24542 players remaining.
#
#
# Start Scraping: Gabriel Donev
# Serve Page: 169
# Return Page: 169
# Raw Page: 169
# Finish Scraping 2047 players.
# 24541 players remaining.
#
#
# Start Scraping: Remi Boutillier
# Serve Page: 309
# Return Page: 309
# Raw Page: 309
# Finish Scraping 2048 players.
# 24540 players remaining.
#
#
# Start Scraping: Komlavi Loglo
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 2049 players.
# 24539 players remaining.
#
#
# Start Scraping: David Novak
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 2050 players.
# 24538 players remaining.
#
#
# Start Scraping: Regis Lavergne
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 2051 players.
# 24537 players remaining.
#
#
# Start Scraping: Sebastian Weisz
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 2052 players.
# 24536 players remaining.
#
#
# Start Scraping: David Salvador Estepa
# Serve Page: 18
# Return Page: 18
# Raw Page: 18
# Finish Scraping 2053 players.
# 24535 players remaining.
#
#
# Start Scraping: Mariano Hood
# Serve Page: 84
# Return Page: 84
# Raw Page: 84
# Finish Scraping 2054 players.
# 24534 players remaining.
#
#
# Start Scraping: Wojtek Kowalski
# Serve Page: 312
# Return Page: 312
# Raw Page: 312
# Finish Scraping 2055 players.
# 24533 players remaining.
#
#
# Start Scraping: Marcos Aurelio Gorriz
# Serve Page: 266
# Return Page: 266
# Raw Page: 266
# Finish Scraping 2056 players.
# 24532 players remaining.
#
#
# Start Scraping: Pavel Slozil
# Serve Page: 312
# Return Page: 312
# Raw Page: 312
# Finish Scraping 2057 players.
# 24531 players remaining.
#
#
# Start Scraping: Juan Manuel Valverde
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 2058 players.
# 24530 players remaining.
#
#
# Start Scraping: Sunil Kumar Sipaeya
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 2059 players.
# 24529 players remaining.
#
#
# Start Scraping: Yahiya Doumbia
# Serve Page: 284
# Return Page: 284
# Raw Page: 284
# Finish Scraping 2060 players.
# 24528 players remaining.
#
#
# Start Scraping: Ulrich Pinner
# Serve Page: 311
# Return Page: 311
# Raw Page: 311
# Finish Scraping 2061 players.
# 24527 players remaining.
#
#
# Start Scraping: Blake Ellis
# Serve Page: 168
# Return Page: 168
# Raw Page: 168
# Finish Scraping 2062 players.
# 24526 players remaining.
#
#
# Start Scraping: Luis Faria
# Serve Page: 155
# Return Page: 155
# Raw Page: 155
# Finish Scraping 2063 players.
# 24525 players remaining.
#
#
# Start Scraping: Vjekoslav Skenderovic
# Serve Page: 35
# Return Page: 35
# Raw Page: 35
# Finish Scraping 2064 players.
# 24524 players remaining.
#
#
# Start Scraping: Tomas Catar
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 2065 players.
# 24523 players remaining.
#
#
# Start Scraping: Maxime Boye
# Serve Page: 25
# Return Page: 25
# Raw Page: 25
# Finish Scraping 2066 players.
# 24522 players remaining.
#
#
# Start Scraping: Matthias Muller
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 2067 players.
# 24521 players remaining.
#
#
# Start Scraping: German Lopez
# Serve Page: 308
# Return Page: 308
# Raw Page: 308
# Finish Scraping 2068 players.
# 24520 players remaining.
#
#
# Start Scraping: Jonas Merckx
# Serve Page: 309
# Return Page: 309
# Raw Page: 309
# Finish Scraping 2069 players.
# 24519 players remaining.
#
#
# Start Scraping: Andre Gaspar Murta
# Serve Page: 309
# Return Page: 309
# Raw Page: 309
# Finish Scraping 2070 players.
# 24518 players remaining.
#
#
# Start Scraping: Ludovic Walter
# Serve Page: 307
# Return Page: 307
# Raw Page: 307
# Finish Scraping 2071 players.
# 24517 players remaining.
#
#
# Start Scraping: Orest Tereshchuk
# Serve Page: 123
# Return Page: 123
# Raw Page: 123
# Finish Scraping 2072 players.
# 24516 players remaining.
#
#
# Start Scraping: Cedric Kauffmann
# Serve Page: 70
# Return Page: 70
# Raw Page: 70
# Finish Scraping 2073 players.
# 24515 players remaining.
#
#
# Start Scraping: Andreas Maurer
# Serve Page: 262
# Return Page: 262
# Raw Page: 262
# Finish Scraping 2074 players.
# 24514 players remaining.
#
#
# Start Scraping: Gauthier Onclin
# Serve Page: 185
# Return Page: 185
# Raw Page: 185
# Finish Scraping 2075 players.
# 24513 players remaining.
#
#
# Start Scraping: Dusty H Boyer
# Serve Page: 154
# Return Page: 154
# Raw Page: 154
# Finish Scraping 2076 players.
# 24512 players remaining.
#
#
# Start Scraping: Gilbert Soares Klier Junior
# Serve Page: 154
# Return Page: 154
# Raw Page: 154
# Finish Scraping 2077 players.
# 24511 players remaining.
#
#
# Start Scraping: Ivan Arenas Gualda
# Serve Page: 300
# Return Page: 300
# Raw Page: 300
# Finish Scraping 2078 players.
# 24510 players remaining.
#
#
# Start Scraping: Florian Fallert
# Serve Page: 307
# Return Page: 307
# Raw Page: 307
# Finish Scraping 2079 players.
# 24509 players remaining.
#
#
# Start Scraping: Nikos Rovas
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 2080 players.
# 24508 players remaining.
#
#
# Start Scraping: Mike Estep
# Serve Page: 310
# Return Page: 310
# Raw Page: 310
# Finish Scraping 2081 players.
# 24507 players remaining.
#
#
# Start Scraping: Alan Kohen
# Serve Page: 153
# Return Page: 153
# Raw Page: 153
# Finish Scraping 2082 players.
# 24506 players remaining.
#
#
# Start Scraping: Martin Rios Benitez
# Serve Page: 153
# Return Page: 153
# Raw Page: 153
# Finish Scraping 2083 players.
# 24505 players remaining.
#
#
# Start Scraping: Florin Mergea
# Serve Page: 300
# Return Page: 300
# Raw Page: 300
# Finish Scraping 2084 players.
# 24504 players remaining.
#
#
# Start Scraping: Andres Schneiter
# Serve Page: 42
# Return Page: 42
# Raw Page: 42
# Finish Scraping 2085 players.
# 24503 players remaining.
#
#
# Start Scraping: Ville Liukko
# Serve Page: 90
# Return Page: 90
# Raw Page: 90
# Finish Scraping 2086 players.
# 24502 players remaining.
#
#
# Start Scraping: Andrew Richardson
# Serve Page: 89
# Return Page: 89
# Raw Page: 89
# Finish Scraping 2087 players.
# 24501 players remaining.
#
#
# Start Scraping: Colin Beecher
# Serve Page: 26
# Return Page: 26
# Raw Page: 26
# Finish Scraping 2088 players.
# 24500 players remaining.
#
#
# Start Scraping: Milan Srejber
# Serve Page: 260
# Return Page: 260
# Raw Page: 260
# Finish Scraping 2089 players.
# 24499 players remaining.
#
#
# Start Scraping: Romain Barbosa
# Serve Page: 305
# Return Page: 305
# Raw Page: 305
# Finish Scraping 2090 players.
# 24498 players remaining.
#
#
# Start Scraping: Mariano Delfino
# Serve Page: 164
# Return Page: 164
# Raw Page: 164
# Finish Scraping 2091 players.
# 24497 players remaining.
#
#
# Start Scraping: Jose Imaz Ruiz
# Serve Page: 66
# Return Page: 66
# Raw Page: 66
# Finish Scraping 2092 players.
# 24496 players remaining.
#
#
# Start Scraping: David Nainkin
# Serve Page: 229
# Return Page: 229
# Raw Page: 229
# Finish Scraping 2093 players.
# 24495 players remaining.
#
#
# Start Scraping: Alexander Donski
# Serve Page: 171
# Return Page: 171
# Raw Page: 171
# Finish Scraping 2094 players.
# 24494 players remaining.
#
#
# Start Scraping: Joaquin Jesus Monteferrario
# Serve Page: 222
# Return Page: 222
# Raw Page: 222
# Finish Scraping 2095 players.
# 24493 players remaining.
#
#
# Start Scraping: Fabio Maggi
# Serve Page: 65
# Return Page: 65
# Raw Page: 65
# Finish Scraping 2096 players.
# 24492 players remaining.
#
#
# Start Scraping: Jhonnatan Medina Alvarez
# Serve Page: 25
# Return Page: 25
# Raw Page: 25
# Finish Scraping 2097 players.
# 24491 players remaining.
#
#
# Start Scraping: Andrei Ciumac
# Serve Page: 226
# Return Page: 226
# Raw Page: 226
# Finish Scraping 2098 players.
# 24490 players remaining.
#
#
# Start Scraping: Eric Nunez
# Serve Page: 144
# Return Page: 144
# Raw Page: 144
# Finish Scraping 2099 players.
# 24489 players remaining.
#
#
# Start Scraping: Guillermo Carry
# Serve Page: 59
# Return Page: 59
# Raw Page: 59
# Finish Scraping 2100 players.
# 24488 players remaining.
#
#
# Start Scraping: Nathan Healey
# Serve Page: 160
# Return Page: 160
# Raw Page: 160
# Finish Scraping 2101 players.
# 24487 players remaining.
#
#
# Start Scraping: Eduardo Medica
# Serve Page: 94
# Return Page: 94
# Raw Page: 94
# Finish Scraping 2102 players.
# 24486 players remaining.
#
#
# Start Scraping: Jozsef Krocsko
# Serve Page: 159
# Return Page: 159
# Raw Page: 159
# Finish Scraping 2103 players.
# 24485 players remaining.
#
#
# Start Scraping: Goran Prpic
# Serve Page: 262
# Return Page: 262
# Raw Page: 262
# Finish Scraping 2104 players.
# 24484 players remaining.
#
#
# Start Scraping: John Feaver
# Serve Page: 303
# Return Page: 303
# Raw Page: 303
# Finish Scraping 2105 players.
# 24483 players remaining.
#
#
# Start Scraping: Omni Kumar
# Serve Page: 167
# Return Page: 167
# Raw Page: 167
# Finish Scraping 2106 players.
# 24482 players remaining.
#
#
# Start Scraping: Franco Feitt
# Serve Page: 151
# Return Page: 151
# Raw Page: 151
# Finish Scraping 2107 players.
# 24481 players remaining.
#
#
# Start Scraping: Vlad Victor Cornea
# Serve Page: 157
# Return Page: 157
# Raw Page: 157
# Finish Scraping 2108 players.
# 24480 players remaining.
#
#
# Start Scraping: Hong Chung
# Serve Page: 154
# Return Page: 154
# Raw Page: 154
# Finish Scraping 2109 players.
# 24479 players remaining.
#
#
# Start Scraping: David Agung Susanto
# Serve Page: 151
# Return Page: 151
# Raw Page: 151
# Finish Scraping 2110 players.
# 24478 players remaining.
#
#
# Start Scraping: Simon Larose
# Serve Page: 80
# Return Page: 80
# Raw Page: 80
# Finish Scraping 2111 players.
# 24477 players remaining.
#
#
# Start Scraping: Florian Allgauer
# Serve Page: 73
# Return Page: 73
# Raw Page: 73
# Finish Scraping 2112 players.
# 24476 players remaining.
#
#
# Start Scraping: Xavier Pujo
# Serve Page: 26
# Return Page: 26
# Raw Page: 26
# Finish Scraping 2113 players.
# 24475 players remaining.
#
#
# Start Scraping: Rayane Roumane
# Serve Page: 149
# Return Page: 149
# Raw Page: 149
# Finish Scraping 2114 players.
# 24474 players remaining.
#
#
# Start Scraping: Aaron Addison
# Serve Page: 156
# Return Page: 156
# Raw Page: 156
# Finish Scraping 2115 players.
# 24473 players remaining.
#
#
# Start Scraping: Gerardo Lopez Villasenor
# Serve Page: 152
# Return Page: 152
# Raw Page: 152
# Finish Scraping 2116 players.
# 24472 players remaining.
#
#
# Start Scraping: Dino Marcan
# Serve Page: 299
# Return Page: 299
# Raw Page: 299
# Finish Scraping 2117 players.
# 24471 players remaining.
#
#
# Start Scraping: Martin Slanar
# Serve Page: 96
# Return Page: 96
# Raw Page: 96
# Finish Scraping 2118 players.
# 24470 players remaining.
#
#
# Start Scraping: Diego Del Rio
# Serve Page: 37
# Return Page: 37
# Raw Page: 37
# Finish Scraping 2119 players.
# 24469 players remaining.
#
#
# Start Scraping: Roberto Azar
# Serve Page: 253
# Return Page: 253
# Raw Page: 253
# Finish Scraping 2120 players.
# 24468 players remaining.
#
#
# Start Scraping: David Estruch
# Serve Page: 195
# Return Page: 195
# Raw Page: 195
# Finish Scraping 2121 players.
# 24467 players remaining.
#
#
# Start Scraping: Vladimir Platenik
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 2122 players.
# 24466 players remaining.
#
#
# Start Scraping: Andrew Foster
# Serve Page: 58
# Return Page: 58
# Raw Page: 58
# Finish Scraping 2123 players.
# 24465 players remaining.
#
#
# Start Scraping: Richard Matuszewski
# Serve Page: 261
# Return Page: 261
# Raw Page: 261
# Finish Scraping 2124 players.
# 24464 players remaining.
#
#
# Start Scraping: Henrik Sundstrom
# Serve Page: 299
# Return Page: 299
# Raw Page: 299
# Finish Scraping 2125 players.
# 24463 players remaining.
#
#
# Start Scraping: Nicola Spear
# Serve Page: 310
# Return Page: 310
# Raw Page: 310
# Finish Scraping 2126 players.
# 24462 players remaining.
#
#
# Start Scraping: Juan Alejandro Hernandez Serrano
# Serve Page: 148
# Return Page: 148
# Raw Page: 148
# Finish Scraping 2127 players.
# 24461 players remaining.
#
#
# Start Scraping: Savriyan Danilov
# Serve Page: 161
# Return Page: 161
# Raw Page: 161
# Finish Scraping 2128 players.
# 24460 players remaining.
#
#
# Start Scraping: Remy Bertola
# Serve Page: 176
# Return Page: 176
# Raw Page: 176
# Finish Scraping 2129 players.
# 24459 players remaining.
#
#
# Start Scraping: Francisco Cabral
# Serve Page: 149
# Return Page: 149
# Raw Page: 149
# Finish Scraping 2130 players.
# 24458 players remaining.
#
#
# Start Scraping: Ivan Liutarevich
# Serve Page: 158
# Return Page: 158
# Raw Page: 158
# Finish Scraping 2131 players.
# 24457 players remaining.
#
#
# Start Scraping: Chris Eaton
# Serve Page: 298
# Return Page: 298
# Raw Page: 298
# Finish Scraping 2132 players.
# 24456 players remaining.
#
#
# Start Scraping: Rodrigo Guidolin
# Serve Page: 17
# Return Page: 17
# Raw Page: 17
# Finish Scraping 2133 players.
# 24455 players remaining.
#
#
# Start Scraping: Ivan Vajda
# Serve Page: 42
# Return Page: 42
# Raw Page: 42
# Finish Scraping 2134 players.
# 24454 players remaining.
#
#
# Start Scraping: Chase Buchanan
# Serve Page: 284
# Return Page: 284
# Raw Page: 284
# Finish Scraping 2135 players.
# 24453 players remaining.
#
#
# Start Scraping: Michael Mcclune
# Serve Page: 127
# Return Page: 127
# Raw Page: 127
# Finish Scraping 2136 players.
# 24452 players remaining.
#
#
# Start Scraping: Gleb Alekseenko
# Serve Page: 296
# Return Page: 296
# Raw Page: 296
# Finish Scraping 2137 players.
# 24451 players remaining.
#
#
# Start Scraping: Jonathan Marray
# Finish Scraping 2138 players.
# 24450 players remaining.
#
#
# Start Scraping: Mario Munoz Bejarano
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 2139 players.
# 24449 players remaining.
#
#
# Start Scraping: David Sherwood
# Serve Page: 50
# Return Page: 50
# Raw Page: 50
# Finish Scraping 2140 players.
# 24448 players remaining.
#
#
# Start Scraping: Claudio Panatta
# Serve Page: 246
# Return Page: 246
# Raw Page: 246
# Finish Scraping 2141 players.
# 24447 players remaining.
#
#
# Start Scraping: Peter Elter
# Serve Page: 297
# Return Page: 297
# Raw Page: 297
# Finish Scraping 2142 players.
# 24446 players remaining.
#
#
# Start Scraping: Antonio Munoz
# Serve Page: 297
# Return Page: 297
# Raw Page: 297
# Finish Scraping 2143 players.
# 24445 players remaining.
#
#
# Start Scraping: Rinky Hijikata
# Serve Page: 170
# Return Page: 170
# Raw Page: 170
# Finish Scraping 2144 players.
# 24444 players remaining.
#
#
# Start Scraping: Stuart Parker
# Serve Page: 166
# Return Page: 166
# Raw Page: 166
# Finish Scraping 2145 players.
# 24443 players remaining.
#
#
# Start Scraping: Marvin Moeller
# Serve Page: 153
# Return Page: 153
# Raw Page: 153
# Finish Scraping 2146 players.
# 24442 players remaining.
#
#
# Start Scraping: Imanol Lopez Morillo
# Serve Page: 169
# Return Page: 169
# Raw Page: 169
# Finish Scraping 2147 players.
# 24441 players remaining.
#
#
# Start Scraping: Petr Hajek
# Serve Page: 148
# Return Page: 148
# Raw Page: 148
# Finish Scraping 2148 players.
# 24440 players remaining.
#
#
# Start Scraping: Marek Jaloviec
# Serve Page: 296
# Return Page: 296
# Raw Page: 296
# Finish Scraping 2149 players.
# 24439 players remaining.
#
#
# Start Scraping: Joffrey De Schepper
# Serve Page: 148
# Return Page: 148
# Raw Page: 148
# Finish Scraping 2150 players.
# 24438 players remaining.
#
#
# Start Scraping: Dennis Nevolo
# Serve Page: 285
# Return Page: 285
# Raw Page: 285
# Finish Scraping 2151 players.
# 24437 players remaining.
#
#
# Start Scraping: Ryler Deheart
# Serve Page: 292
# Return Page: 292
# Raw Page: 292
# Finish Scraping 2152 players.
# 24436 players remaining.
#
#
# Start Scraping: Jonathan Gonzalia
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 2153 players.
# 24435 players remaining.
#
#
# Start Scraping: Dmitri Sitak
# Serve Page: 296
# Return Page: 296
# Raw Page: 296
# Finish Scraping 2154 players.
# 24434 players remaining.
#
#
# Start Scraping: Massimo Ardinghi
# Serve Page: 106
# Return Page: 106
# Raw Page: 106
# Finish Scraping 2155 players.
# 24433 players remaining.
#
#
# Start Scraping: Raphael Baltensperger
# Serve Page: 147
# Return Page: 147
# Raw Page: 147
# Finish Scraping 2156 players.
# 24432 players remaining.
#
#
# Start Scraping: Nicolas Meister
# Serve Page: 295
# Return Page: 295
# Raw Page: 295
# Finish Scraping 2157 players.
# 24431 players remaining.
#
#
# Start Scraping: Sanam Singh
# Serve Page: 292
# Return Page: 292
# Raw Page: 292
# Finish Scraping 2158 players.
# 24430 players remaining.
#
#
# Start Scraping: Owen Casey
# Serve Page: 36
# Return Page: 36
# Raw Page: 36
# Finish Scraping 2159 players.
# 24429 players remaining.
#
#
# Start Scraping: Jonathan Canter
# Serve Page: 294
# Return Page: 294
# Raw Page: 294
# Finish Scraping 2160 players.
# 24428 players remaining.
#
#
# Start Scraping: Eddie Edwards
# Serve Page: 294
# Return Page: 294
# Raw Page: 294
# Finish Scraping 2161 players.
# 24427 players remaining.
#
#
# Start Scraping: Victor Baluda
# Serve Page: 293
# Return Page: 293
# Raw Page: 293
# Finish Scraping 2162 players.
# 24426 players remaining.
#
#
# Start Scraping: Arsenije Zlatanovic
# Serve Page: 293
# Return Page: 293
# Raw Page: 293
# Finish Scraping 2163 players.
# 24425 players remaining.
#
#
# Start Scraping: Mattia Livraghi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 2164 players.
# 24424 players remaining.
#
#
# Start Scraping: Patrik Langvardt
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 2165 players.
# 24423 players remaining.
#
#
# Start Scraping: Jared Palmer
# Serve Page: 283
# Return Page: 283
# Raw Page: 283
# Finish Scraping 2166 players.
# 24422 players remaining.
#
#
# Start Scraping: Geoff Grant
# Serve Page: 168
# Return Page: 168
# Raw Page: 168
# Finish Scraping 2167 players.
# 24421 players remaining.
#
#
# Start Scraping: Robbie Weiss
# Serve Page: 261
# Return Page: 261
# Raw Page: 261
# Finish Scraping 2168 players.
# 24420 players remaining.
#
#
# Start Scraping: Emilio Nava
# Serve Page: 167
# Return Page: 167
# Raw Page: 167
# Finish Scraping 2169 players.
# 24419 players remaining.
#
#
# Start Scraping: Maxime Mora
# Serve Page: 164
# Return Page: 164
# Raw Page: 164
# Finish Scraping 2170 players.
# 24418 players remaining.
#
#
# Start Scraping: Alexios Halebian
# Serve Page: 282
# Return Page: 282
# Raw Page: 282
# Finish Scraping 2171 players.
# 24417 players remaining.
#
#
# Start Scraping: Rainer Falenti
# Serve Page: 58
# Return Page: 58
# Raw Page: 58
# Finish Scraping 2172 players.
# 24416 players remaining.
#
#
# Start Scraping: Kjell Johansson
# Serve Page: 292
# Return Page: 292
# Raw Page: 292
# Finish Scraping 2173 players.
# 24415 players remaining.
#
#
# Start Scraping: Dennis Ralston
# Serve Page: 367
# Return Page: 367
# Raw Page: 367
# Finish Scraping 2174 players.
# 24414 players remaining.
#
#
# Start Scraping: Yuuya Kibi
# Serve Page: 291
# Return Page: 291
# Raw Page: 291
# Finish Scraping 2175 players.
# 24413 players remaining.
#
#
# Start Scraping: Jan Stancik
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 2176 players.
# 24412 players remaining.
#
#
# Start Scraping: Phillip King
# Serve Page: 117
# Return Page: 117
# Raw Page: 117
# Finish Scraping 2177 players.
# 24411 players remaining.
#
#
# Start Scraping: Frederic Jeanclaude
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 2178 players.
# 24410 players remaining.
#
#
# Start Scraping: Silvio Scaiola
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 2179 players.
# 24409 players remaining.
#
#
# Start Scraping: Darren Cahill
# Serve Page: 291
# Return Page: 291
# Raw Page: 291
# Finish Scraping 2180 players.
# 24408 players remaining.
#
#
# Start Scraping: Peter Feigl
# Serve Page: 291
# Return Page: 291
# Raw Page: 291
# Finish Scraping 2181 players.
# 24407 players remaining.
#
#
# Start Scraping: Christoffer Solberg
# Serve Page: 145
# Return Page: 145
# Raw Page: 145
# Finish Scraping 2182 players.
# 24406 players remaining.
#
#
# Start Scraping: Juraj Hasko
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 2183 players.
# 24405 players remaining.
#
#
# Start Scraping: Gabriel Markus
# Serve Page: 258
# Return Page: 258
# Raw Page: 258
# Finish Scraping 2184 players.
# 24404 players remaining.
#
#
# Start Scraping: Johan Carlsson
# Serve Page: 218
# Return Page: 218
# Raw Page: 218
# Finish Scraping 2185 players.
# 24403 players remaining.
#
#
# Start Scraping: Todd Witsken
# Serve Page: 272
# Return Page: 272
# Raw Page: 272
# Finish Scraping 2186 players.
# 24402 players remaining.
#
#
# Start Scraping: Marcos Hocevar
# Serve Page: 203
# Return Page: 203
# Raw Page: 203
# Finish Scraping 2187 players.
# 24401 players remaining.
#
#
# Start Scraping: Mike Cahill
# Serve Page: 290
# Return Page: 290
# Raw Page: 290
# Finish Scraping 2188 players.
# 24400 players remaining.
#
#
# Start Scraping: Sascha Bandermann
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 2189 players.
# 24399 players remaining.
#
#
# Start Scraping: Markus Zillner
# Serve Page: 93
# Return Page: 93
# Raw Page: 93
# Finish Scraping 2190 players.
# 24398 players remaining.
#
#
# Start Scraping: Jan Apell
# Serve Page: 260
# Return Page: 260
# Raw Page: 260
# Finish Scraping 2191 players.
# 24397 players remaining.
#
#
# Start Scraping: Rolf Gehring
# Serve Page: 289
# Return Page: 289
# Raw Page: 289
# Finish Scraping 2192 players.
# 24396 players remaining.
#
#
# Start Scraping: Caio Silva
# Serve Page: 288
# Return Page: 288
# Raw Page: 288
# Finish Scraping 2193 players.
# 24395 players remaining.
#
#
# Start Scraping: Bruno Rodriguez
# Serve Page: 38
# Return Page: 38
# Raw Page: 38
# Finish Scraping 2194 players.
# 24394 players remaining.
#
#
# Start Scraping: Xavier Audouy
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 2195 players.
# 24393 players remaining.
#
#
# Start Scraping: Francisco Cabello
# Serve Page: 126
# Return Page: 126
# Raw Page: 126
# Finish Scraping 2196 players.
# 24392 players remaining.
#
#
# Start Scraping: Lawson Duncan
# Serve Page: 288
# Return Page: 288
# Raw Page: 288
# Finish Scraping 2197 players.
# 24391 players remaining.
#
#
# Start Scraping: Bartolome Salva Vidal
# Serve Page: 33
# Return Page: 33
# Raw Page: 33
# Finish Scraping 2198 players.
# 24390 players remaining.
#
#
# Start Scraping: Alejandro Kon
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 2199 players.
# 24389 players remaining.
#
#
# Start Scraping: Alessandro Accardo
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 2200 players.
# 24388 players remaining.
#
#
# Start Scraping: Christian Magg
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 2201 players.
# 24387 players remaining.
#
#
# Start Scraping: Nicolas Tourte
# Serve Page: 59
# Return Page: 59
# Raw Page: 59
# Finish Scraping 2202 players.
# 24386 players remaining.
#
#
# Start Scraping: Zoltan Nagy
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 2203 players.
# 24385 players remaining.
#
#
# Start Scraping: Nicola Bruno
# Serve Page: 149
# Return Page: 149
# Raw Page: 149
# Finish Scraping 2204 players.
# 24384 players remaining.
#
#
# Start Scraping: Matteo Arnaldi
# Serve Page: 178
# Return Page: 178
# Raw Page: 178
# Finish Scraping 2205 players.
# 24383 players remaining.
#
#
# Start Scraping: Patrick Kypson
# Serve Page: 164
# Return Page: 164
# Raw Page: 164
# Finish Scraping 2206 players.
# 24382 players remaining.
#
#
# Start Scraping: Alberto Barroso Campos
# Serve Page: 158
# Return Page: 158
# Raw Page: 158
# Finish Scraping 2207 players.
# 24381 players remaining.
#
#
# Start Scraping: Kazuma Kawachi
# Serve Page: 159
# Return Page: 159
# Raw Page: 159
# Finish Scraping 2208 players.
# 24380 players remaining.
#
#
# Start Scraping: Vijay Kannan
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 2209 players.
# 24379 players remaining.
#
#
# Start Scraping: Victor Romero
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 2210 players.
# 24378 players remaining.
#
#
# Start Scraping: Scott Barron
# Serve Page: 39
# Return Page: 39
# Raw Page: 39
# Finish Scraping 2211 players.
# 24377 players remaining.
#
#
# Start Scraping: Andrei Vasilevski
# Serve Page: 284
# Return Page: 284
# Raw Page: 284
# Finish Scraping 2212 players.
# 24376 players remaining.
#
#
# Start Scraping: Rafael Camilo
# Serve Page: 172
# Return Page: 172
# Raw Page: 172
# Finish Scraping 2213 players.
# 24375 players remaining.
#
#
# Start Scraping: Jae Sung An
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 2214 players.
# 24374 players remaining.
#
#
# Start Scraping: Brian Baker
# Serve Page: 274
# Return Page: 274
# Raw Page: 274
# Finish Scraping 2215 players.
# 24373 players remaining.
#
#
# Start Scraping: Philipp Marx
# Finish Scraping 2216 players.
# 24372 players remaining.
#
#
# Start Scraping: Chuck Adams
# Serve Page: 261
# Return Page: 261
# Raw Page: 261
# Finish Scraping 2217 players.
# 24371 players remaining.
#
#
# Start Scraping: Damir Keretic
# Serve Page: 219
# Return Page: 219
# Raw Page: 219
# Finish Scraping 2218 players.
# 24370 players remaining.
#
#
# Start Scraping: Milan Holecek
# Serve Page: 308
# Return Page: 308
# Raw Page: 308
# Finish Scraping 2219 players.
# 24369 players remaining.
#
#
# Start Scraping: Arnaud Bovy
# Serve Page: 147
# Return Page: 147
# Raw Page: 147
# Finish Scraping 2220 players.
# 24368 players remaining.
#
#
# Start Scraping: Ugo Blanchet
# Serve Page: 167
# Return Page: 167
# Raw Page: 167
# Finish Scraping 2221 players.
# 24367 players remaining.
#
#
# Start Scraping: Guy Den Heijer
# Serve Page: 144
# Return Page: 144
# Raw Page: 144
# Finish Scraping 2222 players.
# 24366 players remaining.
#
#
# Start Scraping: David Volfson
# Serve Page: 142
# Return Page: 142
# Raw Page: 142
# Finish Scraping 2223 players.
# 24365 players remaining.
#
#
# Start Scraping: Sagadat Ayap
# Serve Page: 142
# Return Page: 142
# Raw Page: 142
# Finish Scraping 2224 players.
# 24364 players remaining.
#
#
# Start Scraping: Dmitry Vlasov
# Serve Page: 110
# Return Page: 110
# Raw Page: 110
# Finish Scraping 2225 players.
# 24363 players remaining.
#
#
# Start Scraping: Ignacio Gonzalez King
# Serve Page: 70
# Return Page: 70
# Raw Page: 70
# Finish Scraping 2226 players.
# 24362 players remaining.
#
#
# Start Scraping: Rod Frawley
# Serve Page: 285
# Return Page: 285
# Raw Page: 285
# Finish Scraping 2227 players.
# 24361 players remaining.
#
#
# Start Scraping: Pietro Licciardi
# Serve Page: 283
# Return Page: 283
# Raw Page: 283
# Finish Scraping 2228 players.
# 24360 players remaining.
#
#
# Start Scraping: Vladimir Pavicevic
# Serve Page: 27
# Return Page: 27
# Raw Page: 27
# Finish Scraping 2229 players.
# 24359 players remaining.
#
#
# Start Scraping: Michael Geserer
# Serve Page: 97
# Return Page: 97
# Raw Page: 97
# Finish Scraping 2230 players.
# 24358 players remaining.
#
#
# Start Scraping: Yanki Erel
# Serve Page: 158
# Return Page: 158
# Raw Page: 158
# Finish Scraping 2231 players.
# 24357 players remaining.
#
#
# Start Scraping: Benjamin Winter Lopez
# Serve Page: 159
# Return Page: 159
# Raw Page: 159
# Finish Scraping 2232 players.
# 24356 players remaining.
#
#
# Start Scraping: Gorazd Srbljak
# Serve Page: 148
# Return Page: 148
# Raw Page: 148
# Finish Scraping 2233 players.
# 24355 players remaining.
#
#
# Start Scraping: Alejandro Aramburu Acuna
# Serve Page: 26
# Return Page: 26
# Raw Page: 26
# Finish Scraping 2234 players.
# 24354 players remaining.
#
#
# Start Scraping: Guillem Burniol
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 2235 players.
# 24353 players remaining.
#
#
# Start Scraping: Rabie Chaki
# Serve Page: 34
# Return Page: 34
# Raw Page: 34
# Finish Scraping 2236 players.
# 24352 players remaining.
#
#
# Start Scraping: Artem Derepasko
# Serve Page: 78
# Return Page: 78
# Raw Page: 78
# Finish Scraping 2237 players.
# 24351 players remaining.
#
#
# Start Scraping: Yu Zhang
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 2238 players.
# 24350 players remaining.
#
#
# Start Scraping: Tomislav Ternar
# Serve Page: 244
# Return Page: 244
# Raw Page: 244
# Finish Scraping 2239 players.
# 24349 players remaining.
#
#
# Start Scraping: Thomas Blake
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 2240 players.
# 24348 players remaining.
#
#
# Start Scraping: Francisco Rodriguez
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 2241 players.
# 24347 players remaining.
#
#
# Start Scraping: Lars Koslowski
# Serve Page: 270
# Return Page: 270
# Raw Page: 270
# Finish Scraping 2242 players.
# 24346 players remaining.
#
#
# Start Scraping: Butch Walts
# Serve Page: 281
# Return Page: 281
# Raw Page: 281
# Finish Scraping 2243 players.
# 24345 players remaining.
#
#
# Start Scraping: Graham Stilwell
# Serve Page: 307
# Return Page: 307
# Raw Page: 307
# Finish Scraping 2244 players.
# 24344 players remaining.
#
#
# Start Scraping: Alejo Lorenzo Lingua Lavallen
# Serve Page: 146
# Return Page: 146
# Raw Page: 146
# Finish Scraping 2245 players.
# 24343 players remaining.
#
#
# Start Scraping: Flavio Cobolli
# Serve Page: 158
# Return Page: 158
# Raw Page: 158
# Finish Scraping 2246 players.
# 24342 players remaining.
#
#
# Start Scraping: Juan Bautista Otegui
# Serve Page: 165
# Return Page: 165
# Raw Page: 165
# Finish Scraping 2247 players.
# 24341 players remaining.
#
#
# Start Scraping: Ondrej Krstev
# Serve Page: 140
# Return Page: 140
# Raw Page: 140
# Finish Scraping 2248 players.
# 24340 players remaining.
#
#
# Start Scraping: Conner Huertas Del Pino
# Serve Page: 156
# Return Page: 156
# Raw Page: 156
# Finish Scraping 2249 players.
# 24339 players remaining.
#
#
# Start Scraping: Nikita Kryvonos
# Serve Page: 153
# Return Page: 153
# Raw Page: 153
# Finish Scraping 2250 players.
# 24338 players remaining.
#
#
# Start Scraping: Mariano Albert Ferrando
# Serve Page: 28
# Return Page: 28
# Raw Page: 28
# Finish Scraping 2251 players.
# 24337 players remaining.
#
#
# Start Scraping: Igor Zelenay
# Serve Page: 280
# Return Page: 280
# Raw Page: 280
# Finish Scraping 2252 players.
# 24336 players remaining.
#
#
# Start Scraping: Kalle Flygt
# Serve Page: 62
# Return Page: 62
# Raw Page: 62
# Finish Scraping 2253 players.
# 24335 players remaining.
#
#
# Start Scraping: Roger Smith
# Serve Page: 246
# Return Page: 246
# Raw Page: 246
# Finish Scraping 2254 players.
# 24334 players remaining.
#
#
# Start Scraping: Dekel Bar
# Serve Page: 279
# Return Page: 279
# Raw Page: 279
# Finish Scraping 2255 players.
# 24333 players remaining.
#
#
# Start Scraping: Dimitar Kutrovsky
# Finish Scraping 2256 players.
# 24332 players remaining.
#
#
# Start Scraping: Andre Begemann
# Serve Page: 279
# Return Page: 279
# Raw Page: 279
# Finish Scraping 2257 players.
# 24331 players remaining.
#
#
# Start Scraping: Michal Navratil
# Serve Page: 33
# Return Page: 33
# Raw Page: 33
# Finish Scraping 2258 players.
# 24330 players remaining.
#
#
# Start Scraping: Brian Vahaly
# Serve Page: 262
# Return Page: 262
# Raw Page: 262
# Finish Scraping 2259 players.
# 24329 players remaining.
#
#
# Start Scraping: Frank Moser
# Finish Scraping 2260 players.
# 24328 players remaining.
#
#
# Start Scraping: Alex Radulescu
# Serve Page: 279
# Return Page: 279
# Raw Page: 279
# Finish Scraping 2261 players.
# 24327 players remaining.
#
#
# Start Scraping: Patrik Fredriksson
# Serve Page: 277
# Return Page: 277
# Raw Page: 277
# Finish Scraping 2262 players.
# 24326 players remaining.
#
#
# Start Scraping: Joao Soares
# Serve Page: 278
# Return Page: 278
# Raw Page: 278
# Finish Scraping 2263 players.
# 24325 players remaining.
#
#
# Start Scraping: Aleksandar Kovacevic
# Serve Page: 162
# Return Page: 162
# Raw Page: 162
# Finish Scraping 2264 players.
# 24324 players remaining.
#
#
# Start Scraping: Valentin Vacherot
# Serve Page: 165
# Return Page: 165
# Raw Page: 165
# Finish Scraping 2265 players.
# 24323 players remaining.
#
#
# Start Scraping: Edoardo Lavagno
# Serve Page: 163
# Return Page: 163
# Raw Page: 163
# Finish Scraping 2266 players.
# 24322 players remaining.
#
#
# Start Scraping: Kenneth Raisma
# Serve Page: 141
# Return Page: 141
# Raw Page: 141
# Finish Scraping 2267 players.
# 24321 players remaining.
#
#
# Start Scraping: Alexis Canter
# Serve Page: 141
# Return Page: 141
# Raw Page: 141
# Finish Scraping 2268 players.
# 24320 players remaining.
#
#
# Start Scraping: Miguel Semmler
# Serve Page: 278
# Return Page: 278
# Raw Page: 278
# Finish Scraping 2269 players.
# 24319 players remaining.
#
#
# Start Scraping: Leonardo Olguin
# Serve Page: 86
# Return Page: 86
# Raw Page: 86
# Finish Scraping 2270 players.
# 24318 players remaining.
#
#
# Start Scraping: Colin Van Beem
# Serve Page: 278
# Return Page: 278
# Raw Page: 278
# Finish Scraping 2271 players.
# 24317 players remaining.
#
#
# Start Scraping: Florent Diep
# Serve Page: 278
# Return Page: 278
# Raw Page: 278
# Finish Scraping 2272 players.
# 24316 players remaining.
#
#
# Start Scraping: Milos Sekulic
# Serve Page: 278
# Return Page: 278
# Raw Page: 278
# Finish Scraping 2273 players.
# 24315 players remaining.
#
#
# Start Scraping: Reda El Amrani
# Serve Page: 280
# Return Page: 280
# Raw Page: 280
# Finish Scraping 2274 players.
# 24314 players remaining.
#
#
# Start Scraping: Juan Manuel Elizondo
# Serve Page: 31
# Return Page: 31
# Raw Page: 31
# Finish Scraping 2275 players.
# 24313 players remaining.
#
#
# Start Scraping: Baptiste Dupuy
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 2276 players.
# 24312 players remaining.
#
#
# Start Scraping: Jun Kato
# Serve Page: 27
# Return Page: 27
# Raw Page: 27
# Finish Scraping 2277 players.
# 24311 players remaining.
#
#
# Start Scraping: Andres Dellatorre
# Serve Page: 73
# Return Page: 73
# Raw Page: 73
# Finish Scraping 2278 players.
# 24310 players remaining.
#
#
# Start Scraping: Julien Cuaz
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 2279 players.
# 24309 players remaining.
#
#
# Start Scraping: Roberto Arguello
# Serve Page: 278
# Return Page: 278
# Raw Page: 278
# Finish Scraping 2280 players.
# 24308 players remaining.
#
#
# Start Scraping: Kirill Dmitriev
# Serve Page: 271
# Return Page: 271
# Raw Page: 271
# Finish Scraping 2281 players.
# 24307 players remaining.
#
#
# Start Scraping: Ben Ellwood
# Serve Page: 134
# Return Page: 134
# Raw Page: 134
# Finish Scraping 2282 players.
# 24306 players remaining.
#
#
# Start Scraping: Daniel Orsanic
# Serve Page: 184
# Return Page: 184
# Raw Page: 184
# Finish Scraping 2283 players.
# 24305 players remaining.
#
#
# Start Scraping: Broderick Dyke
# Serve Page: 209
# Return Page: 209
# Raw Page: 209
# Finish Scraping 2284 players.
# 24304 players remaining.
#
#
# Start Scraping: Stefan Simonsson
# Serve Page: 277
# Return Page: 277
# Raw Page: 277
# Finish Scraping 2285 players.
# 24303 players remaining.
#
#
# Start Scraping: Stanislav Birner
# Serve Page: 277
# Return Page: 277
# Raw Page: 277
# Finish Scraping 2286 players.
# 24302 players remaining.
#
#
# Start Scraping: Alexey Zakharov
# Serve Page: 138
# Return Page: 138
# Raw Page: 138
# Finish Scraping 2287 players.
# 24301 players remaining.
#
#
# Start Scraping: Ronnie Schneider
# Serve Page: 138
# Return Page: 138
# Raw Page: 138
# Finish Scraping 2288 players.
# 24300 players remaining.
#
#
# Start Scraping: Robert Rumler
# Serve Page: 137
# Return Page: 137
# Raw Page: 137
# Finish Scraping 2289 players.
# 24299 players remaining.
#
#
# Start Scraping: Adam Kellner
# Serve Page: 276
# Return Page: 276
# Raw Page: 276
# Finish Scraping 2290 players.
# 24298 players remaining.
#
#
# Start Scraping: Konstantin Don Gruber
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 2291 players.
# 24297 players remaining.
#
#
# Start Scraping: Rodrigo Cerdera
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 2292 players.
# 24296 players remaining.
#
#
# Start Scraping: Tom Spinks
# Serve Page: 17
# Return Page: 17
# Raw Page: 17
# Finish Scraping 2293 players.
# 24295 players remaining.
#
#
# Start Scraping: Andy Zingman
# Serve Page: 80
# Return Page: 80
# Raw Page: 80
# Finish Scraping 2294 players.
# 24294 players remaining.
#
#
# Start Scraping: Jaroslav Bulant
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 2295 players.
# 24293 players remaining.
#
#
# Start Scraping: Pablo Martin Adalia
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 2296 players.
# 24292 players remaining.
#
#
# Start Scraping: Anton Zaitsev
# Serve Page: 274
# Return Page: 274
# Raw Page: 274
# Finish Scraping 2297 players.
# 24291 players remaining.
#
#
# Start Scraping: Andy Ram
# Serve Page: 143
# Return Page: 143
# Raw Page: 143
# Finish Scraping 2298 players.
# 24290 players remaining.
#
#
# Start Scraping: Jeff Coetzee
# Serve Page: 84
# Return Page: 84
# Raw Page: 84
# Finish Scraping 2299 players.
# 24289 players remaining.
#
#
# Start Scraping: Vladimir Zednik
# Serve Page: 275
# Return Page: 275
# Raw Page: 275
# Finish Scraping 2300 players.
# 24288 players remaining.
#
#
# Start Scraping: Tadeas Paroulek
# Serve Page: 141
# Return Page: 141
# Raw Page: 141
# Finish Scraping 2301 players.
# 24287 players remaining.
#
#
# Start Scraping: Marko Miladinovic
# Serve Page: 137
# Return Page: 137
# Raw Page: 137
# Finish Scraping 2302 players.
# 24286 players remaining.
#
#
# Start Scraping: Yuki Mochizuki
# Serve Page: 143
# Return Page: 143
# Raw Page: 143
# Finish Scraping 2303 players.
# 24285 players remaining.
#
#
# Start Scraping: Chien Hsun Lo
# Serve Page: 144
# Return Page: 144
# Raw Page: 144
# Finish Scraping 2304 players.
# 24284 players remaining.
#
#
# Start Scraping: Ferran Ventura Martell
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 2305 players.
# 24283 players remaining.
#
#
# Start Scraping: George Von Massow
# Serve Page: 272
# Return Page: 272
# Raw Page: 272
# Finish Scraping 2306 players.
# 24282 players remaining.
#
#
# Start Scraping: Sam Warburg
# Serve Page: 185
# Return Page: 185
# Raw Page: 185
# Finish Scraping 2307 players.
# 24281 players remaining.
#
#
# Start Scraping: Sebastian Fitz
# Serve Page: 35
# Return Page: 35
# Raw Page: 35
# Finish Scraping 2308 players.
# 24280 players remaining.
#
#
# Start Scraping: Mark Merklein
# Serve Page: 102
# Return Page: 102
# Raw Page: 102
# Finish Scraping 2309 players.
# 24279 players remaining.
#
#
# Start Scraping: Mike Bauer
# Serve Page: 273
# Return Page: 273
# Raw Page: 273
# Finish Scraping 2310 players.
# 24278 players remaining.
#
#
# Start Scraping: Mariano Navone
# Serve Page: 164
# Return Page: 164
# Raw Page: 164
# Finish Scraping 2311 players.
# 24277 players remaining.
#
#
# Start Scraping: Koray Kirci
# Serve Page: 149
# Return Page: 149
# Raw Page: 149
# Finish Scraping 2312 players.
# 24276 players remaining.
#
#
# Start Scraping: Alexander Cozbinov
# Serve Page: 164
# Return Page: 164
# Raw Page: 164
# Finish Scraping 2313 players.
# 24275 players remaining.
#
#
# Start Scraping: Andoni Vivanco Guzman
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 2314 players.
# 24274 players remaining.
#
#
# Start Scraping: Mikal Oliver Statham
# Serve Page: 136
# Return Page: 136
# Raw Page: 136
# Finish Scraping 2315 players.
# 24273 players remaining.
#
#
# Start Scraping: Photos Kallias
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 2316 players.
# 24272 players remaining.
#
#
# Start Scraping: Alexandre Strambini
# Serve Page: 50
# Return Page: 50
# Raw Page: 50
# Finish Scraping 2317 players.
# 24271 players remaining.
#
#
# Start Scraping: Roberto Alvarez
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 2318 players.
# 24270 players remaining.
#
#
# Start Scraping: Markus Zoecke
# Serve Page: 249
# Return Page: 249
# Raw Page: 249
# Finish Scraping 2319 players.
# 24269 players remaining.
#
#
# Start Scraping: Duilio Beretta
# Serve Page: 254
# Return Page: 254
# Raw Page: 254
# Finish Scraping 2320 players.
# 24268 players remaining.
#
#
# Start Scraping: Francesco Picco
# Serve Page: 262
# Return Page: 262
# Raw Page: 262
# Finish Scraping 2321 players.
# 24267 players remaining.
#
#
# Start Scraping: Dekel Valtzer
# Serve Page: 28
# Return Page: 28
# Raw Page: 28
# Finish Scraping 2322 players.
# 24266 players remaining.
#
#
# Start Scraping: Ivan Cinkus
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 2323 players.
# 24265 players remaining.
#
#
# Start Scraping: Mathias Hellstrom
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 2324 players.
# 24264 players remaining.
#
#
# Start Scraping: Henrik Andersson
# Serve Page: 28
# Return Page: 28
# Raw Page: 28
# Finish Scraping 2325 players.
# 24263 players remaining.
#
#
# Start Scraping: Giuseppe Menga
# Serve Page: 271
# Return Page: 271
# Raw Page: 271
# Finish Scraping 2326 players.
# 24262 players remaining.
#
#
# Start Scraping: Massimo Valeri
# Serve Page: 114
# Return Page: 114
# Raw Page: 114
# Finish Scraping 2327 players.
# 24261 players remaining.
#
#
# Start Scraping: Belus Prajoux
# Serve Page: 271
# Return Page: 271
# Raw Page: 271
# Finish Scraping 2328 players.
# 24260 players remaining.
#
#
# Start Scraping: Alibek Kachmazov
# Serve Page: 153
# Return Page: 153
# Raw Page: 153
# Finish Scraping 2329 players.
# 24259 players remaining.
#
#
# Start Scraping: Dane Sweeny
# Serve Page: 164
# Return Page: 164
# Raw Page: 164
# Finish Scraping 2330 players.
# 24258 players remaining.
#
#
# Start Scraping: Benjamin Pietri
# Serve Page: 142
# Return Page: 142
# Raw Page: 142
# Finish Scraping 2331 players.
# 24257 players remaining.
#
#
# Start Scraping: Brandon Holt
# Serve Page: 152
# Return Page: 152
# Raw Page: 152
# Finish Scraping 2332 players.
# 24256 players remaining.
#
#
# Start Scraping: Adrian Obert
# Serve Page: 135
# Return Page: 135
# Raw Page: 135
# Finish Scraping 2333 players.
# 24255 players remaining.
#
#
# Start Scraping: Dante Gennaro
# Serve Page: 270
# Return Page: 270
# Raw Page: 270
# Finish Scraping 2334 players.
# 24254 players remaining.
#
#
# Start Scraping: Alexis Klegou
# Serve Page: 136
# Return Page: 136
# Raw Page: 136
# Finish Scraping 2335 players.
# 24253 players remaining.
#
#
# Start Scraping: Yves Allegro
# Serve Page: 99
# Return Page: 99
# Raw Page: 99
# Finish Scraping 2336 players.
# 24252 players remaining.
#
#
# Start Scraping: Jose Francisco Altur
# Serve Page: 188
# Return Page: 188
# Raw Page: 188
# Finish Scraping 2337 players.
# 24251 players remaining.
#
#
# Start Scraping: Byron Bertram
# Serve Page: 272
# Return Page: 272
# Raw Page: 272
# Finish Scraping 2338 players.
# 24250 players remaining.
#
#
# Start Scraping: Maximilian Abel
# Finish Scraping 2339 players.
# 24249 players remaining.
#
#
# Start Scraping: Young Jun Kim
# Serve Page: 35
# Return Page: 35
# Raw Page: 35
# Finish Scraping 2340 players.
# 24248 players remaining.
#
#
# Start Scraping: Bobby Kokavec
# Serve Page: 56
# Return Page: 56
# Raw Page: 56
# Finish Scraping 2341 players.
# 24247 players remaining.
#
#
# Start Scraping: Gianni Ocleppo
# Serve Page: 269
# Return Page: 269
# Raw Page: 269
# Finish Scraping 2342 players.
# 24246 players remaining.
#
#
# Start Scraping: Naoki Tajima
# Serve Page: 139
# Return Page: 139
# Raw Page: 139
# Finish Scraping 2343 players.
# 24245 players remaining.
#
#
# Start Scraping: Filip Duda
# Serve Page: 140
# Return Page: 140
# Raw Page: 140
# Finish Scraping 2344 players.
# 24244 players remaining.
#
#
# Start Scraping: Matthew Christopher Romios
# Serve Page: 134
# Return Page: 134
# Raw Page: 134
# Finish Scraping 2345 players.
# 24243 players remaining.
#
#
# Start Scraping: Yassine Idmbarek
# Serve Page: 161
# Return Page: 161
# Raw Page: 161
# Finish Scraping 2346 players.
# 24242 players remaining.
#
#
# Start Scraping: Ilia Kushev
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 2347 players.
# 24241 players remaining.
#
#
# Start Scraping: Adolf Musil
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 2348 players.
# 24240 players remaining.
#
#
# Start Scraping: Roman Recarte
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 2349 players.
# 24239 players remaining.
#
#
# Start Scraping: Christopher Kas
# Serve Page: 57
# Return Page: 57
# Raw Page: 57
# Finish Scraping 2350 players.
# 24238 players remaining.
#
#
# Start Scraping: Ben Qiang Zhu
# Serve Page: 31
# Return Page: 31
# Raw Page: 31
# Finish Scraping 2351 players.
# 24237 players remaining.
#
#
# Start Scraping: Olivier Malcor
# Serve Page: 71
# Return Page: 71
# Raw Page: 71
# Finish Scraping 2352 players.
# 24236 players remaining.
#
#
# Start Scraping: Juan Bautista Torres
# Serve Page: 146
# Return Page: 146
# Raw Page: 146
# Finish Scraping 2353 players.
# 24235 players remaining.
#
#
# Start Scraping: Anton Matusevich
# Serve Page: 141
# Return Page: 141
# Raw Page: 141
# Finish Scraping 2354 players.
# 24234 players remaining.
#
#
# Start Scraping: Ken Onishi
# Serve Page: 133
# Return Page: 133
# Raw Page: 133
# Finish Scraping 2355 players.
# 24233 players remaining.
#
#
# Start Scraping: Dusan Karol
# Serve Page: 17
# Return Page: 17
# Raw Page: 17
# Finish Scraping 2356 players.
# 24232 players remaining.
#
#
# Start Scraping: Diego Cristin
# Serve Page: 16
# Return Page: 16
# Raw Page: 16
# Finish Scraping 2357 players.
# 24231 players remaining.
#
#
# Start Scraping: Thomas Schiessling
# Serve Page: 255
# Return Page: 255
# Raw Page: 255
# Finish Scraping 2358 players.
# 24230 players remaining.
#
#
# Start Scraping: Marco Osorio
# Serve Page: 57
# Return Page: 57
# Raw Page: 57
# Finish Scraping 2359 players.
# 24229 players remaining.
#
#
# Start Scraping: Xavier Daufresne
# Serve Page: 182
# Return Page: 182
# Raw Page: 182
# Finish Scraping 2360 players.
# 24228 players remaining.
#
#
# Start Scraping: Joaquin Loyo Mayo
# Serve Page: 275
# Return Page: 275
# Raw Page: 275
# Finish Scraping 2361 players.
# 24227 players remaining.
#
#
# Start Scraping: Carlos Cuadrado
# Serve Page: 69
# Return Page: 69
# Raw Page: 69
# Finish Scraping 2362 players.
# 24226 players remaining.
#
#
# Start Scraping: Vincent Van Patten
# Serve Page: 265
# Return Page: 265
# Raw Page: 265
# Finish Scraping 2363 players.
# 24225 players remaining.
#
#
# Start Scraping: Luciano Darderi
# Serve Page: 142
# Return Page: 142
# Raw Page: 142
# Finish Scraping 2364 players.
# 24224 players remaining.
#
#
# Start Scraping: Dalibor Svrcina
# Serve Page: 143
# Return Page: 143
# Raw Page: 143
# Finish Scraping 2365 players.
# 24223 players remaining.
#
#
# Start Scraping: Luca Potenza
# Serve Page: 152
# Return Page: 152
# Raw Page: 152
# Finish Scraping 2366 players.
# 24222 players remaining.
#
#
# Start Scraping: Jurgen Briand
# Serve Page: 153
# Return Page: 153
# Raw Page: 153
# Finish Scraping 2367 players.
# 24221 players remaining.
#
#
# Start Scraping: Rodrigo Antonio Grilli
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 2368 players.
# 24220 players remaining.
#
#
# Start Scraping: Andrew Coelho
# Serve Page: 53
# Return Page: 53
# Raw Page: 53
# Finish Scraping 2369 players.
# 24219 players remaining.
#
#
# Start Scraping: Lesley Joseph
# Serve Page: 69
# Return Page: 69
# Raw Page: 69
# Finish Scraping 2370 players.
# 24218 players remaining.
#
#
# Start Scraping: Charles Edouard Maria
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 2371 players.
# 24217 players remaining.
#
#
# Start Scraping: Andrei Rybalko
# Serve Page: 57
# Return Page: 57
# Raw Page: 57
# Finish Scraping 2372 players.
# 24216 players remaining.
#
#
# Start Scraping: Marcelo Ingaramo
# Serve Page: 184
# Return Page: 184
# Raw Page: 184
# Finish Scraping 2373 players.
# 24215 players remaining.
#
#
# Start Scraping: Ronaldo Carvalho
# Serve Page: 18
# Return Page: 18
# Raw Page: 18
# Finish Scraping 2374 players.
# 24214 players remaining.
#
#
# Start Scraping: Walid Jallali
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 2375 players.
# 24213 players remaining.
#
#
# Start Scraping: Jamie Holmes
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 2376 players.
# 24212 players remaining.
#
#
# Start Scraping: Arne Thoms
# Serve Page: 252
# Return Page: 252
# Raw Page: 252
# Finish Scraping 2377 players.
# 24211 players remaining.
#
#
# Start Scraping: Ryuso Tsujino
# Serve Page: 26
# Return Page: 26
# Raw Page: 26
# Finish Scraping 2378 players.
# 24210 players remaining.
#
#
# Start Scraping: Ricardo Acuna
# Serve Page: 263
# Return Page: 263
# Raw Page: 263
# Finish Scraping 2379 players.
# 24209 players remaining.
#
#
# Start Scraping: Mattia Bellucci
# Serve Page: 153
# Return Page: 153
# Raw Page: 153
# Finish Scraping 2380 players.
# 24208 players remaining.
#
#
# Start Scraping: Marc Rath
# Serve Page: 239
# Return Page: 239
# Raw Page: 239
# Finish Scraping 2381 players.
# 24207 players remaining.
#
#
# Start Scraping: Ilija Vucic
# Serve Page: 262
# Return Page: 262
# Raw Page: 262
# Finish Scraping 2382 players.
# 24206 players remaining.
#
#
# Start Scraping: Oscar Sabate Bretos
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 2383 players.
# 24205 players remaining.
#
#
# Start Scraping: Vasco Goncalves
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 2384 players.
# 24204 players remaining.
#
#
# Start Scraping: Martijn Belgraver
# Serve Page: 29
# Return Page: 29
# Raw Page: 29
# Finish Scraping 2385 players.
# 24203 players remaining.
#
#
# Start Scraping: Nicklas Utgren
# Serve Page: 112
# Return Page: 112
# Raw Page: 112
# Finish Scraping 2386 players.
# 24202 players remaining.
#
#
# Start Scraping: Jaime Cortes
# Serve Page: 77
# Return Page: 77
# Raw Page: 77
# Finish Scraping 2387 players.
# 24201 players remaining.
#
#
# Start Scraping: Nicklas Timfjord
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 2388 players.
# 24200 players remaining.
#
#
# Start Scraping: Paul Kilderry
# Serve Page: 114
# Return Page: 114
# Raw Page: 114
# Finish Scraping 2389 players.
# 24199 players remaining.
#
#
# Start Scraping: Martin Strelba
# Serve Page: 240
# Return Page: 240
# Raw Page: 240
# Finish Scraping 2390 players.
# ...
#
#
# Start Scraping: Aleksey Bessonov
# Finish Scraping 8403 players.
# 18185 players remaining.
#
#
# Start Scraping: Maxim Geraskin
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 8404 players.
# 18184 players remaining.
#
#
# Start Scraping: Ivan Galic
# Finish Scraping 8405 players.
# 18183 players remaining.
#
#
# Start Scraping: Josip Juric
# Finish Scraping 8406 players.
# 18182 players remaining.
#
#
# Start Scraping: Luca Stoppini
# Finish Scraping 8407 players.
# 18181 players remaining.
#
#
# Start Scraping: Ryan Jones
# Finish Scraping 8408 players.
# 18180 players remaining.
#
#
# Start Scraping: Sung Hyuk Yu
# Finish Scraping 8409 players.
# 18179 players remaining.
#
#
# Start Scraping: Nikos Serkedakis
# Finish Scraping 8410 players.
# 18178 players remaining.
#
#
# Start Scraping: Ognian Kolev
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 8411 players.
# 18177 players remaining.
#
#
# Start Scraping: Edy Kusdaryanto
# Finish Scraping 8412 players.
# 18176 players remaining.
#
#
# Start Scraping: Florian Marquardt
# Finish Scraping 8413 players.
# 18175 players remaining.
#
#
# Start Scraping: Jan Axel Tribler
# Finish Scraping 8414 players.
# 18174 players remaining.
#
#
# Start Scraping: Konstantin Zinchenko
# Finish Scraping 8415 players.
# 18173 players remaining.
#
#
# Start Scraping: Mat Lowe
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 8416 players.
# 18172 players remaining.
#
#
# Start Scraping: Alexei Grigorov
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 8417 players.
# 18171 players remaining.
#
#
# Start Scraping: Tom Allen
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 8418 players.
# 18170 players remaining.
#
#
# Start Scraping: Anze Kapun
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 8419 players.
# 18169 players remaining.
#
#
# Start Scraping: Jan Subota
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8420 players.
# 18168 players remaining.
#
#
# Start Scraping: Hussain Akbari
# Serve Page: 20
# Return Page: 20
# Raw Page: 20
# Finish Scraping 8421 players.
# 18167 players remaining.
#
#
# Start Scraping: Pongsiri Niroj
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 8422 players.
# 18166 players remaining.
#
#
# Start Scraping: Chiradip Mukerjea
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 8423 players.
# 18165 players remaining.
#
#
# Start Scraping: John De Mendoza
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 8424 players.
# 18164 players remaining.
#
#
# Start Scraping: Ken Stuart
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8425 players.
# 18163 players remaining.
#
#
# Start Scraping: Cody Conley
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8426 players.
# 18162 players remaining.
#
#
# Start Scraping: Juan Pedro Torres
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8427 players.
# 18161 players remaining.
#
#
# Start Scraping: Michal Walkow
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8428 players.
# 18160 players remaining.
#
#
# Start Scraping: Dejan Djokic
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 8429 players.
# 18159 players remaining.
#
#
# Start Scraping: Enrique Pena
# Serve Page: 18
# Return Page: 18
# Raw Page: 18
# Finish Scraping 8430 players.
# 18158 players remaining.
#
#
# Start Scraping: Nikolai Parkhomenko
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 8431 players.
# 18157 players remaining.
#
#
# Start Scraping: Claudio Rizzo
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 8432 players.
# 18156 players remaining.
#
#
# Start Scraping: Jeff Laski
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8433 players.
# 18155 players remaining.
#
#
# Start Scraping: Juan Andres Gomez
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 8434 players.
# 18154 players remaining.
#
#
# Start Scraping: Zibusiso Ncube
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 8435 players.
# 18153 players remaining.
#
#
# Start Scraping: Ganiyu Adenekan
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 8436 players.
# 18152 players remaining.
#
#
# Start Scraping: Daniel Chavez Morales
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 8437 players.
# 18151 players remaining.
#
#
# Start Scraping: Takeshi Murakami
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8438 players.
# 18150 players remaining.
#
#
# Start Scraping: Steve Wiere
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8439 players.
# 18149 players remaining.
#
#
# Start Scraping: Spencer Segura
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 8440 players.
# 18148 players remaining.
#
#
# Start Scraping: Pekka Saila
# Serve Page: 34
# Return Page: 34
# Raw Page: 34
# Finish Scraping 8441 players.
# 18147 players remaining.
#
#
# Start Scraping: Olivier Launo
# Finish Scraping 8442 players.
# 18146 players remaining.
#
#
# Start Scraping: Mike Sassano
# Finish Scraping 8443 players.
# 18145 players remaining.
#
#
# Start Scraping: Mike Kreiss
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 8444 players.
# 18144 players remaining.
#
#
# Start Scraping: Juan Hernandez
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 8445 players.
# 18143 players remaining.
#
#
# Start Scraping: Jay Royappa
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8446 players.
# 18142 players remaining.
#
#
# Start Scraping: Ivan Papell
# Finish Scraping 8447 players.
# 18141 players remaining.
#
#
# Start Scraping: Ivan Camus
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8448 players.
# 18140 players remaining.
#
#
# Start Scraping: Gonzalo Prida
# Finish Scraping 8449 players.
# 18139 players remaining.
#
#
# Start Scraping: Fabiano Mintz
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 8450 players.
# 18138 players remaining.
#
#
# Start Scraping: Dmitro Tolok
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 8451 players.
# 18137 players remaining.
#
#
# Start Scraping: David Gonzalez
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 8452 players.
# 18136 players remaining.
#
#
# Start Scraping: Danny Erez
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8453 players.
# 18135 players remaining.
#
#
# Start Scraping: Bojidar Pampoulov
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 8454 players.
# 18134 players remaining.
#
#
# Start Scraping: Alkis Papamichael
# Serve Page: 20
# Return Page: 20
# Raw Page: 20
# Finish Scraping 8455 players.
# 18133 players remaining.
#
#
# Start Scraping: Ali Madani
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 8456 players.
# 18132 players remaining.
#
#
# Start Scraping: Wisnu Adi Nugroho
# Finish Scraping 8457 players.
# 18131 players remaining.
#
#
# Start Scraping: Michael Eibl
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 8458 players.
# 18130 players remaining.
#
#
# Start Scraping: Constantin Christ
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 8459 players.
# 18129 players remaining.
#
#
# Start Scraping: Renato Nunes Dos Santos
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Jerry CHENG\OneDrive - The University of Chicago\桌面\datascience\tennis\tennis_dataprocess.ipynb Cell 11 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> driver = webdriver.Chrome(service=s)
#       <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> driver.set_window_rect(x=10, y=10, width=100, height=200)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> scrape_from(2030, 'm', driver)
#
# c:\Users\Jerry CHENG\OneDrive - The University of Chicago\桌面\datascience\tennis\tennis_dataprocess.ipynb Cell 11 in scrape_from(idx, sex, driver)
#     <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=478'>479</a> names = get_names(sex)
#     <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=479'>480</a> for i in range(idx, len(names)):
# --> <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=480'>481</a>     scrape_matches(names[i], driver)
#     <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=481'>482</a>     print('Finish Scraping', i + 1, 'players.')
#     <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=482'>483</a>     print(len(names) - (i + 1), 'players remaining.')
#
# c:\Users\Jerry CHENG\OneDrive - The University of Chicago\桌面\datascience\tennis\tennis_dataprocess.ipynb Cell 11 in scrape_matches(name, driver)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=57'>58</a>     dic[attr] = []
#      <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=59'>60</a> # for serve page
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=60'>61</a> driver.get(url + name_cleaned.replace(' ', '') + "&f=ACareerqq")
#      <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=61'>62</a> driver.refresh()
#      <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20CHENG/OneDrive%20-%20The%20University%20of%20Chicago/%E6%A1%8C%E9%9D%A2/datascience/tennis/tennis_dataprocess.ipynb#X13sZmlsZQ%3D%3D?line=62'>63</a> soup = BeautifulSoup(driver.page_source, 'html.parser')
#
# File d:\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.get(self, url)
#     436 def get(self, url: str) -> None:
#     437     """
#     438     Loads a web page in the current browser session.
#     439     """
# --> 440     self.execute(Command.GET, {'url': url})
#
# File d:\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:426, in WebDriver.execute(self, driver_command, params)
#     423         params['sessionId'] = self.session_id
#     425 params = self._wrap_value(params)
# --> 426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
#     428     self.error_handler.check_response(response)
#
# File d:\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:344, in RemoteConnection.execute(self, command, params)
#     342 data = utils.dump_json(params)
#     343 url = f"{self._url}{path}"
# --> 344 return self._request(command_info[0], url, body=data)
#
# File d:\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:366, in RemoteConnection._request(self, method, url, body)
#     363     body = None
#     365 if self.keep_alive:
# --> 366     response = self._conn.request(method, url, body=body, headers=headers)
#     367     statuscode = response.status
#     368 else:
#
# File d:\anaconda3\lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File d:\anaconda3\lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File d:\anaconda3\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File d:\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File d:\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File d:\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File d:\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File d:\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File d:\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File d:\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
scrape_matches('(M) Rafael Nadal')
