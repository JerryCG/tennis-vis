# %% [markdown]
# # Normal Weekly Updates - Past

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import numpy as np
from geopy.geocoders import Nominatim

# %% [markdown]
# ## 1. Update ATP Ranking

# %% [markdown]
# ### Single Date Update - Last: 2023-09-11

# %%
# load txt files
def load_txt(file):
    with open(file, 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    f.close()
    return df

# %%
def scrape_a_date_rank(date, previous):
    # scrape a particular date
    prefix = 'https://www.atptour.com/en/rankings/singles?rankRange=0-100&rankDate='
    img_pre = 'https://www.atptour.com'

    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)

    # get url
    driver.get(prefix + date)
    driver.refresh()

    # get content
    print('Start scraping:', date)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    trs = soup.find('table', {'id':'player-rank-detail-ajax'}).find_all('tr')

    # set attrs
    attrs = ['Date', 'Rank', 'Country', 'Image', 'Player', 'Points']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # date
    dict['Date'] = [date for i in range(len(trs) - 1)]

    for tr in trs[1:]:
        tds = tr.find_all('td')
        # rank
        dict['Rank'].append(tds[0].text.strip())
        # country
        dict['Country'].append(tds[2].img.attrs.get('alt', None))
        # image
        dict['Image'].append(img_pre + tds[2].img.attrs.get('src', None))
        # player
        dict['Player'].append(tds[3].text.strip())
        # points
        dict['Points'].append(tds[5].text.strip().replace(',', ''))

    # save to txt
    df = pd.DataFrame(dict)
    df.to_csv('m/rank/dates/' + date + '.txt', index = False, sep = ',', encoding='utf-8-sig')
    print('Finished:', date)

    # open the ranking file
    dict_r = load_txt('m/rank/atpranking_20000110_'+previous.replace('-', '')+'.txt').to_dict('list')
    dict_r[date] = []

    # first get points for existing players
    for p in dict_r['Player']:
        found = False
        for i in range(len(dict['Player'])):
            if p == dict['Player'][i]:
                # add new point
                dict_r[date].append(dict['Points'][i])
                found = True
                break
        if not found:
            dict_r[date].append(0)

    # add new player if any
    for p in dict['Player']:
        if p not in dict_r['Player']:
            # add player
            dict_r['Player'].append(p)
            for i in range(len(dict['Player'])):
                if p == dict['Player'][i]:
                    # add country
                    dict_r['Country'].append(dict['Country'][i])
                    # add image
                    dict_r['Country_Image'].append(dict['Image'][i])
                    # add point
                    dict_r[date].append(dict['Points'][i])
                    break
            # add previous points, all 0
            for d in [key for key in dict_r.keys()][3:-1]:
                dict_r[d].append(0)

    # save to txt
    df_new = pd.DataFrame(dict_r)
    df_new.to_csv('m/rank/atpranking_20000110_'+date.replace('-', '')+'.txt', index = False, sep = ',', encoding='utf-8-sig')

# %%
scrape_a_date_rank('2023-09-11', '2023-08-28')
# Out:
# Start scraping: 2023-09-11
# Finished: 2023-09-11

# %% [markdown]
# Remember to add the new dates to dates.txt

# %% [markdown]
# ## 2. Update ATP Links According to New Ranks - Last: 2023-09-11

# %%
def update_link_by_new_rank(dates):
    '''
    dates: a list of dates text
    '''
    prefix = 'https://www.atptour.com/en/rankings/singles?rankRange=0-100&rankDate='
    head = 'https://www.atptour.com'

    # open txt
    df = load_txt('m/basics/atpprofilebasics.txt')
    pl = [p for p in df['Player']]

    with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
        links = [line[:-1] for line in f]
    f.close()

    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=100, height=200)

    # date list, MODIFY DATE HERE!!!
    for date in dates:
        driver.get(prefix + date)
        driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        trs = soup.find('table', {'id':'player-rank-detail-ajax'}).find_all('tr')
        for tr in trs[1:]:
            tds = tr.find_all('td')
            if tds[3].text.strip().replace('-', ' ') not in pl:
                # add new link
                links.append(head+tds[3].a.get('href'))
                pl.append(tds[3].text.strip().replace('-', ' '))
                print('Found:', tds[3].text.strip().replace('-', ' '))
        print('Finish:', date)
    f.close()

    # update links
    with open('m/basics/atpprofilelinks.txt', 'w', encoding='utf-8-sig') as f:
        for link in set(links):
            if link != '':
                f.write(link)
                f.write('\n')
    f.close()

# %%
update_link_by_new_rank(["2023-09-11"])
# Out:
# Found: Thiago Seyboth Wild
# Found: Rinky Hijikata
# Found: Dominic Stricker
# Found: Fabian Marozsan
# Found: Facundo Diaz Acosta
# Finish: 2023-09-11

# %% [markdown]
# Remember to update rank file in Flourish

# %% [markdown]
# ## 3. Update ATP Profile Information - Last: 2023-09-11

# %%
# UPDATE new basics based on new links in atprofilelinks

with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
    links = [line[:-1] for line in f]
f.close()

dict = load_txt('m/basics/atpprofilebasics.txt').to_dict('list')

chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)

for i, link in enumerate(links):
    if link not in dict['ATP Link']:
        driver.get(link)
        driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        # add name
        try:
            dict['Player'].append(soup.find('div', {'class': 'first-name'}).text.strip().replace('-', ' ') 
                                  + ' ' + soup.find('div', {'class': 'last-name'}).text.strip().replace('-', ' '))
        except:
            print(link, 'not found')
            break
        # add link
        dict['ATP Link'].append(link)
        # add birthday
        try:
            txt = soup.find('span', {'class': 'table-birthday'}).text.split('.')
            birthday = txt[0][-4:] + '-' + txt[1] + '-' + txt[2][:2]
        except:
            birthday = ''
        dict['Birthday'].append(birthday)
        # add birthplace, plays
        try:
            birthplace_plays = soup.find_all('div', {'class': 'table-value'})
            dict['Birthplace'].append(birthplace_plays[0].text.strip('\n ').replace(',', ' -'))
            dict['Plays'].append(birthplace_plays[1].text.strip().replace(',', ' -'))
        except:
            dict['Birthplace'].append('')
            dict['Plays'].append('')
        # add turned pro
        try:
            dict['Turned Pro'].append(soup.find_all('div', {'class': 'table-big-value'})[1].text.strip())
        except:
            dict['Turned Pro'].append('')
        # add weight, height
        try:
            dict['Weight (kg)'].append(soup.find('span', {'class': 'table-weight-kg-wrapper'}).text.strip('()kg'))
        except:
            dict['Weight (kg)'].append('')
        try:
            dict['Height (cm)'].append(soup.find('span', {'class': 'table-height-cm-wrapper'}).text.strip('()cm'))
        except:
            dict['Height (cm)'].append('')
        print('Finished:', i+1)
        # add birthplace details, matched region, lat, lon
        place = birthplace_plays[0].text.strip('\n ')
        geolocator = Nominatim(user_agent='tennis-vis')
        try:
            location = geolocator.geocode(place)
            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
            dict['Birthplace_lat'].append(location.latitude)
            dict['Birthplace_lon'].append(location.longitude)
            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
        except:
            try:
                location = geolocator.geocode(place.split(',')[0]+','+place.split(',')[1])
                dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                dict['Birthplace_lat'].append(location.latitude)
                dict['Birthplace_lon'].append(location.longitude)
                print(location.address.replace(',', ' -'), location.latitude, location.longitude)
            except:
                try:
                    location = geolocator.geocode(place.split(',')[0])
                    dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                    dict['Birthplace_lat'].append(location.latitude)
                    dict['Birthplace_lon'].append(location.longitude)
                    print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                except:
                    try:
                        location = geolocator.geocode(place.split(',')[1])
                        dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                        dict['Birthplace_lat'].append(location.latitude)
                        dict['Birthplace_lon'].append(location.longitude)
                        print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                    except:
                        try:
                            location = geolocator.geocode(place.split(',')[2])
                            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                            dict['Birthplace_lat'].append(location.latitude)
                            dict['Birthplace_lon'].append(location.longitude)
                            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                        except:
                            dict['Birthplace_matched'].append('')
                            dict['Birthplace_lat'].append('')
                            dict['Birthplace_lon'].append('')
                            print('','','')

df = pd.DataFrame(dict)
df.to_csv('m/basics/atpprofilebasics.txt', index = False, sep = ',', encoding='utf-8-sig')
# Out:
# Finished: 758
# Marechal Cândido Rondon - Região Geográfica Imediata de Marechal Cândido Rondon - Região Geográfica Intermediária de Cascavel - Paraná - Região Sul - Brasil -24.5582532 -54.0587821
# Finished: 2117
# Sydney - Council of the City of Sydney - New South Wales - Australia -33.8698439 151.2082848
# Finished: 2793
# Buenos Aires - Comuna 6 - Ciudad Autónoma de Buenos Aires - Argentina -34.6075682 -58.4370894
# Finished: 2954
# Grosshöchstetten - Verwaltungskreis Bern-Mittelland - Verwaltungsregion Bern-Mittelland - Bern/Berne - 3506 - Schweiz/Suisse/Svizzera/Svizra 46.9079431 7.6385085
# https://www.atptour.com/en/players/fabian-marozsan/m0ci/overview not found

# %% [markdown]
# ## 4. Update ATP TOP 100 Distribution - Last: 2023-09-11

# %%
def update_geo_atp100(date,num):
    # get basics
    df_basics = load_txt('m/basics/atpprofilebasics.txt')

    # set basic dict
    attrs = ['Start', 'End', 'Player', 'Rank', 'Points', 'Birthplace', 'Lat', 'Lon']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # get dates
    dates = []
    with open('m/rank/dates.txt', 'r') as f:
        for date in f:
            dates.append(date[:-1])
    f.close()

    # MODIFY HOW MANY DATES TO CONSIDER FROM 2000-01-10, E.G., 2023-02-20 (num=1117)
    for k, date in enumerate([dates[num - i - 1] for i in range(num)]):
        df_rank = load_txt('m/rank/dates/'+date+'.txt')
        for i, p in enumerate(df_rank['Player']):
            for j, r in enumerate(df_basics['Player']):
                if p.replace('-', ' ') == r and k != (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append(dates[num - k - 2])
                    except:
                        pass
                    break
                if p.replace('-', ' ') == r and k == (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append('')
                    except:
                        pass
                    break

        print('Finished:', date)

    df = pd.DataFrame(dict)

    # MODIFY FILE NAME!!!!
    df.to_csv('m/rank/atp100geo20000110_'+date.replace("-","")+'.txt', index = False, sep = ',', encoding = 'utf-8-sig')

# %%
# 2023-09-11 (num=1139)
update_geo_atp100("2023-09-11",1139)
# Out:
# Finished: 2000-01-10
# Finished: 2000-01-17
# Finished: 2000-01-24
# Finished: 2000-01-31
# Finished: 2000-02-07
# Finished: 2000-02-14
# Finished: 2000-02-21
# Finished: 2000-02-28
# Finished: 2000-03-06
# Finished: 2000-03-13
# Finished: 2000-03-20
# Finished: 2000-03-27
# Finished: 2000-04-03
# Finished: 2000-04-10
# Finished: 2000-04-17
# Finished: 2000-04-24
# Finished: 2000-05-01
# Finished: 2000-05-08
# Finished: 2000-05-15
# Finished: 2000-05-22
# Finished: 2000-05-29
# Finished: 2000-06-05
# Finished: 2000-06-12
# Finished: 2000-06-19
# Finished: 2000-06-26
# Finished: 2000-07-03
# Finished: 2000-07-10
# Finished: 2000-07-17
# Finished: 2000-07-24
# Finished: 2000-07-31
# Finished: 2000-08-07
# Finished: 2000-08-14
# Finished: 2000-08-21
# Finished: 2000-08-28
# Finished: 2000-09-04
# Finished: 2000-09-11
# Finished: 2000-09-18
# Finished: 2000-09-25
# Finished: 2000-10-02
# Finished: 2000-10-09
# Finished: 2000-10-16
# Finished: 2000-10-23
# Finished: 2000-10-30
# Finished: 2000-11-06
# Finished: 2000-11-13
# Finished: 2000-11-20
# Finished: 2000-11-27
# Finished: 2000-12-04
# Finished: 2000-12-11
# Finished: 2000-12-18
# Finished: 2000-12-25
# Finished: 2001-01-01
# Finished: 2001-01-08
# Finished: 2001-01-15
# Finished: 2022-11-28
# Finished: 2022-12-05
# Finished: 2022-12-12
# Finished: 2022-12-19
# Finished: 2022-12-26
# Finished: 2023-01-02
# Finished: 2023-01-09
# Finished: 2023-01-16
# Finished: 2023-01-30
# Finished: 2023-02-06
# Finished: 2023-02-13
# Finished: 2023-02-20
# Finished: 2023-02-27
# Finished: 2023-03-06
# Finished: 2023-03-20
# Finished: 2023-04-03
# Finished: 2023-04-10
# Finished: 2023-04-17
# Finished: 2023-04-24
# Finished: 2023-05-08
# Finished: 2023-05-22
# Finished: 2023-05-29
# Finished: 2023-06-12
# Finished: 2023-06-19
# Finished: 2023-06-26
# Finished: 2023-07-03
# Finished: 2023-07-17
# Finished: 2023-07-24
# Finished: 2023-07-31
# Finished: 2023-08-07
# Finished: 2023-08-14
# Finished: 2023-08-21
# Finished: 2023-08-28
# Finished: 2023-09-11

# %% [markdown]
# Remember to update geo file in Flourish

# %% [markdown]
# ## 5. Update All Matches Player by Player, LAST: 2023-09-11

# %%
# define functions to get all players' names and scrape all matches data
def get_names(sex = ''):
    names = []
    if sex == 'm':
        with open('mp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    elif sex == 'w':
        with open('wp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    else:
        with open('mwplayerlist_processed.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    return names

# define a function to scrape for a single man player's matches
def scrape_matches(name, driver):
    try:
        # set attributes
        attributes_m = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'TP', 'Aces', 'DFs', 'SP', 
                        '1SP', '2SP', 'vA', 'Time']

        attributes_w = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'Time']

        # get cleaned name
        sex = name[1]
        name_cleaned = name[4:].replace(' ', '')

        # set url prefix and types of webpages
        if sex == 'M':
            url = "https://www.tennisabstract.com/cgi-bin/player-classic.cgi?p=" 
        #   types = ["&f=ACareerqq", "&f=ACareerqqr1", "&f=ACareerqqw1"]
        else:
            url = "https://www.tennisabstract.com/cgi-bin/wplayer-classic.cgi?p="

        # Start of Scraping
        print('Start Scraping:', name[4:])
        
        # man and woman pages are different
        if sex == 'M':

            # for man players
            # set dictionary
            dic = {}
            for attr in attributes_m:
                dic[attr] = []

            # for serve page
            driver.get(url + name_cleaned.replace(' ', '') + "&f=ACareerqq")
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
        #   driver.quit()

            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # for return page
                show_return = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Return"]')))
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[1])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # for raw page
                show_raw = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Raw"]')))
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[2])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

            else:

                # serve page
                driver.get(url + name_cleaned.replace(' ', ''))
                driver.refresh()
                # show career
                try:
                    show_career = driver.find_element(By.ID, 'careerclick')
                except:
                    return None
                show_career.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # return page
                show_return = driver.find_element(By.XPATH, '//span[text()="Return"]')
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # raw page
                show_raw = driver.find_element(By.XPATH, '//span[text()="Raw"]')
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
              # driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

        else:

            # for woman players
            # set dictionary
            dic = {}
            for attr in attributes_w:
                dic[attr] = []

            # for serve page
            driver.get(url + name_cleaned.replace(' ', '') + '&f=ACareerqq')
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')

            for match in matches[2:]:
                tds = match.find_all('td')
                # first check if it is ongoing match
                spans = tds[6].find_all('span')
                if spans[3].text != 'vs':
                    # date, contain special character
                    date = tds[0].text.split('‑')
                    dic[attributes_w[0]].append('-'.join(date))
                    # tournament
                    dic[attributes_w[1]].append(tds[1].text)
                    # sets
                    dic[attributes_w[2]].append(3)
                    # surface
                    dic[attributes_w[3]].append(tds[2].text)
                    # round
                    dic[attributes_w[4]].append(tds[3].text)
                    # rank
                    dic[attributes_w[5]].append(tds[4].text)
                    # opponent rank
                    dic[attributes_w[6]].append(tds[5].text)
                    # win?, tournament rank, opponent tournament rank, winner, loser
                    if spans[1].text in name:
                        # win?
                        dic[attributes_w[7]].append(1)
                        # winner
                        dic[attributes_w[10]].append(name[4:])
                        # loser
                        dic[attributes_w[11]].append(spans[6].text)
                        # tRk
                        if spans[0].text != '':
                            dic[attributes_w[8]].append(spans[0].text[1:-1])
                        else:
                            dic[attributes_w[8]].append('')
                        # vtRk
                        if spans[5].text != '':
                            dic[attributes_w[9]].append(spans[5].text[1:-1])
                        else:
                            dic[attributes_w[9]].append('')
                    else:
                        # win?
                        dic[attributes_w[7]].append(0)
                        # winner
                        dic[attributes_w[10]].append(spans[1].text)
                        # loser
                        dic[attributes_w[11]].append(name[4:])
                        # tRk
                        if spans[6].text != '':
                            dic[attributes_w[8]].append(spans[6].text[1:-1])
                        else:
                            dic[attributes_w[8]].append('')
                        # vtRk
                        if spans[0].text != '':
                            dic[attributes_w[9]].append(spans[0].text[1:-1])
                        else:
                            dic[attributes_w[9]].append('')
                    # score
                    dic[attributes_w[12]].append(tds[7].text)
                    # DR
                    dic[attributes_w[13]].append(tds[8].text)
                    # A%
                    dic[attributes_w[14]].append(tds[9].text)
                    # DF%
                    dic[attributes_w[15]].append(tds[10].text)
                    # 1stIn
                    dic[attributes_w[16]].append(tds[11].text)
                    # 1st%
                    dic[attributes_w[17]].append(tds[12].text)
                    # 2rd%
                    dic[attributes_w[18]].append(tds[13].text)
                    # BPSvd
                    dic[attributes_w[19]].append(tds[14].text)

            print('Serve Page:', len(dic['Date']))

            # for return page
            page_return = driver.find_element(By.XPATH, '//span[text()="Show Return Stats"]')
            page_return.click()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
        #   driver.quit()

            for match in matches[2:]:
                tds = match.find_all('td')
                # first check if it is ongoing match
                spans = tds[6].find_all('span')
                if spans[3].text != 'vs':
                    # TPW
                    dic[attributes_w[20]].append(tds[9].text)
                    # RPW
                    dic[attributes_w[21]].append(tds[10].text)
                    # vA%
                    dic[attributes_w[22]].append(tds[11].text)
                    # v1st%
                    dic[attributes_w[23]].append(tds[12].text)
                    # v2rd%
                    dic[attributes_w[24]].append(tds[13].text)
                    # BPCvt
                    dic[attributes_w[25]].append(tds[14].text)
                    # Time
                    dic[attributes_w[26]].append(tds[15].text)

            print('Return Page:', len(dic['TPW']))

        # save to text, separated by gender
        df = pd.DataFrame(dic)
        df.to_csv(sex.lower() + '/matches/txt/' + name[4:] + '.txt', index = False, sep = ',', encoding='utf-8-sig')

    except (IndexError, AttributeError) as e:
        pass
    
# define a loop function to scrape players from a given index
def scrape_from(idx, sex, driver):
    names = get_names(sex)
    for i in range(idx, len(names)):
        scrape_matches(names[i], driver)
        print('Finish Scraping', i + 1, 'players.')
        print(len(names) - (i + 1), 'players remaining.')
        print('\n')
        
# load txt files
def load_txt(name):
    with open(name[1].lower() + '/matches/txt/' + name[4:] + '.txt', 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    return df

# %%
# UPDATE MATCHES DATA!!!
# set up chromdriver
chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)
scrape_from(11571, 'm', driver)
# Out:
# Start Scraping: Florian Loddenkemper
# Finish Scraping 11572 players.
# 15016 players remaining.
#
#
# Start Scraping: Ferenc Csepai
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11573 players.
# 15015 players remaining.
#
#
# Start Scraping: Dusan Kulhaj
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11574 players.
# 15014 players remaining.
#
#
# Start Scraping: Claude England
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11575 players.
# 15013 players remaining.
#
#
# Start Scraping: Bill Csipkay
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11576 players.
# 15012 players remaining.
#
#
# Start Scraping: Arjan Van Der Zande
# Finish Scraping 11577 players.
# 15011 players remaining.
#
#
# Start Scraping: Anthony Fawcett
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 11578 players.
# 15010 players remaining.
#
#
# Start Scraping: Andy Mccurry
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11579 players.
# 15009 players remaining.
#
#
# Start Scraping: Andrew Keve
# Finish Scraping 11580 players.
# 15008 players remaining.
#
#
# Start Scraping: Adrian Popovici
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 11581 players.
# 15007 players remaining.
#
#
# Start Scraping: Onyeka Mbanu
# Finish Scraping 11582 players.
# 15006 players remaining.
#
#
# Start Scraping: Juan Pablo Boada G
# Finish Scraping 11583 players.
# 15005 players remaining.
#
#
# Start Scraping: Aviv Ben Shabat
# Finish Scraping 11584 players.
# 15004 players remaining.
#
#
# Start Scraping: Andrey Yuzhnyy
# Finish Scraping 11585 players.
# 15003 players remaining.
#
#
# Start Scraping: Rafael Aita
# Finish Scraping 11586 players.
# 15002 players remaining.
#
#
# Start Scraping: Jui Mao
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 11587 players.
# 15001 players remaining.
#
#
# Start Scraping: Daniel Fernandez
# Finish Scraping 11588 players.
# 15000 players remaining.
#
#
# Start Scraping: Arturs Kazijevs
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11589 players.
# 14999 players remaining.
#
#
# Start Scraping: Raphael Hemmeler
# Finish Scraping 11590 players.
# 14998 players remaining.
#
#
# Start Scraping: Georgi Jordanov
# Finish Scraping 11591 players.
# 14997 players remaining.
#
#
# Start Scraping: Chen Ye
# Finish Scraping 11592 players.
# 14996 players remaining.
#
#
# Start Scraping: Dawid Piatkowski
# Finish Scraping 11593 players.
# 14995 players remaining.
#
#
# Start Scraping: Dominic Ross Hurst
# Finish Scraping 11594 players.
# 14994 players remaining.
#
#
# Start Scraping: Juan Jose Seminara
# Finish Scraping 11595 players.
# 14993 players remaining.
#
#
# Start Scraping: David Emery
# Finish Scraping 11596 players.
# 14992 players remaining.
#
#
# Start Scraping: Andre Van Der Merwe B
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 11597 players.
# 14991 players remaining.
#
#
# Start Scraping: Mark Sibilla
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11598 players.
# 14990 players remaining.
#
#
# Start Scraping: Pablo Cordova
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11599 players.
# 14989 players remaining.
#
#
# Start Scraping: Alexander Frey
# Finish Scraping 11600 players.
# 14988 players remaining.
#
#
# Start Scraping: Arno Otterman
# Finish Scraping 11601 players.
# 14987 players remaining.
#
#
# Start Scraping: Ramon Bernal
# Finish Scraping 11602 players.
# 14986 players remaining.
#
#
# Start Scraping: Daniel Dragu
# Finish Scraping 11603 players.
# 14985 players remaining.
#
#
# Start Scraping: Emil Egerer
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11604 players.
# 14984 players remaining.
#
#
# Start Scraping: Fritz Bissell
# Finish Scraping 11605 players.
# 14983 players remaining.
#
#
# Start Scraping: Thomas Walter
# Finish Scraping 11606 players.
# 14982 players remaining.
#
#
# Start Scraping: Jeff Cathrall
# Finish Scraping 11607 players.
# 14981 players remaining.
#
#
# Start Scraping: Martin Hipp
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11608 players.
# 14980 players remaining.
#
#
# Start Scraping: Dave Clark
# Serve Page: 893
# Return Page: 893
# Raw Page: 893
# Finish Scraping 11609 players.
# 14979 players remaining.
#
#
# Start Scraping: David Graham
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11610 players.
# 14978 players remaining.
#
#
# Start Scraping: John Davis
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11611 players.
# 14977 players remaining.
#
#
# Start Scraping: Richard Akel
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11612 players.
# 14976 players remaining.
#
#
# Start Scraping: Erik Vant Hof
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11613 players.
# 14975 players remaining.
#
#
# Start Scraping: Jeff Lee
# Finish Scraping 11614 players.
# 14974 players remaining.
#
#
# Start Scraping: Paul Avis
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 11615 players.
# 14973 players remaining.
#
#
# Start Scraping: Joakim Berner
# Finish Scraping 11616 players.
# 14972 players remaining.
#
#
# Start Scraping: Robert Bettauer
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11617 players.
# 14971 players remaining.
#
#
# Start Scraping: Lui Maxted
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11618 players.
# 14970 players remaining.
#
#
# Start Scraping: Majun Li
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 11619 players.
# 14969 players remaining.
#
#
# Start Scraping: Jakub Katuch
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 11620 players.
# 14968 players remaining.
#
#
# Start Scraping: Taym Al Azmeh
# Serve Page: 16
# Return Page: 16
# Raw Page: 16
# Finish Scraping 11621 players.
# 14967 players remaining.
#
#
# Start Scraping: Cesar Bouchelaghem
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 11622 players.
# 14966 players remaining.
#
#
# Start Scraping: Robin Catry
# Serve Page: 17
# Return Page: 17
# Raw Page: 17
# Finish Scraping 11623 players.
# 14965 players remaining.
#
#
# Start Scraping: Pawit Sornlaksup
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 11624 players.
# 14964 players remaining.
#
#
# Start Scraping: Ha Minh Duc Vu
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 11625 players.
# 14963 players remaining.
#
#
# Start Scraping: Hanival Kahsay
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11626 players.
# 14962 players remaining.
#
#
# Start Scraping: Omar Suarez Berrezueta
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11627 players.
# 14961 players remaining.
#
#
# Start Scraping: Juan Martin Bosmediano Pazmino
# Finish Scraping 11628 players.
# 14960 players remaining.
#
#
# Start Scraping: Dusan Rsovac
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11629 players.
# 14959 players remaining.
#
#
# Start Scraping: Peetu Pohjola
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 11630 players.
# 14958 players remaining.
#
#
# Start Scraping: Joshua Schaefer
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11631 players.
# 14957 players remaining.
#
#
# Start Scraping: Eugenio Gonzalez Fitzmaurice
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11632 players.
# 14956 players remaining.
#
#
# Start Scraping: Tobias Smoliner
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 11633 players.
# 14955 players remaining.
#
#
# Start Scraping: Eric Padgham
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11634 players.
# 14954 players remaining.
#
#
# Start Scraping: Luca Pow
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11635 players.
# 14953 players remaining.
#
#
# Start Scraping: Tuncay Duran
# Serve Page: 32
# Return Page: 32
# Raw Page: 32
# Finish Scraping 11636 players.
# 14952 players remaining.
#
#
# Start Scraping: Lautaro Midon
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 11637 players.
# 14951 players remaining.
#
#
# Start Scraping: Lennon Roark Jones
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11638 players.
# 14950 players remaining.
#
#
# Start Scraping: Nishesh Basavareddy
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11639 players.
# 14949 players remaining.
#
#
# Start Scraping: Karim Ibrahim
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 11640 players.
# 14948 players remaining.
#
#
# Start Scraping: Jesse De Jager
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 11641 players.
# 14947 players remaining.
#
#
# Start Scraping: Maceo Simpson
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 11642 players.
# 14946 players remaining.
#
#
# Start Scraping: Fabian Hansch Mauritzson
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11643 players.
# 14945 players remaining.
#
#
# Start Scraping: Federico Mirgone
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11644 players.
# 14944 players remaining.
#
#
# Start Scraping: Alessandro Spadola
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 11645 players.
# 14943 players remaining.
#
#
# Start Scraping: Benjamin Ignacio Torres Fernandez
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11646 players.
# 14942 players remaining.
#
#
# Start Scraping: Benjamin Kittay
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 11647 players.
# 14941 players remaining.
#
#
# Start Scraping: Lambert Ruland
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11648 players.
# 14940 players remaining.
#
#
# Start Scraping: Pijus Vaitiekunas
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11649 players.
# 14939 players remaining.
#
#
# Start Scraping: Josef Southcombe
# Finish Scraping 11650 players.
# 14938 players remaining.
#
#
# Start Scraping: Jakub Kroslak
# Serve Page: 16
# Return Page: 16
# Raw Page: 16
# Finish Scraping 11651 players.
# 14937 players remaining.
#
#
# Start Scraping: Matija Samardzic
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11652 players.
# 14936 players remaining.
#
#
# Start Scraping: Bruno Fernandez
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 11653 players.
# 14935 players remaining.
#
#
# Start Scraping: Timofey Stepanov
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 11654 players.
# 14934 players remaining.
#
#
# Start Scraping: Luca Teboul
# Finish Scraping 11655 players.
# 14933 players remaining.
#
#
# Start Scraping: Andrei Cuceu
# Finish Scraping 11656 players.
# 14932 players remaining.
#
#
# Start Scraping: Borys Zgola
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 11657 players.
# 14931 players remaining.
#
#
# Start Scraping: Tomas Lanik
# Serve Page: 29
# Return Page: 29
# Raw Page: 29
# Finish Scraping 11658 players.
# 14930 players remaining.
#
#
# Start Scraping: Jibril Nettles
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 11659 players.
# 14929 players remaining.
#
#
# Start Scraping: Alessandro Bellifemine
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 11660 players.
# 14928 players remaining.
#
#
# Start Scraping: Jan Dimitrijevic
# Finish Scraping 11661 players.
# 14927 players remaining.
#
#
# Start Scraping: Michele Vianello
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11662 players.
# 14926 players remaining.
#
#
# Start Scraping: Filiberto Fumagalli
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11663 players.
# 14925 players remaining.
#
#
# Start Scraping: Aleksandar Mihailovic
# Finish Scraping 11664 players.
# 14924 players remaining.
#
#
# Start Scraping: Luka Todorovic
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11665 players.
# 14923 players remaining.
#
#
# Start Scraping: Adrian Mateo Bejenaru
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11666 players.
# 14922 players remaining.
#
#
# Start Scraping: Asaf Friedler
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11667 players.
# 14921 players remaining.
#
#
# Start Scraping: Tushar Sharma
# Finish Scraping 11668 players.
# 14920 players remaining.
#
#
# Start Scraping: Yerassyl Yerdilda
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11669 players.
# 14919 players remaining.
#
#
# Start Scraping: Adit Sinha
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 11670 players.
# 14918 players remaining.
#
#
# Start Scraping: Suleyman Deniz Gursoy
# Finish Scraping 11671 players.
# 14917 players remaining.
#
#
# Start Scraping: Alexander Stepin
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11672 players.
# 14916 players remaining.
#
#
# Start Scraping: Carl Roothman
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11673 players.
# 14915 players remaining.
#
#
# Start Scraping: Stevan Popovic
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11674 players.
# 14914 players remaining.
#
#
# Start Scraping: Sergo Sikharulidze
# Finish Scraping 11675 players.
# 14913 players remaining.
#
#
# Start Scraping: Toomas Leius
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 11676 players.
# 14912 players remaining.
#
#
# Start Scraping: Thomas Pavlekovich Smith
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 11677 players.
# 14911 players remaining.
#
#
# Start Scraping: Bruno Nhavene
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11678 players.
# 14910 players remaining.
#
#
# Start Scraping: Miguel Perez Pena
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11679 players.
# 14909 players remaining.
#
#
# Start Scraping: Marco Mania
# Finish Scraping 11680 players.
# 14908 players remaining.
#
#
# Start Scraping: Iacopo Sada
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11681 players.
# 14907 players remaining.
#
#
# Start Scraping: Chrisjan Van Wyk
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11682 players.
# 14906 players remaining.
#
#
# Start Scraping: Mans Dahlberg
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11683 players.
# 14905 players remaining.
#
#
# Start Scraping: Carl Emil Overbeck
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11684 players.
# 14904 players remaining.
#
#
# Start Scraping: Romain Gales
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11685 players.
# 14903 players remaining.
#
#
# Start Scraping: Janos Fekete
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11686 players.
# 14902 players remaining.
#
#
# Start Scraping: Oskar Antinheimo
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11687 players.
# 14901 players remaining.
#
#
# Start Scraping: Noppadol Noikor
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11688 players.
# 14900 players remaining.
#
#
# Start Scraping: Aissa Benchakroun
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11689 players.
# 14899 players remaining.
#
#
# Start Scraping: Agustin Maria Gascia
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11690 players.
# 14898 players remaining.
#
#
# Start Scraping: Benjamin Denis Alarcon
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 11691 players.
# 14897 players remaining.
#
#
# Start Scraping: Quinn Vandecasteele
# Serve Page: 35
# Return Page: 35
# Raw Page: 35
# Finish Scraping 11692 players.
# 14896 players remaining.
#
#
# Start Scraping: Ethan Denzel Sibanda
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11693 players.
# 14895 players remaining.
#
#
# Start Scraping: Kamen Damov
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11694 players.
# 14894 players remaining.
#
#
# Start Scraping: Mateo Berta
# Finish Scraping 11695 players.
# 14893 players remaining.
#
#
# Start Scraping: Eduardo Cohen
# Finish Scraping 11696 players.
# 14892 players remaining.
#
#
# Start Scraping: Kyle Lok Yin Tang
# Finish Scraping 11697 players.
# 14891 players remaining.
#
#
# Start Scraping: Keshav Chopra
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 11698 players.
# 14890 players remaining.
#
#
# Start Scraping: Cihan Akay
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 11699 players.
# 14889 players remaining.
#
#
# Start Scraping: Roni Rikkonen
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11700 players.
# 14888 players remaining.
#
#
# Start Scraping: Ishaan Ravichander
# Serve Page: 17
# Return Page: 17
# Raw Page: 17
# Finish Scraping 11701 players.
# 14887 players remaining.
#
#
# Start Scraping: Bekzat Usipbekov
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11702 players.
# 14886 players remaining.
#
#
# Start Scraping: Yerassyl Murat
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11703 players.
# 14885 players remaining.
#
#
# Start Scraping: Jonas Schaer
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 11704 players.
# 14884 players remaining.
#
#
# Start Scraping: Gerhardt Marius Becker
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11705 players.
# 14883 players remaining.
#
#
# Start Scraping: Joao Giannella
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11706 players.
# 14882 players remaining.
#
#
# Start Scraping: Preston Touliatos
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11707 players.
# 14881 players remaining.
#
#
# Start Scraping: Neel Rajesh
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11708 players.
# 14880 players remaining.
#
#
# Start Scraping: Juan Carlos Garcia Garcia
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11709 players.
# 14879 players remaining.
#
#
# Start Scraping: Jim Walder
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11710 players.
# 14878 players remaining.
#
#
# Start Scraping: Brandon Stringfellow
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11711 players.
# 14877 players remaining.
#
#
# Start Scraping: Ignacio Novo
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 11712 players.
# 14876 players remaining.
#
#
# Start Scraping: Ilya Rudiukov
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11713 players.
# 14875 players remaining.
#
#
# Start Scraping: Alberto Bronzetti
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11714 players.
# 14874 players remaining.
#
#
# Start Scraping: Thomas George Brun
# Finish Scraping 11715 players.
# 14873 players remaining.
#
#
# Start Scraping: Philip Hjorth
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11716 players.
# 14872 players remaining.
#
#
# Start Scraping: Arda Azkara
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 11717 players.
# 14871 players remaining.
#
#
# Start Scraping: Robin Erik Parts
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11718 players.
# 14870 players remaining.
#
#
# Start Scraping: Vincentiu Andrei Niculescu
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11719 players.
# 14869 players remaining.
#
#
# Start Scraping: Nick Lagaev
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11720 players.
# 14868 players remaining.
#
#
# Start Scraping: Valentin De Carvalho
# Finish Scraping 11721 players.
# 14867 players remaining.
#
#
# Start Scraping: Luka Miklavcic
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 11722 players.
# 14866 players remaining.
#
#
# Start Scraping: Lucas Horve
# Finish Scraping 11723 players.
# 14865 players remaining.
#
#
# Start Scraping: Hien Quang Hien Pham
# Finish Scraping 11724 players.
# 14864 players remaining.
#
#
# Start Scraping: Maximilian Gatev
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11725 players.
# 14863 players remaining.
#
#
# Start Scraping: Denis Parshutin
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11726 players.
# 14862 players remaining.
#
#
# Start Scraping: Ivan Ponomarenko
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11727 players.
# 14861 players remaining.
#
#
# Start Scraping: Masi Sarpola
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11728 players.
# 14860 players remaining.
#
#
# Start Scraping: Rikhardt Bierman
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11729 players.
# 14859 players remaining.
#
#
# Start Scraping: Mikel Lopez Hernaez
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11730 players.
# 14858 players remaining.
#
#
# Start Scraping: Ottaviano Martini
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 11731 players.
# 14857 players remaining.
#
#
# Start Scraping: Adam Blecha
# Finish Scraping 11732 players.
# 14856 players remaining.
#
#
# Start Scraping: Isaac Arturo Arevalo
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11733 players.
# 14855 players remaining.
#
#
# Start Scraping: Elliott Farmer
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11734 players.
# 14854 players remaining.
#
#
# Start Scraping: Giordan Kunz
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11735 players.
# 14853 players remaining.
#
#
# Start Scraping: Doug Smith
# Serve Page: 34
# Return Page: 34
# Raw Page: 34
# Finish Scraping 11736 players.
# 14852 players remaining.
#
#
# Start Scraping: Frank Briscoe
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 11737 players.
# 14851 players remaining.
#
#
# Start Scraping: Matt Halpin
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11738 players.
# 14850 players remaining.
#
#
# Start Scraping: Alvaro Saez Royuela Ariza
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11739 players.
# 14849 players remaining.
#
#
# Start Scraping: Timothy Sah
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11740 players.
# 14848 players remaining.
#
#
# Start Scraping: Marcel Marlon Sudzum
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 11741 players.
# 14847 players remaining.
#
#
# Start Scraping: Vazha Shubladze
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11742 players.
# 14846 players remaining.
#
#
# Start Scraping: Mateusz Smolicki
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11743 players.
# 14845 players remaining.
#
#
# Start Scraping: Gregor Ramskogler
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 11744 players.
# 14844 players remaining.
#
#
# Start Scraping: Mateus De Carvalho Cardoso Alves
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11745 players.
# 14843 players remaining.
#
#
# Start Scraping: Svyatoslav Shainyan
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11746 players.
# 14842 players remaining.
#
#
# Start Scraping: Michael Boguslavsky
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11747 players.
# 14841 players remaining.
#
#
# Start Scraping: Jannik Rother
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11748 players.
# 14840 players remaining.
#
#
# Start Scraping: Julien Evrard
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11749 players.
# 14839 players remaining.
#
#
# Start Scraping: Simon Yastremskiy
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11750 players.
# 14838 players remaining.
#
#
# Start Scraping: Delmas Ntcha
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11751 players.
# 14837 players remaining.
#
#
# Start Scraping: Yaron Guberman
# Finish Scraping 11752 players.
# 14836 players remaining.
#
#
# Start Scraping: Alexandre Ribeiro
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11753 players.
# 14835 players remaining.
#
#
# Start Scraping: Themi Sitzoukis
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11754 players.
# 14834 players remaining.
#
#
# Start Scraping: Stephan Koenigsfest
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11755 players.
# 14833 players remaining.
#
#
# Start Scraping: Lucas Koelle
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11756 players.
# 14832 players remaining.
#
#
# Start Scraping: Athanassios Manekas
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11757 players.
# 14831 players remaining.
#
#
# Start Scraping: Jossefa Elias
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11758 players.
# 14830 players remaining.
#
#
# Start Scraping: Matteo Herrmann Zunic
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11759 players.
# 14829 players remaining.
#
#
# Start Scraping: Frazier Rengifo
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 11760 players.
# 14828 players remaining.
#
#
# Start Scraping: Mohamed Belcora
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11761 players.
# 14827 players remaining.
#
#
# Start Scraping: Gwen Arne Corches
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11762 players.
# 14826 players remaining.
#
#
# Start Scraping: Alexandre Lichtchenko
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11763 players.
# 14825 players remaining.
#
#
# Start Scraping: Shibo Du
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11764 players.
# 14824 players remaining.
#
#
# Start Scraping: Joel Meda
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11765 players.
# 14823 players remaining.
#
#
# Start Scraping: Arturo Schmidt
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11766 players.
# 14822 players remaining.
#
#
# Start Scraping: Pietro Miki
# Finish Scraping 11767 players.
# 14821 players remaining.
#
#
# Start Scraping: Hao Sheng Koay
# Finish Scraping 11768 players.
# 14820 players remaining.
#
#
# Start Scraping: Camilo Ponce
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11769 players.
# 14819 players remaining.
#
#
# Start Scraping: William Mason
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 11770 players.
# 14818 players remaining.
#
#
# Start Scraping: Dmytro Ishtuganov
# Finish Scraping 11771 players.
# 14817 players remaining.
#
#
# Start Scraping: Richard Yang
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11772 players.
# 14816 players remaining.
#
#
# Start Scraping: Tomas Kaluzik
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11773 players.
# 14815 players remaining.
#
#
# Start Scraping: Basil Khuma
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11774 players.
# 14814 players remaining.
#
#
# Start Scraping: Pascal Ziyab Alome
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 11775 players.
# 14813 players remaining.
#
#
# Start Scraping: Christopher Grant
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11776 players.
# 14812 players remaining.
#
#
# Start Scraping: Ansu Bhuyan
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 11777 players.
# 14811 players remaining.
#
#
# Start Scraping: Christopher Helliar
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11778 players.
# 14810 players remaining.
#
#
# Start Scraping: Miguel Deus
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11779 players.
# 14809 players remaining.
#
#
# Start Scraping: Alan Bzarov
# Finish Scraping 11780 players.
# 14808 players remaining.
#
#
# Start Scraping: Daniel Svensson
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11781 players.
# 14807 players remaining.
#
#
# Start Scraping: Henrik Heise Korsgaard
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11782 players.
# 14806 players remaining.
#
#
# Start Scraping: Yannick Lenaerts
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 11783 players.
# 14805 players remaining.
#
#
# Start Scraping: Vorachon Rakpuangchon
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11784 players.
# 14804 players remaining.
#
#
# Start Scraping: Arnaud Restifo
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11785 players.
# 14803 players remaining.
#
#
# Start Scraping: Fermin Peralta Martinez
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11786 players.
# 14802 players remaining.
#
#
# Start Scraping: Luis Eduardo Morfin Friebel
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11787 players.
# 14801 players remaining.
#
#
# Start Scraping: Gianluca Bergomi
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11788 players.
# 14800 players remaining.
#
#
# Start Scraping: Andrei Marinescu
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11789 players.
# 14799 players remaining.
#
#
# Start Scraping: Radu Andrei Stelian
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11790 players.
# 14798 players remaining.
#
#
# Start Scraping: Cem Erturk
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11791 players.
# 14797 players remaining.
#
#
# Start Scraping: Sai Saran Reddy Byreddy
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11792 players.
# 14796 players remaining.
#
#
# Start Scraping: Christopher Morin Kougoucheff
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11793 players.
# 14795 players remaining.
#
#
# Start Scraping: Aleksandr Malyshev
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11794 players.
# 14794 players remaining.
#
#
# Start Scraping: David Novotny
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11795 players.
# 14793 players remaining.
#
#
# Start Scraping: Samuel Sanchez
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 11796 players.
# 14792 players remaining.
#
#
# Start Scraping: Tiago Silva
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 11797 players.
# 14791 players remaining.
#
#
# Start Scraping: Woo Hyeok Jang
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11798 players.
# 14790 players remaining.
#
#
# Start Scraping: Jamie Asanee Praditngam
# Finish Scraping 11799 players.
# 14789 players remaining.
#
#
# Start Scraping: Hsin Lin
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11800 players.
# 14788 players remaining.
#
#
# Start Scraping: Osama Zoghlami
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11801 players.
# 14787 players remaining.
#
#
# Start Scraping: Sergey Belov
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11802 players.
# 14786 players remaining.
#
#
# Start Scraping: Yu Chang Wang
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11803 players.
# 14785 players remaining.
#
#
# Start Scraping: Jordan Dyke
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11804 players.
# 14784 players remaining.
#
#
# Start Scraping: Pedro Munafo
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11805 players.
# 14783 players remaining.
#
#
# Start Scraping: Refiloe Molaoa
# Finish Scraping 11806 players.
# 14782 players remaining.
#
#
# Start Scraping: Gabriel Francisco Cucalon Jacques
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11807 players.
# 14781 players remaining.
#
#
# Start Scraping: Javier Ladron De Guevara Hi
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11808 players.
# 14780 players remaining.
#
#
# Start Scraping: Edin Zecevic
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11809 players.
# 14779 players remaining.
#
#
# Start Scraping: Andrei Andrukhou
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11810 players.
# 14778 players remaining.
#
#
# Start Scraping: Mika Julin
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11811 players.
# 14777 players remaining.
#
#
# Start Scraping: Kyle Joshua Dandan
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 11812 players.
# 14776 players remaining.
#
#
# Start Scraping: Oleg Koval
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11813 players.
# 14775 players remaining.
#
#
# Start Scraping: Fahad Mohammed
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 11814 players.
# 14774 players remaining.
#
#
# Start Scraping: Garry Tokas
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11815 players.
# 14773 players remaining.
#
#
# Start Scraping: Piercarlo Bianciardi
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11816 players.
# 14772 players remaining.
#
#
# Start Scraping: Frantisek Polanka
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11817 players.
# 14771 players remaining.
#
#
# Start Scraping: Andreas Moltke Leth
# Finish Scraping 11818 players.
# 14770 players remaining.
#
#
# Start Scraping: Mina Albert
# Finish Scraping 11819 players.
# 14769 players remaining.
#
#
# Start Scraping: Robin Goodman
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11820 players.
# 14768 players remaining.
#
#
# Start Scraping: Oleg Dovgan
# Finish Scraping 11821 players.
# 14767 players remaining.
#
#
# Start Scraping: Carlos Anez
# Finish Scraping 11822 players.
# 14766 players remaining.
#
#
# Start Scraping: Antonio Sabugueiro
# Finish Scraping 11823 players.
# 14765 players remaining.
#
#
# Start Scraping: Rudy Richter
# Finish Scraping 11824 players.
# 14764 players remaining.
#
#
# Start Scraping: Koki Takada
# Finish Scraping 11825 players.
# 14763 players remaining.
#
#
# Start Scraping: James Buckley
# Finish Scraping 11826 players.
# 14762 players remaining.
#
#
# Start Scraping: Jean Neuman
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 11827 players.
# 14761 players remaining.
#
#
# Start Scraping: Miguel Maurtua
# Finish Scraping 11828 players.
# 14760 players remaining.
#
#
# Start Scraping: Abdel Ghani Mohammed
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 11829 players.
# 14759 players remaining.
#
#
# Start Scraping: Kenneth Tsui
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11830 players.
# 14758 players remaining.
#
#
# Start Scraping: Lluis Soler Jimenez
# Finish Scraping 11831 players.
# 14757 players remaining.
#
#
# Start Scraping: Mohamed Abdel Moneim
# Finish Scraping 11832 players.
# 14756 players remaining.
#
#
# Start Scraping: Marco Sitepu
# Finish Scraping 11833 players.
# 14755 players remaining.
#
#
# Start Scraping: Stephen Sruk
# Finish Scraping 11834 players.
# 14754 players remaining.
#
#
# Start Scraping: Phalkun Mam
# Finish Scraping 11835 players.
# 14753 players remaining.
#
#
# Start Scraping: Soufiane Sahli
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11836 players.
# 14752 players remaining.
#
#
# Start Scraping: Emmanuel Idoko
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11837 players.
# 14751 players remaining.
#
#
# Start Scraping: Jorge Enrique Gonzalez Aramburu
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11838 players.
# 14750 players remaining.
#
#
# Start Scraping: Ivan Polyakov
# Finish Scraping 11839 players.
# 14749 players remaining.
#
#
# Start Scraping: Johnny Wang
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11840 players.
# 14748 players remaining.
#
#
# Start Scraping: Artur Madzhar
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11841 players.
# 14747 players remaining.
#
#
# Start Scraping: Magomed Akaev
# Finish Scraping 11842 players.
# 14746 players remaining.
#
#
# Start Scraping: Wenceslao Robles Febrer
# Finish Scraping 11843 players.
# 14745 players remaining.
#
#
# Start Scraping: Kodjo Sodji
# Finish Scraping 11844 players.
# 14744 players remaining.
#
#
# Start Scraping: Doug Bloom
# Finish Scraping 11845 players.
# 14743 players remaining.
#
#
# Start Scraping: Robin Fiorina
# Finish Scraping 11846 players.
# 14742 players remaining.
#
#
# Start Scraping: Jeff Morneau
# Finish Scraping 11847 players.
# 14741 players remaining.
#
#
# Start Scraping: Yong Min Kwon
# Finish Scraping 11848 players.
# 14740 players remaining.
#
#
# Start Scraping: Richard Benvin
# Finish Scraping 11849 players.
# 14739 players remaining.
#
#
# Start Scraping: Yi Da Chuang
# Finish Scraping 11850 players.
# 14738 players remaining.
#
#
# Start Scraping: Ivan Toth
# Finish Scraping 11851 players.
# 14737 players remaining.
#
#
# Start Scraping: Ricardo Ferreira
# Finish Scraping 11852 players.
# 14736 players remaining.
#
#
# Start Scraping: Claudio Galoppini
# Finish Scraping 11853 players.
# 14735 players remaining.
#
#
# Start Scraping: Ashley Fickel
# Finish Scraping 11854 players.
# 14734 players remaining.
#
#
# Start Scraping: Jose Maria Moreno
# Finish Scraping 11855 players.
# 14733 players remaining.
#
#
# Start Scraping: Eddy Schol
# Finish Scraping 11856 players.
# 14732 players remaining.
#
#
# Start Scraping: Dino Bohm
# Finish Scraping 11857 players.
# 14731 players remaining.
#
#
# Start Scraping: David Shann
# Finish Scraping 11858 players.
# 14730 players remaining.
#
#
# Start Scraping: Sascha Schewiola
# Finish Scraping 11859 players.
# 14729 players remaining.
#
#
# Start Scraping: Jan Hage
# Finish Scraping 11860 players.
# 14728 players remaining.
#
#
# Start Scraping: Bas Wild
# Finish Scraping 11861 players.
# 14727 players remaining.
#
#
# Start Scraping: Ivan Espilez Urbon
# Finish Scraping 11862 players.
# 14726 players remaining.
#
#
# Start Scraping: Fulgencio Tello Rodriguez
# Finish Scraping 11863 players.
# 14725 players remaining.
#
#
# Start Scraping: Hector Calvo Garcia
# Finish Scraping 11864 players.
# 14724 players remaining.
#
#
# Start Scraping: Juan Diego Marin
# Finish Scraping 11865 players.
# 14723 players remaining.
#
#
# Start Scraping: Jesco Von Heintze
# Finish Scraping 11866 players.
# 14722 players remaining.
#
#
# Start Scraping: Eugeniy Samsonov
# Finish Scraping 11867 players.
# 14721 players remaining.
#
#
# Start Scraping: Garett Prins
# Finish Scraping 11868 players.
# 14720 players remaining.
#
#
# Start Scraping: Kevin Erickson
# Finish Scraping 11869 players.
# 14719 players remaining.
#
#
# Start Scraping: Thomas Pablo
# Finish Scraping 11870 players.
# 14718 players remaining.
#
#
# Start Scraping: Stefan Pampulov
# Finish Scraping 11871 players.
# 14717 players remaining.
#
#
# Start Scraping: Pavlin Marginov
# Finish Scraping 11872 players.
# 14716 players remaining.
#
#
# Start Scraping: Diego Carlucho
# Finish Scraping 11873 players.
# 14715 players remaining.
#
#
# Start Scraping: Nikolaus Patzak
# Finish Scraping 11874 players.
# 14714 players remaining.
#
#
# Start Scraping: William Oneil
# Finish Scraping 11875 players.
# 14713 players remaining.
#
#
# Start Scraping: Cristian Segni
# Finish Scraping 11876 players.
# 14712 players remaining.
#
#
# Start Scraping: Ryoma Sloane
# Finish Scraping 11877 players.
# 14711 players remaining.
#
#
# Start Scraping: Athanasios Verbis
# Finish Scraping 11878 players.
# 14710 players remaining.
#
#
# Start Scraping: Agustin Savarino
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11879 players.
# 14709 players remaining.
#
#
# Start Scraping: Gonzalo Tomas Perez Bacigalupo
# Finish Scraping 11880 players.
# 14708 players remaining.
#
#
# Start Scraping: Iancu Lustinian Ghinda
# Finish Scraping 11881 players.
# 14707 players remaining.
#
#
# Start Scraping: Thibaud Berland
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11882 players.
# 14706 players remaining.
#
#
# Start Scraping: Yehonatan Kaufman
# Finish Scraping 11883 players.
# 14705 players remaining.
#
#
# Start Scraping: Ravi Patel
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11884 players.
# 14704 players remaining.
#
#
# Start Scraping: Przemyslaw Filipek
# Finish Scraping 11885 players.
# 14703 players remaining.
#
#
# Start Scraping: Jaan Kononov
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11886 players.
# 14702 players remaining.
#
#
# Start Scraping: Phillip Anderson
# Finish Scraping 11887 players.
# 14701 players remaining.
#
#
# Start Scraping: Arief Rahman
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11888 players.
# 14700 players remaining.
#
#
# Start Scraping: Aaditya Tewari
# Finish Scraping 11889 players.
# 14699 players remaining.
#
#
# Start Scraping: Rodrigo Giudici
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11890 players.
# 14698 players remaining.
#
#
# Start Scraping: Alejandro Andino Vallverdu
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11891 players.
# 14697 players remaining.
#
#
# Start Scraping: Samuel Omoile
# Finish Scraping 11892 players.
# 14696 players remaining.
#
#
# Start Scraping: Cristian Chavez
# Finish Scraping 11893 players.
# 14695 players remaining.
#
#
# Start Scraping: Ognjen Jovanovic
# Finish Scraping 11894 players.
# 14694 players remaining.
#
#
# Start Scraping: Christian Oliver Lee
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11895 players.
# 14693 players remaining.
#
#
# Start Scraping: Leonard Ivic
# Finish Scraping 11896 players.
# 14692 players remaining.
#
#
# Start Scraping: Matej Leljak
# Finish Scraping 11897 players.
# 14691 players remaining.
#
#
# Start Scraping: Alex J Trillini
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11898 players.
# 14690 players remaining.
#
#
# Start Scraping: Eduardo Segura Mandarino
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11899 players.
# 14689 players remaining.
#
#
# Start Scraping: Joey B Burkhardt
# Finish Scraping 11900 players.
# 14688 players remaining.
#
#
# Start Scraping: Mauricio Fosado Lopez
# Finish Scraping 11901 players.
# 14687 players remaining.
#
#
# Start Scraping: Lorenzo Cremonini
# Finish Scraping 11902 players.
# 14686 players remaining.
#
#
# Start Scraping: Ricardo Jorge
# Finish Scraping 11903 players.
# 14685 players remaining.
#
#
# Start Scraping: Krishik Divakar
# Finish Scraping 11904 players.
# 14684 players remaining.
#
#
# Start Scraping: Chris Kearney
# Finish Scraping 11905 players.
# 14683 players remaining.
#
#
# Start Scraping: Zeyad Montasser
# Finish Scraping 11906 players.
# 14682 players remaining.
#
#
# Start Scraping: Marco Stancati
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 11907 players.
# 14681 players remaining.
#
#
# Start Scraping: Ashley Watling
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 11908 players.
# 14680 players remaining.
#
#
# Start Scraping: Luca Roshardt
# Finish Scraping 11909 players.
# 14679 players remaining.
#
#
# Start Scraping: Alexander Gigitashvili
# Finish Scraping 11910 players.
# 14678 players remaining.
#
#
# Start Scraping: Alex Bothe
# Finish Scraping 11911 players.
# 14677 players remaining.
#
#
# Start Scraping: Aboubacar Sigue
# Finish Scraping 11912 players.
# 14676 players remaining.
#
#
# Start Scraping: Andrei Gratian Onciu
# Finish Scraping 11913 players.
# 14675 players remaining.
#
#
# Start Scraping: Remi Groenendaal
# Finish Scraping 11914 players.
# 14674 players remaining.
#
#
# Start Scraping: Matthew Leahy
# Finish Scraping 11915 players.
# 14673 players remaining.
#
#
# Start Scraping: Stefan Dmitrovic
# Finish Scraping 11916 players.
# 14672 players remaining.
#
#
# Start Scraping: Mikolaj Borkowski
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 11917 players.
# 14671 players remaining.
#
#
# Start Scraping: Jan Serdakowski
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 11918 players.
# 14670 players remaining.
#
#
# Start Scraping: Tomohiro Shinokawa
# Finish Scraping 11919 players.
# 14669 players remaining.
#
#
# Start Scraping: Danny Bryan
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11920 players.
# 14668 players remaining.
#
#
# Start Scraping: Andre Brisighello
# Finish Scraping 11921 players.
# 14667 players remaining.
#
#
# Start Scraping: Menford Owusu
# Finish Scraping 11922 players.
# 14666 players remaining.
#
#
# Start Scraping: Kirill Sinitsyn
# Finish Scraping 11923 players.
# 14665 players remaining.
#
#
# Start Scraping: Calin Paar
# Finish Scraping 11924 players.
# 14664 players remaining.
#
#
# Start Scraping: Edgars Manusis
# Finish Scraping 11925 players.
# 14663 players remaining.
#
#
# Start Scraping: Diego Oliveira
# Finish Scraping 11926 players.
# 14662 players remaining.
#
#
# Start Scraping: Paul Moggre
# Finish Scraping 11927 players.
# 14661 players remaining.
#
#
# Start Scraping: Danny Spierenburg
# Finish Scraping 11928 players.
# 14660 players remaining.
#
#
# Start Scraping: Pierre Mouillon
# Finish Scraping 11929 players.
# 14659 players remaining.
#
#
# Start Scraping: Alexandru Joitoiu
# Finish Scraping 11930 players.
# 14658 players remaining.
#
#
# Start Scraping: Filip Spasojevic
# Finish Scraping 11931 players.
# 14657 players remaining.
#
#
# Start Scraping: Pim Van Mele
# Finish Scraping 11932 players.
# 14656 players remaining.
#
#
# Start Scraping: Diego Puerto Jaimez
# Finish Scraping 11933 players.
# 14655 players remaining.
#
#
# Start Scraping: Cristian Orduna Guzman
# Finish Scraping 11934 players.
# 14654 players remaining.
#
#
# Start Scraping: Juan Carlo Acuna Gerard
# Finish Scraping 11935 players.
# 14653 players remaining.
#
#
# Start Scraping: Diego Medrano
# Finish Scraping 11936 players.
# 14652 players remaining.
#
#
# Start Scraping: Suleman Jafarey Hall
# Finish Scraping 11937 players.
# 14651 players remaining.
#
#
# Start Scraping: Renato Pereira
# Finish Scraping 11938 players.
# 14650 players remaining.
#
#
# Start Scraping: Pedro Zanotelli
# Finish Scraping 11939 players.
# 14649 players remaining.
#
#
# Start Scraping: Wasif Cheema
# Finish Scraping 11940 players.
# 14648 players remaining.
#
#
# Start Scraping: Dmitry Sventitsky
# Finish Scraping 11941 players.
# 14647 players remaining.
#
#
# Start Scraping: Christian Lichtenegger
# Finish Scraping 11942 players.
# 14646 players remaining.
#
#
# Start Scraping: Tomislav Raca
# Finish Scraping 11943 players.
# 14645 players remaining.
#
#
# Start Scraping: Roy Radwan
# Finish Scraping 11944 players.
# 14644 players remaining.
#
#
# Start Scraping: Cheikh Salif Kante
# Finish Scraping 11945 players.
# 14643 players remaining.
#
#
# Start Scraping: Kotaro Isobe
# Finish Scraping 11946 players.
# 14642 players remaining.
#
#
# Start Scraping: Ivan Cressoni
# Finish Scraping 11947 players.
# 14641 players remaining.
#
#
# Start Scraping: Duje Tomasovic
# Finish Scraping 11948 players.
# 14640 players remaining.
#
#
# Start Scraping: Miloslav Navratil
# Finish Scraping 11949 players.
# 14639 players remaining.
#
#
# Start Scraping: Pertti Vesantera
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11950 players.
# 14638 players remaining.
#
#
# Start Scraping: Rikus De Villiers
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 11951 players.
# 14637 players remaining.
#
#
# Start Scraping: Rainier Nagel
# Finish Scraping 11952 players.
# 14636 players remaining.
#
#
# Start Scraping: Guo Bin Cen
# Finish Scraping 11953 players.
# 14635 players remaining.
#
#
# Start Scraping: Daniele Micolani
# Finish Scraping 11954 players.
# 14634 players remaining.
#
#
# Start Scraping: Tomas Banczi
# Finish Scraping 11955 players.
# 14633 players remaining.
#
#
# Start Scraping: Roger Lacaci Dominguez
# Finish Scraping 11956 players.
# 14632 players remaining.
#
#
# Start Scraping: Elliot Wronski
# Finish Scraping 11957 players.
# 14631 players remaining.
#
#
# Start Scraping: Kevin Abele
# Finish Scraping 11958 players.
# 14630 players remaining.
#
#
# Start Scraping: Andy De Bruijne
# Finish Scraping 11959 players.
# 14629 players remaining.
#
#
# Start Scraping: Sebastian Gallego Betancor
# Finish Scraping 11960 players.
# 14628 players remaining.
#
#
# Start Scraping: Jesus Martinez Mozo
# Finish Scraping 11961 players.
# 14627 players remaining.
#
#
# Start Scraping: Jorge Laranjeiro
# Finish Scraping 11962 players.
# 14626 players remaining.
#
#
# Start Scraping: Javier Ferrin Kranewitter
# Finish Scraping 11963 players.
# 14625 players remaining.
#
#
# Start Scraping: Oscar Castillon Miguez
# Finish Scraping 11964 players.
# 14624 players remaining.
#
#
# Start Scraping: Adam Barratclough
# Finish Scraping 11965 players.
# 14623 players remaining.
#
#
# Start Scraping: Parantap Chaturvedi
# Finish Scraping 11966 players.
# 14622 players remaining.
#
#
# Start Scraping: Andrey Kozhemyakin
# Finish Scraping 11967 players.
# 14621 players remaining.
#
#
# Start Scraping: Nicolas Riquelme
# Finish Scraping 11968 players.
# 14620 players remaining.
#
#
# Start Scraping: David Brady
# Finish Scraping 11969 players.
# 14619 players remaining.
#
#
# Start Scraping: Eric Hagenimana
# Finish Scraping 11970 players.
# 14618 players remaining.
#
#
# Start Scraping: Salvador De La Torre
# Finish Scraping 11971 players.
# 14617 players remaining.
#
#
# Start Scraping: Hamed Al Solaiteen
# Finish Scraping 11972 players.
# 14616 players remaining.
#
#
# Start Scraping: Ron Mercer
# Finish Scraping 11973 players.
# 14615 players remaining.
#
#
# Start Scraping: Juan Torres Palacios
# Finish Scraping 11974 players.
# 14614 players remaining.
#
#
# Start Scraping: Alexei Zharinov
# Finish Scraping 11975 players.
# 14613 players remaining.
#
#
# Start Scraping: Ross Nwachukwu
# Finish Scraping 11976 players.
# 14612 players remaining.
#
#
# Start Scraping: Doruk Baglan
# Finish Scraping 11977 players.
# 14611 players remaining.
#
#
# Start Scraping: Christian Kern
# Finish Scraping 11978 players.
# 14610 players remaining.
#
#
# Start Scraping: Luca Casanova
# Finish Scraping 11979 players.
# 14609 players remaining.
#
#
# Start Scraping: Yasser Arafat Mohammad
# Finish Scraping 11980 players.
# 14608 players remaining.
#
#
# Start Scraping: Janusch Graf
# Finish Scraping 11981 players.
# 14607 players remaining.
#
#
# Start Scraping: Justin Visser
# Finish Scraping 11982 players.
# 14606 players remaining.
#
#
# Start Scraping: Andrew Irving
# Finish Scraping 11983 players.
# 14605 players remaining.
#
#
# Start Scraping: Dinos Pavlou
# Finish Scraping 11984 players.
# 14604 players remaining.
#
#
# Start Scraping: Regnier Azevedo
# Finish Scraping 11985 players.
# 14603 players remaining.
#
#
# Start Scraping: Unai Corujo Rodriguez
# Finish Scraping 11986 players.
# 14602 players remaining.
#
#
# Start Scraping: Ivor Lovrak
# Finish Scraping 11987 players.
# 14601 players remaining.
#
#
# Start Scraping: Mitko Blagoev
# Finish Scraping 11988 players.
# 14600 players remaining.
#
#
# Start Scraping: Michael Dalus
# Finish Scraping 11989 players.
# 14599 players remaining.
#
#
# Start Scraping: Gilles Lagardere
# Finish Scraping 11990 players.
# 14598 players remaining.
#
#
# Start Scraping: Wilson Montoya
# Finish Scraping 11991 players.
# 14597 players remaining.
#
#
# Start Scraping: Marius Raicea
# Finish Scraping 11992 players.
# 14596 players remaining.
#
#
# Start Scraping: Kevron Bennett
# Finish Scraping 11993 players.
# 14595 players remaining.
#
#
# Start Scraping: Atsufumi Yoshikawa
# Finish Scraping 11994 players.
# 14594 players remaining.
#
#
# Start Scraping: Emiliano Peralta
# Finish Scraping 11995 players.
# 14593 players remaining.
#
#
# Start Scraping: Billy Wilkinson
# Finish Scraping 11996 players.
# 14592 players remaining.
#
#
# Start Scraping: Royce Ramey
# Finish Scraping 11997 players.
# 14591 players remaining.
#
#
# Start Scraping: Marko Vukelic
# Finish Scraping 11998 players.
# 14590 players remaining.
#
#
# Start Scraping: Aleksander Djuranovic
# Finish Scraping 11999 players.
# 14589 players remaining.
#
#
# Start Scraping: Andrew Cochrane
# Finish Scraping 12000 players.
# 14588 players remaining.
#
#
# Start Scraping: Roberto Palpacelli
# Finish Scraping 12001 players.
# ...
#
#
# Start Scraping: Jose Fernandez
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26430 players.
# 158 players remaining.
#
#
# Start Scraping: Jose Delafuente
# Finish Scraping 26431 players.
# 157 players remaining.
#
#
# Start Scraping: Jorge Cano
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26432 players.
# 156 players remaining.
#
#
# Start Scraping: Johnies Sauer
# Finish Scraping 26433 players.
# 155 players remaining.
#
#
# Start Scraping: John Werner
# Finish Scraping 26434 players.
# 154 players remaining.
#
#
# Start Scraping: John Kapakoglu
# Finish Scraping 26435 players.
# 153 players remaining.
#
#
# Start Scraping: Johan Sjogren
# Finish Scraping 26436 players.
# 152 players remaining.
#
#
# Start Scraping: Johan Milbrimk
# Finish Scraping 26437 players.
# 151 players remaining.
#
#
# Start Scraping: Joe Shaheen
# Finish Scraping 26438 players.
# 150 players remaining.
#
#
# Start Scraping: Joao Guedes
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26439 players.
# 149 players remaining.
#
#
# Start Scraping: Joao Coutinho
# Finish Scraping 26440 players.
# 148 players remaining.
#
#
# Start Scraping: Jin So Lee
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26441 players.
# 147 players remaining.
#
#
# Start Scraping: Jim Somerville
# Finish Scraping 26442 players.
# 146 players remaining.
#
#
# Start Scraping: Jeremy Grubi
# Finish Scraping 26443 players.
# 145 players remaining.
#
#
# Start Scraping: Jeff Player
# Finish Scraping 26444 players.
# 144 players remaining.
#
#
# Start Scraping: Jeff Crowne
# Finish Scraping 26445 players.
# 143 players remaining.
#
#
# Start Scraping: Jean Francois Blain
# Finish Scraping 26446 players.
# 142 players remaining.
#
#
# Start Scraping: Javier Duarte
# Finish Scraping 26447 players.
# 141 players remaining.
#
#
# Start Scraping: Jason Wilkie
# Finish Scraping 26448 players.
# 140 players remaining.
#
#
# Start Scraping: James Ilako
# Finish Scraping 26449 players.
# 139 players remaining.
#
#
# Start Scraping: Jacques Bonnemaison
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26450 players.
# 138 players remaining.
#
#
# Start Scraping: J Spinnenweber
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26451 players.
# 137 players remaining.
#
#
# Start Scraping: J Potgieter
# Finish Scraping 26452 players.
# 136 players remaining.
#
#
# Start Scraping: Ian Duvenhage
# Finish Scraping 26453 players.
# 135 players remaining.
#
#
# Start Scraping: Ian Bersin
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26454 players.
# 134 players remaining.
#
#
# Start Scraping: Horacio Marin
# Finish Scraping 26455 players.
# 133 players remaining.
#
#
# Start Scraping: Holger Trahn
# Finish Scraping 26456 players.
# 132 players remaining.
#
#
# Start Scraping: Hiroshi Ito
# Finish Scraping 26457 players.
# 131 players remaining.
#
#
# Start Scraping: Herve Bardot
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26458 players.
# 130 players remaining.
#
#
# Start Scraping: Hernan Valenzuela
# Finish Scraping 26459 players.
# 129 players remaining.
#
#
# Start Scraping: Harvey Becker
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26460 players.
# 128 players remaining.
#
#
# Start Scraping: H Hsu
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26461 players.
# 127 players remaining.
#
#
# Start Scraping: Gustavo Merbilhaa
# Finish Scraping 26462 players.
# 126 players remaining.
#
#
# Start Scraping: Gustavo Espinosa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26463 players.
# 125 players remaining.
#
#
# Start Scraping: Gulio Melchiorre
# Finish Scraping 26464 players.
# 124 players remaining.
#
#
# Start Scraping: Guido Possamai
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26465 players.
# 123 players remaining.
#
#
# Start Scraping: Greg Muller
# Finish Scraping 26466 players.
# 122 players remaining.
#
#
# Start Scraping: Greg Ewansky
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26467 players.
# 121 players remaining.
#
#
# Start Scraping: Graziano Risi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26468 players.
# 120 players remaining.
#
#
# Start Scraping: Graham Epsley Jones
# Finish Scraping 26469 players.
# 119 players remaining.
#
#
# Start Scraping: Gerardo Hernandez
# Finish Scraping 26470 players.
# 118 players remaining.
#
#
# Start Scraping: George Obidiegwu
# Finish Scraping 26471 players.
# 117 players remaining.
#
#
# Start Scraping: George Goncalves
# Finish Scraping 26472 players.
# 116 players remaining.
#
#
# Start Scraping: Gavin Hewson
# Finish Scraping 26473 players.
# 115 players remaining.
#
#
# Start Scraping: Gary Seymour
# Finish Scraping 26474 players.
# 114 players remaining.
#
#
# Start Scraping: Frank Apecehea
# Finish Scraping 26475 players.
# 113 players remaining.
#
#
# Start Scraping: Francis Ikosa
# Finish Scraping 26476 players.
# 112 players remaining.
#
#
# Start Scraping: Fernando Souza
# Finish Scraping 26477 players.
# 111 players remaining.
#
#
# Start Scraping: Evgeni Zhelyazkov
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26478 players.
# 110 players remaining.
#
#
# Start Scraping: Enno Van Veggel
# Finish Scraping 26479 players.
# 109 players remaining.
#
#
# Start Scraping: Emmanuel Brard
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26480 players.
# 108 players remaining.
#
#
# Start Scraping: Emeka Igbinebor
# Finish Scraping 26481 players.
# 107 players remaining.
#
#
# Start Scraping: Eduardo Bricio
# Finish Scraping 26482 players.
# 106 players remaining.
#
#
# Start Scraping: Eddie Siegenthaler
# Finish Scraping 26483 players.
# 105 players remaining.
#
#
# Start Scraping: Donald England
# Finish Scraping 26484 players.
# 104 players remaining.
#
#
# Start Scraping: Didier Frantz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26485 players.
# 103 players remaining.
#
#
# Start Scraping: Delroy Reid
# Finish Scraping 26486 players.
# 102 players remaining.
#
#
# Start Scraping: Davn Santiago
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26487 players.
# 101 players remaining.
#
#
# Start Scraping: David Leveaux
# Finish Scraping 26488 players.
# 100 players remaining.
#
#
# Start Scraping: David Kacharava
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26489 players.
# 99 players remaining.
#
#
# Start Scraping: David Culley
# Finish Scraping 26490 players.
# 98 players remaining.
#
#
# Start Scraping: David Betous
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26491 players.
# 97 players remaining.
#
#
# Start Scraping: Daryl Greeves
# Finish Scraping 26492 players.
# 96 players remaining.
#
#
# Start Scraping: Darren Cole
# Finish Scraping 26493 players.
# 95 players remaining.
#
#
# Start Scraping: Daniel Garcia
# Finish Scraping 26494 players.
# 94 players remaining.
#
#
# Start Scraping: Dan Rastland
# Finish Scraping 26495 players.
# 93 players remaining.
#
#
# Start Scraping: Curtis Hollinger
# Finish Scraping 26496 players.
# 92 players remaining.
#
#
# Start Scraping: Cristofer Leberth
# Finish Scraping 26497 players.
# 91 players remaining.
#
#
# Start Scraping: Cris Herman
# Finish Scraping 26498 players.
# 90 players remaining.
#
#
# Start Scraping: Corey Wittenberg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26499 players.
# 89 players remaining.
#
#
# Start Scraping: Claudio Semmelmann
# Finish Scraping 26500 players.
# 88 players remaining.
#
#
# Start Scraping: Claudio Menna
# Finish Scraping 26501 players.
# 87 players remaining.
#
#
# Start Scraping: Claudio Fava
# Finish Scraping 26502 players.
# 86 players remaining.
#
#
# Start Scraping: Christopher Wolff
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26503 players.
# 85 players remaining.
#
#
# Start Scraping: Christoph Geukens
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26504 players.
# 84 players remaining.
#
#
# Start Scraping: Chris Vermeeren
# Finish Scraping 26505 players.
# 83 players remaining.
#
#
# Start Scraping: Chris Ellis
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26506 players.
# 82 players remaining.
#
#
# Start Scraping: Chip Tolleson
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26507 players.
# 81 players remaining.
#
#
# Start Scraping: Carlos Stocker
# Finish Scraping 26508 players.
# 80 players remaining.
#
#
# Start Scraping: Carlo Zugarelli
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26509 players.
# 79 players remaining.
#
#
# Start Scraping: Carl Williams
# Finish Scraping 26510 players.
# 78 players remaining.
#
#
# Start Scraping: Carey Brading
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26511 players.
# 77 players remaining.
#
#
# Start Scraping: Bunge Nahor
# Finish Scraping 26512 players.
# 76 players remaining.
#
#
# Start Scraping: Brett Hibbert
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26513 players.
# 75 players remaining.
#
#
# Start Scraping: Brendan Sharp
# Finish Scraping 26514 players.
# 74 players remaining.
#
#
# Start Scraping: Bosko Simundsa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26515 players.
# 73 players remaining.
#
#
# Start Scraping: Bob Deller
# Finish Scraping 26516 players.
# 72 players remaining.
#
#
# Start Scraping: Bjorn Wahlstrom
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26517 players.
# 71 players remaining.
#
#
# Start Scraping: Bernardo Padilha
# Finish Scraping 26518 players.
# 70 players remaining.
#
#
# Start Scraping: Babatunde Akinola
# Finish Scraping 26519 players.
# 69 players remaining.
#
#
# Start Scraping: B Hochstadter
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26520 players.
# 68 players remaining.
#
#
# Start Scraping: Archie Adams
# Finish Scraping 26521 players.
# 67 players remaining.
#
#
# Start Scraping: Antti Eranne
# Finish Scraping 26522 players.
# 66 players remaining.
#
#
# Start Scraping: Antonio Zampieri
# Finish Scraping 26523 players.
# 65 players remaining.
#
#
# Start Scraping: Anthony Burke
# Finish Scraping 26524 players.
# 64 players remaining.
#
#
# Start Scraping: Andreas Fink
# Finish Scraping 26525 players.
# 63 players remaining.
#
#
# Start Scraping: Anders Rolfsen
# Finish Scraping 26526 players.
# 62 players remaining.
#
#
# Start Scraping: Alberto Kulmann
# Finish Scraping 26527 players.
# 61 players remaining.
#
#
# Start Scraping: Alan Tunik
# Finish Scraping 26528 players.
# 60 players remaining.
#
#
# Start Scraping: Alan Douglas
# Finish Scraping 26529 players.
# 59 players remaining.
#
#
# Start Scraping: A Noffat
# Finish Scraping 26530 players.
# 58 players remaining.
#
#
# Start Scraping: A Hall
# Serve Page: 893
# Return Page: 893
# Raw Page: 893
# Finish Scraping 26531 players.
# 57 players remaining.
#
#
# Start Scraping: Arkadiusz Kocyla Kd20
# Finish Scraping 26532 players.
# 56 players remaining.
#
#
# Start Scraping: Yoann Re
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 26533 players.
# 55 players remaining.
#
#
# Start Scraping: Antonio Ruiz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26534 players.
# 54 players remaining.
#
#
# Start Scraping: Ravishankar Pathanjali
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26535 players.
# 53 players remaining.
#
#
# Start Scraping: Eduardo Magadan
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26536 players.
# 52 players remaining.
#
#
# Start Scraping: Will Farah
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26537 players.
# 51 players remaining.
#
#
# Start Scraping: Juri Margotto
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26538 players.
# 50 players remaining.
#
#
# Start Scraping: Emmanuel Marmillod
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26539 players.
# 49 players remaining.
#
#
# Start Scraping: Juan Olivert
# Finish Scraping 26540 players.
# 48 players remaining.
#
#
# Start Scraping: David Franco
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26541 players.
# 47 players remaining.
#
#
# Start Scraping: Alexander Lindholm L174
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26542 players.
# 46 players remaining.
#
#
# Start Scraping: Adi Kremer
# Finish Scraping 26543 players.
# 45 players remaining.
#
#
# Start Scraping: Paul Lord
# Finish Scraping 26544 players.
# 44 players remaining.
#
#
# Start Scraping: Alberto Gutierrez G230
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26545 players.
# 43 players remaining.
#
#
# Start Scraping: Glenn Dickerson
# Finish Scraping 26546 players.
# 42 players remaining.
#
#
# Start Scraping: Jochen Wolff
# Finish Scraping 26547 players.
# 41 players remaining.
#
#
# Start Scraping: Yann Drieux
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26548 players.
# 40 players remaining.
#
#
# Start Scraping: Jeff Brown
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 26549 players.
# 39 players remaining.
#
#
# Start Scraping: Peter Herrmann
# Finish Scraping 26550 players.
# 38 players remaining.
#
#
# Start Scraping: Trey Carter
# Finish Scraping 26551 players.
# 37 players remaining.
#
#
# Start Scraping: Doug Pielet
# Finish Scraping 26552 players.
# 36 players remaining.
#
#
# Start Scraping: Eric Rosenfeld
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26553 players.
# 35 players remaining.
#
#
# Start Scraping: Bill Stanley
# Finish Scraping 26554 players.
# 34 players remaining.
#
#
# Start Scraping: Dave Richmond
# Finish Scraping 26555 players.
# 33 players remaining.
#
#
# Start Scraping: Peter Smith
# Serve Page: 893
# Return Page: 893
# Raw Page: 893
# Finish Scraping 26556 players.
# 32 players remaining.
#
#
# Start Scraping: Jim Sharton
# Finish Scraping 26557 players.
# 31 players remaining.
#
#
# Start Scraping: Martin Fortun
# Finish Scraping 26558 players.
# 30 players remaining.
#
#
# Start Scraping: Tom Fontana
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26559 players.
# 29 players remaining.
#
#
# Start Scraping: Kai Niemi
# Finish Scraping 26560 players.
# 28 players remaining.
#
#
# Start Scraping: Rob Mitchell
# Finish Scraping 26561 players.
# 27 players remaining.
#
#
# Start Scraping: Hans Fredborg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26562 players.
# 26 players remaining.
#
#
# Start Scraping: Leighton Alfred
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26563 players.
# 25 players remaining.
#
#
# Start Scraping: Fred Viancos
# Finish Scraping 26564 players.
# 24 players remaining.
#
#
# Start Scraping: Jean Luc Cotard
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26565 players.
# 23 players remaining.
#
#
# Start Scraping: Steven Matthews
# Finish Scraping 26566 players.
# 22 players remaining.
#
#
# Start Scraping: John Losito
# Finish Scraping 26567 players.
# 21 players remaining.
#
#
# Start Scraping: Darcy Carroll
# Finish Scraping 26568 players.
# 20 players remaining.
#
#
# Start Scraping: Mark Pinchoff
# Finish Scraping 26569 players.
# 19 players remaining.
#
#
# Start Scraping: Tracy Fenelon
# Finish Scraping 26570 players.
# 18 players remaining.
#
#
# Start Scraping: Tim Robson
# Finish Scraping 26571 players.
# 17 players remaining.
#
#
# Start Scraping: Tim Downey
# Finish Scraping 26572 players.
# 16 players remaining.
#
#
# Start Scraping: James Rubin
# Finish Scraping 26573 players.
# 15 players remaining.
#
#
# Start Scraping: Andy Gordon
# Finish Scraping 26574 players.
# 14 players remaining.
#
#
# Start Scraping: Larry Barnett
# Finish Scraping 26575 players.
# 13 players remaining.
#
#
# Start Scraping: Eduard Pana
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26576 players.
# 12 players remaining.
#
#
# Start Scraping: Tom Caine
# Finish Scraping 26577 players.
# 11 players remaining.
#
#
# Start Scraping: Doug Adler
# Finish Scraping 26578 players.
# 10 players remaining.
#
#
# Start Scraping: Renald Etienne
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26579 players.
# 9 players remaining.
#
#
# Start Scraping: Jochen Hierl
# Finish Scraping 26580 players.
# 8 players remaining.
#
#
# Start Scraping: Robert Baumgartner
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26581 players.
# 7 players remaining.
#
#
# Start Scraping: David Parker
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26582 players.
# 6 players remaining.
#
#
# Start Scraping: George Glowa
# Finish Scraping 26583 players.
# 5 players remaining.
#
#
# Start Scraping: Zdenek Slizek
# Finish Scraping 26584 players.
# 4 players remaining.
#
#
# Start Scraping: Grant Golden
# Serve Page: 67
# Return Page: 67
# Raw Page: 67
# Finish Scraping 26585 players.
# 3 players remaining.
#
#
# Start Scraping: Jeff Sackmann
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 26586 players.
# 2 players remaining.
#
#
# Start Scraping: Carl Bialik
# Serve Page: 18
# Return Page: 18
# Raw Page: 18
# Finish Scraping 26587 players.
# 1 players remaining.
#
#
# Start Scraping: Edoardo Salvati
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26588 players.
# 0 players remaining.
