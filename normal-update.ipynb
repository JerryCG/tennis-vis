# %% [markdown]
# # Normal Updates - Last Update: 2024-08-26

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from geopy.geocoders import Nominatim

# %% [markdown]
# ## 1. Update ATP Ranking

# %% [markdown]
# ### Single Date Update

# %%
# Load txt files
def load_txt(file):
    with open(file, 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    f.close()
    return df

# %%
# The webdesign may change over time!

def scrape_a_date_rank(date, previous):
    # scrape a particular date
    prefix = 'https://www.atptour.com/en/rankings/singles?RankRange=0-100&DateWeek='  # subject to change
    img_pre = 'https://www.atptour.com/en/~/media/images/flags/'

    # open chrome window
    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=1500, height=800)

    # get url
    driver.get(prefix + date)
    # driver.refresh()   # Refreshing can be detected by blockers

    # get content
    print('Start scraping:', date)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    trs = soup.find('table', {'class':'mega-table desktop-table non-live'}).find_all('tr')

    # set attrs
    attrs = ['Date', 'Rank', 'Country', 'Image', 'Player', 'Points']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # date
    dict['Date'] = [date for i in range(100)]

    for tr in trs:
        
        tds = tr.find_all('td')

        if len(tds) == 8: # check error
            # rank
            dict['Rank'].append(tds[0].text.strip())

            # country, image, player name
            lis = tds[1].find_all('li')
            country_abbr = (lis[1].svg.use.get('href', None))[-3:]
            dict['Country'].append(country_abbr.upper())
            dict['Image'].append(img_pre + country_abbr + '.svg')
            dict['Player'].append(lis[2].text.strip())

            # points
            dict['Points'].append(tds[3].text.strip().replace(',', ''))

    # save to txt
    df = pd.DataFrame(dict)
    df.to_csv('m/rank/dates/' + date + '.txt', index = False, sep = ',', encoding='utf-8-sig')
    print('Finished:', date)

    # open the ranking file
    dict_r = load_txt('m/rank/atpranking_20000110_'+previous.replace('-', '')+'.txt').to_dict('list')
    dict_r[date] = []

    # first get points for existing players
    for p in dict_r['Player']:
        found = False
        for i in range(len(dict['Player'])):
            if p == dict['Player'][i]:
                # add new point
                dict_r[date].append(dict['Points'][i])
                found = True
                break
        if not found:
            dict_r[date].append(0)

    # add new player if any
    for p in dict['Player']:
        if p not in dict_r['Player']:
            # add player
            dict_r['Player'].append(p)
            for i in range(len(dict['Player'])):
                if p == dict['Player'][i]:
                    # add country
                    dict_r['Country'].append(dict['Country'][i])
                    # add image
                    dict_r['Country_Image'].append(dict['Image'][i])
                    # add point
                    dict_r[date].append(dict['Points'][i])
                    break
            # add previous points, all 0
            for d in [key for key in dict_r.keys()][3:-1]:
                dict_r[d].append(0)

    # save to txt
    df_new = pd.DataFrame(dict_r)
    df_new.to_csv('m/rank/atpranking_20000110_'+date.replace('-', '')+'.txt', index = False, sep = ',', encoding='utf-8-sig')

# %%
scrape_a_date_rank('2024-08-26', '2024-08-19')
# Out:
# Start scraping: 2024-08-26
# Finished: 2024-08-26

# %% [markdown]
# Remember to add the new dates to dates.txt

# %% [markdown]
# Remember to update rank file in Flourish

# %% [markdown]
# ## 2. Update ATP Links According to New Ranks

# %%
# Define the function to update ATP profile links by ATP Top 100 ranks
def update_link_by_new_rank(dates):
    '''
    dates: a list of dates text
    '''
    # update links according to atp ranking

    prefix = 'https://www.atptour.com/en/rankings/singles?RankRange=0-100&DateWeek='
    head = 'https://www.atptour.com'

    # open txt
    df = load_txt('m/basics/atpprofilebasics.txt')
    pl = [p for p in df['Player']]

    with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
        links = [line[:-1] for line in f]
    f.close()

    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=1500, height=800)

    # date list
    for date in dates:
        driver.get(prefix + date)
        # driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        trs = soup.find('table', {'class':'mega-table desktop-table non-live'}).find_all('tr')
        for tr in trs[1:]:
            tds = tr.find_all('td')
            if len(tds) == 8:
                lis = tds[1].find_all('li')
                if lis[2].text.strip().replace('-', ' ') not in pl:
                    # add new link
                    links.append(head+lis[2].a.get('href'))
                    pl.append(lis[2].text.strip().replace('-', ' '))
                    print('Found:', lis[2].text.strip().replace('-', ' '))
        print('Finish:', date)
    f.close()

    # update links
    with open('m/basics/atpprofilelinks.txt', 'w', encoding='utf-8-sig') as f:
        for link in set(links):
            if link != '':
                f.write(link)
                f.write('\n')
    f.close()

# %%
update_link_by_new_rank(["2024-08-26"])
# Out:
# Found: Juncheng  Shang
# Found: Thiago Agustin Tirante
# Finish: 2024-08-26

# %% [markdown]
# ## 3. Update ATP Profile Information

# %%
# Update new basics based on new links in atprofilelinks
# Website design may change

with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
    links = [line[:-1] for line in f]
f.close()

dict = load_txt('m/basics/atpprofilebasics.txt').to_dict('list')

chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)

for i, link in enumerate(links):
    if link not in dict['ATP Link']:
        driver.get(link)
        # driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        # add name
        try:
            dict['Player'].append(soup.find('div', {'class': 'player_name'}).text.strip().replace('-', ' '))
        except:
            print(link, 'not found')
            break
        # add link
        dict['ATP Link'].append(link)
        # add birthday
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Birthday'].append(lis[0].find_all('span')[1].text.split('(')[1][:-1].replace('.', '-'))
        except:
            dict['Birthday'].append('')
        # add birthplace
        try:
            lis = soup.find('ul', {'class': 'pd_right'}).find_all('li')
            birthplace = lis[1].find_all('span')[1].text.replace(', ', ' - ')
        except:
            birthplace = ''
        dict['Birthplace'].append(birthplace)
        # add plays
        try:
            lis = soup.find('ul', {'class': 'pd_right'}).find_all('li')
            dict['Plays'].append(lis[2].find_all('span')[1].text.replace(', ', ' - '))
        except:
            dict['Plays'].append('')
        # add turned pro
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Turned Pro'].append(lis[3].find_all('span')[1].text)
        except:
            dict['Turned Pro'].append('')
        # add weight
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Weight (kg)'].append(lis[1].find_all('span')[1].text.split('(')[1][:-3])
        except:
            dict['Weight (kg)'].append('')
        # add height
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Height (cm)'].append(lis[2].find_all('span')[1].text.split('(')[1][:-3])
        except:
            dict['Height (cm)'].append('')
        print('Finished:', i+1)

        # add birthplace details, matched region, lat, lon
        geolocator = Nominatim(user_agent='tennis-vis')
        try:
            location = geolocator.geocode(birthplace)
            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
            dict['Birthplace_lat'].append(location.latitude)
            dict['Birthplace_lon'].append(location.longitude)
            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
        except:
            try:
                location = geolocator.geocode(birthplace.split(',')[0]+','+birthplace.split(',')[1])
                dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                dict['Birthplace_lat'].append(location.latitude)
                dict['Birthplace_lon'].append(location.longitude)
                print(location.address.replace(',', ' -'), location.latitude, location.longitude)
            except:
                try:
                    location = geolocator.geocode(birthplace.split(',')[0])
                    dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                    dict['Birthplace_lat'].append(location.latitude)
                    dict['Birthplace_lon'].append(location.longitude)
                    print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                except:
                    try:
                        location = geolocator.geocode(birthplace.split(',')[1])
                        dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                        dict['Birthplace_lat'].append(location.latitude)
                        dict['Birthplace_lon'].append(location.longitude)
                        print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                    except:
                        try:
                            location = geolocator.geocode(birthplace.split(',')[2])
                            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                            dict['Birthplace_lat'].append(location.latitude)
                            dict['Birthplace_lon'].append(location.longitude)
                            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                        except:
                            dict['Birthplace_matched'].append('')
                            dict['Birthplace_lat'].append('')
                            dict['Birthplace_lon'].append('')
                            print('','','')

df = pd.DataFrame(dict)
df.to_csv('m/basics/atpprofilebasics.txt', index = False, sep = ',', encoding='utf-8-sig')
# Out:
# Finished: 1080
# La Plata - Partido de La Plata - Buenos Aires - Argentina -34.9206797 -57.9537638

# %% [markdown]
# ## 4. Update ATP TOP 100 Distribution

# %%
# Define the function to update Geo distribution of ATP Top 100 players
def update_geo_atp100(date,num):
    # get basics
    df_basics = load_txt('m/basics/atpprofilebasics.txt')

    # set basic dict
    attrs = ['Start', 'End', 'Player', 'Rank', 'Points', 'Birthplace', 'Lat', 'Lon']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # get dates
    dates = []
    with open('m/rank/dates.txt', 'r') as f:
        for date in f:
            dates.append(date[:-1])
    f.close()

    # Start looping
    for k, date in enumerate([dates[num - i - 1] for i in range(num)]):
        df_rank = load_txt('m/rank/dates/'+date+'.txt')
        for i, p in enumerate(df_rank['Player']):
            for j, r in enumerate(df_basics['Player']):
                if p.replace('-', ' ') == r and k != (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append(dates[num - k - 2])
                    except:
                        pass
                    break
                if p.replace('-', ' ') == r and k == (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append('')
                    except:
                        pass
                    break

        print('Finished:', date)

    df = pd.DataFrame(dict)

    # Save csv
    df.to_csv('m/rank/atp100geo20000110_'+date.replace("-","")+'.txt', index = False, sep = ',', encoding = 'utf-8-sig')

# %%
# num = Row Number of "2000-01-10" in date.txt file
update_geo_atp100("2024-07-15",1181)
# Out:
# Finished: 2000-01-10
# Finished: 2000-01-17
# Finished: 2000-01-24
# Finished: 2000-01-31
# Finished: 2000-02-07
# Finished: 2000-02-14
# Finished: 2000-02-21
# Finished: 2000-02-28
# Finished: 2000-03-06
# Finished: 2000-03-13
# Finished: 2000-03-20
# Finished: 2000-03-27
# Finished: 2000-04-03
# Finished: 2000-04-10
# Finished: 2000-04-17
# Finished: 2000-04-24
# Finished: 2000-05-01
# Finished: 2000-05-08
# Finished: 2000-05-15
# Finished: 2000-05-22
# Finished: 2000-05-29
# Finished: 2000-06-05
# Finished: 2000-06-12
# Finished: 2000-06-19
# Finished: 2000-06-26
# Finished: 2000-07-03
# Finished: 2000-07-10
# Finished: 2000-07-17
# Finished: 2000-07-24
# Finished: 2000-07-31
# Finished: 2000-08-07
# Finished: 2000-08-14
# Finished: 2000-08-21
# Finished: 2000-08-28
# Finished: 2000-09-04
# Finished: 2000-09-11
# Finished: 2000-09-18
# Finished: 2000-09-25
# Finished: 2000-10-02
# Finished: 2000-10-09
# Finished: 2000-10-16
# Finished: 2000-10-23
# Finished: 2000-10-30
# Finished: 2000-11-06
# Finished: 2000-11-13
# Finished: 2000-11-20
# Finished: 2000-11-27
# Finished: 2000-12-04
# Finished: 2000-12-11
# Finished: 2000-12-18
# Finished: 2000-12-25
# Finished: 2001-01-01
# Finished: 2001-01-08
# Finished: 2001-01-15
# Finished: 2001-01-22
# Finished: 2001-01-29
# Finished: 2001-02-05
# Finished: 2001-02-12
# Finished: 2001-02-19
# Finished: 2001-02-26
# Finished: 2001-03-05
# Finished: 2001-03-12
# Finished: 2001-03-19
# Finished: 2001-03-26
# Finished: 2001-04-02
# Finished: 2001-04-09
# Finished: 2001-04-16
# Finished: 2001-04-23
# Finished: 2001-04-30
# Finished: 2001-05-07
# Finished: 2001-05-14
# Finished: 2001-05-21
# Finished: 2001-05-28
# Finished: 2001-06-04
# Finished: 2001-06-11
# Finished: 2001-06-18
# Finished: 2001-06-25
# Finished: 2001-07-02
# Finished: 2001-07-09
# Finished: 2001-07-16
# Finished: 2001-07-23
# Finished: 2001-07-30
# Finished: 2023-09-25
# Finished: 2023-10-02
# Finished: 2023-10-16
# Finished: 2023-10-23
# Finished: 2023-10-30
# Finished: 2023-11-06
# Finished: 2023-11-13
# Finished: 2023-11-20
# Finished: 2023-11-27
# Finished: 2023-12-04
# Finished: 2023-12-11
# Finished: 2023-12-18
# Finished: 2023-12-25
# Finished: 2024-01-01
# Finished: 2024-01-08
# Finished: 2024-01-15
# Finished: 2024-01-29
# Finished: 2024-02-05
# Finished: 2024-02-12
# Finished: 2024-02-19
# Finished: 2024-02-26
# Finished: 2024-03-04
# Finished: 2024-03-18
# Finished: 2024-04-01
# Finished: 2024-04-08
# Finished: 2024-04-15
# Finished: 2024-04-22
# Finished: 2024-05-06
# Finished: 2024-05-20
# Finished: 2024-05-27
# Finished: 2024-06-10
# Finished: 2024-06-17
# Finished: 2024-06-24
# Finished: 2024-07-01
# Finished: 2024-07-15
# Finished: 2024-07-22
# Finished: 2024-07-29
# Finished: 2024-08-05
# Finished: 2024-08-12
# Finished: 2024-08-19
# Finished: 2024-08-26

# %% [markdown]
# Remember to update geo file in Flourish

# %% [markdown]
# ## 5. Update All Matches Player by Player

# %%
# define functions to get all players' names and scrape all matches data
def get_names(sex = ''):
    names = []
    if sex == 'm':
        with open('mp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    elif sex == 'w':
        with open('wp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    else:
        with open('mwplayerlist_processed.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    return names

# define a function to scrape for a single man player's matches
def scrape_matches(name, driver):
    try:
        # set attributes
        attributes_m = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'TP', 'Aces', 'DFs', 'SP', 
                        '1SP', '2SP', 'vA', 'Time']

        attributes_w = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'Time']

        # get cleaned name
        sex = name[1]
        name_cleaned = name[4:].replace(' ', '')

        # set url prefix and types of webpages
        if sex == 'M':
            url = "https://www.tennisabstract.com/cgi-bin/player-classic.cgi?p=" 
        #   types = ["&f=ACareerqq", "&f=ACareerqqr1", "&f=ACareerqqw1"]
        else:
            url = "https://www.tennisabstract.com/cgi-bin/wplayer-classic.cgi?p="

        # Start of Scraping
        print('Start Scraping:', name[4:])
        
        # Man and woman pages are different
        if sex == 'M':

            # For man players
            # Set dictionary
            dic = {}
            for attr in attributes_m:
                dic[attr] = []

            # For serve page
            driver.get(url + name_cleaned.replace(' ', '') + "&f=ACareerqq")
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
        #   driver.quit()

            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # For return page
                show_return = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Return"]')))
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[1])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # For raw page
                show_raw = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Raw"]')))
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[2])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

            else:
                # Serve page
                driver.get(url + name_cleaned.replace(' ', ''))
                driver.refresh()
                # Show career
                try:
                    show_career = driver.find_element(By.ID, 'careerclick')
                except:
                    return None
                show_career.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # Return page
                show_return = driver.find_element(By.XPATH, '//span[text()="Return"]')
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # raw page
                show_raw = driver.find_element(By.XPATH, '//span[text()="Raw"]')
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
              # driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

        else:

            # For woman players
            # set dictionary
            dic = {}
            for attr in attributes_w:
                dic[attr] = []

            # For serve page
            driver.get(url + name_cleaned.replace(' ', '') + '&f=ACareerqq')
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')

            # Check whether it is empty
            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_w[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_w[1]].append(tds[1].text)
                        # sets
                        dic[attributes_w[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_w[3]].append(tds[2].text)
                        # round
                        dic[attributes_w[4]].append(tds[3].text)
                        # rank
                        dic[attributes_w[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_w[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_w[7]].append(1)
                            # winner
                            dic[attributes_w[10]].append(name[4:])
                            # loser
                            dic[attributes_w[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_w[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_w[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_w[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_w[9]].append('')
                        else:
                            # win?
                            dic[attributes_w[7]].append(0)
                            # winner
                            dic[attributes_w[10]].append(spans[1].text)
                            # loser
                            dic[attributes_w[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_w[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_w[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_w[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_w[9]].append('')
                        # score
                        dic[attributes_w[12]].append(tds[7].text.replace(" (ch)", ""))
                        # DR
                        dic[attributes_w[13]].append(tds[8].text)
                        # A%
                        dic[attributes_w[14]].append(tds[9].text)
                        # DF%
                        dic[attributes_w[15]].append(tds[10].text)
                        # 1stIn
                        dic[attributes_w[16]].append(tds[11].text)
                        # 1st%
                        dic[attributes_w[17]].append(tds[12].text)
                        # 2rd%
                        dic[attributes_w[18]].append(tds[13].text)
                        # BPSvd
                        dic[attributes_w[19]].append(tds[14].text)

                print('Serve Page:', len(dic['Date']))

                # For return page
                page_return = driver.find_element(By.XPATH, '//span[text()="Show Return Stats"]')
                page_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
            #   driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_w[20]].append(tds[9].text)
                        # RPW
                        dic[attributes_w[21]].append(tds[10].text)
                        # vA%
                        dic[attributes_w[22]].append(tds[11].text)
                        # v1st%
                        dic[attributes_w[23]].append(tds[12].text)
                        # v2rd%
                        dic[attributes_w[24]].append(tds[13].text)
                        # BPCvt
                        dic[attributes_w[25]].append(tds[14].text)
                        # Time
                        dic[attributes_w[26]].append(tds[15].text)

                print('Return Page:', len(dic['TPW']))

        # save to text, separated by gender
        df = pd.DataFrame(dic)
        df.to_csv(sex.lower() + '/matches/txt/' + name[4:] + '.txt', index = False, sep = ',', encoding='utf-8-sig')

    except (IndexError, AttributeError) as e:
        pass
    
# define a loop function to scrape players from a given index
def scrape_from(idx, sex, driver):
    names = get_names(sex)
    for i in range(idx, len(names)):
        scrape_matches(names[i], driver)
        print('Finish Scraping', i + 1, 'players.')
        print(len(names) - (i + 1), 'players remaining.')
        print('\n')
        
# load txt files
def load_txt(name):
    with open(name[1].lower() + '/matches/txt/' + name[4:] + '.txt', 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    return df

# %%
# UPDATE MATCHES DATA!!!
# set up chromdriver
chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)
scrape_from(26757, 'm', driver)
# Out:
# Start Scraping: Tom Bird
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26758 players.
# 4739 players remaining.
#
#
# Start Scraping: Merwin Miller
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 26759 players.
# 4738 players remaining.
#
#
# Start Scraping: Merrill Ehmke
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26760 players.
# 4737 players remaining.
#
#
# Start Scraping: Carlos Ayala
# Finish Scraping 26761 players.
# 4736 players remaining.
#
#
# Start Scraping: John Maguire
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26762 players.
# 4735 players remaining.
#
#
# Start Scraping: Bob Nihousen
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26763 players.
# 4734 players remaining.
#
#
# Start Scraping: Ken Dubose
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26764 players.
# 4733 players remaining.
#
#
# Start Scraping: David Dozier
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26765 players.
# 4732 players remaining.
#
#
# Start Scraping: Ray Salazar
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26766 players.
# 4731 players remaining.
#
#
# Start Scraping: Ed Jones
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26767 players.
# 4730 players remaining.
#
#
# Start Scraping: Carlos Juliao
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26768 players.
# 4729 players remaining.
#
#
# Start Scraping: Domingo Tepedino
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26769 players.
# 4728 players remaining.
#
#
# Start Scraping: Jay Kovler
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26770 players.
# 4727 players remaining.
#
#
# Start Scraping: Drayton Nabors
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 26771 players.
# 4726 players remaining.
#
#
# Start Scraping: Dick Baldwin
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26772 players.
# 4725 players remaining.
#
#
# Start Scraping: William Ellis
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26773 players.
# 4724 players remaining.
#
#
# Start Scraping: Mike Montcalm
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26774 players.
# 4723 players remaining.
#
#
# Start Scraping: Bob Trapenberg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26775 players.
# 4722 players remaining.
#
#
# Start Scraping: Tim Scharff
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26776 players.
# 4721 players remaining.
#
#
# Start Scraping: Bill Reynolds
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26777 players.
# 4720 players remaining.
#
#
# Start Scraping: Bart Mcguire
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26778 players.
# 4719 players remaining.
#
#
# Start Scraping: Hal Carspacken
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26779 players.
# 4718 players remaining.
#
#
# Start Scraping: Russell Cleveland
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26780 players.
# 4717 players remaining.
#
#
# Start Scraping: Ray Morris
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26781 players.
# 4716 players remaining.
#
#
# Start Scraping: Tony Brooks
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26782 players.
# 4715 players remaining.
#
#
# Start Scraping: Steve Anderson
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26783 players.
# 4714 players remaining.
#
#
# Start Scraping: John Kent
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26784 players.
# 4713 players remaining.
#
#
# Start Scraping: Cary Perry
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26785 players.
# 4712 players remaining.
#
#
# Start Scraping: Sandy Ackley
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26786 players.
# 4711 players remaining.
#
#
# Start Scraping: Tony Thompson
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26787 players.
# 4710 players remaining.
#
#
# Start Scraping: Andrew Bloomfield
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26788 players.
# 4709 players remaining.
#
#
# Start Scraping: B V Volvodich
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26789 players.
# 4708 players remaining.
#
#
# Start Scraping: G Usher
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26790 players.
# 4707 players remaining.
#
#
# Start Scraping: R Bailey
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26791 players.
# 4706 players remaining.
#
#
# Start Scraping: G Woolacott
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26792 players.
# 4705 players remaining.
#
#
# Start Scraping: T Crannage
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26793 players.
# 4704 players remaining.
#
#
# Start Scraping: F Bayne
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26794 players.
# 4703 players remaining.
#
#
# Start Scraping: Erwin Schuldt
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26795 players.
# 4702 players remaining.
#
#
# Start Scraping: Hans Bjarsch
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26796 players.
# 4701 players remaining.
#
#
# Start Scraping: J C Heemskerk
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26797 players.
# 4700 players remaining.
#
#
# Start Scraping: Wali Mohamed
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26798 players.
# 4699 players remaining.
#
#
# Start Scraping: A J Warmenhoyen
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26799 players.
# 4698 players remaining.
#
#
# Start Scraping: J Van De Torre
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26800 players.
# 4697 players remaining.
#
#
# Start Scraping: E Rupold
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26801 players.
# 4696 players remaining.
#
#
# Start Scraping: L A Bradshaw
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26802 players.
# 4695 players remaining.
#
#
# Start Scraping: Umar Din
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26803 players.
# 4694 players remaining.
#
#
# Start Scraping: Erich Schoenemann
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26804 players.
# 4693 players remaining.
#
#
# Start Scraping:  Maimone
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26805 players.
# 4692 players remaining.
#
#
# Start Scraping: M Sabet
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26806 players.
# 4691 players remaining.
#
#
# Start Scraping: Istvan Heinrich
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26807 players.
# 4690 players remaining.
#
#
# Start Scraping: Robert Kaufmann
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26808 players.
# 4689 players remaining.
#
#
# Start Scraping: Rolf Huber
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26809 players.
# 4688 players remaining.
#
#
# Start Scraping: Wolfram Becker
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26810 players.
# 4687 players remaining.
#
#
# Start Scraping: Werner Nier
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26811 players.
# 4686 players remaining.
#
#
# Start Scraping: Jan Foldina
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26812 players.
# 4685 players remaining.
#
#
# Start Scraping: Kevin Robinson
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26813 players.
# 4684 players remaining.
#
#
# Start Scraping: G Lucke
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26814 players.
# 4683 players remaining.
#
#
# Start Scraping: J Lyons
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26815 players.
# 4682 players remaining.
#
#
# Start Scraping: J Clegg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26816 players.
# 4681 players remaining.
#
#
# Start Scraping: H Roche
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26817 players.
# 4680 players remaining.
#
#
# Start Scraping: R Ouchesne
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26818 players.
# 4679 players remaining.
#
#
# Start Scraping: G Herring
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26819 players.
# 4678 players remaining.
#
#
# Start Scraping:  Van Den Beussche
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26820 players.
# 4677 players remaining.
#
#
# Start Scraping: Ray Widelski
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26821 players.
# 4676 players remaining.
#
#
# Start Scraping: Geoff Saunders
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26822 players.
# 4675 players remaining.
#
#
# Start Scraping: L Danna
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 26823 players.
# 4674 players remaining.
#
#
# Start Scraping: Graham Alvan Gaydon
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 26824 players.
# 4673 players remaining.
#
#
# Start Scraping: G Mcgann
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26825 players.
# 4672 players remaining.
#
#
# Start Scraping: Jack Rodgers
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 26826 players.
# 4671 players remaining.
#
#
# Start Scraping: Gene Vash
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26827 players.
# 4670 players remaining.
#
#
# Start Scraping: Jack March
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26828 players.
# 4669 players remaining.
#
#
# Start Scraping: T Jones
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26829 players.
# 4668 players remaining.
#
#
# Start Scraping: R Burns
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26830 players.
# 4667 players remaining.
#
#
# Start Scraping: Larry Greene
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26831 players.
# 4666 players remaining.
#
#
# Start Scraping: Kazunari Hirano
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26832 players.
# 4665 players remaining.
#
#
# Start Scraping: Willis Fennell
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26833 players.
# 4664 players remaining.
#
#
# Start Scraping: Kazuyuki Akutagawa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26834 players.
# 4663 players remaining.
#
#
# Start Scraping: Jochen Maurer
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26835 players.
# 4662 players remaining.
#
#
# Start Scraping: Heinrich Morgen
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26836 players.
# 4661 players remaining.
#
#
# Start Scraping: Edmund Halliday Jr
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26837 players.
# 4660 players remaining.
#
#
# Start Scraping: F M B Cope
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26838 players.
# 4659 players remaining.
#
#
# Start Scraping: M H Penty
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26839 players.
# 4658 players remaining.
#
#
# Start Scraping: Max Meinhold
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26840 players.
# 4657 players remaining.
#
#
# Start Scraping: Anand Pandit
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26841 players.
# 4656 players remaining.
#
#
# Start Scraping: N G Stuart
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26842 players.
# 4655 players remaining.
#
#
# Start Scraping: Bernie Gunderson
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26843 players.
# 4654 players remaining.
#
#
# Start Scraping:  Mertel
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26844 players.
# 4653 players remaining.
#
#
# Start Scraping: Al Doyle
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 26845 players.
# 4652 players remaining.
#
#
# Start Scraping: Bill Bane
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 26846 players.
# 4651 players remaining.
#
#
# Start Scraping: Gordon Talbot
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 26847 players.
# 4650 players remaining.
#
#
# Start Scraping: Hugh Lynch Iii
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 26848 players.
# 4649 players remaining.
#
#
# Start Scraping: Laury Hunt
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 26849 players.
# 4648 players remaining.
#
#
# Start Scraping: Don Coughlin
# Finish Scraping 26850 players.
# 4647 players remaining.
#
#
# Start Scraping: Pete Green
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26851 players.
# 4646 players remaining.
#
#
# Start Scraping: A Linon
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26852 players.
# 4645 players remaining.
#
#
# Start Scraping: E E Blincow
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26853 players.
# 4644 players remaining.
#
#
# Start Scraping: Edward Garofalo
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26854 players.
# 4643 players remaining.
#
#
# Start Scraping: Filippo Terrasi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26855 players.
# 4642 players remaining.
#
#
# Start Scraping:  Di Carlo
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26856 players.
# 4641 players remaining.
#
#
# Start Scraping: Aurelio Saitta
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26857 players.
# 4640 players remaining.
#
#
# Start Scraping: Gaetano Alfano
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26858 players.
# 4639 players remaining.
#
#
# Start Scraping:  Morgano
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26859 players.
# 4638 players remaining.
#
#
# Start Scraping: Arthur Stenek
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26860 players.
# 4637 players remaining.
#
#
# Start Scraping: G Wynwood
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26861 players.
# 4636 players remaining.
#
#
# Start Scraping: M Melrose
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26862 players.
# 4635 players remaining.
#
#
# Start Scraping: I Stocks
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26863 players.
# 4634 players remaining.
#
#
# Start Scraping: D Keogh
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26864 players.
# 4633 players remaining.
#
#
# Start Scraping: T Prosynski
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26865 players.
# 4632 players remaining.
#
#
# Start Scraping: R Collins
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26866 players.
# 4631 players remaining.
#
#
# Start Scraping: Derek Turner
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26867 players.
# 4630 players remaining.
#
#
# Start Scraping: R Palk
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26868 players.
# 4629 players remaining.
#
#
# Start Scraping: S Kerr
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26869 players.
# 4628 players remaining.
#
#
# Start Scraping: Don Bell
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26870 players.
# 4627 players remaining.
#
#
# Start Scraping: Don Richardson
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26871 players.
# 4626 players remaining.
#
#
# Start Scraping: Sheldon Caldwell
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26872 players.
# 4625 players remaining.
#
#
# Start Scraping: Harold Soule
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26873 players.
# 4624 players remaining.
#
#
# Start Scraping: Steven Leovey
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26874 players.
# 4623 players remaining.
#
#
# Start Scraping: Bill Kenney
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 26875 players.
# 4622 players remaining.
#
#
# Start Scraping: Ramu Raju
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26876 players.
# 4621 players remaining.
#
#
# Start Scraping: John Hall
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26877 players.
# 4620 players remaining.
#
#
# Start Scraping: Bill Frantz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26878 players.
# 4619 players remaining.
#
#
# Start Scraping: I Jankovic
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26879 players.
# 4618 players remaining.
#
#
# Start Scraping: D Rehling
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26880 players.
# 4617 players remaining.
#
#
# Start Scraping: C Sprey Smith
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26881 players.
# 4616 players remaining.
#
#
# Start Scraping: F Pol
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26882 players.
# 4615 players remaining.
#
#
# Start Scraping: Jack Evans
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26883 players.
# 4614 players remaining.
#
#
# Start Scraping: P J Boylan
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26884 players.
# 4613 players remaining.
#
#
# Start Scraping: Maurice Davitt
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 26885 players.
# 4612 players remaining.
#
#
# Start Scraping: Sarsfield Smith
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 26886 players.
# 4611 players remaining.
#
#
# Start Scraping: M J Buchanan
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26887 players.
# 4610 players remaining.
#
#
# Start Scraping: Frank Omahony
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26888 players.
# 4609 players remaining.
#
#
# Start Scraping: John Osullivan
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26889 players.
# 4608 players remaining.
#
#
# Start Scraping: Peter Delaney
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26890 players.
# 4607 players remaining.
#
#
# Start Scraping: Lex Karamoy
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 26891 players.
# 4606 players remaining.
#
#
# Start Scraping: D Arends
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26892 players.
# 4605 players remaining.
#
#
# Start Scraping: Cees Marre
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26893 players.
# 4604 players remaining.
#
#
# Start Scraping: R Brewis
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26894 players.
# 4603 players remaining.
#
#
# Start Scraping: A D Marval
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26895 players.
# 4602 players remaining.
#
#
# Start Scraping: T Jefferies
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26896 players.
# 4601 players remaining.
#
#
# Start Scraping: J Bruce
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26897 players.
# 4600 players remaining.
#
#
# Start Scraping: K Brandle
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26898 players.
# 4599 players remaining.
#
#
# Start Scraping: R Ashburst
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26899 players.
# 4598 players remaining.
#
#
# Start Scraping: P D Dodds
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26900 players.
# 4597 players remaining.
#
#
# Start Scraping: A Denslow
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26901 players.
# 4596 players remaining.
#
#
# Start Scraping: J Kimberley Bowen
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26902 players.
# 4595 players remaining.
#
#
# Start Scraping: D Kurdys
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26903 players.
# 4594 players remaining.
#
#
# Start Scraping: Jon Paldan
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26904 players.
# 4593 players remaining.
#
#
# Start Scraping: M Merazzi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26905 players.
# 4592 players remaining.
#
#
# Start Scraping: Norbert Escher
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 26906 players.
# 4591 players remaining.
#
#
# Start Scraping: I Vitellini
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 26907 players.
# 4590 players remaining.
#
#
# Start Scraping: G Santi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26908 players.
# 4589 players remaining.
#
#
# Start Scraping: S Fontana
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26909 players.
# 4588 players remaining.
#
#
# Start Scraping: J Mei
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26910 players.
# 4587 players remaining.
#
#
# Start Scraping: A G Chapman
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26911 players.
# 4586 players remaining.
#
#
# Start Scraping: P L Gardner
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26912 players.
# 4585 players remaining.
#
#
# Start Scraping: T Clapp
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26913 players.
# 4584 players remaining.
#
#
# Start Scraping: A Irwin
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26914 players.
# 4583 players remaining.
#
#
# Start Scraping: R W Higgins
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26915 players.
# 4582 players remaining.
#
#
# Start Scraping: E V Honer
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26916 players.
# 4581 players remaining.
#
#
# Start Scraping: R P Hancock
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26917 players.
# 4580 players remaining.
#
#
# Start Scraping: G Dulouart
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26918 players.
# 4579 players remaining.
#
#
# Start Scraping: George Wanstrath
# Finish Scraping 26919 players.
# 4578 players remaining.
#
#
# Start Scraping: Bernie Friedman
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26920 players.
# 4577 players remaining.
#
#
# Start Scraping: Joe Schwartz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26921 players.
# 4576 players remaining.
#
#
# Start Scraping: Merlin Johnson
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26922 players.
# 4575 players remaining.
#
#
# Start Scraping: John Devereaux
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26923 players.
# 4574 players remaining.
#
#
# Start Scraping: Bob Bortner
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26924 players.
# 4573 players remaining.
#
#
# Start Scraping: William Mitchell
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26925 players.
# 4572 players remaining.
#
#
# Start Scraping: Elias Gonzales
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26926 players.
# 4571 players remaining.
#
#
# Start Scraping: Guido Laccarozza
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26927 players.
# 4570 players remaining.
#
#
# Start Scraping:  Topodine
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26928 players.
# 4569 players remaining.
#
#
# Start Scraping: Enrique Buse
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26929 players.
# 4568 players remaining.
#
#
# Start Scraping:  Osby
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26930 players.
# 4567 players remaining.
#
#
# Start Scraping: Guy Ashton
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26931 players.
# 4566 players remaining.
#
#
# Start Scraping: Cliff Hourston
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26932 players.
# 4565 players remaining.
#
#
# Start Scraping: Jose Gonzalez
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26933 players.
# 4564 players remaining.
#
#
# Start Scraping: Jose Maria Mota
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26934 players.
# 4563 players remaining.
#
#
# Start Scraping: Brian Bloomberg
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 26935 players.
# 4562 players remaining.
#
#
# Start Scraping: Ted Keesler
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 26936 players.
# 4561 players remaining.
#
#
# Start Scraping: J Mackenzie
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26937 players.
# 4560 players remaining.
#
#
# Start Scraping: Lawrence Becker
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 26938 players.
# 4559 players remaining.
#
#
# Start Scraping: L Cziraky
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 26939 players.
# 4558 players remaining.
#
#
# Start Scraping: Stu Fitelson
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 26940 players.
# 4557 players remaining.
#
#
# Start Scraping: Johnny Hunter
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 26941 players.
# 4556 players remaining.
#
#
# Start Scraping: Eddie Strayhorn
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26942 players.
# 4555 players remaining.
#
#
# Start Scraping: Rick Fried
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 26943 players.
# 4554 players remaining.
#
#
# Start Scraping: Nour Nehme
# Finish Scraping 26944 players.
# 4553 players remaining.
#
#
# Start Scraping: Alexander Rushin
# Finish Scraping 26945 players.
# 4552 players remaining.
#
#
# Start Scraping: Sankha Atukorale
# Finish Scraping 26946 players.
# 4551 players remaining.
#
#
# Start Scraping: Pedro Daniel Gutierrez Arreaga
# Finish Scraping 26947 players.
# 4550 players remaining.
#
#
# Start Scraping: Anish Wijesinghe
# Finish Scraping 26948 players.
# 4549 players remaining.
#
#
# Start Scraping: Anudeep Kodali
# Finish Scraping 26949 players.
# 4548 players remaining.
#
#
# Start Scraping: Samuele Galli
# Finish Scraping 26950 players.
# 4547 players remaining.
#
#
# Start Scraping: Souleymane Diallo
# Finish Scraping 26951 players.
# 4546 players remaining.
#
#
# Start Scraping: Momar Martin Ndiaye
# Finish Scraping 26952 players.
# 4545 players remaining.
#
#
# Start Scraping: Ahmadou Bamba Ndiaye
# Finish Scraping 26953 players.
# 4544 players remaining.
#
#
# Start Scraping: Jeremy Voisin
# Finish Scraping 26954 players.
# 4543 players remaining.
#
#
# Start Scraping: Michael Dubecq
# Finish Scraping 26955 players.
# 4542 players remaining.
#
#
# Start Scraping: Fernando Ramirez Lascurain
# Finish Scraping 26956 players.
# 4541 players remaining.
#
#
# Start Scraping: Bernard Dugbah
# Finish Scraping 26957 players.
# 4540 players remaining.
#
#
# Start Scraping: Dominique Gandonou
# Finish Scraping 26958 players.
# 4539 players remaining.
#
#
# Start Scraping: Omar Abdalla Aljufairi
# Finish Scraping 26959 players.
# 4538 players remaining.
#
#
# Start Scraping: Frederik Schoop
# Finish Scraping 26960 players.
# 4537 players remaining.
#
#
# Start Scraping: Shane Marshall
# Finish Scraping 26961 players.
# 4536 players remaining.
#
#
# Start Scraping: Jesus Nolasco
# Finish Scraping 26962 players.
# 4535 players remaining.
#
#
# Start Scraping: Amilcar Ibarra Barreda
# Finish Scraping 26963 players.
# 4534 players remaining.
#
#
# Start Scraping: Miguel Vazquez
# Finish Scraping 26964 players.
# 4533 players remaining.
#
#
# Start Scraping: Sebastian Arce
# Finish Scraping 26965 players.
# 4532 players remaining.
#
#
# Start Scraping: Oscar Rene Jeppesen
# Finish Scraping 26966 players.
# 4531 players remaining.
#
#
# Start Scraping: Brandon Emery Kwo
# Finish Scraping 26967 players.
# 4530 players remaining.
#
#
# Start Scraping: Cormac Clissold
# Finish Scraping 26968 players.
# 4529 players remaining.
#
#
# Start Scraping: Jesus David Ordonez Achinte
# Finish Scraping 26969 players.
# 4528 players remaining.
#
#
# Start Scraping: Christopher Robin Klettenberg
# Finish Scraping 26970 players.
# 4527 players remaining.
#
#
# Start Scraping: Matthew Westmoreland
# Finish Scraping 26971 players.
# 4526 players remaining.
#
#
# Start Scraping: Leonardo Nakai
# Finish Scraping 26972 players.
# 4525 players remaining.
#
#
# Start Scraping: Miracle Moses Matanga
# Finish Scraping 26973 players.
# 4524 players remaining.
#
#
# Start Scraping: Marcus Vidgren
# Finish Scraping 26974 players.
# 4523 players remaining.
#
#
# Start Scraping: Bruno Pellecchia
# Finish Scraping 26975 players.
# 4522 players remaining.
#
#
# Start Scraping: Clement Marzol
# Finish Scraping 26976 players.
# 4521 players remaining.
#
#
# Start Scraping: Julian Nicolas Baca Guzman
# Finish Scraping 26977 players.
# 4520 players remaining.
#
#
# Start Scraping: Alvaro Daniel Riveros
# Finish Scraping 26978 players.
# 4519 players remaining.
#
#
# Start Scraping: Lazar Darus Poaty Pango Nkongo
# Finish Scraping 26979 players.
# 4518 players remaining.
#
#
# Start Scraping: Florentin Meynie
# Finish Scraping 26980 players.
# 4517 players remaining.
#
#
# Start Scraping: Jose Maria Cortes Gonzalez
# Finish Scraping 26981 players.
# 4516 players remaining.
#
#
# Start Scraping: David Hsu
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 26982 players.
# 4515 players remaining.
#
#
# Start Scraping: Nick Andree Concha Colchado
# Finish Scraping 26983 players.
# 4514 players remaining.
#
#
# Start Scraping: Lucas Trentin
# Finish Scraping 26984 players.
# 4513 players remaining.
#
#
# Start Scraping: Vuk Trbojevic
# Finish Scraping 26985 players.
# 4512 players remaining.
#
#
# Start Scraping: Max Voglgruber
# Finish Scraping 26986 players.
# 4511 players remaining.
#
#
# Start Scraping: Christopher Waite
# Finish Scraping 26987 players.
# 4510 players remaining.
#
#
# Start Scraping: Vladimir Lukyanov
# Finish Scraping 26988 players.
# 4509 players remaining.
#
#
# Start Scraping: Luiz Leonardo Andreolli
# Finish Scraping 26989 players.
# 4508 players remaining.
#
#
# Start Scraping: Edgar Alonso Palacio Molina
# Finish Scraping 26990 players.
# 4507 players remaining.
#
#
# Start Scraping: Atly Kurbanov
# Finish Scraping 26991 players.
# 4506 players remaining.
#
#
# Start Scraping: Eric Lavaud
# Finish Scraping 26992 players.
# 4505 players remaining.
#
#
# Start Scraping: Matteo Donnini
# Finish Scraping 26993 players.
# 4504 players remaining.
#
#
# Start Scraping: Vladimir Kurek
# Finish Scraping 26994 players.
# 4503 players remaining.
#
#
# Start Scraping: Vladimir Cosic
# Finish Scraping 26995 players.
# 4502 players remaining.
#
#
# Start Scraping: Carlos Gomez Sanchez
# Finish Scraping 26996 players.
# 4501 players remaining.
#
#
# Start Scraping: Thomas Heyse
# Finish Scraping 26997 players.
# 4500 players remaining.
#
#
# Start Scraping: Enzo Varrone
# Finish Scraping 26998 players.
# 4499 players remaining.
#
#
# Start Scraping: Hayden Sabatka
# Finish Scraping 26999 players.
# 4498 players remaining.
#
#
# Start Scraping: Seung Ri Choi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27000 players.
# 4497 players remaining.
#
#
# Start Scraping: Christopher Morrow
# Finish Scraping 27001 players.
# 4496 players remaining.
#
#
# Start Scraping: Aurelien Richaud
# Finish Scraping 27002 players.
# 4495 players remaining.
#
#
# Start Scraping: Xiuneng Wang
# Finish Scraping 27003 players.
# 4494 players remaining.
#
#
# Start Scraping: Nathan De Veer
# Finish Scraping 27004 players.
# 4493 players remaining.
#
#
# Start Scraping: Alexandru Grigorescu
# Finish Scraping 27005 players.
# 4492 players remaining.
#
#
# Start Scraping: Alexander G Steinroeder
# Finish Scraping 27006 players.
# 4491 players remaining.
#
#
# Start Scraping: Igor Turcan
# Finish Scraping 27007 players.
# 4490 players remaining.
#
#
# Start Scraping: William Conigliaro
# Finish Scraping 27008 players.
# 4489 players remaining.
#
#
# Start Scraping: Gaston Bazzoni
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27009 players.
# 4488 players remaining.
#
#
# Start Scraping: Gergo Weidinger
# Finish Scraping 27010 players.
# 4487 players remaining.
#
#
# Start Scraping: Drew B Lied
# Finish Scraping 27011 players.
# 4486 players remaining.
#
#
# Start Scraping: Balazs Csontos
# Finish Scraping 27012 players.
# 4485 players remaining.
#
#
# Start Scraping: Miha Okorn
# Finish Scraping 27013 players.
# 4484 players remaining.
#
#
# Start Scraping: Kim Ki Jun
# Finish Scraping 27014 players.
# 4483 players remaining.
#
#
# Start Scraping: Rudi Dawid Matthee
# Finish Scraping 27015 players.
# 4482 players remaining.
#
#
# Start Scraping: Bjorn Scheepbouwer
# Finish Scraping 27016 players.
# 4481 players remaining.
#
#
# Start Scraping: Jd Malan
# Finish Scraping 27017 players.
# 4480 players remaining.
#
#
# Start Scraping: Nikola Solaja
# Finish Scraping 27018 players.
# 4479 players remaining.
#
#
# Start Scraping: Enrique Vidal
# Finish Scraping 27019 players.
# 4478 players remaining.
#
#
# Start Scraping: Nik Popovic
# Finish Scraping 27020 players.
# 4477 players remaining.
#
#
# Start Scraping: Dorian Puric
# Finish Scraping 27021 players.
# 4476 players remaining.
#
#
# Start Scraping: Jonathan Gomont
# Finish Scraping 27022 players.
# 4475 players remaining.
#
#
# Start Scraping: Andrew Barabashov
# Finish Scraping 27023 players.
# 4474 players remaining.
#
#
# Start Scraping: Ervin Duratovic
# Finish Scraping 27024 players.
# 4473 players remaining.
#
#
# Start Scraping: Dan Stefan
# Finish Scraping 27025 players.
# 4472 players remaining.
#
#
# Start Scraping: Zacharie El Ayat
# Finish Scraping 27026 players.
# 4471 players remaining.
#
#
# Start Scraping: Khumoun Abdumalikov
# Finish Scraping 27027 players.
# 4470 players remaining.
#
#
# Start Scraping: Kevin Riviere
# Finish Scraping 27028 players.
# 4469 players remaining.
#
#
# Start Scraping: Marco Danielo Geronimo
# Finish Scraping 27029 players.
# 4468 players remaining.
#
#
# Start Scraping: Sataporn Simmalavong
# Finish Scraping 27030 players.
# 4467 players remaining.
#
#
# Start Scraping: Frank Acierno
# Finish Scraping 27031 players.
# 4466 players remaining.
#
#
# Start Scraping: Logan Powell
# Finish Scraping 27032 players.
# 4465 players remaining.
#
#
# Start Scraping: Calvin Charles Canlas
# Finish Scraping 27033 players.
# 4464 players remaining.
#
#
# Start Scraping: Vikrant Dahiya
# Finish Scraping 27034 players.
# 4463 players remaining.
#
#
# Start Scraping: Thomas Finck
# Finish Scraping 27035 players.
# 4462 players remaining.
#
#
# Start Scraping: Brock Sakey
# Finish Scraping 27036 players.
# 4461 players remaining.
#
#
# Start Scraping: Jose Carlos Peralta
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27037 players.
# 4460 players remaining.
#
#
# Start Scraping: Dylan Centella
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27038 players.
# 4459 players remaining.
#
#
# Start Scraping: Lukas Schaefer
# Finish Scraping 27039 players.
# 4458 players remaining.
#
#
# Start Scraping: Wael Ezzedine
# Finish Scraping 27040 players.
# 4457 players remaining.
#
#
# Start Scraping: Daniel Sebastian Wilches Betancur
# Finish Scraping 27041 players.
# 4456 players remaining.
#
#
# Start Scraping: Maycon Santos Dias
# Finish Scraping 27042 players.
# 4455 players remaining.
#
#
# Start Scraping: Prateek Pushkar Baxi
# Finish Scraping 27043 players.
# 4454 players remaining.
#
#
# Start Scraping: Spyridon Naoum
# Finish Scraping 27044 players.
# 4453 players remaining.
#
#
# Start Scraping: Judd Berg Graul
# Finish Scraping 27045 players.
# 4452 players remaining.
#
#
# Start Scraping: Semen Tripolskiy
# Finish Scraping 27046 players.
# 4451 players remaining.
#
#
# Start Scraping: Bruno Vasami
# Finish Scraping 27047 players.
# 4450 players remaining.
#
#
# Start Scraping: Tiago Miranda Tavares
# Finish Scraping 27048 players.
# 4449 players remaining.
#
#
# Start Scraping: Benjamin Brammert
# Finish Scraping 27049 players.
# 4448 players remaining.
#
#
# Start Scraping: Alexandre Guilherme Da Silva Nunes
# Finish Scraping 27050 players.
# 4447 players remaining.
#
#
# Start Scraping: Igor Carvalho
# Finish Scraping 27051 players.
# 4446 players remaining.
#
#
# Start Scraping: Vadim Malakhov
# Finish Scraping 27052 players.
# 4445 players remaining.
#
#
# Start Scraping: Nick Zieziula
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27053 players.
# 4444 players remaining.
#
#
# Start Scraping: Patrick Walker
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27054 players.
# 4443 players remaining.
#
#
# Start Scraping: Richard Cooper
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27055 players.
# 4442 players remaining.
#
#
# Start Scraping: Carlos Garcia
# Finish Scraping 27056 players.
# 4441 players remaining.
#
#
# Start Scraping: Juan Antonio Maranon
# Finish Scraping 27057 players.
# 4440 players remaining.
#
#
# Start Scraping: Joao Guerra
# Finish Scraping 27058 players.
# 4439 players remaining.
#
#
# Start Scraping: Roberto Dellisanti
# Finish Scraping 27059 players.
# 4438 players remaining.
#
#
# Start Scraping: Roy Boutagy
# Finish Scraping 27060 players.
# 4437 players remaining.
#
#
# Start Scraping: Luis Perez
# Finish Scraping 27061 players.
# 4436 players remaining.
#
#
# Start Scraping: Berke Tombul
# Finish Scraping 27062 players.
# 4435 players remaining.
#
#
# Start Scraping: Eduardo Giordani
# Finish Scraping 27063 players.
# 4434 players remaining.
#
#
# Start Scraping: Emmanuel Ikakah
# Finish Scraping 27064 players.
# 4433 players remaining.
#
#
# Start Scraping: Abdullah Hamidu
# Finish Scraping 27065 players.
# 4432 players remaining.
#
#
# Start Scraping: Jeff Lewis
# Finish Scraping 27066 players.
# 4431 players remaining.
#
#
# Start Scraping: Javier Flores
# Finish Scraping 27067 players.
# 4430 players remaining.
#
#
# Start Scraping: Ribhav Ravikiran
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 27068 players.
# 4429 players remaining.
#
#
# Start Scraping: Yacine Benaissa
# Finish Scraping 27069 players.
# 4428 players remaining.
#
#
# Start Scraping: Frank Suarez
# Finish Scraping 27070 players.
# 4427 players remaining.
#
#
# Start Scraping: Yifan Dang
# Finish Scraping 27071 players.
# 4426 players remaining.
#
#
# Start Scraping: Thomas Weibye
# Finish Scraping 27072 players.
# 4425 players remaining.
#
#
# Start Scraping: Bernard Ashitey Armaah
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27073 players.
# 4424 players remaining.
#
#
# Start Scraping: Vuk Skadarka
# Finish Scraping 27074 players.
# 4423 players remaining.
#
#
# Start Scraping: Nicolas Brand
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27075 players.
# 4422 players remaining.
#
#
# Start Scraping: Per Nordstrom
# Finish Scraping 27076 players.
# 4421 players remaining.
#
#
# Start Scraping: Robert Maric
# Finish Scraping 27077 players.
# 4420 players remaining.
#
#
# Start Scraping: Kevin Kaan Andrusch
# Finish Scraping 27078 players.
# 4419 players remaining.
#
#
# Start Scraping: Justyn Levin
# Finish Scraping 27079 players.
# 4418 players remaining.
#
#
# Start Scraping: Pavel Kravchenko
# Finish Scraping 27080 players.
# 4417 players remaining.
#
#
# Start Scraping: Wei Seem Lee
# Finish Scraping 27081 players.
# 4416 players remaining.
#
#
# Start Scraping: Ivan Dikenstein
# Finish Scraping 27082 players.
# 4415 players remaining.
#
#
# Start Scraping: Alexander Todorov
# Finish Scraping 27083 players.
# 4414 players remaining.
#
#
# Start Scraping: Dennis Kazistov
# Finish Scraping 27084 players.
# 4413 players remaining.
#
#
# Start Scraping: Henrik Nikoghosyan
# Finish Scraping 27085 players.
# 4412 players remaining.
#
#
# Start Scraping: Arshak Ghazaryan
# Finish Scraping 27086 players.
# 4411 players remaining.
#
#
# Start Scraping: Cristobal Rivera
# Finish Scraping 27087 players.
# 4410 players remaining.
#
#
# Start Scraping: Robert Kjellberg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27088 players.
# 4409 players remaining.
#
#
# Start Scraping: Constantinos Papavasiliou
# Finish Scraping 27089 players.
# 4408 players remaining.
#
#
# Start Scraping: Anton Samuilau
# Finish Scraping 27090 players.
# 4407 players remaining.
#
#
# Start Scraping: Maciej Kazanowski
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27091 players.
# 4406 players remaining.
#
#
# Start Scraping: Thiago Yuji Yoshimori
# Finish Scraping 27092 players.
# 4405 players remaining.
#
#
# Start Scraping: Joao Lucas Pinto Alves
# Finish Scraping 27093 players.
# 4404 players remaining.
#
#
# Start Scraping: Federico Terreni
# Finish Scraping 27094 players.
# 4403 players remaining.
#
#
# Start Scraping: Maximilian Engshuber
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27095 players.
# 4402 players remaining.
#
#
# Start Scraping: Daniel Hoyos
# Finish Scraping 27096 players.
# 4401 players remaining.
#
#
# Start Scraping: Frank Alexander Vega Ortiz
# Finish Scraping 27097 players.
# 4400 players remaining.
#
#
# Start Scraping: Shuai Xu
# Finish Scraping 27098 players.
# 4399 players remaining.
#
#
# Start Scraping: Abdulrahman Al Janahi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27099 players.
# 4398 players remaining.
#
#
# Start Scraping: Joaquin Gabriel Noguera Linarez
# Finish Scraping 27100 players.
# 4397 players remaining.
#
#
# Start Scraping: Marco Bergagnin
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27101 players.
# 4396 players remaining.
#
#
# Start Scraping: Georgiy Pochay
# Finish Scraping 27102 players.
# 4395 players remaining.
#
#
# Start Scraping: Aleksandr Ernepesov
# Finish Scraping 27103 players.
# 4394 players remaining.
#
#
# Start Scraping: Cristian Popa
# Finish Scraping 27104 players.
# 4393 players remaining.
#
#
# Start Scraping: James Tallman
# Finish Scraping 27105 players.
# 4392 players remaining.
#
#
# Start Scraping: Graham Alrutz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27106 players.
# 4391 players remaining.
#
#
# Start Scraping: Yuki Nakamura
# Finish Scraping 27107 players.
# 4390 players remaining.
#
#
# Start Scraping: Oscar Janglin
# Finish Scraping 27108 players.
# 4389 players remaining.
#
#
# Start Scraping: Juan Barrera
# Finish Scraping 27109 players.
# 4388 players remaining.
#
#
# Start Scraping: Kabiru Abdulmalik
# Finish Scraping 27110 players.
# 4387 players remaining.
#
#
# Start Scraping: Lucas Lima Freitas
# Finish Scraping 27111 players.
# 4386 players remaining.
#
#
# Start Scraping: Guillermo Alejandro Arrambide Herrera
# Finish Scraping 27112 players.
# 4385 players remaining.
#
#
# Start Scraping: Thierry Halemai
# Finish Scraping 27113 players.
# 4384 players remaining.
#
#
# Start Scraping: Geoffrey Embry
# Finish Scraping 27114 players.
# 4383 players remaining.
#
#
# Start Scraping: Benjamin Donovan
# Finish Scraping 27115 players.
# 4382 players remaining.
#
#
# Start Scraping: Nicholas C Crystal
# Finish Scraping 27116 players.
# 4381 players remaining.
#
#
# Start Scraping: Adil Tleshov
# Finish Scraping 27117 players.
# 4380 players remaining.
#
#
# Start Scraping: Alex Sidney
# Finish Scraping 27118 players.
# 4379 players remaining.
#
#
# Start Scraping: Jocelyn Devilliers
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27119 players.
# 4378 players remaining.
#
#
# Start Scraping: Richard Ashforth
# Finish Scraping 27120 players.
# 4377 players remaining.
#
#
# Start Scraping: Angel Diaz Mendez
# Finish Scraping 27121 players.
# 4376 players remaining.
#
#
# Start Scraping: David Papis
# Finish Scraping 27122 players.
# 4375 players remaining.
#
#
# Start Scraping: Jaroslav Vondrasek
# Finish Scraping 27123 players.
# 4374 players remaining.
#
#
# Start Scraping: Christoph Lang
# Finish Scraping 27124 players.
# 4373 players remaining.
#
#
# Start Scraping: Jonathan Bejar
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27125 players.
# 4372 players remaining.
#
#
# Start Scraping: Joshua Tran
# Finish Scraping 27126 players.
# 4371 players remaining.
#
#
# Start Scraping: Zachary Pelts
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27127 players.
# 4370 players remaining.
#
#
# Start Scraping: Andres Ignacio Punti Lagos
# Finish Scraping 27128 players.
# 4369 players remaining.
#
#
# Start Scraping: Sven Burus
# Finish Scraping 27129 players.
# 4368 players remaining.
#
#
# Start Scraping: Sean Karl
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27130 players.
# 4367 players remaining.
#
#
# Start Scraping: Gregory Andrade
# Finish Scraping 27131 players.
# 4366 players remaining.
#
#
# Start Scraping: Davis Mark Dawson
# Finish Scraping 27132 players.
# 4365 players remaining.
#
#
# Start Scraping: Garrett Gordon
# Finish Scraping 27133 players.
# 4364 players remaining.
#
#
# Start Scraping: Stratton Gilmore
# Finish Scraping 27134 players.
# 4363 players remaining.
#
#
# Start Scraping: Joao Victor Amato Trindade
# Finish Scraping 27135 players.
# 4362 players remaining.
#
#
# Start Scraping: Kevin Gardner
# Finish Scraping 27136 players.
# 4361 players remaining.
#
#
# Start Scraping: Pierre Debrosse
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27137 players.
# 4360 players remaining.
#
#
# Start Scraping: Cameron Lickle
# Finish Scraping 27138 players.
# 4359 players remaining.
#
#
# Start Scraping: Taylor Witt
# Finish Scraping 27139 players.
# 4358 players remaining.
#
#
# Start Scraping: Mika De Coster
# Finish Scraping 27140 players.
# 4357 players remaining.
#
#
# Start Scraping: Kianosh Fakharzadeh
# Finish Scraping 27141 players.
# 4356 players remaining.
#
#
# Start Scraping: Andres Vazquez Machuca
# Finish Scraping 27142 players.
# 4355 players remaining.
#
#
# Start Scraping: Frederic Stotz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27143 players.
# 4354 players remaining.
#
#
# Start Scraping: Vladimir Molkanov
# Finish Scraping 27144 players.
# 4353 players remaining.
#
#
# Start Scraping: Renzo Rovetto
# Finish Scraping 27145 players.
# 4352 players remaining.
#
#
# Start Scraping: Elias Chala
# Finish Scraping 27146 players.
# 4351 players remaining.
#
#
# Start Scraping: Christoph Herr
# Finish Scraping 27147 players.
# 4350 players remaining.
#
#
# Start Scraping: Warren Race
# Finish Scraping 27148 players.
# 4349 players remaining.
#
#
# Start Scraping: Siim Tuus
# Finish Scraping 27149 players.
# 4348 players remaining.
#
#
# Start Scraping: Steven Williams
# Finish Scraping 27150 players.
# 4347 players remaining.
#
#
# Start Scraping: Khalil Outaleb
# Finish Scraping 27151 players.
# 4346 players remaining.
#
#
# Start Scraping: Nicolas Le Gros
# Finish Scraping 27152 players.
# 4345 players remaining.
#
#
# Start Scraping: Javier Rodriguez
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27153 players.
# 4344 players remaining.
#
#
# Start Scraping: Yanick Mandl
# Finish Scraping 27154 players.
# 4343 players remaining.
#
#
# Start Scraping: Max Gregor
# Finish Scraping 27155 players.
# 4342 players remaining.
#
#
# Start Scraping: Lefa Ashley Sibanda
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27156 players.
# 4341 players remaining.
#
#
# Start Scraping: Paul Polarczyk
# Finish Scraping 27157 players.
# 4340 players remaining.
#
#
# Start Scraping: Josip Smoljan
# Finish Scraping 27158 players.
# 4339 players remaining.
#
#
# Start Scraping: Humzah Mahmood
# Finish Scraping 27159 players.
# 4338 players remaining.
#
#
# Start Scraping: Torben Otto
# Finish Scraping 27160 players.
# 4337 players remaining.
#
#
# Start Scraping: Zdravko Divic
# Finish Scraping 27161 players.
# 4336 players remaining.
#
#
# Start Scraping: Christian Kuehne
# Finish Scraping 27162 players.
# 4335 players remaining.
#
#
# Start Scraping: Nika Dolidze
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27163 players.
# 4334 players remaining.
#
#
# Start Scraping: Alvaro Iturriaga Romero
# Finish Scraping 27164 players.
# 4333 players remaining.
#
#
# Start Scraping: Evgeniy Belov
# Finish Scraping 27165 players.
# 4332 players remaining.
#
#
# Start Scraping: Rodrigo Marques Perdigao
# Finish Scraping 27166 players.
# 4331 players remaining.
#
#
# Start Scraping: Marco Pivotto
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27167 players.
# 4330 players remaining.
#
#
# Start Scraping: Myrohn Miranda
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27168 players.
# 4329 players remaining.
#
#
# Start Scraping: Lukas Sanchez
# Finish Scraping 27169 players.
# 4328 players remaining.
#
#
# Start Scraping: Carlos Alejandro Macias Torres
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 27170 players.
# 4327 players remaining.
#
#
# Start Scraping: Matias Fernando Casanello
# Finish Scraping 27171 players.
# 4326 players remaining.
#
#
# Start Scraping: Karl Grossey
# Finish Scraping 27172 players.
# 4325 players remaining.
#
#
# Start Scraping: Marcos Asvestas
# Finish Scraping 27173 players.
# 4324 players remaining.
#
#
# Start Scraping: Matteo Ales
# Finish Scraping 27174 players.
# 4323 players remaining.
#
#
# Start Scraping: Timothy Elgegren
# Finish Scraping 27175 players.
# 4322 players remaining.
#
#
# Start Scraping: Gaylord Messin
# Finish Scraping 27176 players.
# 4321 players remaining.
#
#
# Start Scraping: Rafael Gonzalez Almazan
# Finish Scraping 27177 players.
# 4320 players remaining.
#
#
# Start Scraping: Florian Remond
# Finish Scraping 27178 players.
# 4319 players remaining.
#
#
# Start Scraping: Andrea Di Meo
# Finish Scraping 27179 players.
# 4318 players remaining.
#
#
# Start Scraping: Loic Blanco
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 27180 players.
# 4317 players remaining.
#
#
# Start Scraping: Marius Pimishofer
# Finish Scraping 27181 players.
# 4316 players remaining.
#
#
# Start Scraping: Vinicius Fialho
# Finish Scraping 27182 players.
# 4315 players remaining.
#
#
# Start Scraping: Marcello Donato
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 27183 players.
# 4314 players remaining.
#
#
# Start Scraping: Heitor Garcia
# Finish Scraping 27184 players.
# 4313 players remaining.
#
#
# Start Scraping: Yorni Vargas
# Finish Scraping 27185 players.
# 4312 players remaining.
#
#
# Start Scraping: Antonio Ramirez
# Finish Scraping 27186 players.
# 4311 players remaining.
#
#
# Start Scraping: Nikola Korov
# Finish Scraping 27187 players.
# 4310 players remaining.
#
#
# Start Scraping: Ali Al Qallaf
# Finish Scraping 27188 players.
# 4309 players remaining.
#
#
# Start Scraping: Tamim Hallak
# Finish Scraping 27189 players.
# 4308 players remaining.
#
#
# Start Scraping: Agustin Sacco
# Finish Scraping 27190 players.
# 4307 players remaining.
#
#
# Start Scraping: Ignacio Ortega Enriquez
# Finish Scraping 27191 players.
# 4306 players remaining.
#
#
# Start Scraping: Franco Nicoletti
# Finish Scraping 27192 players.
# 4305 players remaining.
#
#
# Start Scraping: Wilver Etchebarne
# Finish Scraping 27193 players.
# 4304 players remaining.
#
#
# Start Scraping: Ignacio German Dagostino Herrera
# Finish Scraping 27194 players.
# 4303 players remaining.
#
#
# Start Scraping: Matias Ezequiel Vitola
# Finish Scraping 27195 players.
# 4302 players remaining.
#
#
# Start Scraping: Mikhail Yehayan
# Finish Scraping 27196 players.
# 4301 players remaining.
#
#
# Start Scraping: Florian Nicoud
# Finish Scraping 27197 players.
# 4300 players remaining.
#
#
# Start Scraping: Valtteri Ahti
# Finish Scraping 27198 players.
# 4299 players remaining.
#
#
# Start Scraping: Christian Bartmann
# Finish Scraping 27199 players.
# 4298 players remaining.
#
#
# Start Scraping: Przemyslaw Zielinski
# Finish Scraping 27200 players.
# 4297 players remaining.
#
#
# Start Scraping: Edgar D Espindola
# Finish Scraping 27201 players.
# 4296 players remaining.
#
#
# Start Scraping: Samuel Serrano
# Finish Scraping 27202 players.
# 4295 players remaining.
#
#
# ...
#
#
# Start Scraping: Jose Maria Blasi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31338 players.
# 159 players remaining.
#
#
# Start Scraping: Jose Fontes
# Finish Scraping 31339 players.
# 158 players remaining.
#
#
# Start Scraping: Jose Fernandez
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 31340 players.
# 157 players remaining.
#
#
# Start Scraping: Jose Delafuente
# Finish Scraping 31341 players.
# 156 players remaining.
#
#
# Start Scraping: Jorge Cano
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31342 players.
# 155 players remaining.
#
#
# Start Scraping: Johnies Sauer
# Finish Scraping 31343 players.
# 154 players remaining.
#
#
# Start Scraping: John Werner
# Finish Scraping 31344 players.
# 153 players remaining.
#
#
# Start Scraping: John Kapakoglu
# Finish Scraping 31345 players.
# 152 players remaining.
#
#
# Start Scraping: Johan Sjogren
# Finish Scraping 31346 players.
# 151 players remaining.
#
#
# Start Scraping: Johan Milbrimk
# Finish Scraping 31347 players.
# 150 players remaining.
#
#
# Start Scraping: Joe Shaheen
# Finish Scraping 31348 players.
# 149 players remaining.
#
#
# Start Scraping: Joao Guedes
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31349 players.
# 148 players remaining.
#
#
# Start Scraping: Joao Coutinho
# Finish Scraping 31350 players.
# 147 players remaining.
#
#
# Start Scraping: Jin So Lee
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31351 players.
# 146 players remaining.
#
#
# Start Scraping: Jim Somerville
# Finish Scraping 31352 players.
# 145 players remaining.
#
#
# Start Scraping: Jeremy Grubi
# Finish Scraping 31353 players.
# 144 players remaining.
#
#
# Start Scraping: Jeff Player
# Finish Scraping 31354 players.
# 143 players remaining.
#
#
# Start Scraping: Jeff Hamilton
# Finish Scraping 31355 players.
# 142 players remaining.
#
#
# Start Scraping: Jeff Crowne
# Finish Scraping 31356 players.
# 141 players remaining.
#
#
# Start Scraping: Jean Francois Blain
# Finish Scraping 31357 players.
# 140 players remaining.
#
#
# Start Scraping: Javier Duarte
# Finish Scraping 31358 players.
# 139 players remaining.
#
#
# Start Scraping: Jason Wilkie
# Finish Scraping 31359 players.
# 138 players remaining.
#
#
# Start Scraping: James Ilako
# Finish Scraping 31360 players.
# 137 players remaining.
#
#
# Start Scraping: Jacques Bonnemaison
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31361 players.
# 136 players remaining.
#
#
# Start Scraping: Jack Kruger
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 31362 players.
# 135 players remaining.
#
#
# Start Scraping: J Spinnenweber
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31363 players.
# 134 players remaining.
#
#
# Start Scraping: J Potgieter
# Finish Scraping 31364 players.
# 133 players remaining.
#
#
# Start Scraping: Ilyas Ghouse
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31365 players.
# 132 players remaining.
#
#
# Start Scraping: Ian Duvenhage
# Finish Scraping 31366 players.
# 131 players remaining.
#
#
# Start Scraping: Ian Bersin
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31367 players.
# 130 players remaining.
#
#
# Start Scraping: Horacio Marin
# Finish Scraping 31368 players.
# 129 players remaining.
#
#
# Start Scraping: Holger Trahn
# Finish Scraping 31369 players.
# 128 players remaining.
#
#
# Start Scraping: Hiroshi Ito
# Finish Scraping 31370 players.
# 127 players remaining.
#
#
# Start Scraping: Herve Bardot
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31371 players.
# 126 players remaining.
#
#
# Start Scraping: Hernan Valenzuela
# Finish Scraping 31372 players.
# 125 players remaining.
#
#
# Start Scraping: Harvey Becker
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31373 players.
# 124 players remaining.
#
#
# Start Scraping: H Hsu
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31374 players.
# 123 players remaining.
#
#
# Start Scraping: Gustavo Merbilhaa
# Finish Scraping 31375 players.
# 122 players remaining.
#
#
# Start Scraping: Gustavo Espinosa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31376 players.
# 121 players remaining.
#
#
# Start Scraping: Gulio Melchiorre
# Finish Scraping 31377 players.
# 120 players remaining.
#
#
# Start Scraping: Guido Possamai
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31378 players.
# 119 players remaining.
#
#
# Start Scraping: Greg Muller
# Finish Scraping 31379 players.
# 118 players remaining.
#
#
# Start Scraping: Greg Ewansky
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31380 players.
# 117 players remaining.
#
#
# Start Scraping: Graziano Risi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31381 players.
# 116 players remaining.
#
#
# Start Scraping: DUPE Graydon Garner
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31382 players.
# 115 players remaining.
#
#
# Start Scraping: Graham Epsley Jones
# Finish Scraping 31383 players.
# 114 players remaining.
#
#
# Start Scraping: Gerardo Hernandez
# Finish Scraping 31384 players.
# 113 players remaining.
#
#
# Start Scraping: George Obidiegwu
# Finish Scraping 31385 players.
# 112 players remaining.
#
#
# Start Scraping: George Goncalves
# Finish Scraping 31386 players.
# 111 players remaining.
#
#
# Start Scraping: Gavin Hewson
# Finish Scraping 31387 players.
# 110 players remaining.
#
#
# Start Scraping: Frank Apecehea
# Finish Scraping 31388 players.
# 109 players remaining.
#
#
# Start Scraping: Francis Ikosa
# Finish Scraping 31389 players.
# 108 players remaining.
#
#
# Start Scraping: Fernando Souza
# Finish Scraping 31390 players.
# 107 players remaining.
#
#
# Start Scraping: Evgeni Zhelyazkov
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31391 players.
# 106 players remaining.
#
#
# Start Scraping: Enno Van Veggel
# Finish Scraping 31392 players.
# 105 players remaining.
#
#
# Start Scraping: Emmanuel Brard
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31393 players.
# 104 players remaining.
#
#
# Start Scraping: Emeka Igbinebor
# Finish Scraping 31394 players.
# 103 players remaining.
#
#
# Start Scraping: Eduardo Bricio
# Finish Scraping 31395 players.
# 102 players remaining.
#
#
# Start Scraping: Eddie Siegenthaler
# Finish Scraping 31396 players.
# 101 players remaining.
#
#
# Start Scraping: Drazen Humar
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31397 players.
# 100 players remaining.
#
#
# Start Scraping: Donald England
# Finish Scraping 31398 players.
# 99 players remaining.
#
#
# Start Scraping: Didier Frantz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31399 players.
# 98 players remaining.
#
#
# Start Scraping: Delroy Reid
# Finish Scraping 31400 players.
# 97 players remaining.
#
#
# Start Scraping: Davn Santiago
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31401 players.
# 96 players remaining.
#
#
# Start Scraping: David Leveaux
# Finish Scraping 31402 players.
# 95 players remaining.
#
#
# Start Scraping: David Kacharava
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31403 players.
# 94 players remaining.
#
#
# Start Scraping: David Culley
# Finish Scraping 31404 players.
# 93 players remaining.
#
#
# Start Scraping: David Betous
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31405 players.
# 92 players remaining.
#
#
# Start Scraping: Daryl Greeves
# Finish Scraping 31406 players.
# 91 players remaining.
#
#
# Start Scraping: Darren Cole
# Finish Scraping 31407 players.
# 90 players remaining.
#
#
# Start Scraping: Daniel Garcia
# Finish Scraping 31408 players.
# 89 players remaining.
#
#
# Start Scraping: Dan Rastland
# Finish Scraping 31409 players.
# 88 players remaining.
#
#
# Start Scraping: Curtis Hollinger
# Finish Scraping 31410 players.
# 87 players remaining.
#
#
# Start Scraping: Cristofer Leberth
# Finish Scraping 31411 players.
# 86 players remaining.
#
#
# Start Scraping: Cris Herman
# Finish Scraping 31412 players.
# 85 players remaining.
#
#
# Start Scraping: Corey Wittenberg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31413 players.
# 84 players remaining.
#
#
# Start Scraping: Claudio Semmelmann
# Finish Scraping 31414 players.
# 83 players remaining.
#
#
# Start Scraping: Claudio Menna
# Finish Scraping 31415 players.
# 82 players remaining.
#
#
# Start Scraping: Claudio Fava
# Finish Scraping 31416 players.
# 81 players remaining.
#
#
# Start Scraping: Christopher Wolff
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31417 players.
# 80 players remaining.
#
#
# Start Scraping: Chris Kaskow
# Finish Scraping 31418 players.
# 79 players remaining.
#
#
# Start Scraping: Christoph Geukens
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31419 players.
# 78 players remaining.
#
#
# Start Scraping: Chris Vermeeren
# Finish Scraping 31420 players.
# 77 players remaining.
#
#
# Start Scraping: Chris Ellis
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31421 players.
# 76 players remaining.
#
#
# Start Scraping: Carlos Stocker
# Finish Scraping 31422 players.
# 75 players remaining.
#
#
# Start Scraping: Carlos Bravo
# Finish Scraping 31423 players.
# 74 players remaining.
#
#
# Start Scraping: Carl Williams
# Finish Scraping 31424 players.
# 73 players remaining.
#
#
# Start Scraping: Carey Brading
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31425 players.
# 72 players remaining.
#
#
# Start Scraping: Bunge Nahor
# Finish Scraping 31426 players.
# 71 players remaining.
#
#
# Start Scraping: Brett Hibbert
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31427 players.
# 70 players remaining.
#
#
# Start Scraping: Brendan Sharp
# Finish Scraping 31428 players.
# 69 players remaining.
#
#
# Start Scraping: Bosko Simundsa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31429 players.
# 68 players remaining.
#
#
# Start Scraping: Bob Deller
# Finish Scraping 31430 players.
# 67 players remaining.
#
#
# Start Scraping: Bjorn Wahlstrom
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31431 players.
# 66 players remaining.
#
#
# Start Scraping: Bernardo Padilha
# Finish Scraping 31432 players.
# 65 players remaining.
#
#
# Start Scraping: Babatunde Akinola
# Finish Scraping 31433 players.
# 64 players remaining.
#
#
# Start Scraping: B Hochstadter
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31434 players.
# 63 players remaining.
#
#
# Start Scraping: Archie Adams
# Finish Scraping 31435 players.
# 62 players remaining.
#
#
# Start Scraping: Antti Eranne
# Finish Scraping 31436 players.
# 61 players remaining.
#
#
# Start Scraping: Antonio Zampieri
# Finish Scraping 31437 players.
# 60 players remaining.
#
#
# Start Scraping: Anthony Burke
# Finish Scraping 31438 players.
# 59 players remaining.
#
#
# Start Scraping: Andreas Fink
# Finish Scraping 31439 players.
# 58 players remaining.
#
#
# Start Scraping: Anders Rolfsen
# Finish Scraping 31440 players.
# 57 players remaining.
#
#
# Start Scraping: Alberto Kulmann
# Finish Scraping 31441 players.
# 56 players remaining.
#
#
# Start Scraping: Alan Tunik
# Finish Scraping 31442 players.
# 55 players remaining.
#
#
# Start Scraping: Alan Douglas
# Finish Scraping 31443 players.
# 54 players remaining.
#
#
# Start Scraping: A Noffat
# Finish Scraping 31444 players.
# 53 players remaining.
#
#
# Start Scraping: A Hall
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 31445 players.
# 52 players remaining.
#
#
# Start Scraping: Arkadiusz Kocyla Kd20
# Finish Scraping 31446 players.
# 51 players remaining.
#
#
# Start Scraping: Yoann Re
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 31447 players.
# 50 players remaining.
#
#
# Start Scraping: Antonio Ruiz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31448 players.
# 49 players remaining.
#
#
# Start Scraping: Ravishankar Pathanjali
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31449 players.
# 48 players remaining.
#
#
# Start Scraping: Eduardo Magadan
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31450 players.
# 47 players remaining.
#
#
# Start Scraping: Will Farah
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31451 players.
# 46 players remaining.
#
#
# Start Scraping: Juri Margotto
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31452 players.
# 45 players remaining.
#
#
# Start Scraping: Emmanuel Marmillod
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31453 players.
# 44 players remaining.
#
#
# Start Scraping: Juan Olivert
# Finish Scraping 31454 players.
# 43 players remaining.
#
#
# Start Scraping: David Franco
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31455 players.
# 42 players remaining.
#
#
# Start Scraping: Alexander Lindholm L174
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31456 players.
# 41 players remaining.
#
#
# Start Scraping: Adi Kremer
# Finish Scraping 31457 players.
# 40 players remaining.
#
#
# Start Scraping: Paul Lord
# Finish Scraping 31458 players.
# 39 players remaining.
#
#
# Start Scraping: Glenn Solomon
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31459 players.
# 38 players remaining.
#
#
# Start Scraping: Alberto Gutierrez G230
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31460 players.
# 37 players remaining.
#
#
# Start Scraping: Glenn Dickerson
# Finish Scraping 31461 players.
# 36 players remaining.
#
#
# Start Scraping: Jochen Wolff
# Finish Scraping 31462 players.
# 35 players remaining.
#
#
# Start Scraping: Yann Drieux
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31463 players.
# 34 players remaining.
#
#
# Start Scraping: Peter Herrmann
# Finish Scraping 31464 players.
# 33 players remaining.
#
#
# Start Scraping: Trey Carter
# Finish Scraping 31465 players.
# 32 players remaining.
#
#
# Start Scraping: Doug Pielet
# Finish Scraping 31466 players.
# 31 players remaining.
#
#
# Start Scraping: Eric Rosenfeld
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31467 players.
# 30 players remaining.
#
#
# Start Scraping: Bill Stanley
# Finish Scraping 31468 players.
# 29 players remaining.
#
#
# Start Scraping: Dave Richmond
# Finish Scraping 31469 players.
# 28 players remaining.
#
#
# Start Scraping: Peter Smith
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 31470 players.
# 27 players remaining.
#
#
# Start Scraping: Jim Sharton
# Finish Scraping 31471 players.
# 26 players remaining.
#
#
# Start Scraping: Martin Fortun
# Finish Scraping 31472 players.
# 25 players remaining.
#
#
# Start Scraping: Tom Fontana
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31473 players.
# 24 players remaining.
#
#
# Start Scraping: Kai Niemi
# Finish Scraping 31474 players.
# 23 players remaining.
#
#
# Start Scraping: Rob Mitchell
# Finish Scraping 31475 players.
# 22 players remaining.
#
#
# Start Scraping: Hans Fredborg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31476 players.
# 21 players remaining.
#
#
# Start Scraping: Leighton Alfred
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31477 players.
# 20 players remaining.
#
#
# Start Scraping: Fred Viancos
# Finish Scraping 31478 players.
# 19 players remaining.
#
#
# Start Scraping: Jean Luc Cotard
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31479 players.
# 18 players remaining.
#
#
# Start Scraping: Steven Matthews
# Finish Scraping 31480 players.
# 17 players remaining.
#
#
# Start Scraping: John Losito
# Finish Scraping 31481 players.
# 16 players remaining.
#
#
# Start Scraping: Darcy Carroll
# Finish Scraping 31482 players.
# 15 players remaining.
#
#
# Start Scraping: Mark Pinchoff
# Finish Scraping 31483 players.
# 14 players remaining.
#
#
# Start Scraping: Tracy Fenelon
# Finish Scraping 31484 players.
# 13 players remaining.
#
#
# Start Scraping: Tim Robson
# Finish Scraping 31485 players.
# 12 players remaining.
#
#
# Start Scraping: Tim Downey
# Finish Scraping 31486 players.
# 11 players remaining.
#
#
# Start Scraping: James Rubin
# Finish Scraping 31487 players.
# 10 players remaining.
#
#
# Start Scraping: Andy Gordon
# Finish Scraping 31488 players.
# 9 players remaining.
#
#
# Start Scraping: Larry Barnett
# Finish Scraping 31489 players.
# 8 players remaining.
#
#
# Start Scraping: Eduard Pana
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31490 players.
# 7 players remaining.
#
#
# Start Scraping: Tom Caine
# Finish Scraping 31491 players.
# 6 players remaining.
#
#
# Start Scraping: Doug Adler
# Finish Scraping 31492 players.
# 5 players remaining.
#
#
# Start Scraping: Renald Etienne
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31493 players.
# 4 players remaining.
#
#
# Start Scraping: Jochen Hierl
# Finish Scraping 31494 players.
# 3 players remaining.
#
#
# Start Scraping: Robert Baumgartner
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31495 players.
# 2 players remaining.
#
#
# Start Scraping: George Glowa
# Finish Scraping 31496 players.
# 1 players remaining.
#
#
# Start Scraping: Zdenek Slizek
# Finish Scraping 31497 players.
# 0 players remaining.
