# %% [markdown]
# # Normal Updates - Last Update: 2024-11-18

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from geopy.geocoders import Nominatim

# %% [markdown]
# ## 1. Update ATP Ranking

# %% [markdown]
# ### Single Date Update

# %%
# Load txt files
def load_txt(file):
    with open(file, 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    f.close()
    return df

# %%
# The webdesign may change over time!

def scrape_a_date_rank(date, previous):
    # scrape a particular date
    prefix = 'https://www.atptour.com/en/rankings/singles?RankRange=0-100&DateWeek='  # subject to change
    img_pre = 'https://www.atptour.com/en/~/media/images/flags/'

    # open chrome window
    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=1500, height=800)

    # get url
    driver.get(prefix + date)
    # driver.refresh()   # Refreshing can be detected by blockers

    # get content
    print('Start scraping:', date)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    trs = soup.find('table', {'class':'mega-table desktop-table non-live'}).find_all('tr')

    # set attrs
    attrs = ['Date', 'Rank', 'Country', 'Image', 'Player', 'Points']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # date
    dict['Date'] = [date for i in range(100)]

    for tr in trs:
        
        tds = tr.find_all('td')

        if len(tds) == 8: # check error
            # rank
            dict['Rank'].append(tds[0].text.strip())

            # country, image, player name
            lis = tds[1].find_all('li')
            country_abbr = (lis[1].svg.use.get('href', None))[-3:]
            dict['Country'].append(country_abbr.upper())
            dict['Image'].append(img_pre + country_abbr + '.svg')
            dict['Player'].append(lis[2].text.strip())

            # points
            dict['Points'].append(tds[3].text.strip().replace(',', ''))

    # save to txt
    df = pd.DataFrame(dict)
    df.to_csv('m/rank/dates/' + date + '.txt', index = False, sep = ',', encoding='utf-8-sig')
    print('Finished:', date)

    # open the ranking file
    dict_r = load_txt('m/rank/atpranking_20000110_'+previous.replace('-', '')+'.txt').to_dict('list')
    dict_r[date] = []

    # first get points for existing players
    for p in dict_r['Player']:
        found = False
        for i in range(len(dict['Player'])):
            if p == dict['Player'][i]:
                # add new point
                dict_r[date].append(dict['Points'][i])
                found = True
                break
        if not found:
            dict_r[date].append(0)

    # add new player if any
    for p in dict['Player']:
        if p not in dict_r['Player']:
            # add player
            dict_r['Player'].append(p)
            for i in range(len(dict['Player'])):
                if p == dict['Player'][i]:
                    # add country
                    dict_r['Country'].append(dict['Country'][i])
                    # add image
                    dict_r['Country_Image'].append(dict['Image'][i])
                    # add point
                    dict_r[date].append(dict['Points'][i])
                    break
            # add previous points, all 0
            for d in [key for key in dict_r.keys()][3:-1]:
                dict_r[d].append(0)

    # save to txt
    df_new = pd.DataFrame(dict_r)
    df_new.to_csv('m/rank/atpranking_20000110_'+date.replace('-', '')+'.txt', index = False, sep = ',', encoding='utf-8-sig')

# %%
scrape_a_date_rank('2024-11-18', '2024-11-11')
# Out:
# Start scraping: 2024-11-18
# Finished: 2024-11-18

# %% [markdown]
# Remember to add the new dates to dates.txt

# %% [markdown]
# Remember to update rank file in Flourish

# %% [markdown]
# ## 2. Update ATP Links According to New Ranks

# %%
# Define the function to update ATP profile links by ATP Top 100 ranks
def update_link_by_new_rank(dates):
    '''
    dates: a list of dates text
    '''
    # update links according to atp ranking

    prefix = 'https://www.atptour.com/en/rankings/singles?RankRange=0-100&DateWeek='
    head = 'https://www.atptour.com'

    # open txt
    df = load_txt('m/basics/atpprofilebasics.txt')
    pl = [p for p in df['Player']]

    with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
        links = [line[:-1] for line in f]
    f.close()

    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=1500, height=800)

    # date list
    for date in dates:
        driver.get(prefix + date)
        # driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        trs = soup.find('table', {'class':'mega-table desktop-table non-live'}).find_all('tr')
        for tr in trs[1:]:
            tds = tr.find_all('td')
            if len(tds) == 8:
                lis = tds[1].find_all('li')
                if lis[2].text.strip().replace('-', ' ') not in pl:
                    # add new link
                    links.append(head+lis[2].a.get('href'))
                    pl.append(lis[2].text.strip().replace('-', ' '))
                    print('Found:', lis[2].text.strip().replace('-', ' '))
        print('Finish:', date)
    f.close()

    # update links
    with open('m/basics/atpprofilelinks.txt', 'w', encoding='utf-8-sig') as f:
        for link in set(links):
            if link != '':
                f.write(link)
                f.write('\n')
    f.close()

# %%
update_link_by_new_rank(["2024-11-18"])
# Out:
# Found: Mattia Bellucci
# Finish: 2024-11-18

# %% [markdown]
# ## 3. Update ATP Profile Information

# %%
# Update new basics based on new links in atprofilelinks
# Website design may change

with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
    links = [line[:-1] for line in f]
f.close()

dict = load_txt('m/basics/atpprofilebasics.txt').to_dict('list')

chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)

for i, link in enumerate(links):
    if link not in dict['ATP Link']:
        driver.get(link)
        # driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        # add name
        try:
            dict['Player'].append(soup.find('div', {'class': 'player_name'}).text.strip().replace('-', ' '))
        except:
            print(link, 'not found')
            break
        # add link
        dict['ATP Link'].append(link)
        # add birthday
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Birthday'].append(lis[0].find_all('span')[1].text.split('(')[1][:-1].replace('.', '-'))
        except:
            dict['Birthday'].append('')
        # add birthplace
        try:
            lis = soup.find('ul', {'class': 'pd_right'}).find_all('li')
            birthplace = lis[1].find_all('span')[1].text.replace(', ', ' - ')
        except:
            birthplace = ''
        dict['Birthplace'].append(birthplace)
        # add plays
        try:
            lis = soup.find('ul', {'class': 'pd_right'}).find_all('li')
            dict['Plays'].append(lis[2].find_all('span')[1].text.replace(', ', ' - '))
        except:
            dict['Plays'].append('')
        # add turned pro
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Turned Pro'].append(lis[3].find_all('span')[1].text)
        except:
            dict['Turned Pro'].append('')
        # add weight
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Weight (kg)'].append(lis[1].find_all('span')[1].text.split('(')[1][:-3])
        except:
            dict['Weight (kg)'].append('')
        # add height
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Height (cm)'].append(lis[2].find_all('span')[1].text.split('(')[1][:-3])
        except:
            dict['Height (cm)'].append('')
        print('Finished:', i+1)

        # add birthplace details, matched region, lat, lon
        geolocator = Nominatim(user_agent='tennis-vis')
        try:
            location = geolocator.geocode(birthplace)
            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
            dict['Birthplace_lat'].append(location.latitude)
            dict['Birthplace_lon'].append(location.longitude)
            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
        except:
            try:
                location = geolocator.geocode(birthplace.split(',')[0]+','+birthplace.split(',')[1])
                dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                dict['Birthplace_lat'].append(location.latitude)
                dict['Birthplace_lon'].append(location.longitude)
                print(location.address.replace(',', ' -'), location.latitude, location.longitude)
            except:
                try:
                    location = geolocator.geocode(birthplace.split(',')[0])
                    dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                    dict['Birthplace_lat'].append(location.latitude)
                    dict['Birthplace_lon'].append(location.longitude)
                    print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                except:
                    try:
                        location = geolocator.geocode(birthplace.split(',')[1])
                        dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                        dict['Birthplace_lat'].append(location.latitude)
                        dict['Birthplace_lon'].append(location.longitude)
                        print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                    except:
                        try:
                            location = geolocator.geocode(birthplace.split(',')[2])
                            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                            dict['Birthplace_lat'].append(location.latitude)
                            dict['Birthplace_lon'].append(location.longitude)
                            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                        except:
                            dict['Birthplace_matched'].append('')
                            dict['Birthplace_lat'].append('')
                            dict['Birthplace_lon'].append('')
                            print('','','')

df = pd.DataFrame(dict)
df.to_csv('m/basics/atpprofilebasics.txt', index = False, sep = ',', encoding='utf-8-sig')
# Out:
# Finished: 1513
# Busto Arsizio - Varese - Lombardia - 21052 - Italia 45.611932 8.8518269

# %% [markdown]
# ## 4. Update ATP TOP 100 Distribution

# %%
# Define the function to update Geo distribution of ATP Top 100 players
def update_geo_atp100(date,num):
    # get basics
    df_basics = load_txt('m/basics/atpprofilebasics.txt')

    # set basic dict
    attrs = ['Start', 'End', 'Player', 'Rank', 'Points', 'Birthplace', 'Lat', 'Lon']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # get dates
    dates = []
    with open('m/rank/dates.txt', 'r') as f:
        for date in f:
            dates.append(date[:-1])
    f.close()

    # Start looping
    for k, date in enumerate([dates[num - i - 1] for i in range(num)]):
        df_rank = load_txt('m/rank/dates/'+date+'.txt')
        for i, p in enumerate(df_rank['Player']):
            for j, r in enumerate(df_basics['Player']):
                if p.replace('-', ' ') == r and k != (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append(dates[num - k - 2])
                    except:
                        pass
                    break
                if p.replace('-', ' ') == r and k == (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append('')
                    except:
                        pass
                    break

        print('Finished:', date)

    df = pd.DataFrame(dict)

    # Save csv
    df.to_csv('m/rank/atp100geo20000110_'+date.replace("-","")+'.txt', index = False, sep = ',', encoding = 'utf-8-sig')

# %%
# num = Row Number of "2000-01-10" in date.txt file
update_geo_atp100("2024-11-18", 1191)
# Out:
# Finished: 2000-01-10
# Finished: 2000-01-17
# Finished: 2000-01-24
# Finished: 2000-01-31
# Finished: 2000-02-07
# Finished: 2000-02-14
# Finished: 2000-02-21
# Finished: 2000-02-28
# Finished: 2000-03-06
# Finished: 2000-03-13
# Finished: 2000-03-20
# Finished: 2000-03-27
# Finished: 2000-04-03
# Finished: 2000-04-10
# Finished: 2000-04-17
# Finished: 2000-04-24
# Finished: 2000-05-01
# Finished: 2000-05-08
# Finished: 2000-05-15
# Finished: 2000-05-22
# Finished: 2000-05-29
# Finished: 2000-06-05
# Finished: 2000-06-12
# Finished: 2000-06-19
# Finished: 2000-06-26
# Finished: 2000-07-03
# Finished: 2000-07-10
# Finished: 2000-07-17
# Finished: 2000-07-24
# Finished: 2000-07-31
# Finished: 2000-08-07
# Finished: 2000-08-14
# Finished: 2000-08-21
# Finished: 2000-08-28
# Finished: 2000-09-04
# Finished: 2000-09-11
# Finished: 2000-09-18
# Finished: 2000-09-25
# Finished: 2000-10-02
# Finished: 2000-10-09
# Finished: 2000-10-16
# Finished: 2000-10-23
# Finished: 2000-10-30
# Finished: 2000-11-06
# Finished: 2000-11-13
# Finished: 2000-11-20
# Finished: 2000-11-27
# Finished: 2000-12-04
# Finished: 2000-12-11
# Finished: 2000-12-18
# Finished: 2000-12-25
# Finished: 2001-01-01
# Finished: 2001-01-08
# Finished: 2001-01-15
# Finished: 2001-01-22
# Finished: 2001-01-29
# Finished: 2001-02-05
# Finished: 2001-02-12
# Finished: 2001-02-19
# Finished: 2001-02-26
# Finished: 2001-03-05
# Finished: 2001-03-12
# Finished: 2001-03-19
# Finished: 2001-03-26
# Finished: 2001-04-02
# Finished: 2001-04-09
# Finished: 2001-04-16
# Finished: 2001-04-23
# Finished: 2001-04-30
# Finished: 2001-05-07
# Finished: 2001-05-14
# Finished: 2001-05-21
# Finished: 2001-05-28
# Finished: 2001-06-04
# Finished: 2001-06-11
# Finished: 2001-06-18
# Finished: 2001-06-25
# Finished: 2001-07-02
# Finished: 2001-07-09
# Finished: 2001-07-16
# Finished: 2001-07-23
# Finished: 2001-07-30
# Finished: 2001-08-06
# Finished: 2001-08-13
# Finished: 2001-08-20
# Finished: 2001-08-27
# Finished: 2001-09-03
# Finished: 2024-01-08
# Finished: 2024-01-15
# Finished: 2024-01-29
# Finished: 2024-02-05
# Finished: 2024-02-12
# Finished: 2024-02-19
# Finished: 2024-02-26
# Finished: 2024-03-04
# Finished: 2024-03-18
# Finished: 2024-04-01
# Finished: 2024-04-08
# Finished: 2024-04-15
# Finished: 2024-04-22
# Finished: 2024-05-06
# Finished: 2024-05-20
# Finished: 2024-05-27
# Finished: 2024-06-10
# Finished: 2024-06-17
# Finished: 2024-06-24
# Finished: 2024-07-01
# Finished: 2024-07-15
# Finished: 2024-07-22
# Finished: 2024-07-29
# Finished: 2024-08-05
# Finished: 2024-08-12
# Finished: 2024-08-19
# Finished: 2024-08-26
# Finished: 2024-09-09
# Finished: 2024-09-16
# Finished: 2024-09-23
# Finished: 2024-09-30
# Finished: 2024-10-14
# Finished: 2024-10-21
# Finished: 2024-10-28
# Finished: 2024-11-04
# Finished: 2024-11-11
# Finished: 2024-11-18

# %% [markdown]
# Remember to update geo file in Flourish

# %% [markdown]
# ## 5. Update All Matches Player by Player

# %%
# define functions to get all players' names and scrape all matches data
def get_names(sex = ''):
    names = []
    if sex == 'm':
        with open('mp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    elif sex == 'w':
        with open('wp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    else:
        with open('mwplayerlist_processed.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    return names

# define a function to scrape for a single man player's matches
def scrape_matches(name, driver):
    try:
        # set attributes
        attributes_m = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'TP', 'Aces', 'DFs', 'SP', 
                        '1SP', '2SP', 'vA', 'Time']

        attributes_w = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'Time']

        # get cleaned name
        sex = name[1]
        name_cleaned = name[4:].replace(' ', '')

        # set url prefix and types of webpages
        if sex == 'M':
            url = "https://www.tennisabstract.com/cgi-bin/player-classic.cgi?p=" 
        #   types = ["&f=ACareerqq", "&f=ACareerqqr1", "&f=ACareerqqw1"]
        else:
            url = "https://www.tennisabstract.com/cgi-bin/wplayer-classic.cgi?p="

        # Start of Scraping
        print('Start Scraping:', name[4:])
        
        # Man and woman pages are different
        if sex == 'M':

            # For man players
            # Set dictionary
            dic = {}
            for attr in attributes_m:
                dic[attr] = []

            # For serve page
            driver.get(url + name_cleaned.replace(' ', '') + "&f=ACareerqq")
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
        #   driver.quit()

            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # For return page
                show_return = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Return"]')))
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[1])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # For raw page
                show_raw = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Raw"]')))
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[2])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

            else:
                # Serve page
                driver.get(url + name_cleaned.replace(' ', ''))
                driver.refresh()
                # Show career
                try:
                    show_career = driver.find_element(By.ID, 'careerclick')
                except:
                    return None
                show_career.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # Return page
                show_return = driver.find_element(By.XPATH, '//span[text()="Return"]')
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # raw page
                show_raw = driver.find_element(By.XPATH, '//span[text()="Raw"]')
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
              # driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

        else:

            # For woman players
            # set dictionary
            dic = {}
            for attr in attributes_w:
                dic[attr] = []

            # For serve page
            driver.get(url + name_cleaned.replace(' ', '') + '&f=ACareerqq')
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')

            # Check whether it is empty
            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_w[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_w[1]].append(tds[1].text)
                        # sets
                        dic[attributes_w[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_w[3]].append(tds[2].text)
                        # round
                        dic[attributes_w[4]].append(tds[3].text)
                        # rank
                        dic[attributes_w[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_w[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_w[7]].append(1)
                            # winner
                            dic[attributes_w[10]].append(name[4:])
                            # loser
                            dic[attributes_w[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_w[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_w[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_w[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_w[9]].append('')
                        else:
                            # win?
                            dic[attributes_w[7]].append(0)
                            # winner
                            dic[attributes_w[10]].append(spans[1].text)
                            # loser
                            dic[attributes_w[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_w[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_w[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_w[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_w[9]].append('')
                        # score
                        dic[attributes_w[12]].append(tds[7].text.replace(" (ch)", ""))
                        # DR
                        dic[attributes_w[13]].append(tds[8].text)
                        # A%
                        dic[attributes_w[14]].append(tds[9].text)
                        # DF%
                        dic[attributes_w[15]].append(tds[10].text)
                        # 1stIn
                        dic[attributes_w[16]].append(tds[11].text)
                        # 1st%
                        dic[attributes_w[17]].append(tds[12].text)
                        # 2rd%
                        dic[attributes_w[18]].append(tds[13].text)
                        # BPSvd
                        dic[attributes_w[19]].append(tds[14].text)

                print('Serve Page:', len(dic['Date']))

                # For return page
                page_return = driver.find_element(By.XPATH, '//span[text()="Show Return Stats"]')
                page_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
            #   driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_w[20]].append(tds[9].text)
                        # RPW
                        dic[attributes_w[21]].append(tds[10].text)
                        # vA%
                        dic[attributes_w[22]].append(tds[11].text)
                        # v1st%
                        dic[attributes_w[23]].append(tds[12].text)
                        # v2rd%
                        dic[attributes_w[24]].append(tds[13].text)
                        # BPCvt
                        dic[attributes_w[25]].append(tds[14].text)
                        # Time
                        dic[attributes_w[26]].append(tds[15].text)

                print('Return Page:', len(dic['TPW']))

        # save to text, separated by gender
        df = pd.DataFrame(dic)
        df.to_csv(sex.lower() + '/matches/txt/' + name[4:] + '.txt', index = False, sep = ',', encoding='utf-8-sig')

    except (IndexError, AttributeError) as e:
        pass
    
# define a loop function to scrape players from a given index
def scrape_from(idx, sex, driver):
    names = get_names(sex)
    for i in range(idx, len(names)):
        try:
            scrape_matches(names[i], driver)
            print('Finish Scraping', i + 1, 'players.')
            print(len(names) - (i + 1), 'players remaining.')
            print('\n')

        except:

            continue
        
# load txt files
def load_txt(name):
    with open(name[1].lower() + '/matches/txt/' + name[4:] + '.txt', 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    return df

# %%
# UPDATE MATCHES DATA!!!
# set up chromdriver
chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)
scrape_from(6785, 'm', driver)
# Out:
# Start Scraping: Amirvala Madanchi
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 6786 players.
# 24711 players remaining.
#
#
# Start Scraping: Sizya Ernest Kivanda
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 6787 players.
# 24710 players remaining.
#
#
# Start Scraping: Alfonso Honrado Comas
# Finish Scraping 6788 players.
# 24709 players remaining.
#
#
# Start Scraping: Stefan Merunka
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 6789 players.
# 24708 players remaining.
#
#
# Start Scraping: James Junior Storme
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 6790 players.
# 24707 players remaining.
#
#
# Start Scraping: Denis Kapric
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 6791 players.
# 24706 players remaining.
#
#
# Start Scraping: Antonio Zucca
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 6792 players.
# 24705 players remaining.
#
#
# Start Scraping: Ramsey Earnhart
# Serve Page: 51
# Return Page: 51
# Raw Page: 51
# Finish Scraping 6793 players.
# 24704 players remaining.
#
#
# Start Scraping: Ivan Stelko
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 6794 players.
# 24703 players remaining.
#
#
# Start Scraping: Andrei Cociasu
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6795 players.
# 24702 players remaining.
#
#
# Start Scraping: Tico Carrero
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 6796 players.
# 24701 players remaining.
#
#
# Start Scraping: Christian Duxin
# Serve Page: 50
# Return Page: 50
# Raw Page: 50
# Finish Scraping 6797 players.
# 24700 players remaining.
#
#
# Start Scraping: Tommaso Cafferata
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 6798 players.
# 24699 players remaining.
#
#
# Start Scraping: Richard Nicholls
# Finish Scraping 6799 players.
# 24698 players remaining.
#
#
# Start Scraping: Leif Johansson
# Serve Page: 40
# Return Page: 40
# Raw Page: 40
# Finish Scraping 6800 players.
# 24697 players remaining.
#
#
# Start Scraping: Keith Hancock
# Serve Page: 40
# Return Page: 40
# Raw Page: 40
# Finish Scraping 6801 players.
# 24696 players remaining.
#
#
# Start Scraping: Frank Stettner
# Finish Scraping 6802 players.
# 24695 players remaining.
#
#
# Start Scraping: Bertrand Lacombe
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 6803 players.
# 24694 players remaining.
#
#
# Start Scraping: Neeraj Elangovan
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 6804 players.
# 24693 players remaining.
#
#
# Start Scraping: Andrea Patracchini
# Finish Scraping 6805 players.
# 24692 players remaining.
#
#
# Start Scraping: Lucas Zweili
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 6806 players.
# 24691 players remaining.
#
#
# Start Scraping: Marious Zelba
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6807 players.
# 24690 players remaining.
#
#
# Start Scraping: Francesc Montanes Roca
# Finish Scraping 6808 players.
# 24689 players remaining.
#
#
# Start Scraping: Matthias Dorfler
# Finish Scraping 6809 players.
# 24688 players remaining.
#
#
# Start Scraping: Javier Ramos
# Finish Scraping 6810 players.
# 24687 players remaining.
#
#
# Start Scraping: Serguei Tarasevitch
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 6811 players.
# 24686 players remaining.
#
#
# Start Scraping: Joel Kerley
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 6812 players.
# 24685 players remaining.
#
#
# Start Scraping: James Cluskey
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 6813 players.
# 24684 players remaining.
#
#
# Start Scraping: Mohammed Fetov
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 6814 players.
# 24683 players remaining.
#
#
# Start Scraping: Igor Racic
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 6815 players.
# 24682 players remaining.
#
#
# Start Scraping: Dave Lingman
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 6816 players.
# 24681 players remaining.
#
#
# Start Scraping: Christian Straka
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 6817 players.
# 24680 players remaining.
#
#
# Start Scraping: Patrick Schnidrig
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6818 players.
# 24679 players remaining.
#
#
# Start Scraping: Stephan Grebe
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 6819 players.
# 24678 players remaining.
#
#
# Start Scraping: Novak Nash
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 6820 players.
# 24677 players remaining.
#
#
# Start Scraping: Cosmin Reti
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6821 players.
# 24676 players remaining.
#
#
# Start Scraping: Wolfgang Winkler
# Finish Scraping 6822 players.
# 24675 players remaining.
#
#
# Start Scraping: Oscar Del Amo
# Finish Scraping 6823 players.
# 24674 players remaining.
#
#
# Start Scraping: Jonas Kushner
# Finish Scraping 6824 players.
# 24673 players remaining.
#
#
# Start Scraping: Thomas Thieulot
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6825 players.
# 24672 players remaining.
#
#
# Start Scraping: Juan Carlos Bianchi
# Serve Page: 18
# Return Page: 18
# Raw Page: 18
# Finish Scraping 6826 players.
# 24671 players remaining.
#
#
# Start Scraping: Chris Munnerlyn
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 6827 players.
# 24670 players remaining.
#
#
# Start Scraping: Tj Middleton
# Finish Scraping 6828 players.
# 24669 players remaining.
#
#
# Start Scraping: Denis Langaskens
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 6829 players.
# 24668 players remaining.
#
#
# Start Scraping: Damir Buljevic
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 6830 players.
# 24667 players remaining.
#
#
# Start Scraping: Johan Vekemans
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 6831 players.
# 24666 players remaining.
#
#
# Start Scraping: Laurie Warder
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 6832 players.
# 24665 players remaining.
#
#
# Start Scraping: Mike Shore
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 6833 players.
# 24664 players remaining.
#
#
# Start Scraping: Alexander Lebedev
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6834 players.
# 24663 players remaining.
#
#
# Start Scraping: Jorge Blanco Guadalupe
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6835 players.
# 24662 players remaining.
#
#
# Start Scraping: Bruce Strachan
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6836 players.
# 24661 players remaining.
#
#
# Start Scraping: Ferdinando Bonuccelli
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6837 players.
# 24660 players remaining.
#
#
# Start Scraping: Andrea Grazioso
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6838 players.
# 24659 players remaining.
#
#
# Start Scraping: Oscar Fabian Matthews
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6839 players.
# 24658 players remaining.
#
#
# Start Scraping: Berk Iliescu
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6840 players.
# 24657 players remaining.
#
#
# Start Scraping: Morgan Johansson
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6841 players.
# 24656 players remaining.
#
#
# Start Scraping: David Barclay
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6842 players.
# 24655 players remaining.
#
#
# Start Scraping: Vittorio Rubino
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 6843 players.
# 24654 players remaining.
#
#
# Start Scraping: Laurent Bondaz
# Finish Scraping 6844 players.
# 24653 players remaining.
#
#
# Start Scraping: Bodo Nitsche
# Serve Page: 61
# Return Page: 61
# Raw Page: 61
# Finish Scraping 6845 players.
# 24652 players remaining.
#
#
# Start Scraping: Chuck Rombeau
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 6846 players.
# 24651 players remaining.
#
#
# Start Scraping: Mustapha Belkhodja
# Serve Page: 55
# Return Page: 55
# Raw Page: 55
# Finish Scraping 6847 players.
# 24650 players remaining.
#
#
# Start Scraping: John Stephens
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6848 players.
# 24649 players remaining.
#
#
# Start Scraping: Siyu Liu
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6849 players.
# 24648 players remaining.
#
#
# Start Scraping: Shiv Prakash Misra
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6850 players.
# 24647 players remaining.
#
#
# Start Scraping: Sergio Monges
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6851 players.
# 24646 players remaining.
#
#
# Start Scraping: G Turner Howard
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6852 players.
# 24645 players remaining.
#
#
# Start Scraping: Roberto Aubone
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 6853 players.
# 24644 players remaining.
#
#
# Start Scraping: Shuon Madden
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 6854 players.
# 24643 players remaining.
#
#
# Start Scraping: Erik Brummer
# Finish Scraping 6855 players.
# 24642 players remaining.
#
#
# Start Scraping: Arata Ito
# Finish Scraping 6856 players.
# 24641 players remaining.
#
#
# Start Scraping: Konstantin Gerlakh
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6857 players.
# 24640 players remaining.
#
#
# Start Scraping: Gaston Paz
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6858 players.
# 24639 players remaining.
#
#
# Start Scraping: Antonio Lupieri
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 6859 players.
# 24638 players remaining.
#
#
# Start Scraping: Reda Karakhi
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 6860 players.
# 24637 players remaining.
#
#
# Start Scraping: Tzvetan Mihov
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 6861 players.
# 24636 players remaining.
#
#
# Start Scraping: Victor Maynard
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6862 players.
# 24635 players remaining.
#
#
# Start Scraping: Evthimios Karaliolios
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6863 players.
# 24634 players remaining.
#
#
# Start Scraping: Guy Michelevitz
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6864 players.
# 24633 players remaining.
#
#
# Start Scraping: Alexandre Lacroix
# Finish Scraping 6865 players.
# 24632 players remaining.
#
#
# Start Scraping: Huai En Chang
# Finish Scraping 6866 players.
# 24631 players remaining.
#
#
# Start Scraping: Gary Sacks
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 6867 players.
# 24630 players remaining.
#
#
# Start Scraping: Yao Lun Chang
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6868 players.
# 24629 players remaining.
#
#
# Start Scraping: Travis Helgeson
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 6869 players.
# 24628 players remaining.
#
#
# Start Scraping: Mikolaj Szmyrgala
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6870 players.
# 24627 players remaining.
#
#
# Start Scraping: Daniel Chu
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 6871 players.
# 24626 players remaining.
#
#
# Start Scraping: Maxime Bonami
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 6872 players.
# 24625 players remaining.
#
#
# Start Scraping: Robert Phillips
# Finish Scraping 6873 players.
# 24624 players remaining.
#
#
# Start Scraping: David Corrie
# Finish Scraping 6874 players.
# 24623 players remaining.
#
#
# Start Scraping: Juan Pablo Di Cesare
# Finish Scraping 6875 players.
# 24622 players remaining.
#
#
# Start Scraping: Sergei Samoseiko
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 6876 players.
# 24621 players remaining.
#
#
# Start Scraping: Marcin Matkowski
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6877 players.
# 24620 players remaining.
#
#
# Start Scraping: Sylvain Anibie
# Serve Page: 20
# Return Page: 20
# Raw Page: 20
# Finish Scraping 6878 players.
# 24619 players remaining.
#
#
# Start Scraping: Sunday Maku
# Finish Scraping 6879 players.
# 24618 players remaining.
#
#
# Start Scraping: Patrice Atias
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6880 players.
# 24617 players remaining.
#
#
# Start Scraping: Daouda Ndiaye
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 6881 players.
# 24616 players remaining.
#
#
# Start Scraping: Sebastian Da Costa
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 6882 players.
# 24615 players remaining.
#
#
# Start Scraping: Reed Cordish
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6883 players.
# 24614 players remaining.
#
#
# Start Scraping: Thierry Massa
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 6884 players.
# 24613 players remaining.
#
#
# Start Scraping: Robert Tucker
# Finish Scraping 6885 players.
# 24612 players remaining.
#
#
# Start Scraping: Sung Ho Im
# Finish Scraping 6886 players.
# 24611 players remaining.
#
#
# Start Scraping: Jorge Cordova
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6887 players.
# 24610 players remaining.
#
#
# Start Scraping: Julian Vespan
# Finish Scraping 6888 players.
# 24609 players remaining.
#
#
# Start Scraping: Tino Anda
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6889 players.
# 24608 players remaining.
#
#
# Start Scraping: Ken Kuperstein
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 6890 players.
# 24607 players remaining.
#
#
# Start Scraping: Brian Devening
# Serve Page: 26
# Return Page: 26
# Raw Page: 26
# Finish Scraping 6891 players.
# 24606 players remaining.
#
#
# Start Scraping: Johnny Goudenbour
# Serve Page: 42
# Return Page: 42
# Raw Page: 42
# Finish Scraping 6892 players.
# 24605 players remaining.
#
#
# Start Scraping: Joseph Russell
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 6893 players.
# 24604 players remaining.
#
#
# Start Scraping: Pender Murphy
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 6894 players.
# 24603 players remaining.
#
#
# Start Scraping: Hubertus Hoyt
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6895 players.
# 24602 players remaining.
#
#
# Start Scraping: Jacques Thamin
# Serve Page: 39
# Return Page: 39
# Raw Page: 39
# Finish Scraping 6896 players.
# 24601 players remaining.
#
#
# Start Scraping: F D Robbins
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 6897 players.
# 24600 players remaining.
#
#
# Start Scraping: Kane Bonsach Ganley
# Serve Page: 57
# Return Page: 57
# Raw Page: 57
# Finish Scraping 6898 players.
# 24599 players remaining.
#
#
# Start Scraping: Alejandro Melero Kretzer
# Serve Page: 31
# Return Page: 31
# Raw Page: 31
# Finish Scraping 6899 players.
# 24598 players remaining.
#
#
# Start Scraping: Ernesto Aguirre
# Serve Page: 72
# Return Page: 72
# Raw Page: 72
# Finish Scraping 6900 players.
# 24597 players remaining.
#
#
# Start Scraping: Yannik Rahman
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 6901 players.
# 24596 players remaining.
#
#
# Start Scraping: Andrew Rogers
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 6902 players.
# 24595 players remaining.
#
#
# Start Scraping: Felipe De Dios
# Serve Page: 31
# Return Page: 31
# Raw Page: 31
# Finish Scraping 6903 players.
# 24594 players remaining.
#
#
# Start Scraping: Matic Kriznik
# Serve Page: 50
# Return Page: 50
# Raw Page: 50
# Finish Scraping 6904 players.
# 24593 players remaining.
#
#
# Start Scraping: Miha Vetrih
# Serve Page: 30
# Return Page: 30
# Raw Page: 30
# Finish Scraping 6905 players.
# 24592 players remaining.
#
#
# Start Scraping: Giammarco Gandolfi
# Serve Page: 25
# Return Page: 25
# Raw Page: 25
# Finish Scraping 6906 players.
# 24591 players remaining.
#
#
# Start Scraping: Jack Karlsson Wistrand
# Serve Page: 33
# Return Page: 33
# Raw Page: 33
# Finish Scraping 6907 players.
# 24590 players remaining.
#
#
# Start Scraping: Oliver Tarvet
# Serve Page: 39
# Return Page: 39
# Raw Page: 39
# Finish Scraping 6908 players.
# 24589 players remaining.
#
#
# Start Scraping: Jannik Maute
# Serve Page: 26
# Return Page: 26
# Raw Page: 26
# Finish Scraping 6909 players.
# 24588 players remaining.
#
#
# Start Scraping: David Fix
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 6910 players.
# 24587 players remaining.
#
#
# Start Scraping: Max Basing
# Serve Page: 48
# Return Page: 48
# Raw Page: 48
# Finish Scraping 6911 players.
# 24586 players remaining.
#
#
# Start Scraping: Micah Braswell
# Serve Page: 52
# Return Page: 52
# Raw Page: 52
# Finish Scraping 6912 players.
# 24585 players remaining.
#
#
# Start Scraping: Tommaso Carnevale Miino
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 6913 players.
# 24584 players remaining.
#
#
# Start Scraping: Muthu Aadhitiya Senthilkumar
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 6914 players.
# 24583 players remaining.
#
#
# Start Scraping: Cristobal Castro
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 6915 players.
# 24582 players remaining.
#
#
# Start Scraping: Maxwell Mckennon
# Serve Page: 54
# Return Page: 54
# Raw Page: 54
# Finish Scraping 6916 players.
# 24581 players remaining.
#
#
# Start Scraping: Siem Woldeab
# Serve Page: 29
# Return Page: 29
# Raw Page: 29
# Finish Scraping 6917 players.
# 24580 players remaining.
#
#
# Start Scraping: Geun Jun Kim
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 6918 players.
# 24579 players remaining.
#
#
# Start Scraping: Ronan Jachuck
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 6919 players.
# 24578 players remaining.
#
#
# Start Scraping: Chase Ferguson
# Serve Page: 39
# Return Page: 39
# Raw Page: 39
# Finish Scraping 6920 players.
# 24577 players remaining.
#
#
# Start Scraping: Dong Ju Kim
# Serve Page: 25
# Return Page: 25
# Raw Page: 25
# Finish Scraping 6921 players.
# 24576 players remaining.
#
#
# Start Scraping: Nini Gabriel Dica
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 6922 players.
# 24575 players remaining.
#
#
# Start Scraping: Karl Poling
# Serve Page: 47
# Return Page: 47
# Raw Page: 47
# Finish Scraping 6923 players.
# 24574 players remaining.
#
#
# Start Scraping: Bader Alabdullah
# Serve Page: 18
# Return Page: 18
# Raw Page: 18
# Finish Scraping 6924 players.
# 24573 players remaining.
#
#
# Start Scraping: Daniel Salazar Martinez
# Serve Page: 36
# Return Page: 36
# Raw Page: 36
# Finish Scraping 6925 players.
# 24572 players remaining.
#
#
# Start Scraping: Mike Loccisano
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 6926 players.
# 24571 players remaining.
#
#
# Start Scraping: Phuong Van Nguyen
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 6927 players.
# 24570 players remaining.
#
#
# Start Scraping: Juan Carlos Manuel Aguilar
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6928 players.
# 24569 players remaining.
#
#
# Start Scraping: Miguel Semedo
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6929 players.
# 24568 players remaining.
#
#
# Start Scraping: Drew Van Orderlain
# Serve Page: 35
# Return Page: 35
# Raw Page: 35
# Finish Scraping 6930 players.
# 24567 players remaining.
#
#
# Start Scraping: Marko Osmakcic
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6931 players.
# 24566 players remaining.
#
#
# Start Scraping: Daniel Hobart
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6932 players.
# 24565 players remaining.
#
#
# Start Scraping: Antun Vidak
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6933 players.
# 24564 players remaining.
#
#
# Start Scraping: Rodrigo Banzer
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6934 players.
# 24563 players remaining.
#
#
# Start Scraping: Eric Fomba
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 6935 players.
# 24562 players remaining.
#
#
# Start Scraping: Vincent Jaensch Mueller
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 6936 players.
# 24561 players remaining.
#
#
# Start Scraping: Mauricio Resendiz Dominguez
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6937 players.
# 24560 players remaining.
#
#
# Start Scraping: Slobodan Jevtic
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 6938 players.
# 24559 players remaining.
#
#
# Start Scraping: Alberto Gonzalez Lopez
# Finish Scraping 6939 players.
# 24558 players remaining.
#
#
# Start Scraping: Jacques Renavand
# Serve Page: 58
# Return Page: 58
# Raw Page: 58
# Finish Scraping 6940 players.
# 24557 players remaining.
#
#
# Start Scraping: Khalid Allouch
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6941 players.
# 24556 players remaining.
#
#
# Start Scraping: Chuck Darley
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6942 players.
# 24555 players remaining.
#
#
# Start Scraping: Gabriel Wanderley
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6943 players.
# 24554 players remaining.
#
#
# Start Scraping: Tony Parun
# Serve Page: 39
# Return Page: 39
# Raw Page: 39
# Finish Scraping 6944 players.
# 24553 players remaining.
#
#
# Start Scraping: Stelian Gima
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6945 players.
# 24552 players remaining.
#
#
# Start Scraping: Martin Sjoqvist
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 6946 players.
# 24551 players remaining.
#
#
# Start Scraping: Juan Pablo Etchecoin
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 6947 players.
# 24550 players remaining.
#
#
# Start Scraping: Ignace Rotman
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6948 players.
# 24549 players remaining.
#
#
# Start Scraping: Mateo Andres Ruiz Naranjo
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6949 players.
# 24548 players remaining.
#
#
# Start Scraping: Austin Smith
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 6950 players.
# 24547 players remaining.
#
#
# Start Scraping: Mateo Facundo Cressa
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6951 players.
# 24546 players remaining.
#
#
# Start Scraping: Hasier Pastor
# Serve Page: 46
# Return Page: 46
# Raw Page: 46
# Finish Scraping 6952 players.
# 24545 players remaining.
#
#
# Start Scraping: Jose Benitez
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 6953 players.
# 24544 players remaining.
#
#
# Start Scraping: Raphael Lustenberger
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6954 players.
# 24543 players remaining.
#
#
# Start Scraping: Moacir Santos Filho
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6955 players.
# 24542 players remaining.
#
#
# Start Scraping: Laurent Vigne
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6956 players.
# 24541 players remaining.
#
#
# Start Scraping: Matias De Genaro
# Finish Scraping 6957 players.
# 24540 players remaining.
#
#
# Start Scraping: Hyun Joon Suk
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 6958 players.
# 24539 players remaining.
#
#
# Start Scraping: Florian Nufer
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 6959 players.
# 24538 players remaining.
#
#
# Start Scraping: Heinrich Heyl
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 6960 players.
# 24537 players remaining.
#
#
# Start Scraping: Clayton Almeida
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 6961 players.
# 24536 players remaining.
#
#
# Start Scraping: Nikola Gnjatovic
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 6962 players.
# 24535 players remaining.
#
#
# Start Scraping: Vincent Baudat
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6963 players.
# 24534 players remaining.
#
#
# Start Scraping: Stanislav Pribylov
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6964 players.
# 24533 players remaining.
#
#
# Start Scraping: Artemi Tchernenko
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 6965 players.
# 24532 players remaining.
#
#
# Start Scraping: Emil Lenart
# Finish Scraping 6966 players.
# 24531 players remaining.
#
#
# Start Scraping: Ladislav Simon
# Finish Scraping 6967 players.
# 24530 players remaining.
#
#
# Start Scraping: Paul Harsanyi
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 6968 players.
# 24529 players remaining.
#
#
# Start Scraping: Steeve El Haik
# Finish Scraping 6969 players.
# 24528 players remaining.
#
#
# Start Scraping: Andrew Turner
# Finish Scraping 6970 players.
# 24527 players remaining.
#
#
# Start Scraping: Jan Havel
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 6971 players.
# 24526 players remaining.
#
#
# Start Scraping: Michael Herb
# Finish Scraping 6972 players.
# 24525 players remaining.
#
#
# Start Scraping: Jeff Chiang
# Finish Scraping 6973 players.
# 24524 players remaining.
#
#
# Start Scraping: Desmond Tyson
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 6974 players.
# 24523 players remaining.
#
#
# Start Scraping: Ricardo Rivera
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 6975 players.
# 24522 players remaining.
#
#
# Start Scraping: Randy Nixon
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 6976 players.
# 24521 players remaining.
#
#
# Start Scraping: Brent Pirow
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 6977 players.
# 24520 players remaining.
#
#
# Start Scraping: Randy Crawford
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 6978 players.
# 24519 players remaining.
#
#
# Start Scraping: Paul Torre
# Serve Page: 35
# Return Page: 35
# Raw Page: 35
# Finish Scraping 6979 players.
# 24518 players remaining.
#
#
# Start Scraping: Bill Freer
# Serve Page: 37
# Return Page: 37
# Raw Page: 37
# Finish Scraping 6980 players.
# 24517 players remaining.
#
#
# Start Scraping: Niklas Guttau
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 6981 players.
# 24516 players remaining.
#
#
# Start Scraping: Graydon Garner
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 6982 players.
# 24515 players remaining.
#
#
# Start Scraping: Alejandro Ibanez Gallego
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 6983 players.
# 24514 players remaining.
#
#
# Start Scraping: Anatoliy Petrenko
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 6984 players.
# 24513 players remaining.
#
#
# Start Scraping: Osni Junior
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 6985 players.
# 24512 players remaining.
#
#
# Start Scraping: Riaan Du Toit
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 6986 players.
# 24511 players remaining.
#
#
# Start Scraping: Luis Fernando Ramirez
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 6987 players.
# 24510 players remaining.
#
#
# Start Scraping: Ramy Kamal Aita
# Serve Page: 37
# Return Page: 37
# Raw Page: 37
# Finish Scraping 6988 players.
# 24509 players remaining.
#
#
# Start Scraping: Frederico Casaro
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 6989 players.
# 24508 players remaining.
#
#
# Start Scraping: Kamil Filali
# Finish Scraping 6990 players.
# 24507 players remaining.
#
#
# Start Scraping: Patricio Konortoff
# Finish Scraping 6991 players.
# 24506 players remaining.
#
#
# Start Scraping: Pedro Pereira
# Finish Scraping 6992 players.
# 24505 players remaining.
#
#
# Start Scraping: Emilio Martinez
# Serve Page: 97
# Return Page: 97
# Raw Page: 97
# Finish Scraping 6993 players.
# 24504 players remaining.
#
#
# Start Scraping: Adolf Kreinberg
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 6994 players.
# 24503 players remaining.
#
#
# Start Scraping: Peter Scholl
# Serve Page: 94
# Return Page: 94
# Raw Page: 94
# Finish Scraping 6995 players.
# 24502 players remaining.
#
#
# Start Scraping: Ichizo Konishi
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 6996 players.
# 24501 players remaining.
#
#
# Start Scraping: Ronald Mckenzie
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 6997 players.
# 24500 players remaining.
#
#
# Start Scraping: John Obrien
# Serve Page: 64
# Return Page: 64
# Raw Page: 64
# Finish Scraping 6998 players.
# 24499 players remaining.
#
#
# Start Scraping: Matthew Brown
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 6999 players.
# 24498 players remaining.
#
#
# Start Scraping: Satoshi Yoshino
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7000 players.
# 24497 players remaining.
#
#
# Start Scraping: Djordje Djokovic
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 7001 players.
# 24496 players remaining.
#
#
# Start Scraping: Dick Knight
# Serve Page: 37
# Return Page: 37
# Raw Page: 37
# Finish Scraping 7002 players.
# 24495 players remaining.
#
#
# Start Scraping: Don Mccormick
# Serve Page: 40
# Return Page: 40
# Raw Page: 40
# Finish Scraping 7003 players.
# 24494 players remaining.
#
#
# Start Scraping: Anthony Ross
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7004 players.
# 24493 players remaining.
#
#
# Start Scraping: Sergey Shipilov
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 7005 players.
# 24492 players remaining.
#
#
# Start Scraping: Ali Ghareeb
# Serve Page: 28
# Return Page: 28
# Raw Page: 28
# Finish Scraping 7006 players.
# 24491 players remaining.
#
#
# Start Scraping: Hamed Ul Haq
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 7007 players.
# 24490 players remaining.
#
#
# Start Scraping: Asim Shafik
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 7008 players.
# 24489 players remaining.
#
#
# Start Scraping: Torsten Park
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 7009 players.
# 24488 players remaining.
#
#
# Start Scraping: Sven Stadtlander
# Finish Scraping 7010 players.
# 24487 players remaining.
#
#
# Start Scraping: Lazare Kukhalashvili
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 7011 players.
# 24486 players remaining.
#
#
# Start Scraping: Francisco Carbajal
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7012 players.
# 24485 players remaining.
#
#
# Start Scraping: Tomer Hodorov
# Finish Scraping 7013 players.
# 24484 players remaining.
#
#
# Start Scraping: Mark Alexander Kepler
# Finish Scraping 7014 players.
# 24483 players remaining.
#
#
# Start Scraping: Michael Johnson
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 7015 players.
# 24482 players remaining.
#
#
# Start Scraping: Matus Horecny
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 7016 players.
# 24481 players remaining.
#
#
# Start Scraping: Sebastien Louis
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 7017 players.
# 24480 players remaining.
#
#
# Start Scraping: Aivaras Balzekas
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 7018 players.
# 24479 players remaining.
#
#
# Start Scraping: Marcin Golab
# Finish Scraping 7019 players.
# 24478 players remaining.
#
#
# Start Scraping: Zach Dailey
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7020 players.
# 24477 players remaining.
#
#
# Start Scraping: Ivan Caballero
# Finish Scraping 7021 players.
# 24476 players remaining.
#
#
# Start Scraping: Julian Gast
# Finish Scraping 7022 players.
# 24475 players remaining.
#
#
# Start Scraping: Neil Watts
# Finish Scraping 7023 players.
# 24474 players remaining.
#
#
# Start Scraping: Gergely Hultai
# Finish Scraping 7024 players.
# 24473 players remaining.
#
#
# Start Scraping: Marius Calugaru
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 7025 players.
# 24472 players remaining.
#
#
# Start Scraping: Michal Piekos
# Finish Scraping 7026 players.
# 24471 players remaining.
#
#
# Start Scraping: Ling Lu
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 7027 players.
# 24470 players remaining.
#
#
# Start Scraping: Ludwig Sundin
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7028 players.
# 24469 players remaining.
#
#
# Start Scraping: Jan Patrik Jakob
# Finish Scraping 7029 players.
# 24468 players remaining.
#
#
# Start Scraping: Jorge Gonzalez
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 7030 players.
# 24467 players remaining.
#
#
# Start Scraping: Marcus Barbosa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7031 players.
# 24466 players remaining.
#
#
# Start Scraping: Claudio Rodilosso
# Finish Scraping 7032 players.
# 24465 players remaining.
#
#
# Start Scraping: Nevio Devide
# Finish Scraping 7033 players.
# 24464 players remaining.
#
#
# Start Scraping: Alberto Paris
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7034 players.
# 24463 players remaining.
#
#
# Start Scraping: Ivo Werner
# Serve Page: 17
# Return Page: 17
# Raw Page: 17
# Finish Scraping 7035 players.
# 24462 players remaining.
#
#
# Start Scraping: Franco Merlone
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 7036 players.
# 24461 players remaining.
#
#
# Start Scraping: Greg Halder
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 7037 players.
# 24460 players remaining.
#
#
# Start Scraping: Peter Kanderal
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7038 players.
# 24459 players remaining.
#
#
# Start Scraping: Amit Vales
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 7039 players.
# 24458 players remaining.
#
#
# Start Scraping: Arthur Nagel
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 7040 players.
# 24457 players remaining.
#
#
# Start Scraping: Mark Wallner
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 7041 players.
# 24456 players remaining.
#
#
# Start Scraping: Vitor Leal
# Serve Page: 27
# Return Page: 27
# Raw Page: 27
# Finish Scraping 7042 players.
# 24455 players remaining.
#
#
# Start Scraping: Manuel Mouilleron Salvo
# Serve Page: 32
# Return Page: 32
# Raw Page: 32
# Finish Scraping 7043 players.
# 24454 players remaining.
#
#
# Start Scraping: Vuk Radjenovic
# Serve Page: 54
# Return Page: 54
# Raw Page: 54
# Finish Scraping 7044 players.
# 24453 players remaining.
#
#
# Start Scraping: Francisco Pini
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 7045 players.
# 24452 players remaining.
#
#
# Start Scraping: Hudson Rivera
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 7046 players.
# 24451 players remaining.
#
#
# Start Scraping: Theo Papamalamis
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7047 players.
# 24450 players remaining.
#
#
# Start Scraping: Jonathan Baron
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 7048 players.
# 24449 players remaining.
#
#
# Start Scraping: Gabriel Elicha Navas
# Serve Page: 37
# Return Page: 37
# Raw Page: 37
# Finish Scraping 7049 players.
# 24448 players remaining.
#
#
# Start Scraping: Pierre Yves Bailly
# Serve Page: 25
# Return Page: 25
# Raw Page: 25
# Finish Scraping 7050 players.
# 24447 players remaining.
#
#
# Start Scraping: Mehdi Benchakroun
# Serve Page: 34
# Return Page: 34
# Raw Page: 34
# Finish Scraping 7051 players.
# 24446 players remaining.
#
#
# Start Scraping: Simeon Terziev
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 7052 players.
# 24445 players remaining.
#
#
# Start Scraping: Etienne Donnet
# Serve Page: 50
# Return Page: 50
# Raw Page: 50
# Finish Scraping 7053 players.
# 24444 players remaining.
#
#
# Start Scraping: Arda Azkara
# Serve Page: 32
# Return Page: 32
# Raw Page: 32
# Finish Scraping 7054 players.
# 24443 players remaining.
#
#
# Start Scraping: Roni Mikael Hietaranta
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 7055 players.
# 24442 players remaining.
#
#
# Start Scraping: Leonardo Taddia
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 7056 players.
# 24441 players remaining.
#
#
# Start Scraping: Cesar Bourgois
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 7057 players.
# 24440 players remaining.
#
#
# Start Scraping: Essa Qabazard
# Serve Page: 20
# Return Page: 20
# Raw Page: 20
# Finish Scraping 7058 players.
# 24439 players remaining.
#
#
# Start Scraping: Ran Amar
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 7059 players.
# 24438 players remaining.
#
#
# Start Scraping: Gilad Tamar
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 7060 players.
# 24437 players remaining.
#
#
# Start Scraping: Nicolas Xiviller
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7061 players.
# 24436 players remaining.
#
#
# Start Scraping: Joshua Peck
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7062 players.
# 24435 players remaining.
#
#
# Start Scraping: Gary Kushnirovich
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7063 players.
# 24434 players remaining.
#
#
# Start Scraping: Javier Naser
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7064 players.
# 24433 players remaining.
#
#
# Start Scraping: Patric Prinoth
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 7065 players.
# 24432 players remaining.
#
#
# Start Scraping: Worovin Kumthonkittikul
# Serve Page: 20
# Return Page: 20
# Raw Page: 20
# Finish Scraping 7066 players.
# 24431 players remaining.
#
#
# Start Scraping: Augusto Virgili
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 7067 players.
# 24430 players remaining.
#
#
# Start Scraping: William Griffith
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7068 players.
# 24429 players remaining.
#
#
# Start Scraping: Keisuke Watanuki
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7069 players.
# 24428 players remaining.
#
#
# Start Scraping: Jose Fernando Carvajal Torres
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7070 players.
# 24427 players remaining.
#
#
# Start Scraping: Michal Franek
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7071 players.
# 24426 players remaining.
#
#
# Start Scraping: Carlos Cuenca Navarro
# Finish Scraping 7072 players.
# 24425 players remaining.
#
#
# Start Scraping: Mario Cuellar Gonzalez
# Finish Scraping 7073 players.
# 24424 players remaining.
#
#
# Start Scraping: Pierre Berntsson
# Finish Scraping 7074 players.
# 24423 players remaining.
#
#
# Start Scraping: Myles Orton
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 7075 players.
# 24422 players remaining.
#
#
# Start Scraping: Syed Mohd Agil Syed Naguib
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 7076 players.
# 24421 players remaining.
#
#
# Start Scraping: Steve Avoyer
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7077 players.
# 24420 players remaining.
#
#
# Start Scraping: Rod Brent
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 7078 players.
# 24419 players remaining.
#
#
# Start Scraping: Dimo Tolev
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 7079 players.
# 24418 players remaining.
#
#
# Start Scraping: Johnny Arcilla
# Serve Page: 35
# Return Page: 35
# Raw Page: 35
# Finish Scraping 7080 players.
# 24417 players remaining.
#
#
# Start Scraping: Yaser Zaatini
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 7081 players.
# 24416 players remaining.
#
#
# Start Scraping: Will Forsyth
# Finish Scraping 7082 players.
# 24415 players remaining.
#
#
# Start Scraping: Thomas Holzmann
# Finish Scraping 7083 players.
# 24414 players remaining.
#
#
# Start Scraping: Stefano Mezzadri
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 7084 players.
# 24413 players remaining.
#
#
# Start Scraping: Roberto Lombardi
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7085 players.
# 24412 players remaining.
#
#
# Start Scraping: Jose Castanon
# Serve Page: 37
# Return Page: 37
# Raw Page: 37
# Finish Scraping 7086 players.
# 24411 players remaining.
#
#
# Start Scraping: Jan Pisecky
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7087 players.
# 24410 players remaining.
#
#
# Start Scraping: Alex Roberman
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 7088 players.
# 24409 players remaining.
#
#
# Start Scraping: Mike Vermeer
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 7089 players.
# 24408 players remaining.
#
#
# Start Scraping: Maksim Malyshev
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7090 players.
# 24407 players remaining.
#
#
# Start Scraping: Rodrigo Scattareggia
# Finish Scraping 7091 players.
# 24406 players remaining.
#
#
# Start Scraping: Mohsen Hossein Zade
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7092 players.
# 24405 players remaining.
#
#
# Start Scraping: David Sodek
# Finish Scraping 7093 players.
# 24404 players remaining.
#
#
# Start Scraping: Joshua Jones
# Finish Scraping 7094 players.
# 24403 players remaining.
#
#
# Start Scraping: Aditya Hari Sasongko
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7095 players.
# 24402 players remaining.
#
#
# Start Scraping: Dong Kyu Lee
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7096 players.
# 24401 players remaining.
#
#
# Start Scraping: Joel Kincaid
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 7097 players.
# 24400 players remaining.
#
#
# Start Scraping: Kacper Owsian
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7098 players.
# 24399 players remaining.
#
#
# Start Scraping: Stephen Amritraj
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 7099 players.
# 24398 players remaining.
#
#
# Start Scraping: Branislav Repa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7100 players.
# 24397 players remaining.
#
#
# Start Scraping: Yong Bum Seo
# Serve Page: 16
# Return Page: 16
# Raw Page: 16
# Finish Scraping 7101 players.
# 24396 players remaining.
#
#
# Start Scraping: Bart De Gier
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 7102 players.
# 24395 players remaining.
#
#
# Start Scraping: David Tosas Ros
# Finish Scraping 7103 players.
# 24394 players remaining.
#
#
# Start Scraping: Rolando Vargas
# Finish Scraping 7104 players.
# 24393 players remaining.
#
#
# Start Scraping: Michael Kosta
# Finish Scraping 7105 players.
# 24392 players remaining.
#
#
# Start Scraping: Pieter Joubert
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7106 players.
# 24391 players remaining.
#
#
# Start Scraping: Jordi Fernandez
# Finish Scraping 7107 players.
# 24390 players remaining.
#
#
# Start Scraping: Jaco Van Der Westhuizen
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 7108 players.
# 24389 players remaining.
#
#
# Start Scraping: Santiago Messora
# Finish Scraping 7109 players.
# 24388 players remaining.
#
#
# Start Scraping: Cyril Francois
# Finish Scraping 7110 players.
# 24387 players remaining.
#
#
# Start Scraping: Stephane Martinez
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7111 players.
# 24386 players remaining.
#
#
# Start Scraping: Francesco Zugarelli
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7112 players.
# 24385 players remaining.
#
#
# Start Scraping: Alexei Ageev
# Finish Scraping 7113 players.
# 24384 players remaining.
#
#
# Start Scraping: Radoslav Radev
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7114 players.
# 24383 players remaining.
#
#
# Start Scraping: Nick Adams
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7115 players.
# 24382 players remaining.
#
#
# Start Scraping: Stefan Fueg
# Finish Scraping 7116 players.
# 24381 players remaining.
#
#
# Start Scraping: Peter Wright
# Serve Page: 17
# Return Page: 17
# Raw Page: 17
# Finish Scraping 7117 players.
# 24380 players remaining.
#
#
# Start Scraping: Jeff Klaparda
# Serve Page: 44
# Return Page: 44
# Raw Page: 44
# Finish Scraping 7118 players.
# 24379 players remaining.
#
#
# Start Scraping: Jan Van Langendonck
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 7119 players.
# 24378 players remaining.
#
#
# Start Scraping: Tim Garcia
# Serve Page: 25
# Return Page: 25
# Raw Page: 25
# Finish Scraping 7120 players.
# 24377 players remaining.
#
#
# Start Scraping: Lars Elvstrom
# Serve Page: 42
# Return Page: 42
# Raw Page: 42
# Finish Scraping 7121 players.
# 24376 players remaining.
#
#
# Start Scraping: Peter Fishbach
# Serve Page: 37
# Return Page: 37
# Raw Page: 37
# Finish Scraping 7122 players.
# 24375 players remaining.
#
#
# Start Scraping: Sammy Giammalva
# Serve Page: 117
# Return Page: 117
# Raw Page: 117
# Finish Scraping 7123 players.
# 24374 players remaining.
#
#
# Start Scraping: Mitchell Thomas Mcdaniels
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7124 players.
# 24373 players remaining.
#
#
# Start Scraping: Stan Smith Sr
# Finish Scraping 7125 players.
# 24372 players remaining.
#
#
# Start Scraping: Mattias Siimar
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7126 players.
# 24371 players remaining.
#
#
# Start Scraping: Vincent Van Den Honert
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7127 players.
# 24370 players remaining.
#
#
# Start Scraping: Young Hoon Jeong
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7128 players.
# 24369 players remaining.
#
#
# Start Scraping: Bogdan Djurdjevic
# Serve Page: 42
# Return Page: 42
# Raw Page: 42
# Finish Scraping 7129 players.
# 24368 players remaining.
#
#
# Start Scraping: Enric Guaita Pais
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 7130 players.
# 24367 players remaining.
#
#
# Start Scraping: Mohamed Hassan
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7131 players.
# 24366 players remaining.
#
#
# Start Scraping: Robert Nita
# Finish Scraping 7132 players.
# 24365 players remaining.
#
#
# Start Scraping: Jim Hobson
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 7133 players.
# 24364 players remaining.
#
#
# Start Scraping: Jim Beste
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 7134 players.
# 24363 players remaining.
#
#
# Start Scraping: Wayne Reid
# Serve Page: 74
# Return Page: 74
# Raw Page: 74
# Finish Scraping 7135 players.
# 24362 players remaining.
#
#
# Start Scraping: Neil Gibson
# Serve Page: 90
# Return Page: 90
# Raw Page: 90
# Finish Scraping 7136 players.
# 24361 players remaining.
#
#
# Start Scraping: Stephen Hoh
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7137 players.
# 24360 players remaining.
#
#
# Start Scraping: Peter Jackson
# Serve Page: 45
# Return Page: 45
# Raw Page: 45
# Finish Scraping 7138 players.
# 24359 players remaining.
#
#
# Start Scraping: Thomas Cristian Hodel
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 7139 players.
# 24358 players remaining.
#
#
# Start Scraping: Dmitri Marfinsky
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 7140 players.
# 24357 players remaining.
#
#
# Start Scraping: Benjamin Janse Van Rensburg
# Finish Scraping 7141 players.
# 24356 players remaining.
#
#
# Start Scraping: Ignacio Vicente
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7142 players.
# 24355 players remaining.
#
#
# Start Scraping: Wael Kilani
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 7143 players.
# 24354 players remaining.
#
#
# Start Scraping: Carlos Gomez Ferre
# Finish Scraping 7144 players.
# 24353 players remaining.
#
#
# Start Scraping: Edgar Hernandez Perez
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 7145 players.
# 24352 players remaining.
#
#
# Start Scraping: Walter Redondo
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 7146 players.
# 24351 players remaining.
#
#
# Start Scraping: Vittorio Magnelli
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 7147 players.
# 24350 players remaining.
#
#
# Start Scraping: Shinichi Sakamoto
# Serve Page: 41
# Return Page: 41
# Raw Page: 41
# Finish Scraping 7148 players.
# 24349 players remaining.
#
#
# Start Scraping: Roberto Chavez
# Serve Page: 39
# Return Page: 39
# Raw Page: 39
# Finish Scraping 7149 players.
# 24348 players remaining.
#
#
# Start Scraping: Graeme Thomson
# Serve Page: 36
# Return Page: 36
# Raw Page: 36
# Finish Scraping 7150 players.
# 24347 players remaining.
#
#
# Start Scraping: Yuri Andrade
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7151 players.
# 24346 players remaining.
#
#
# Start Scraping: Sahak Bazrganian
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7152 players.
# 24345 players remaining.
#
#
# Start Scraping: Ivan Gomez Mantilla
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7153 players.
# 24344 players remaining.
#
#
# Start Scraping: Francisco Arrechea
# Finish Scraping 7154 players.
# 24343 players remaining.
#
#
# Start Scraping: Martin Trueva
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 7155 players.
# 24342 players remaining.
#
#
# Start Scraping: Ignacio Martire
# Finish Scraping 7156 players.
# 24341 players remaining.
#
#
# Start Scraping: Yannick Thomet
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 7157 players.
# 24340 players remaining.
#
#
# Start Scraping: Egor Puntus
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7158 players.
# 24339 players remaining.
#
#
# Start Scraping: Aleksandar Cvetkov
# Finish Scraping 7159 players.
# 24338 players remaining.
#
#
# Start Scraping: Andrei Somov
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 7160 players.
# 24337 players remaining.
#
#
# Start Scraping: Alvaro Izquierdo
# Finish Scraping 7161 players.
# 24336 players remaining.
#
#
# Start Scraping: Peter Jon Nomdo
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 7162 players.
# 24335 players remaining.
#
#
# Start Scraping: Eric Butorac
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 7163 players.
# 24334 players remaining.
#
#
# Start Scraping: Jorge Haro
# Serve Page: 7
# Return Page: 7
# Raw Page: 7
# Finish Scraping 7164 players.
# 24333 players remaining.
#
#
# Start Scraping: Daniel Dios
# Finish Scraping 7165 players.
# 24332 players remaining.
#
#
# Start Scraping: Andrew Nisker
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7166 players.
# 24331 players remaining.
#
#
# Start Scraping: Fernando Las Heras
# Finish Scraping 7167 players.
# 24330 players remaining.
#
#
# Start Scraping: Christian Hill
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7168 players.
# 24329 players remaining.
#
#
# Start Scraping: Ross Loel
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 7169 players.
# 24328 players remaining.
#
#
# Start Scraping: Rene Heidbrink
# Finish Scraping 7170 players.
# 24327 players remaining.
#
#
# Start Scraping: Grady Burnett
# Finish Scraping 7171 players.
# 24326 players remaining.
#
#
# Start Scraping: Jeremy Sutter
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 7172 players.
# 24325 players remaining.
#
#
# Start Scraping: Chad Rosser
# Finish Scraping 7173 players.
# 24324 players remaining.
#
#
# Start Scraping: Derek Brown
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 7174 players.
# 24323 players remaining.
#
#
# Start Scraping: Johan Sandberg
# ...
# Finish Scraping 8842 players.
# 22655 players remaining.
#
#
# Start Scraping: James Pade
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 8843 players.
# 22654 players remaining.
#
#
# Start Scraping: Danilo Pila
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 8844 players.
# 22653 players remaining.
#
#
# Start Scraping: Daniel Heryanto
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 8845 players.
# 22652 players remaining.
#
#
# Start Scraping: Craig Johnson
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8846 players.
# 22651 players remaining.
#
#
# Start Scraping: Christoph Hoop
# Finish Scraping 8847 players.
# 22650 players remaining.
#
#
# Start Scraping: Brandon Fallon
# Finish Scraping 8848 players.
# 22649 players remaining.
#
#
# Start Scraping: Shu Saito
# Serve Page: 20
# Return Page: 20
# Raw Page: 20
# Finish Scraping 8849 players.
# 22648 players remaining.
#
#
# Start Scraping: Elwin Antony
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 8850 players.
# 22647 players remaining.
#
#
# Start Scraping: Inigo Santos Fernandez
# Serve Page: 18
# Return Page: 18
# Raw Page: 18
# Finish Scraping 8851 players.
# 22646 players remaining.
#
#
# Start Scraping: Alexey Golovachev
# Finish Scraping 8852 players.
# 22645 players remaining.
#
#
# Start Scraping: Jonas Koenig
# Finish Scraping 8853 players.
# 22644 players remaining.
#
#
# Start Scraping: Sardor Pulatov
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 8854 players.
# 22643 players remaining.
#
#
# Start Scraping: Yu Wang
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8855 players.
# 22642 players remaining.
#
#
# Start Scraping: Serguei Vassine
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 8856 players.
# 22641 players remaining.
#
#
# Start Scraping: Christophe Deveaux
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 8857 players.
# 22640 players remaining.
#
#
# Start Scraping: Vinicius Bortolatto
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 8858 players.
# 22639 players remaining.
#
#
# Start Scraping: Christian Groh
# Finish Scraping 8859 players.
# 22638 players remaining.
#
#
# Start Scraping: Kamil Lewandowicz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8860 players.
# 22637 players remaining.
#
#
# Start Scraping: Michal Holenda
# Finish Scraping 8861 players.
# 22636 players remaining.
#
#
# Start Scraping: Matthew Porter
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 8862 players.
# 22635 players remaining.
#
#
# Start Scraping: Jeremy Berman
# Finish Scraping 8863 players.
# 22634 players remaining.
#
#
# Start Scraping: Jiri Hobler
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 8864 players.
# 22633 players remaining.
#
#
# Start Scraping: Francisco Mendez
# Finish Scraping 8865 players.
# 22632 players remaining.
#
#
# Start Scraping: Fernando Sierra
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 8866 players.
# 22631 players remaining.
#
#
# Start Scraping: Fernando Araujo
# Finish Scraping 8867 players.
# 22630 players remaining.
#
#
# Start Scraping: Ekkarin Pisuth Arnonth
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 8868 players.
# 22629 players remaining.
#
#
# Start Scraping: Luis Uribe
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8869 players.
# 22628 players remaining.
#
#
# Start Scraping: Sylvain Charrier
# Finish Scraping 8870 players.
# 22627 players remaining.
#
#
# Start Scraping: Fabio Massetta
# Finish Scraping 8871 players.
# 22626 players remaining.
#
#
# Start Scraping: Melvin Tong
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 8872 players.
# 22625 players remaining.
#
#
# Start Scraping: Jean Francois Berard
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 8873 players.
# 22624 players remaining.
#
#
# Start Scraping: Hiram Silfa
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 8874 players.
# 22623 players remaining.
#
#
# Start Scraping: Robert Orlik
# Finish Scraping 8875 players.
# 22622 players remaining.
#
#
# Start Scraping: Thassilo Haun
# Finish Scraping 8876 players.
# 22621 players remaining.
#
#
# Start Scraping: Marc Lohrmann
# Finish Scraping 8877 players.
# 22620 players remaining.
#
#
# Start Scraping: Lech Sidor
# Serve Page: 6
# Return Page: 6
# Raw Page: 6
# Finish Scraping 8878 players.
# 22619 players remaining.
#
#
# Start Scraping: Ulli Nganga
# Finish Scraping 8879 players.
# 22618 players remaining.
#
#
# Start Scraping: James Lenton
# Finish Scraping 8880 players.
# 22617 players remaining.
#
#
# Start Scraping: Matthew Stroyman
# Finish Scraping 8881 players.
# 22616 players remaining.
#
#
# Start Scraping: Brad Koontz
# Finish Scraping 8882 players.
# 22615 players remaining.
#
#
# Start Scraping: Chris Kennedy
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8883 players.
# 22614 players remaining.
#
#
# Start Scraping: Ruben Lamothe
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8884 players.
# 22613 players remaining.
#
#
# Start Scraping: Andrew Burrow
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 8885 players.
# 22612 players remaining.
#
#
# Start Scraping: Miloslav Lacek
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 8886 players.
# 22611 players remaining.
#
#
# Start Scraping: Victor Eke
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 8887 players.
# 22610 players remaining.
#
#
# Start Scraping: Alexander Razeghi
# Serve Page: 16
# Return Page: 16
# Raw Page: 16
# Finish Scraping 8888 players.
# 22609 players remaining.
#
#
# Start Scraping: Matteo Lavizzari
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 8889 players.
# 22608 players remaining.
#
#
# Start Scraping: Lorenzo Ferri
# Serve Page: 20
# Return Page: 20
# Raw Page: 20
# Finish Scraping 8890 players.
# 22607 players remaining.
#
#
# Start Scraping: Aleksander Chayka
# Serve Page: 27
# Return Page: 27
# Raw Page: 27
# Finish Scraping 8891 players.
# 22606 players remaining.
#
#
# Start Scraping: Henrik Bladelius
# Serve Page: 18
# Return Page: 18
# Raw Page: 18
# Finish Scraping 8892 players.
# 22605 players remaining.
#
#
# Start Scraping: Oren Vasser
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 8893 players.
# 22604 players remaining.
#
#
# Start Scraping: Guillaume Dalmasso
# Serve Page: 33
# Return Page: 33
# Raw Page: 33
# Finish Scraping 8894 players.
# 22603 players remaining.
#
#
# Start Scraping: Vladimir Bazilevskiy
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8895 players.
# 22602 players remaining.
#
#
# Start Scraping: Alessio Vasquez Gehrke
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 8896 players.
# 22601 players remaining.
#
#
# Start Scraping: Majun Li
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8897 players.
# 22600 players remaining.
#
#
# Start Scraping: Jakub Katuch
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 8898 players.
# 22599 players remaining.
#
#
# Start Scraping: Filip Jeff Planinsek
# Serve Page: 29
# Return Page: 29
# Raw Page: 29
# Finish Scraping 8899 players.
# 22598 players remaining.
#
#
# Start Scraping: Reda Bennani
# Serve Page: 27
# Return Page: 27
# Raw Page: 27
# Finish Scraping 8900 players.
# 22597 players remaining.
#
#
# Start Scraping: Mao Takada
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8901 players.
# 22596 players remaining.
#
#
# Start Scraping: Igor Dudun
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8902 players.
# 22595 players remaining.
#
#
# Start Scraping: Stepan Mruzek
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8903 players.
# 22594 players remaining.
#
#
# Start Scraping: Mateo Bejenaru
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8904 players.
# 22593 players remaining.
#
#
# Start Scraping: Nicholas Jovanovski
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 8905 players.
# 22592 players remaining.
#
#
# Start Scraping: Mykhailo Mossur
# Serve Page: 8
# Return Page: 8
# Raw Page: 8
# Finish Scraping 8906 players.
# 22591 players remaining.
#
#
# Start Scraping: Pijus Vaitiekunas
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 8907 players.
# 22590 players remaining.
#
#
# Start Scraping: Drazen Petrovic
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 8908 players.
# 22589 players remaining.
#
#
# Start Scraping: Borys Zgola
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 8909 players.
# 22588 players remaining.
#
#
# Start Scraping: Mark Havlicek
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8910 players.
# 22587 players remaining.
#
#
# Start Scraping: Pierre Antoine Tailleu
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8911 players.
# 22586 players remaining.
#
#
# Start Scraping: Konstantin Zhzhenov
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 8912 players.
# 22585 players remaining.
#
#
# Start Scraping: Liova Ayite Ajavon
# Finish Scraping 8913 players.
# 22584 players remaining.
#
#
# Start Scraping: Elbert Barr
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8914 players.
# 22583 players remaining.
#
#
# Start Scraping: Danylo Veremeichuk
# Finish Scraping 8915 players.
# 22582 players remaining.
#
#
# Start Scraping: Andreja Petrovic
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8916 players.
# 22581 players remaining.
#
#
# Start Scraping: Sergo Sikharulidze
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 8917 players.
# 22580 players remaining.
#
#
# Start Scraping: Ioannis Stamoulos
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8918 players.
# 22579 players remaining.
#
#
# Start Scraping: Jing Long Weng
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8919 players.
# 22578 players remaining.
#
#
# Start Scraping: Takeru Yuzuki
# Serve Page: 18
# Return Page: 18
# Raw Page: 18
# Finish Scraping 8920 players.
# 22577 players remaining.
#
#
# Start Scraping: Adrien Burdet
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8921 players.
# 22576 players remaining.
#
#
# Start Scraping: David Quayle
# Serve Page: 15
# Return Page: 15
# Raw Page: 15
# Finish Scraping 8922 players.
# 22575 players remaining.
#
#
# Start Scraping: Pierce Rollins
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8923 players.
# 22574 players remaining.
#
#
# Start Scraping: Kevin Major
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8924 players.
# 22573 players remaining.
#
#
# Start Scraping: Grey Hamilton
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8925 players.
# 22572 players remaining.
#
#
# Start Scraping: Raul Garcia
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 8926 players.
# 22571 players remaining.
#
#
# Start Scraping: James Story
# Serve Page: 33
# Return Page: 33
# Raw Page: 33
# Finish Scraping 8927 players.
# 22570 players remaining.
#
#
# Start Scraping: Laelson Rodrigues
# Serve Page: 17
# Return Page: 17
# Raw Page: 17
# Finish Scraping 8928 players.
# 22569 players remaining.
#
#
# Start Scraping: Osman Torski
# Serve Page: 9
# Return Page: 9
# Raw Page: 9
# Finish Scraping 8929 players.
# 22568 players remaining.
#
#
# Start Scraping: Matthew Foster Estwick
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8930 players.
# 22567 players remaining.
#
#
# Start Scraping: Darrshan Suresh
# Serve Page: 16
# Return Page: 16
# Raw Page: 16
# Finish Scraping 8931 players.
# 22566 players remaining.
#
#
# Start Scraping: Aziz Dadabaev
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8932 players.
# 22565 players remaining.
#
#
# Start Scraping: Chanon Phunsawat
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 8933 players.
# 22564 players remaining.
#
#
# Start Scraping: Christian Lerby
# Serve Page: 21
# Return Page: 21
# Raw Page: 21
# Finish Scraping 8934 players.
# 22563 players remaining.
#
#
# Start Scraping: Max Benaim
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 8935 players.
# 22562 players remaining.
#
#
# Start Scraping: Joao Vitor Goncalves Ceolin
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 8936 players.
# 22561 players remaining.
#
#
# Start Scraping: Simon Partridge
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 8937 players.
# 22560 players remaining.
#
#
# Start Scraping: Alexandre Ruscica
# Serve Page: 13
# Return Page: 13
# Raw Page: 13
# Finish Scraping 8938 players.
# 22559 players remaining.
#
#
# Start Scraping: Bjorn Nareyka
# Serve Page: 10
# Return Page: 10
# Raw Page: 10
# Finish Scraping 8939 players.
# 22558 players remaining.
#
#
# Start Scraping: Samy Grace
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8940 players.
# 22557 players remaining.
#
#
# Start Scraping: Sven Lah
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8941 players.
# 22556 players remaining.
#
#
# Start Scraping: Mislav Bosnjak
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8942 players.
# 22555 players remaining.
#
#
# Start Scraping: Joel Angel Lucero
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 8943 players.
# 22554 players remaining.
#
#
# Start Scraping: Christian Paul
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8944 players.
# 22553 players remaining.
#
#
# Start Scraping: Samuel Hodor
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8945 players.
# 22552 players remaining.
#
#
# Start Scraping: Jason Taylor
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8946 players.
# 22551 players remaining.
#
#
# Start Scraping: Edoardo Lamberti
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8947 players.
# 22550 players remaining.
#
#
# Start Scraping: Damian Farinola
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8948 players.
# 22549 players remaining.
#
#
# Start Scraping: Chris Cooprider
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8949 players.
# 22548 players remaining.
#
#
# Start Scraping: Vaughn Hunter
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8950 players.
# 22547 players remaining.
#
#
# Start Scraping: Max Andrews
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8951 players.
# 22546 players remaining.
#
#
# Start Scraping: Lance Cowart
# Finish Scraping 8952 players.
# 22545 players remaining.
#
#
# Start Scraping: Alexander Lindholm
# Finish Scraping 8953 players.
# 22544 players remaining.
#
#
# Start Scraping: Vicente Castano Nicolas
# Finish Scraping 8954 players.
# 22543 players remaining.
#
#
# Start Scraping: Shaun Smith
# Finish Scraping 8955 players.
# 22542 players remaining.
#
#
# Start Scraping: Clive Ullyett
# Finish Scraping 8956 players.
# 22541 players remaining.
#
#
# Start Scraping: Rodrigo Suarez
# Finish Scraping 8957 players.
# 22540 players remaining.
#
#
# Start Scraping: Alberto Santos Bravo
# Finish Scraping 8958 players.
# 22539 players remaining.
#
#
# Start Scraping: Aviv Darmon
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 8959 players.
# 22538 players remaining.
#
#
# Start Scraping: Olly Sadler
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8960 players.
# 22537 players remaining.
#
#
# Start Scraping: Hesam Yazdi
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8961 players.
# 22536 players remaining.
#
#
# Start Scraping: Sathi Reddy
# Serve Page: 12
# Return Page: 12
# Raw Page: 12
# Finish Scraping 8962 players.
# 22535 players remaining.
#
#
# Start Scraping: Federico Ottolini
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 8963 players.
# 22534 players remaining.
#
#
# Start Scraping: Mikhail Pavlov
# Finish Scraping 8964 players.
# 22533 players remaining.
#
#
# Start Scraping: Marco Garcia Koch
# Finish Scraping 8965 players.
# 22532 players remaining.
#
#
# Start Scraping: Dan Vasilescu
# Finish Scraping 8966 players.
# 22531 players remaining.
#
#
# Start Scraping: Moti Maaravi
# Finish Scraping 8967 players.
# 22530 players remaining.
#
#
# Start Scraping: Phenyo Matong
# Serve Page: 20
# Return Page: 20
# Raw Page: 20
# Finish Scraping 8968 players.
# 22529 players remaining.
#
#
# Start Scraping: Gouram Kostava
# Finish Scraping 8969 players.
# 22528 players remaining.
#
#
# Start Scraping: Witold Cudny
# Start Scraping: Ronald Rugimbana
# Finish Scraping 8971 players.
# 22526 players remaining.
#
#
# Start Scraping: Dimitrio Martinez Castro
# Finish Scraping 8972 players.
# 22525 players remaining.
#
#
# Start Scraping: Yon Guezuraga Cantero
# Finish Scraping 8973 players.
# 22524 players remaining.
#
#
# Start Scraping: Karl Hedrick
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 8974 players.
# 22523 players remaining.
#
#
# Start Scraping: John Keller
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 8975 players.
# 22522 players remaining.
#
#
# Start Scraping: Dave Snyder
