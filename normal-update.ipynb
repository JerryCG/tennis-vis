# %% [markdown]
# # Normal Updates - Last Update: 2025-06-23

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
import undetected_chromedriver as uc
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from geopy.geocoders import Nominatim
import time
import random

# %% [markdown]
# ## Update ATP Ranking

# %% [markdown]
# ### Single Date Update

# %%
# Load txt files
def load_txt(file):
    with open(file, 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    f.close()
    return df

# %%
# The webdesign may change over time!

def scrape_a_date_rank(date, previous):
    # scrape a particular date
    prefix = 'https://www.atptour.com/en/rankings/singles?RankRange=0-100&DateWeek='  # subject to change
    img_pre = 'https://www.atptour.com/en/~/media/images/flags/'

    # open chrome window
    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=1500, height=800)

    # get url
    driver.get(prefix + date)
    # driver.refresh()   # Refreshing can be detected by blockers

    # get content
    print('Start scraping:', date)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    trs = soup.find('table', {'class':'mega-table desktop-table non-live'}).find_all('tr')

    # set attrs
    attrs = ['Date', 'Rank', 'Country', 'Image', 'Player', 'Points']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # date
    dict['Date'] = [date for i in range(100)]

    for tr in trs:
        
        tds = tr.find_all('td')

        if len(tds) == 8: # check error
            # rank
            dict['Rank'].append(tds[0].text.strip())

            # country, image, player name
            lis = tds[1].find_all('li')
            country_abbr = (lis[1].svg.use.get('href', None))[-3:]
            dict['Country'].append(country_abbr.upper())
            dict['Image'].append(img_pre + country_abbr + '.svg')
            dict['Player'].append(lis[2].text.strip())

            # points
            dict['Points'].append(tds[3].text.strip().replace(',', ''))

    # save to txt
    df = pd.DataFrame(dict)
    df.to_csv('m/rank/dates/' + date + '.txt', index = False, sep = ',', encoding='utf-8-sig')
    print('Finished:', date)

    # open the ranking file
    dict_r = load_txt('m/rank/atpranking_20000110_'+previous.replace('-', '')+'.txt').to_dict('list')
    dict_r[date] = []

    # first get points for existing players
    for p in dict_r['Player']:
        found = False
        for i in range(len(dict['Player'])):
            if p == dict['Player'][i]:
                # add new point
                dict_r[date].append(dict['Points'][i])
                found = True
                break
        if not found:
            dict_r[date].append(0)

    # add new player if any
    for p in dict['Player']:
        if p not in dict_r['Player']:
            # add player
            dict_r['Player'].append(p)
            for i in range(len(dict['Player'])):
                if p == dict['Player'][i]:
                    # add country
                    dict_r['Country'].append(dict['Country'][i])
                    # add image
                    dict_r['Country_Image'].append(dict['Image'][i])
                    # add point
                    dict_r[date].append(dict['Points'][i])
                    break
            # add previous points, all 0
            for d in [key for key in dict_r.keys()][3:-1]:
                dict_r[d].append(0)

    # save to txt
    df_new = pd.DataFrame(dict_r)
    df_new.to_csv('m/rank/atpranking_20000110_'+date.replace('-', '')+'.txt', index = False, sep = ',', encoding='utf-8-sig')

# %%
scrape_a_date_rank('2025-06-23', '2025-06-16')
# Out:
# Start scraping: 2025-06-23
# Finished: 2025-06-23

# %% [markdown]
# Remember to add the new dates to dates.txt

# %% [markdown]
# Remember to update rank file in Flourish

# %% [markdown]
# ## Update ATP Links According to New Ranks

# %%
# Define the function to update ATP profile links by ATP Top 100 ranks
def update_link_by_new_rank(dates):
    '''
    dates: a list of dates text
    '''
    # update links according to atp ranking

    prefix = 'https://www.atptour.com/en/rankings/singles?RankRange=0-100&DateWeek='
    head = 'https://www.atptour.com'

    # open txt
    df = load_txt('m/basics/atpprofilebasics.txt')
    pl = [p for p in df['Player']]

    with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
        links = [line[:-1] for line in f]
    f.close()

    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=1500, height=800)

    # date list
    for date in dates:
        driver.get(prefix + date)
        # driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        trs = soup.find('table', {'class':'mega-table desktop-table non-live'}).find_all('tr')
        for tr in trs[1:]:
            tds = tr.find_all('td')
            if len(tds) == 8:
                lis = tds[1].find_all('li')
                if lis[2].text.strip().replace('-', ' ') not in pl:
                    # add new link
                    links.append(head+lis[2].a.get('href'))
                    pl.append(lis[2].text.strip().replace('-', ' '))
                    print('Found:', lis[2].text.strip().replace('-', ' '))
        print('Finish:', date)
    f.close()

    # update links
    with open('m/basics/atpprofilelinks.txt', 'w', encoding='utf-8-sig') as f:
        for link in set(links):
            if link != '':
                f.write(link)
                f.write('\n')
    f.close()

# %%
update_link_by_new_rank(["2025-06-23"])
# Out:
# Finish: 2025-06-23

# %% [markdown]
# ## Update ATP Profile Information

# %%
# Update new basics based on new links in atprofilelinks
# Website design may change

with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
    links = [line[:-1] for line in f]
f.close()

dict = load_txt('m/basics/atpprofilebasics.txt').to_dict('list')

chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)

for i, link in enumerate(links):
    if link not in dict['ATP Link']:
        driver.get(link)
        # driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        # add name
        try:
            dict['Player'].append(soup.find('div', {'class': 'player_name'}).text.strip().replace('-', ' '))
        except:
            print(link, 'not found')
            break
        # add link
        dict['ATP Link'].append(link)
        # add birthday
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Birthday'].append(lis[0].find_all('span')[1].text.split('(')[1][:-1].replace('.', '-'))
        except:
            dict['Birthday'].append('')
        # add birthplace
        try:
            lis = soup.find('ul', {'class': 'pd_right'}).find_all('li')
            birthplace = lis[1].find_all('span')[1].text.replace(', ', ' - ')
        except:
            birthplace = ''
        dict['Birthplace'].append(birthplace)
        # add plays
        try:
            lis = soup.find('ul', {'class': 'pd_right'}).find_all('li')
            dict['Plays'].append(lis[2].find_all('span')[1].text.replace(', ', ' - '))
        except:
            dict['Plays'].append('')
        # add turned pro
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Turned Pro'].append(lis[3].find_all('span')[1].text)
        except:
            dict['Turned Pro'].append('')
        # add weight
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Weight (kg)'].append(lis[1].find_all('span')[1].text.split('(')[1][:-3])
        except:
            dict['Weight (kg)'].append('')
        # add height
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Height (cm)'].append(lis[2].find_all('span')[1].text.split('(')[1][:-3])
        except:
            dict['Height (cm)'].append('')
        print('Finished:', i+1)

        # add birthplace details, matched region, lat, lon
        geolocator = Nominatim(user_agent='tennis-vis')
        try:
            location = geolocator.geocode(birthplace)
            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
            dict['Birthplace_lat'].append(location.latitude)
            dict['Birthplace_lon'].append(location.longitude)
            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
        except:
            try:
                location = geolocator.geocode(birthplace.split(',')[0]+','+birthplace.split(',')[1])
                dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                dict['Birthplace_lat'].append(location.latitude)
                dict['Birthplace_lon'].append(location.longitude)
                print(location.address.replace(',', ' -'), location.latitude, location.longitude)
            except:
                try:
                    location = geolocator.geocode(birthplace.split(',')[0])
                    dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                    dict['Birthplace_lat'].append(location.latitude)
                    dict['Birthplace_lon'].append(location.longitude)
                    print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                except:
                    try:
                        location = geolocator.geocode(birthplace.split(',')[1])
                        dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                        dict['Birthplace_lat'].append(location.latitude)
                        dict['Birthplace_lon'].append(location.longitude)
                        print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                    except:
                        try:
                            location = geolocator.geocode(birthplace.split(',')[2])
                            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                            dict['Birthplace_lat'].append(location.latitude)
                            dict['Birthplace_lon'].append(location.longitude)
                            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                        except:
                            dict['Birthplace_matched'].append('')
                            dict['Birthplace_lat'].append('')
                            dict['Birthplace_lon'].append('')
                            print('','','')

df = pd.DataFrame(dict)
df.to_csv('m/basics/atpprofilebasics.txt', index = False, sep = ',', encoding='utf-8-sig')

# %% [markdown]
# ## Update ATP TOP 100 Distribution

# %%
# Define the function to update Geo distribution of ATP Top 100 players
def update_geo_atp100(date,num):
    # get basics
    df_basics = load_txt('m/basics/atpprofilebasics.txt')

    # set basic dict
    attrs = ['Start', 'End', 'Player', 'Rank', 'Points', 'Birthplace', 'Lat', 'Lon']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # get dates
    dates = []
    with open('m/rank/dates.txt', 'r') as f:
        for date in f:
            dates.append(date[:-1])
    f.close()

    # Start looping
    for k, date in enumerate([dates[num - i - 1] for i in range(num)]):
        df_rank = load_txt('m/rank/dates/'+date+'.txt')
        for i, p in enumerate(df_rank['Player']):
            for j, r in enumerate(df_basics['Player']):
                if p.replace('-', ' ') == r and k != (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append(dates[num - k - 2])
                    except:
                        pass
                    break
                if p.replace('-', ' ') == r and k == (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append('')
                    except:
                        pass
                    break

        print('Finished:', date)

    df = pd.DataFrame(dict)

    # Save csv
    df.to_csv('m/rank/atp100geo20000110_'+date.replace("-","")+'.txt', index = False, sep = ',', encoding = 'utf-8-sig')

# %%
# num = Row Number of "2000-01-10" in date.txt file
update_geo_atp100("2025-06-23", 1216)
# Out:
# Finished: 2000-01-10
# Finished: 2000-01-17
# Finished: 2000-01-24
# Finished: 2000-01-31
# Finished: 2000-02-07
# Finished: 2000-02-14
# Finished: 2000-02-21
# Finished: 2000-02-28
# Finished: 2000-03-06
# Finished: 2000-03-13
# Finished: 2000-03-20
# Finished: 2000-03-27
# Finished: 2000-04-03
# Finished: 2000-04-10
# Finished: 2000-04-17
# Finished: 2000-04-24
# Finished: 2000-05-01
# Finished: 2000-05-08
# Finished: 2000-05-15
# Finished: 2000-05-22
# Finished: 2000-05-29
# Finished: 2000-06-05
# Finished: 2000-06-12
# Finished: 2000-06-19
# Finished: 2000-06-26
# Finished: 2000-07-03
# Finished: 2000-07-10
# Finished: 2000-07-17
# Finished: 2000-07-24
# Finished: 2000-07-31
# Finished: 2000-08-07
# Finished: 2000-08-14
# Finished: 2000-08-21
# Finished: 2000-08-28
# Finished: 2000-09-04
# Finished: 2000-09-11
# Finished: 2000-09-18
# Finished: 2000-09-25
# Finished: 2000-10-02
# Finished: 2000-10-09
# Finished: 2000-10-16
# Finished: 2000-10-23
# Finished: 2000-10-30
# Finished: 2000-11-06
# Finished: 2000-11-13
# Finished: 2000-11-20
# Finished: 2000-11-27
# Finished: 2000-12-04
# Finished: 2000-12-11
# Finished: 2000-12-18
# Finished: 2000-12-25
# Finished: 2001-01-01
# Finished: 2001-01-08
# Finished: 2001-01-15
# Finished: 2001-01-22
# Finished: 2001-01-29
# Finished: 2001-02-05
# Finished: 2001-02-12
# Finished: 2001-02-19
# Finished: 2001-02-26
# Finished: 2001-03-05
# Finished: 2001-03-12
# Finished: 2001-03-19
# Finished: 2001-03-26
# Finished: 2001-04-02
# Finished: 2001-04-09
# Finished: 2001-04-16
# Finished: 2001-04-23
# Finished: 2001-04-30
# Finished: 2001-05-07
# Finished: 2001-05-14
# Finished: 2001-05-21
# Finished: 2001-05-28
# Finished: 2001-06-04
# Finished: 2001-06-11
# Finished: 2001-06-18
# Finished: 2001-06-25
# Finished: 2001-07-02
# Finished: 2001-07-09
# Finished: 2001-07-16
# Finished: 2023-08-21
# Finished: 2023-08-28
# Finished: 2023-09-11
# Finished: 2023-09-18
# Finished: 2023-09-25
# Finished: 2023-10-02
# Finished: 2023-10-16
# Finished: 2023-10-23
# Finished: 2023-10-30
# Finished: 2023-11-06
# Finished: 2023-11-13
# Finished: 2023-11-20
# Finished: 2023-11-27
# Finished: 2023-12-04
# Finished: 2023-12-11
# Finished: 2023-12-18
# Finished: 2023-12-25
# Finished: 2024-01-01
# Finished: 2024-01-08
# Finished: 2024-01-15
# Finished: 2024-01-29
# Finished: 2024-02-05
# Finished: 2024-02-12
# Finished: 2024-02-19
# Finished: 2024-02-26
# Finished: 2024-03-04
# Finished: 2024-03-18
# Finished: 2024-04-01
# Finished: 2024-04-08
# Finished: 2024-04-15
# Finished: 2024-04-22
# Finished: 2024-05-06
# Finished: 2024-05-20
# Finished: 2024-05-27
# Finished: 2024-06-10
# Finished: 2024-06-17
# Finished: 2024-06-24
# Finished: 2024-07-01
# Finished: 2024-07-15
# Finished: 2024-07-22
# Finished: 2024-07-29
# Finished: 2024-08-05
# Finished: 2024-08-12
# Finished: 2024-08-19
# Finished: 2024-08-26
# Finished: 2024-09-09
# Finished: 2024-09-16
# Finished: 2024-09-23
# Finished: 2024-09-30
# Finished: 2024-10-14
# Finished: 2024-10-21
# Finished: 2024-10-28
# Finished: 2024-11-04
# Finished: 2024-11-11
# Finished: 2024-11-18
# Finished: 2024-11-25
# Finished: 2024-12-02
# Finished: 2024-12-09
# Finished: 2024-12-16
# Finished: 2024-12-23
# Finished: 2024-12-30
# Finished: 2025-01-06
# Finished: 2025-01-13
# Finished: 2025-01-27
# Finished: 2025-02-03
# Finished: 2025-02-10
# Finished: 2025-02-17
# Finished: 2025-02-24
# Finished: 2025-03-03
# Finished: 2025-03-17
# Finished: 2025-03-31
# Finished: 2025-04-07
# Finished: 2025-04-14
# Finished: 2025-04-21
# Finished: 2025-05-05
# Finished: 2025-05-19
# Finished: 2025-05-26
# Finished: 2025-06-09
# Finished: 2025-06-16
# Finished: 2025-06-23

# %% [markdown]
# Remember to update geo file in Flourish

# %% [markdown]
# ## Update All Matches Player by Player
#
# The website started to block me but it seems for most important players I can scrape them.

# %%
# define functions to get all players' names and scrape all matches data
def get_names(sex = ''):
    names = []
    if sex == 'm':
        with open('mp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    elif sex == 'w':
        with open('wp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    else:
        with open('mwplayerlist_processed.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    return names

# define a function to scrape for a single man player's matches
def scrape_matches(name, driver):
    try:
        # set attributes
        attributes_m = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'TP', 'Aces', 'DFs', 'SP', 
                        '1SP', '2SP', 'vA', 'Time']

        attributes_w = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'Time']

        # get cleaned name
        sex = name[1]
        name_cleaned = name[4:].replace(' ', '')

        # set url prefix and types of webpages
        if sex == 'M':
            url = "https://www.tennisabstract.com/cgi-bin/player-classic.cgi?p=" 
        #   types = ["&f=ACareerqq", "&f=ACareerqqr1", "&f=ACareerqqw1"]
        else:
            url = "https://www.tennisabstract.com/cgi-bin/wplayer-classic.cgi?p="

        # Start of Scraping
        print('Start Scraping:', name[4:])
        
        # Man and woman pages are different
        if sex == 'M':

            # For man players
            # Set dictionary
            dic = {}
            for attr in attributes_m:
                dic[attr] = []

            # For serve page
            time.sleep(1 + random.randint(0,1))
            driver.get(url + name_cleaned.replace(' ', '') + "&f=ACareerqq")
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
            # driver.quit()

            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # For return page
                time.sleep(1 + random.randint(0,1))
                show_return = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Return"]')))
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[1])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # For raw page
                time.sleep(1 + random.randint(0,1))
                show_raw = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Raw"]')))
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[2])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

            else:

                # Serve page
                time.sleep(1 + random.randint(0,1))
                driver.get(url + name_cleaned.replace(' ', ''))
                driver.refresh()
                # Show career
                try:
                    show_career = driver.find_element(By.ID, 'careerclick')
                except:
                    return None
                show_career.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # Return page
                time.sleep(1 + random.randint(0,1))
                show_return = driver.find_element(By.XPATH, '//span[text()="Return"]')
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # raw page
                time.sleep(1 + random.randint(0,1))
                show_raw = driver.find_element(By.XPATH, '//span[text()="Raw"]')
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
              # driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

        else:

            # For woman players
            # set dictionary
            dic = {}
            for attr in attributes_w:
                dic[attr] = []

            # For serve page
            driver.get(url + name_cleaned.replace(' ', '') + '&f=ACareerqq')
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')

            # Check whether it is empty
            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_w[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_w[1]].append(tds[1].text)
                        # sets
                        dic[attributes_w[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_w[3]].append(tds[2].text)
                        # round
                        dic[attributes_w[4]].append(tds[3].text)
                        # rank
                        dic[attributes_w[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_w[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_w[7]].append(1)
                            # winner
                            dic[attributes_w[10]].append(name[4:])
                            # loser
                            dic[attributes_w[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_w[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_w[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_w[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_w[9]].append('')
                        else:
                            # win?
                            dic[attributes_w[7]].append(0)
                            # winner
                            dic[attributes_w[10]].append(spans[1].text)
                            # loser
                            dic[attributes_w[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_w[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_w[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_w[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_w[9]].append('')
                        # score
                        dic[attributes_w[12]].append(tds[7].text.replace(" (ch)", ""))
                        # DR
                        dic[attributes_w[13]].append(tds[8].text)
                        # A%
                        dic[attributes_w[14]].append(tds[9].text)
                        # DF%
                        dic[attributes_w[15]].append(tds[10].text)
                        # 1stIn
                        dic[attributes_w[16]].append(tds[11].text)
                        # 1st%
                        dic[attributes_w[17]].append(tds[12].text)
                        # 2rd%
                        dic[attributes_w[18]].append(tds[13].text)
                        # BPSvd
                        dic[attributes_w[19]].append(tds[14].text)

                print('Serve Page:', len(dic['Date']))

                # For return page
                page_return = driver.find_element(By.XPATH, '//span[text()="Show Return Stats"]')
                page_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
            #   driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_w[20]].append(tds[9].text)
                        # RPW
                        dic[attributes_w[21]].append(tds[10].text)
                        # vA%
                        dic[attributes_w[22]].append(tds[11].text)
                        # v1st%
                        dic[attributes_w[23]].append(tds[12].text)
                        # v2rd%
                        dic[attributes_w[24]].append(tds[13].text)
                        # BPCvt
                        dic[attributes_w[25]].append(tds[14].text)
                        # Time
                        dic[attributes_w[26]].append(tds[15].text)

                print('Return Page:', len(dic['TPW']))

        # save to text, separated by gender
        df = pd.DataFrame(dic)
        df.to_csv(sex.lower() + '/matches/txt/' + name[4:] + '.txt', index = False, sep = ',', encoding='utf-8-sig')

    except (IndexError, AttributeError) as e:
        pass
    
# define a loop function to scrape players from a given index
def scrape_from(idx, sex, driver):
    names = get_names(sex)
    for i in range(idx, len(names)):
        try:

            # Scrape the player matches
            scrape_matches(names[i], driver)

            # Print out progress
            print('Finish Scraping', i + 1, 'players.')
            print(len(names) - (i + 1), 'players remaining.')
            print('\n')

            # Sleep for second
            # time.sleep(5)

        except:

            # Sleep for second
            # time.sleep(5)
            
            continue
        
# load txt files
def load_txt(name):
    with open(name[1].lower() + '/matches/txt/' + name[4:] + '.txt', 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    return df

# %%
# UPDATE MATCHES DATA!!!
# # Set up normal chromdriver
# chromedrive_path = "D:\chromedriver.exe"
# s = Service(chromedrive_path)
# driver = webdriver.Chrome(service=s)
# driver.set_window_rect(x=10, y=10, width=100, height=200)

# Set up undetected driver in headless mode
options = uc.ChromeOptions()
options.add_argument("--headless=new")
driver = uc.Chrome(options=options)

scrape_from(0, 'm', driver)
# Out:
# Start Scraping: Rafael Nadal
# Serve Page: 1431
# Return Page: 1431
# Raw Page: 1431
# Finish Scraping 1 players.
# 31496 players remaining.
#
#
# Start Scraping: Novak Djokovic
# Serve Page: 1462
# Return Page: 1462
# Raw Page: 1462
# Finish Scraping 2 players.
# 31495 players remaining.
#
#
# Start Scraping: Feliciano Lopez
# Serve Page: 1279
# Return Page: 1279
# Raw Page: 1279
# Finish Scraping 3 players.
# 31494 players remaining.
#
#
# Start Scraping: Fernando Verdasco
# Serve Page: 1254
# Return Page: 1254
# Raw Page: 1254
# Finish Scraping 4 players.
# 31493 players remaining.
#
#
# Start Scraping: Tommy Robredo
# Serve Page: 1197
# Return Page: 1197
# Raw Page: 1197
# Finish Scraping 5 players.
# 31492 players remaining.
#
#
# Start Scraping: Andreas Seppi
# Serve Page: 1202
# Return Page: 1202
# Raw Page: 1202
# Finish Scraping 6 players.
# 31491 players remaining.
#
#
# Start Scraping: Richard Gasquet
# Serve Page: 1265
# Return Page: 1265
# Raw Page: 1265
# Finish Scraping 7 players.
# 31490 players remaining.
#
#
# Start Scraping: Teymuraz Gabashvili
# Serve Page: 1213
# Return Page: 1213
# Raw Page: 1213
# Finish Scraping 8 players.
# 31489 players remaining.
#
#
# Start Scraping: Lukas Rosol
# Serve Page: 1168
# Return Page: 1168
# Raw Page: 1168
# Finish Scraping 9 players.
# 31488 players remaining.
#
#
# Start Scraping: Gilles Simon
# Serve Page: 1162
# Return Page: 1162
# Raw Page: 1162
# Finish Scraping 10 players.
# 31487 players remaining.
#
#
# Start Scraping: Adrian Mannarino
# Serve Page: 1217
# Return Page: 1217
# Raw Page: 1217
# Finish Scraping 11 players.
# 31486 players remaining.
#
#
# Start Scraping: Albert Ramos
# Serve Page: 1203
# Return Page: 1203
# Raw Page: 1203
# Finish Scraping 12 players.
# 31485 players remaining.
#
#
# Start Scraping: Philipp Kohlschreiber
# Serve Page: 1130
# Return Page: 1130
# Raw Page: 1130
# Finish Scraping 13 players.
# 31484 players remaining.
#
#
# Start Scraping: Andy Murray
# Serve Page: 1139
# Return Page: 1139
# Raw Page: 1139
# Finish Scraping 14 players.
# 31483 players remaining.
#
#
# Start Scraping: Sergiy Stakhovsky
# Serve Page: 1117
# Return Page: 1117
# Raw Page: 1117
# Finish Scraping 15 players.
# 31482 players remaining.
#
#
# Start Scraping: Go Soeda
# Serve Page: 1117
# Return Page: 1117
# Raw Page: 1117
# Finish Scraping 16 players.
# 31481 players remaining.
#
#
# Start Scraping: Roberto Bautista Agut
# Serve Page: 1185
# Return Page: 1185
# Raw Page: 1185
# Finish Scraping 17 players.
# 31480 players remaining.
#
#
# Start Scraping: Fabio Fognini
# Serve Page: 1170
# Return Page: 1170
# Raw Page: 1170
# Finish Scraping 18 players.
# 31479 players remaining.
#
#
# Start Scraping: Aldin Setkic
# Serve Page: 1132
# Return Page: 1132
# Raw Page: 1132
# Finish Scraping 19 players.
# 31478 players remaining.
#
#
# Start Scraping: Andrea Arnaboldi
# Serve Page: 1078
# Return Page: 1078
# Raw Page: 1078
# Finish Scraping 20 players.
# 31477 players remaining.
#
#
# Start Scraping: Stan Wawrinka
# Serve Page: 1119
# Return Page: 1119
# Raw Page: 1119
# Finish Scraping 21 players.
# 31476 players remaining.
#
#
# Start Scraping: Denis Istomin
# Serve Page: 1070
# Return Page: 1070
# Raw Page: 1070
# Finish Scraping 22 players.
# 31475 players remaining.
#
#
# Start Scraping: Yannick Mertens
# Serve Page: 1037
# Return Page: 1037
# Raw Page: 1037
# Finish Scraping 23 players.
# 31474 players remaining.
#
#
# Start Scraping: Malek Jaziri
# Serve Page: 1035
# Return Page: 1035
# Raw Page: 1035
# Finish Scraping 24 players.
# 31473 players remaining.
#
#
# Start Scraping: Facundo Bagnis
# Serve Page: 1040
# Return Page: 1040
# Raw Page: 1040
# Finish Scraping 25 players.
# 31472 players remaining.
#
#
# Start Scraping: Lukas Lacko
# Serve Page: 1025
# Return Page: 1025
# Raw Page: 1025
# Finish Scraping 26 players.
# 31471 players remaining.
#
#
# Start Scraping: Adrian Menendez Maceiras
# Serve Page: 1027
# Return Page: 1027
# Raw Page: 1027
# Finish Scraping 27 players.
# 31470 players remaining.
#
#
# Start Scraping: Benoit Paire
# Serve Page: 1061
# Return Page: 1061
# Raw Page: 1061
# Finish Scraping 28 players.
# 31469 players remaining.
#
#
# Start Scraping: Jaroslav Pospisil
# Serve Page: 1022
# Return Page: 1022
# Raw Page: 1022
# Finish Scraping 29 players.
# 31468 players remaining.
#
#
# Start Scraping: Radu Albot
# Serve Page: 1081
# Return Page: 1081
# Raw Page: 1081
# Finish Scraping 30 players.
# 31467 players remaining.
#
#
# Start Scraping: Marin Cilic
# Serve Page: 1055
# Return Page: 1055
# Raw Page: 1055
# Finish Scraping 31 players.
# 31466 players remaining.
#
#
# Start Scraping: Matteo Viola
# Serve Page: 1011
# Return Page: 1011
# Raw Page: 1011
# Finish Scraping 32 players.
# 31465 players remaining.
#
#
# Start Scraping: Mikhail Kukushkin
# Serve Page: 1078
# Return Page: 1078
# Raw Page: 1078
# Finish Scraping 33 players.
# 31464 players remaining.
#
#
# Start Scraping: Joao Sousa
# Serve Page: 1004
# Return Page: 1004
# Raw Page: 1004
# Finish Scraping 34 players.
# 31463 players remaining.
#
#
# Start Scraping: Marsel Ilhan
# Serve Page: 1012
# Return Page: 1012
# Raw Page: 1012
# Finish Scraping 35 players.
# 31462 players remaining.
#
#
# Start Scraping: Dudi Sela
# Serve Page: 1003
# Return Page: 1003
# Raw Page: 1003
# Finish Scraping 36 players.
# 31461 players remaining.
#
#
# Start Scraping: Matthias Bachinger
# Serve Page: 997
# Return Page: 997
# Raw Page: 997
# Finish Scraping 37 players.
# 31460 players remaining.
#
#
# Start Scraping: Steven Diez
# Serve Page: 1016
# Return Page: 1016
# Raw Page: 1016
# Finish Scraping 38 players.
# 31459 players remaining.
#
#
# Start Scraping: Mohamed Safwat
# Serve Page: 1041
# Return Page: 1041
# Raw Page: 1041
# Finish Scraping 39 players.
# 31458 players remaining.
#
#
# Start Scraping: Gael Monfils
# Serve Page: 1039
# Return Page: 1039
# Raw Page: 1039
# Finish Scraping 40 players.
# 31457 players remaining.
#
#
# Start Scraping: Ivan Nedelko
# Serve Page: 1001
# Return Page: 1001
# Raw Page: 1001
# Finish Scraping 41 players.
# 31456 players remaining.
#
#
# Start Scraping: Tobias Kamke
# Serve Page: 962
# Return Page: 962
# Raw Page: 962
# Finish Scraping 42 players.
# 31455 players remaining.
#
#
# Start Scraping: Tatsuma Ito
# Serve Page: 970
# Return Page: 970
# Raw Page: 970
# Finish Scraping 43 players.
# 31454 players remaining.
#
#
# Start Scraping: Mischa Zverev
# Serve Page: 960
# Return Page: 960
# Raw Page: 960
# Finish Scraping 44 players.
# 31453 players remaining.
#
#
# Start Scraping: David Goffin
# Serve Page: 1029
# Return Page: 1029
# Raw Page: 1029
# Finish Scraping 45 players.
# 31452 players remaining.
#
#
# Start Scraping: Robin Haase
# Serve Page: 953
# Return Page: 953
# Raw Page: 953
# Finish Scraping 46 players.
# 31451 players remaining.
#
#
# Start Scraping: Illya Marchenko
# Serve Page: 972
# Return Page: 972
# Raw Page: 972
# Finish Scraping 47 players.
# 31450 players remaining.
#
#
# Start Scraping: Jo Wilfried Tsonga
# Serve Page: 952
# Return Page: 952
# Raw Page: 952
# Finish Scraping 48 players.
# 31449 players remaining.
#
#
# Start Scraping: Evgeny Donskoy
# Serve Page: 966
# Return Page: 966
# Raw Page: 966
# Finish Scraping 49 players.
# 31448 players remaining.
#
#
# Start Scraping: Konstantin Kravchuk
# Serve Page: 947
# Return Page: 947
# Raw Page: 947
# Finish Scraping 50 players.
# 31447 players remaining.
#
#
# Start Scraping: Pablo Cuevas
# Serve Page: 940
# Return Page: 940
# Raw Page: 940
# Finish Scraping 51 players.
# 31446 players remaining.
#
#
# Start Scraping: Hiroki Moriya
# Serve Page: 1005
# Return Page: 1005
# Raw Page: 1005
# Finish Scraping 52 players.
# 31445 players remaining.
#
#
# Start Scraping: Ruben Bemelmans
# Serve Page: 937
# Return Page: 937
# Raw Page: 937
# Finish Scraping 53 players.
# 31444 players remaining.
#
#
# Start Scraping: Pablo Andujar
# Serve Page: 940
# Return Page: 940
# Raw Page: 940
# Finish Scraping 54 players.
# 31443 players remaining.
#
#
# Start Scraping: Federico Coria
# Serve Page: 1013
# Return Page: 1013
# Raw Page: 1013
# Finish Scraping 55 players.
# 31442 players remaining.
#
#
# Start Scraping: Miljan Zekic
# Serve Page: 955
# Return Page: 955
# Raw Page: 955
# Finish Scraping 56 players.
# 31441 players remaining.
#
#
# Start Scraping: Daniel Dutra Da Silva
# Serve Page: 1026
# Return Page: 1026
# Raw Page: 1026
# Finish Scraping 57 players.
# 31440 players remaining.
#
#
# Start Scraping: Jose Rubin Statham
# Serve Page: 944
# Return Page: 944
# Raw Page: 944
# Finish Scraping 58 players.
# 31439 players remaining.
#
#
# Start Scraping: Taro Daniel
# Serve Page: 978
# Return Page: 978
# Raw Page: 978
# Finish Scraping 59 players.
# 31438 players remaining.
#
#
# Start Scraping: Peter Gojowczyk
# Serve Page: 916
# Return Page: 916
# Raw Page: 916
# Finish Scraping 60 players.
# 31437 players remaining.
#
#
# Start Scraping: Jan Lennard Struff
# Serve Page: 976
# Return Page: 976
# Raw Page: 976
# Finish Scraping 61 players.
# 31436 players remaining.
#
#
# Start Scraping: Stephane Robert
# Serve Page: 915
# Return Page: 915
# Raw Page: 915
# Finish Scraping 62 players.
# 31435 players remaining.
#
#
# Start Scraping: Roberto Carballes Baena
# Serve Page: 985
# Return Page: 985
# Raw Page: 985
# Finish Scraping 63 players.
# 31434 players remaining.
#
#
# Start Scraping: Dusan Lajovic
# Serve Page: 959
# Return Page: 959
# Raw Page: 959
# Finish Scraping 64 players.
# 31433 players remaining.
#
#
# Start Scraping: Diego Schwartzman
# Serve Page: 931
# Return Page: 931
# Raw Page: 931
# Finish Scraping 65 players.
# 31432 players remaining.
#
#
# Start Scraping: Andrej Martin
# Serve Page: 966
# Return Page: 966
# Raw Page: 966
# Finish Scraping 66 players.
# 31431 players remaining.
#
#
# Start Scraping: Rod Laver
# Serve Page: 1932
# Return Page: 1932
# Raw Page: 1932
# Finish Scraping 67 players.
# 31430 players remaining.
#
#
# Start Scraping: Federico Gaio
# Serve Page: 916
# Return Page: 916
# Raw Page: 916
# Finish Scraping 68 players.
# 31429 players remaining.
#
#
# Start Scraping: Uladzimir Ignatik
# Serve Page: 901
# Return Page: 901
# Raw Page: 901
# Finish Scraping 69 players.
# 31428 players remaining.
#
#
# Start Scraping: Peter Polansky
# Serve Page: 898
# Return Page: 898
# Raw Page: 898
# Finish Scraping 70 players.
# 31427 players remaining.
#
#
# Start Scraping: Kevin Anderson
# Serve Page: 901
# Return Page: 901
# Raw Page: 901
# Finish Scraping 71 players.
# 31426 players remaining.
#
#
# Start Scraping: John Isner
# Serve Page: 897
# Return Page: 897
# Raw Page: 897
# Finish Scraping 72 players.
# 31425 players remaining.
#
#
# Start Scraping: Damir Dzumhur
# Serve Page: 979
# Return Page: 979
# Raw Page: 979
# Finish Scraping 73 players.
# 31424 players remaining.
#
#
# Start Scraping: Grigor Dimitrov
# Serve Page: 955
# Return Page: 955
# Raw Page: 955
# Finish Scraping 74 players.
# 31423 players remaining.
#
#
# Start Scraping: Yuichi Sugita
# Serve Page: 882
# Return Page: 882
# Raw Page: 882
# Finish Scraping 75 players.
# 31422 players remaining.
#
#
# Start Scraping: Jeremy Chardy
# Serve Page: 885
# Return Page: 885
# Raw Page: 885
# Finish Scraping 76 players.
# 31421 players remaining.
#
#
# Start Scraping: Ricardas Berankis
# Serve Page: 945
# Return Page: 945
# Raw Page: 945
# Finish Scraping 77 players.
# 31420 players remaining.
#
#
# Start Scraping: Marius Copil
# Serve Page: 887
# Return Page: 887
# Raw Page: 887
# Finish Scraping 78 players.
# 31419 players remaining.
#
#
# Start Scraping: Thomaz Bellucci
# Serve Page: 883
# Return Page: 883
# Raw Page: 883
# Finish Scraping 79 players.
# 31418 players remaining.
#
#
# Start Scraping: Oriol Roca Batalla
# Serve Page: 943
# Return Page: 943
# Raw Page: 943
# Finish Scraping 80 players.
# 31417 players remaining.
#
#
# Start Scraping: Kenny De Schepper
# Serve Page: 942
# Return Page: 942
# Raw Page: 942
# Finish Scraping 81 players.
# 31416 players remaining.
#
#
# Start Scraping: Gastao Elias
# Serve Page: 954
# Return Page: 954
# Raw Page: 954
# Finish Scraping 82 players.
# 31415 players remaining.
#
#
# Start Scraping: Norbert Gombos
# Serve Page: 929
# Return Page: 929
# Raw Page: 929
# Finish Scraping 83 players.
# 31414 players remaining.
#
#
# Start Scraping: Donald Young
# Serve Page: 874
# Return Page: 874
# Raw Page: 874
# Finish Scraping 84 players.
# 31413 players remaining.
#
#
# Start Scraping: Ernests Gulbis
# Serve Page: 865
# Return Page: 865
# Raw Page: 865
# Finish Scraping 85 players.
# 31412 players remaining.
#
#
# Start Scraping: Denis Kudla
# Serve Page: 899
# Return Page: 899
# Raw Page: 899
# Finish Scraping 86 players.
# 31411 players remaining.
#
#
# Start Scraping: Daniel Evans
# Serve Page: 924
# Return Page: 924
# Raw Page: 924
# Finish Scraping 87 players.
# 31410 players remaining.
#
#
# Start Scraping: Lorenzo Giustino
# Serve Page: 953
# Return Page: 953
# Raw Page: 953
# Finish Scraping 88 players.
# 31409 players remaining.
#
#
# Start Scraping: Vasek Pospisil
# Serve Page: 868
# Return Page: 868
# Raw Page: 868
# Finish Scraping 89 players.
# 31408 players remaining.
#
#
# Start Scraping: Federico Delbonis
# Serve Page: 848
# Return Page: 848
# Raw Page: 848
# Finish Scraping 90 players.
# 31407 players remaining.
#
#
# Start Scraping: Thomas Fabbiano
# Serve Page: 850
# Return Page: 850
# Raw Page: 850
# Finish Scraping 91 players.
# 31406 players remaining.
#
#
# Start Scraping: Pablo Carreno Busta
# Serve Page: 901
# Return Page: 901
# Raw Page: 901
# Finish Scraping 92 players.
# 31405 players remaining.
#
#
# Start Scraping: Sam Querrey
# Serve Page: 846
# Return Page: 846
# Raw Page: 846
# Finish Scraping 93 players.
# 31404 players remaining.
#
#
# Start Scraping: Alejandro Gonzalez
# Serve Page: 845
# Return Page: 845
# Raw Page: 845
# Finish Scraping 94 players.
# 31403 players remaining.
#
#
# Start Scraping: Igor Sijsling
# Serve Page: 830
# Return Page: 830
# Raw Page: 830
# Finish Scraping 95 players.
# 31402 players remaining.
#
#
# Start Scraping: Lamine Ouahab
# Serve Page: 828
# Return Page: 828
# Raw Page: 828
# Finish Scraping 96 players.
# 31401 players remaining.
#
#
# Start Scraping: Stefano Travaglia
# Serve Page: 879
# Return Page: 879
# Raw Page: 879
# Finish Scraping 97 players.
# 31400 players remaining.
#
#
# Start Scraping: Andrea Collarini
# Serve Page: 901
# Return Page: 901
# Raw Page: 901
# Finish Scraping 98 players.
# 31399 players remaining.
#
#
# Start Scraping: Marco Trungelliti
# Serve Page: 886
# Return Page: 886
# Raw Page: 886
# Finish Scraping 99 players.
# 31398 players remaining.
#
#
# Start Scraping: Matthew Ebden
# Serve Page: 819
# Return Page: 819
# Raw Page: 819
# Finish Scraping 100 players.
# 31397 players remaining.
#
#
# Start Scraping: Alexey Vatutin
# Serve Page: 900
# Return Page: 900
# Raw Page: 900
# Finish Scraping 101 players.
# 31396 players remaining.
#
#
# Start Scraping: Alessandro Giannessi
# Serve Page: 840
# Return Page: 840
# Raw Page: 840
# Finish Scraping 102 players.
# 31395 players remaining.
#
#
# Start Scraping: Andrey Golubev
# Serve Page: 818
# Return Page: 818
# Raw Page: 818
# Finish Scraping 103 players.
# 31394 players remaining.
#
#
# Start Scraping: Marco Cecchinato
# Serve Page: 867
# Return Page: 867
# Raw Page: 867
# Finish Scraping 104 players.
# 31393 players remaining.
#
#
# Start Scraping: Jimmy Connors
# Serve Page: 1632
# Return Page: 1632
# Raw Page: 1632
# Finish Scraping 105 players.
# 31392 players remaining.
#
#
# Start Scraping: Renzo Olivo
# Serve Page: 871
# Return Page: 871
# Raw Page: 871
# Finish Scraping 106 players.
# 31391 players remaining.
#
#
# Start Scraping: Roger Federer
# Serve Page: 1581
# Return Page: 1581
# Raw Page: 1581
# Finish Scraping 107 players.
# 31390 players remaining.
#
#
# Start Scraping: Kei Nishikori
# Serve Page: 851
# Return Page: 851
# Raw Page: 851
# Finish Scraping 108 players.
# 31389 players remaining.
#
#
# Start Scraping: Liam Broady
# Serve Page: 824
# Return Page: 824
# Raw Page: 824
# Finish Scraping 109 players.
# 31388 players remaining.
#
#
# Start Scraping: Ramkumar Ramanathan
# Serve Page: 829
# Return Page: 829
# Raw Page: 829
# Finish Scraping 110 players.
# 31387 players remaining.
#
#
# Start Scraping: Guido Pella
# Serve Page: 785
# Return Page: 785
# Raw Page: 785
# Finish Scraping 111 players.
# 31386 players remaining.
#
#
# Start Scraping: Martin Klizan
# Serve Page: 852
# Return Page: 852
# Raw Page: 852
# Finish Scraping 112 players.
# 31385 players remaining.
#
#
# Start Scraping: Jonathan Eysseric
# Serve Page: 783
# Return Page: 783
# Raw Page: 783
# Finish Scraping 113 players.
# 31384 players remaining.
#
#
# Start Scraping: Jozef Kovalik
# Serve Page: 827
# Return Page: 827
# Raw Page: 827
# Finish Scraping 114 players.
# 31383 players remaining.
#
#
# Start Scraping: Ilie Nastase
# Serve Page: 1443
# Return Page: 1443
# Raw Page: 1443
# Finish Scraping 115 players.
# 31382 players remaining.
#
#
# Start Scraping: Thiago Monteiro
# Serve Page: 845
# Return Page: 845
# Raw Page: 845
# Finish Scraping 116 players.
# 31381 players remaining.
#
#
# Start Scraping: Arthur Ashe
# Serve Page: 1532
# Return Page: 1532
# Raw Page: 1532
# Finish Scraping 117 players.
# 31380 players remaining.
#
#
# Start Scraping: Nikoloz Basilashvili
# Serve Page: 860
# Return Page: 860
# Raw Page: 860
# Finish Scraping 118 players.
# 31379 players remaining.
#
#
# Start Scraping: Henri Laaksonen
# Serve Page: 775
# Return Page: 775
# Raw Page: 775
# Finish Scraping 119 players.
# 31378 players remaining.
#
#
# Start Scraping: Marton Fucsovics
# Serve Page: 821
# Return Page: 821
# Raw Page: 821
# Finish Scraping 120 players.
# 31377 players remaining.
#
#
# Start Scraping: John Millman
# Serve Page: 769
# Return Page: 769
# Raw Page: 769
# Finish Scraping 121 players.
# 31376 players remaining.
#
#
# Start Scraping: Kento Takeuchi
# Serve Page: 766
# Return Page: 766
# Raw Page: 766
# Finish Scraping 122 players.
# 31375 players remaining.
#
#
# Start Scraping: Zhe Li
# Serve Page: 768
# Return Page: 768
# Raw Page: 768
# Finish Scraping 123 players.
# 31374 players remaining.
#
#
# Start Scraping: Dimitar Kuzmanov
# Serve Page: 820
# Return Page: 820
# Raw Page: 820
# Finish Scraping 124 players.
# 31373 players remaining.
#
#
# Start Scraping: Mirza Basic
# Serve Page: 825
# Return Page: 825
# Raw Page: 825
# Finish Scraping 125 players.
# 31372 players remaining.
#
#
# Start Scraping: Facundo Mena
# Serve Page: 832
# Return Page: 832
# Raw Page: 832
# Finish Scraping 126 players.
# 31371 players remaining.
#
#
# Start Scraping: Juan Martin Del Potro
# Serve Page: 759
# Return Page: 759
# Raw Page: 759
# Finish Scraping 127 players.
# 31370 players remaining.
#
#
# Start Scraping: Goncalo Oliveira
# Serve Page: 826
# Return Page: 826
# Raw Page: 826
# Finish Scraping 128 players.
# 31369 players remaining.
#
#
# Start Scraping: Tsung Hua Yang
# Serve Page: 755
# Return Page: 755
# Raw Page: 755
# Finish Scraping 129 players.
# 31368 players remaining.
#
#
# Start Scraping: Pierre Hugues Herbert
# Serve Page: 815
# Return Page: 815
# Raw Page: 815
# Finish Scraping 130 players.
# 31367 players remaining.
#
#
# Start Scraping: Antoine Escoffier
# Serve Page: 827
# Return Page: 827
# Raw Page: 827
# Finish Scraping 131 players.
# 31366 players remaining.
#
#
# Start Scraping: Denis Yevseyev
# Serve Page: 817
# Return Page: 817
# Raw Page: 817
# Finish Scraping 132 players.
# 31365 players remaining.
#
#
# Start Scraping: Dennis Novak
# Serve Page: 784
# Return Page: 784
# Raw Page: 784
# Finish Scraping 133 players.
# 31364 players remaining.
#
#
# Start Scraping: Salvatore Caruso
# Serve Page: 736
# Return Page: 736
# Raw Page: 736
# Finish Scraping 134 players.
# 31363 players remaining.
#
#
# Start Scraping: Pedro Sousa
# Serve Page: 731
# Return Page: 731
# Raw Page: 731
# Finish Scraping 135 players.
# 31362 players remaining.
#
#
# Start Scraping: James Duckworth
# Serve Page: 812
# Return Page: 812
# Raw Page: 812
# Finish Scraping 136 players.
# 31361 players remaining.
#
#
# Start Scraping: Roberto Marcora
# Serve Page: 724
# Return Page: 724
# Raw Page: 724
# Finish Scraping 137 players.
# 31360 players remaining.
#
#
# Start Scraping: Dominic Thiem
# Serve Page: 747
# Return Page: 747
# Raw Page: 747
# Finish Scraping 138 players.
# 31359 players remaining.
#
#
# Start Scraping: Yasutaka Uchiyama
# Serve Page: 780
# Return Page: 780
# Raw Page: 780
# Finish Scraping 139 players.
# 31358 players remaining.
#
#
# Start Scraping: Gregoire Barrere
# Serve Page: 778
# Return Page: 778
# Raw Page: 778
# Finish Scraping 140 players.
# 31357 players remaining.
#
#
# Start Scraping: Constant Lestienne
# Serve Page: 784
# Return Page: 784
# Raw Page: 784
# Finish Scraping 141 players.
# 31356 players remaining.
#
#
# Start Scraping: Jordan Thompson
# Serve Page: 773
# Return Page: 773
# Raw Page: 773
# Finish Scraping 142 players.
# 31355 players remaining.
#
#
# Start Scraping: Kimmer Coppejans
# Serve Page: 772
# Return Page: 772
# Raw Page: 772
# Finish Scraping 143 players.
# 31354 players remaining.
#
#
# Start Scraping: Laurynas Grigelis
# Serve Page: 723
# Return Page: 723
# Raw Page: 723
# Finish Scraping 144 players.
# 31353 players remaining.
#
#
# Start Scraping: Tennys Sandgren
# Serve Page: 724
# Return Page: 724
# Raw Page: 724
# Finish Scraping 145 players.
# 31352 players remaining.
#
#
# Start Scraping: Thiemo De Bakker
# Serve Page: 721
# Return Page: 721
# Raw Page: 721
# Finish Scraping 146 players.
# 31351 players remaining.
#
#
# Start Scraping: Guido Andreozzi
# Serve Page: 737
# Return Page: 737
# Raw Page: 737
# Finish Scraping 147 players.
# 31350 players remaining.
#
#
# Start Scraping: Blaz Rola
# Serve Page: 737
# Return Page: 737
# Raw Page: 737
# Finish Scraping 148 players.
# 31349 players remaining.
#
#
# Start Scraping: Jiri Vesely
# Serve Page: 760
# Return Page: 760
# Raw Page: 760
# Finish Scraping 149 players.
# 31348 players remaining.
#
#
# Start Scraping: Riccardo Bonadio
# Serve Page: 743
# Return Page: 743
# Raw Page: 743
# Finish Scraping 150 players.
# 31347 players remaining.
#
#
# Start Scraping: Tristan Lamasine
# Serve Page: 764
# Return Page: 764
# Raw Page: 764
# Finish Scraping 151 players.
# 31346 players remaining.
#
#
# Start Scraping: Milos Raonic
# Serve Page: 720
# Return Page: 720
# Raw Page: 720
# Finish Scraping 152 players.
# 31345 players remaining.
#
#
# Start Scraping: Mathias Bourgue
# Serve Page: 771
# Return Page: 771
# Raw Page: 771
# Finish Scraping 153 players.
# 31344 players remaining.
#
#
# Start Scraping: John Newcombe
# Serve Page: 1414
# Return Page: 1414
# Raw Page: 1414
# Finish Scraping 154 players.
# 31343 players remaining.
#
#
# Start Scraping: Hugo Dellien
# Serve Page: 792
# Return Page: 792
# Raw Page: 792
# Finish Scraping 155 players.
# 31342 players remaining.
#
#
# Start Scraping: Ken Rosewall
# Serve Page: 1902
# Return Page: 1902
# Raw Page: 1902
# Finish Scraping 156 players.
# 31341 players remaining.
#
#
# Start Scraping: Filip Horansky
# Serve Page: 693
# Return Page: 693
# Raw Page: 693
# Finish Scraping 157 players.
# 31340 players remaining.
#
#
# Start Scraping: Filip Krajinovic
# Serve Page: 714
# Return Page: 714
# Raw Page: 714
# Finish Scraping 158 players.
# 31339 players remaining.
#
#
# Start Scraping: Alexander Zverev
# Serve Page: 795
# Return Page: 795
# Raw Page: 795
# Finish Scraping 159 players.
# 31338 players remaining.
#
#
# Start Scraping: Juan Pablo Paz
# Serve Page: 766
# Return Page: 766
# Raw Page: 766
# Finish Scraping 160 players.
# 31337 players remaining.
#
#
# Start Scraping: Dmitry Popko
# Serve Page: 779
# Return Page: 779
# Raw Page: 779
# Finish Scraping 161 players.
# 31336 players remaining.
#
#
# Start Scraping: Emilio Gomez
# Serve Page: 711
# Return Page: 711
# Raw Page: 711
# Finish Scraping 162 players.
# 31335 players remaining.
#
#
# Start Scraping: Roy Emerson
# Serve Page: 1578
# Return Page: 1578
# Raw Page: 1578
# Finish Scraping 163 players.
# 31334 players remaining.
#
#
# Start Scraping: Gerald Melzer
# Serve Page: 718
# Return Page: 718
# Raw Page: 718
# Finish Scraping 164 players.
# 31333 players remaining.
#
#
# Start Scraping: Daniil Medvedev
# Serve Page: 763
# Return Page: 763
# Raw Page: 763
# Finish Scraping 165 players.
# 31332 players remaining.
#
#
# Start Scraping: Frederico Ferreira Silva
# Serve Page: 784
# Return Page: 784
# Raw Page: 784
# Finish Scraping 166 players.
# 31331 players remaining.
#
#
# Start Scraping: Bernard Tomic
# Serve Page: 775
# Return Page: 775
# Raw Page: 775
# Finish Scraping 167 players.
# 31330 players remaining.
#
#
# Start Scraping: Jose Pereira
# Serve Page: 755
# Return Page: 755
# Raw Page: 755
# Finish Scraping 168 players.
# 31329 players remaining.
#
#
# Start Scraping: Ivan Gakhov
# Serve Page: 771
# Return Page: 771
# Raw Page: 771
# Finish Scraping 169 players.
# 31328 players remaining.
#
#
# Start Scraping: Jason Jung
# Serve Page: 679
# Return Page: 679
# Raw Page: 679
# Finish Scraping 170 players.
# 31327 players remaining.
#
#
# Start Scraping: David Perez Sanz
# Serve Page: 691
# Return Page: 691
# Raw Page: 691
# Finish Scraping 171 players.
# 31326 players remaining.
#
#
# Start Scraping: Andrey Rublev
# Serve Page: 747
# Return Page: 747
# Raw Page: 747
# Finish Scraping 172 players.
# 31325 players remaining.
#
#
# Start Scraping: Juan Ignacio Londero
# Serve Page: 691
# Return Page: 691
# Raw Page: 691
# Finish Scraping 173 players.
# 31324 players remaining.
#
#
# Start Scraping: Maxime Chazal
# Serve Page: 761
# Return Page: 761
# Raw Page: 761
# Finish Scraping 174 players.
# 31323 players remaining.
#
#
# Start Scraping: Inigo Cervantes Huegun
# Serve Page: 687
# Return Page: 687
# Raw Page: 687
# Finish Scraping 175 players.
# 31322 players remaining.
#
#
# Start Scraping: Guillermo Vilas
# Serve Page: 1362
# Return Page: 1362
# Raw Page: 1362
# Finish Scraping 176 players.
# 31321 players remaining.
#
#
# Start Scraping: Wilson Leite
# Serve Page: 736
# Return Page: 736
# Raw Page: 736
# Finish Scraping 177 players.
# 31320 players remaining.
#
#
# Start Scraping: Hernan Casanova
# Serve Page: 731
# Return Page: 731
# Raw Page: 731
# Finish Scraping 178 players.
# 31319 players remaining.
#
#
# Start Scraping: Mitchell Krueger
# Serve Page: 744
# Return Page: 744
# Raw Page: 744
# Finish Scraping 179 players.
# 31318 players remaining.
#
#
# Start Scraping: Pedro Cachin
# Serve Page: 721
# Return Page: 721
# Raw Page: 721
# Finish Scraping 180 players.
# 31317 players remaining.
#
#
# Start Scraping: Toshihide Matsui
# Serve Page: 676
# Return Page: 676
# Raw Page: 676
# Finish Scraping 181 players.
# 31316 players remaining.
#
#
# Start Scraping: Ricardo Rodriguez
# Serve Page: 702
# Return Page: 702
# Raw Page: 702
# Finish Scraping 182 players.
# 31315 players remaining.
#
#
# Start Scraping: Paolo Lorenzi
# Serve Page: 1335
# Return Page: 1335
# Raw Page: 1335
# Finish Scraping 183 players.
# 31314 players remaining.
#
#
# Start Scraping: Steve Johnson
# Serve Page: 670
# Return Page: 670
# Raw Page: 670
# Finish Scraping 184 players.
# 31313 players remaining.
#
#
# Start Scraping: Cem Ilkel
# Serve Page: 718
# Return Page: 718
# Raw Page: 718
# Finish Scraping 185 players.
# 31312 players remaining.
#
#
# Start Scraping: Filip Peliwo
# Serve Page: 736
# Return Page: 736
# Raw Page: 736
# Finish Scraping 186 players.
# 31311 players remaining.
#
#
# Start Scraping: Aljaz Bedene
# Serve Page: 664
# Return Page: 664
# Raw Page: 664
# Finish Scraping 187 players.
# 31310 players remaining.
#
#
# Start Scraping: Stan Smith
# Serve Page: 43
# Return Page: 43
# Raw Page: 43
# Finish Scraping 188 players.
# 31309 players remaining.
#
#
# Start Scraping: Maximilian Neuchrist
# Finish Scraping 189 players.
# 31308 players remaining.
#
#
# Start Scraping: Dayne Kelly
# Finish Scraping 190 players.
# 31307 players remaining.
#
#
# Start Scraping: Stefanos Tsitsipas
# Finish Scraping 191 players.
# 31306 players remaining.
#
#
# Start Scraping: Egor Gerasimov
# Finish Scraping 192 players.
# 31305 players remaining.
#
#
# Start Scraping: David Ferrer
# Finish Scraping 193 players.
# 31304 players remaining.
#
#
# Start Scraping: Ivan Lendl
# Finish Scraping 194 players.
# 31303 players remaining.
#
#
# Start Scraping: Ryan Harrison
# Serve Page: 658
# Return Page: 658
# Raw Page: 658
# Finish Scraping 195 players.
# 31302 players remaining.
#
#
# Start Scraping: Daniel Cox
# Serve Page: 661
# Return Page: 661
# Raw Page: 661
# Finish Scraping 196 players.
# 31301 players remaining.
#
#
# Start Scraping: Elias Ymer
# Serve Page: 716
# Return Page: 716
# Raw Page: 716
# Finish Scraping 197 players.
# 31300 players remaining.
#
#
# Start Scraping: Pedro Martinez
# Serve Page: 713
# Return Page: 713
# Raw Page: 713
# Finish Scraping 198 players.
# 31299 players remaining.
#
#
# Start Scraping: Peter Heller
# Serve Page: 682
# Return Page: 682
# Raw Page: 682
# Finish Scraping 199 players.
# 31298 players remaining.
#
#
# Start Scraping: Aslan Karatsev
# Serve Page: 693
# Return Page: 693
# Raw Page: 693
# Finish Scraping 200 players.
# 31297 players remaining.
#
#
# Start Scraping: Evgeny Karlovskiy
# Serve Page: 723
# Return Page: 723
# Raw Page: 723
# Finish Scraping 201 players.
# 31296 players remaining.
#
#
# Start Scraping: Quentin Halys
# Serve Page: 723
# Return Page: 723
# Raw Page: 723
# Finish Scraping 202 players.
# 31295 players remaining.
#
#
# Start Scraping: Matwe Middelkoop
# Serve Page: 648
# Return Page: 648
# Raw Page: 648
# Finish Scraping 203 players.
# 31294 players remaining.
#
#
# Start Scraping: Gianluca Mager
# Serve Page: 692
# Return Page: 692
# Raw Page: 692
# Finish Scraping 204 players.
# 31293 players remaining.
#
#
# Start Scraping: Luke Saville
# Serve Page: 660
# Return Page: 660
# Raw Page: 660
# Finish Scraping 205 players.
# 31292 players remaining.
#
#
# Start Scraping: Bjorn Fratangelo
# Serve Page: 642
# Return Page: 642
# Raw Page: 642
# Finish Scraping 206 players.
# 31291 players remaining.
#
#
# Start Scraping: Laslo Djere
# Serve Page: 697
# Return Page: 697
# Raw Page: 697
# Finish Scraping 207 players.
# 31290 players remaining.
#
#
# Start Scraping: Kaichi Uchida
# Serve Page: 719
# Return Page: 719
# Raw Page: 719
# Finish Scraping 208 players.
# 31289 players remaining.
#
#
# Start Scraping: Tom Okker
# Serve Page: 1240
# Return Page: 1240
# Raw Page: 1240
# Finish Scraping 209 players.
# 31288 players remaining.
#
#
# Start Scraping: Attila Balazs
# Serve Page: 630
# Return Page: 630
# Raw Page: 630
# Finish Scraping 210 players.
# 31287 players remaining.
#
#
# Start Scraping: Zdenek Kolar
# Serve Page: 698
# Return Page: 698
# Raw Page: 698
# Finish Scraping 211 players.
# 31286 players remaining.
#
#
# Start Scraping: Denys Molchanov
# Serve Page: 635
# Return Page: 635
# Raw Page: 635
# Finish Scraping 212 players.
# 31285 players remaining.
#
#
# Start Scraping: Joao Domingues
# Serve Page: 665
# Return Page: 665
# Raw Page: 665
# Finish Scraping 213 players.
# 31284 players remaining.
#
#
# Start Scraping: Hugo Grenier
# Finish Scraping 214 players.
# 31283 players remaining.
#
#
# Start Scraping: Andrey Kuznetsov
# Finish Scraping 215 players.
# 31282 players remaining.
#
#
# Start Scraping: Daniel Masur
# Finish Scraping 216 players.
# 31281 players remaining.
#
#
# Start Scraping: Maxime Janvier
# Finish Scraping 217 players.
# 31280 players remaining.
#
#
# Start Scraping: Oscar Otte
# Finish Scraping 218 players.
# 31279 players remaining.
#
#
# Start Scraping: Alexandre Muller
# Finish Scraping 219 players.
# 31278 players remaining.
#
#
# Start Scraping: Yoshihito Nishioka
# Finish Scraping 220 players.
# 31277 players remaining.
#
#
# Start Scraping: Nicolas Jarry
# Serve Page: 665
# Return Page: 665
# Raw Page: 665
# Finish Scraping 221 players.
# 31276 players remaining.
#
#
# Start Scraping: Sekou Bangoura
# Serve Page: 640
# Return Page: 640
# Raw Page: 640
# Finish Scraping 222 players.
# 31275 players remaining.
#
#
# Start Scraping: Alex Bolt
# Serve Page: 679
# Return Page: 679
# Raw Page: 679
# Finish Scraping 223 players.
# 31274 players remaining.
#
#
# Start Scraping: Guilherme Clezar
# Serve Page: 627
# Return Page: 627
# Raw Page: 627
# Finish Scraping 224 players.
# 31273 players remaining.
#
#
# Start Scraping: Bernabe Zapata Miralles
# Serve Page: 677
# Return Page: 677
# Raw Page: 677
# Finish Scraping 225 players.
# 31272 players remaining.
#
#
# Start Scraping: Shuichi Sekiguchi
# Serve Page: 627
# Return Page: 627
# Raw Page: 627
# Finish Scraping 226 players.
# 31271 players remaining.
#
#
# Start Scraping: Ruben Ramirez Hidalgo
# Serve Page: 1244
# Return Page: 1244
# Raw Page: 1244
# Finish Scraping 227 players.
# 31270 players remaining.
#
#
# Start Scraping: Martin Cuevas
# Serve Page: 623
# Return Page: 623
# Raw Page: 623
# Finish Scraping 228 players.
# 31269 players remaining.
#
#
# Start Scraping: Ze Zhang
# Serve Page: 622
# Return Page: 622
# Raw Page: 622
# Finish Scraping 229 players.
# 31268 players remaining.
#
#
# Start Scraping: Gleb Sakharov
# Serve Page: 630
# Return Page: 630
# Raw Page: 630
# Finish Scraping 230 players.
# 31267 players remaining.
#
#
# Start Scraping: Benjamin Bonzi
# Serve Page: 708
# Return Page: 708
# Raw Page: 708
# Finish Scraping 231 players.
# 31266 players remaining.
#
#
# Start Scraping: Maximilian Marterer
# Serve Page: 664
# Return Page: 664
# Raw Page: 664
# Finish Scraping 232 players.
# 31265 players remaining.
#
#
# Start Scraping: Karim Mohamed Maamoun
# Serve Page: 643
# Return Page: 643
# Raw Page: 643
# Finish Scraping 233 players.
# 31264 players remaining.
#
#
# Start Scraping: Daniel Elahi Galan
# Serve Page: 690
# Return Page: 690
# Raw Page: 690
# Finish Scraping 234 players.
# 31263 players remaining.
#
#
# Start Scraping: Juan Pablo Varillas
# Serve Page: 681
# Return Page: 681
# Raw Page: 681
# Finish Scraping 235 players.
# 31262 players remaining.
#
#
# Start Scraping: Karen Khachanov
# Serve Page: 672
# Return Page: 672
# Raw Page: 672
# Finish Scraping 236 players.
# 31261 players remaining.
#
#
# Start Scraping: Gonzalo Lama
# Serve Page: 616
# Return Page: 616
# Raw Page: 616
# Finish Scraping 237 players.
# 31260 players remaining.
#
#
# Start Scraping: Marco Bortolotti
# Serve Page: 616
# Return Page: 616
# Raw Page: 616
# Finish Scraping 238 players.
# 31259 players remaining.
#
#
# Start Scraping: Antoine Hoang
# Serve Page: 632
# Return Page: 632
# Raw Page: 632
# Finish Scraping 239 players.
# 31258 players remaining.
#
#
# Start Scraping: Cristian Garin
# Serve Page: 669
# Return Page: 669
# Raw Page: 669
# Finish Scraping 240 players.
# 31257 players remaining.
#
#
# Start Scraping: Darian King
# Serve Page: 621
# Return Page: 621
# Raw Page: 621
# Finish Scraping 241 players.
# 31256 players remaining.
#
#
# Start Scraping: Nino Serdarusic
# Serve Page: 653
# Return Page: 653
# Raw Page: 653
# Finish Scraping 242 players.
# 31255 players remaining.
#
#
# Start Scraping: Aisam Ul Haq Qureshi
# Serve Page: 595
# Return Page: 595
# Raw Page: 595
# Finish Scraping 243 players.
# 31254 players remaining.
#
#
# Start Scraping: Marcelo Arevalo
# Serve Page: 612
# Return Page: 612
# Raw Page: 612
# Finish Scraping 244 players.
# 31253 players remaining.
#
#
# Start Scraping: Aleksandr Nedovyesov
# Serve Page: 605
# Return Page: 605
# Raw Page: 605
# Finish Scraping 245 players.
# 31252 players remaining.
#
#
# Start Scraping: Takuto Niki
# Serve Page: 604
# Return Page: 604
# Raw Page: 604
# Finish Scraping 246 players.
# 31251 players remaining.
#
#
# Start Scraping: Federico Zeballos
# Serve Page: 608
# Return Page: 608
# Raw Page: 608
# Finish Scraping 247 players.
# 31250 players remaining.
#
#
# Start Scraping: Joris De Loore
# Serve Page: 638
# Return Page: 638
# Raw Page: 638
# Finish Scraping 248 players.
# 31249 players remaining.
#
#
# Start Scraping: Jaume Munar
# Serve Page: 663
# Return Page: 663
# Raw Page: 663
# Finish Scraping 249 players.
# 31248 players remaining.
#
#
# Start Scraping: Gonzalo Villanueva
# Serve Page: 674
# Return Page: 674
# Raw Page: 674
# Finish Scraping 250 players.
# 31247 players remaining.
#
#
# Start Scraping: Tomas Lipovsek Puches
# Serve Page: 593
# Return Page: 593
# Raw Page: 593
# Finish Scraping 251 players.
# 31246 players remaining.
#
#
# Start Scraping: David Marrero
# Serve Page: 593
# Return Page: 593
# Raw Page: 593
# Finish Scraping 252 players.
# 31245 players remaining.
#
#
# Start Scraping: Nikola Milojevic
# Serve Page: 608
# Return Page: 608
# Raw Page: 608
# Finish Scraping 253 players.
# 31244 players remaining.
#
#
# Start Scraping: Pedro Sakamoto
# Finish Scraping 254 players.
# 31243 players remaining.
#
#
# Start Scraping: Pol Toledo Bague
# Finish Scraping 255 players.
# 31242 players remaining.
#
#
# Start Scraping: Sebastian Ofner
# Finish Scraping 256 players.
# 31241 players remaining.
#
#
# Start Scraping: Marcos Giron
# Finish Scraping 257 players.
# 31240 players remaining.
#
#
# Start Scraping: Jerzy Janowicz
# Finish Scraping 258 players.
# 31239 players remaining.
#
#
# Start Scraping: Fernando Romboli
# Serve Page: 589
# Return Page: 589
# Raw Page: 589
# Finish Scraping 259 players.
# 31238 players remaining.
#
#
# Start Scraping: Vishnu Vardhan
# Serve Page: 604
# Return Page: 604
# Raw Page: 604
# Finish Scraping 260 players.
# 31237 players remaining.
#
#
# Start Scraping: Andre Agassi
# Serve Page: 1166
# Return Page: 1166
# Raw Page: 1166
# Finish Scraping 261 players.
# 31236 players remaining.
#
#
# Start Scraping: Tommy Paul
# Serve Page: 641
# Return Page: 641
# Raw Page: 641
# Finish Scraping 262 players.
# 31235 players remaining.
#
#
# Start Scraping: Sasi Kumar Mukund
# Serve Page: 652
# Return Page: 652
# Raw Page: 652
# Finish Scraping 263 players.
# 31234 players remaining.
#
#
# Start Scraping: Jason Kubler
# Serve Page: 609
# Return Page: 609
# Raw Page: 609
# Finish Scraping 264 players.
# 31233 players remaining.
#
#
# Start Scraping: Carlos Taberner
# Serve Page: 661
# Return Page: 661
# Raw Page: 661
# Finish Scraping 265 players.
# 31232 players remaining.
#
#
# Start Scraping: Matias Franco Descotte
# Serve Page: 599
# Return Page: 599
# Raw Page: 599
# Finish Scraping 266 players.
# 31231 players remaining.
#
#
# Start Scraping: Lucas Pouille
# Serve Page: 626
# Return Page: 626
# Raw Page: 626
# Finish Scraping 267 players.
# 31230 players remaining.
#
#
# Start Scraping: Calvin Hemery
# Serve Page: 657
# Return Page: 657
# Raw Page: 657
# Finish Scraping 268 players.
# 31229 players remaining.
#
#
# Start Scraping: Taylor Fritz
# Serve Page: 654
# Return Page: 654
# Raw Page: 654
# Finish Scraping 269 players.
# 31228 players remaining.
#
#
# Start Scraping: Tiago Lopes
# Serve Page: 573
# Return Page: 573
# Raw Page: 573
# Finish Scraping 270 players.
# 31227 players remaining.
#
#
# Start Scraping: Manuel Orantes
# Serve Page: 1138
# Return Page: 1138
# Raw Page: 1138
# Finish Scraping 271 players.
# 31226 players remaining.
#
#
# Start Scraping: Maximiliano Estevez
# Serve Page: 572
# Return Page: 572
# Raw Page: 572
# Finish Scraping 272 players.
# 31225 players remaining.
#
#
# Start Scraping: Ilya Ivashka
# Serve Page: 559
# Return Page: 559
# Raw Page: 559
# Finish Scraping 273 players.
# 31224 players remaining.
#
#
# Start Scraping: Christopher Oconnell
# Finish Scraping 274 players.
# 31223 players remaining.
#
#
# Start Scraping: Jan Choinski
# Finish Scraping 275 players.
# 31222 players remaining.
#
#
# Start Scraping: Stefano Napolitano
# Finish Scraping 276 players.
# 31221 players remaining.
#
#
# Start Scraping: Marty Riessen
# Finish Scraping 277 players.
# 31220 players remaining.
#
#
# Start Scraping: Viktor Durasovic
# Finish Scraping 278 players.
# 31219 players remaining.
#
#
# Start Scraping: Nicolas Kicker
# Serve Page: 607
# Return Page: 607
# Raw Page: 607
# Finish Scraping 279 players.
# 31218 players remaining.
#
#
# Start Scraping: Pedja Krstin
# Serve Page: 564
# Return Page: 564
# Raw Page: 564
# Finish Scraping 280 players.
# 31217 players remaining.
#
#
# Start Scraping: Jack Sock
# Serve Page: 564
# Return Page: 564
# Raw Page: 564
# Finish Scraping 281 players.
# 31216 players remaining.
#
#
# Start Scraping: Laurent Lokoli
# Serve Page: 612
# Return Page: 612
# Raw Page: 612
# Finish Scraping 282 players.
# 31215 players remaining.
#
#
# Start Scraping: Vladyslav Manafov
# Serve Page: 564
# Return Page: 564
# Raw Page: 564
# Finish Scraping 283 players.
# 31214 players remaining.
#
#
# Start Scraping: Alexis Musialek
# Serve Page: 564
# Return Page: 564
# Raw Page: 564
# Finish Scraping 284 players.
# 31213 players remaining.
#
#
# Start Scraping: Lorenzo Sonego
# Serve Page: 629
# Return Page: 629
# Raw Page: 629
# Finish Scraping 285 players.
# 31212 players remaining.
#
#
# Start Scraping: Hubert Hurkacz
# Serve Page: 616
# Return Page: 616
# Raw Page: 616
# Finish Scraping 286 players.
# 31211 players remaining.
#
#
# Start Scraping: Mats Moraing
# Serve Page: 561
# Return Page: 561
# Raw Page: 561
# Finish Scraping 287 players.
# 31210 players remaining.
#
#
# Start Scraping: Tomas Berdych
# Serve Page: 1125
# Return Page: 1125
# Raw Page: 1125
# Finish Scraping 288 players.
# 31209 players remaining.
#
#
# Start Scraping: Ivo Karlovic
# Serve Page: 1105
# Return Page: 1105
# Raw Page: 1105
# Finish Scraping 289 players.
# 31208 players remaining.
#
#
# Start Scraping: Alexander Bublik
# Serve Page: 610
# Return Page: 610
# Raw Page: 610
# Finish Scraping 290 players.
# 31207 players remaining.
#
#
# Start Scraping: Frances Tiafoe
# Serve Page: 625
# Return Page: 625
# Raw Page: 625
# Finish Scraping 291 players.
# 31206 players remaining.
#
#
# Start Scraping: Lloyd Harris
# Serve Page: 587
# Return Page: 587
# Raw Page: 587
# Finish Scraping 292 players.
# 31205 players remaining.
#
#
# Start Scraping: Benjamin Lock
# Serve Page: 635
# Return Page: 635
# Raw Page: 635
# Finish Scraping 293 players.
# 31204 players remaining.
#
#
# Start Scraping: John Mcenroe
# Serve Page: 1113
# Return Page: 1113
# Raw Page: 1113
# Finish Scraping 294 players.
# 31203 players remaining.
#
#
# Start Scraping: Mikhail Youzhny
# Serve Page: 1112
# Return Page: 1112
# Raw Page: 1112
# Finish Scraping 295 players.
# 31202 players remaining.
#
#
# Start Scraping: Cheong Eui Kim
# Serve Page: 557
# Return Page: 557
# Raw Page: 557
# Finish Scraping 296 players.
# 31201 players remaining.
#
#
# Start Scraping: Francesco Vilardo
# Serve Page: 557
# Return Page: 557
# Raw Page: 557
# Finish Scraping 297 players.
# 31200 players remaining.
#
#
# Start Scraping: Fabrice Santoro
# Serve Page: 1113
# Return Page: 1113
# Raw Page: 1113
# Finish Scraping 298 players.
# 31199 players remaining.
#
#
# Start Scraping: Carlos Berlocq
# Serve Page: 1109
# Return Page: 1109
# Raw Page: 1109
# Finish Scraping 299 players.
# 31198 players remaining.
#
#
# Start Scraping: Daniel Altmaier
# Serve Page: 630
# Return Page: 630
# Raw Page: 630
# Finish Scraping 300 players.
# 31197 players remaining.
#
#
# Start Scraping: Tony Roche
# Serve Page: 1083
# Return Page: 1083
# Raw Page: 1083
# Finish Scraping 301 players.
# 31196 players remaining.
#
#
# Start Scraping: Duck Hee Lee
# Serve Page: 587
# Return Page: 587
# Raw Page: 587
# Finish Scraping 302 players.
# 31195 players remaining.
#
#
# Start Scraping: Casper Ruud
# Serve Page: 629
# Return Page: 629
# Raw Page: 629
# Finish Scraping 303 players.
# 31194 players remaining.
#
#
# Start Scraping: Altug Celikbilek
# Serve Page: 599
# Return Page: 599
# Raw Page: 599
# Finish Scraping 304 players.
# 31193 players remaining.
#
#
# Start Scraping: Marc Polmans
# Serve Page: 588
# Return Page: 588
# Raw Page: 588
# Finish Scraping 305 players.
# 31192 players remaining.
#
#
# Start Scraping: Guillermo Garcia Lopez
# Serve Page: 1096
# Return Page: 1096
# Raw Page: 1096
# Finish Scraping 306 players.
# 31191 players remaining.
#
#
# Start Scraping: Juan Pablo Ficovich
# Serve Page: 638
# Return Page: 638
# Raw Page: 638
# Finish Scraping 307 players.
# 31190 players remaining.
#
#
# Start Scraping: Nerman Fatic
# Serve Page: 604
# Return Page: 604
# Raw Page: 604
# Finish Scraping 308 players.
# 31189 players remaining.
#
#
# Start Scraping: Tallon Griekspoor
# Serve Page: 616
# Return Page: 616
# Raw Page: 616
# Finish Scraping 309 players.
# 31188 players remaining.
#
#
# Start Scraping: Roman Safiullin
# Serve Page: 607
# Return Page: 607
# Raw Page: 607
# Finish Scraping 310 players.
# 31187 players remaining.
#
#
# Start Scraping: David Pichler
# Serve Page: 573
# Return Page: 573
# Raw Page: 573
# Finish Scraping 311 players.
# 31186 players remaining.
#
#
# Start Scraping: Yannick Hanfmann
# Serve Page: 592
# Return Page: 592
# Raw Page: 592
# Finish Scraping 312 players.
# 31185 players remaining.
#
#
# Start Scraping: Kamil Majchrzak
# Serve Page: 619
# Return Page: 619
# Raw Page: 619
# Finish Scraping 313 players.
# 31184 players remaining.
#
#
# Start Scraping: Yan Bai
# Serve Page: 620
# Return Page: 620
# Raw Page: 620
# Finish Scraping 314 players.
# 31183 players remaining.
#
#
# Start Scraping: Borna Coric
# Serve Page: 598
# Return Page: 598
# Raw Page: 598
# Finish Scraping 315 players.
# 31182 players remaining.
#
#
# Start Scraping: Corentin Denolly
# Serve Page: 622
# Return Page: 622
# Raw Page: 622
# Finish Scraping 316 players.
# 31181 players remaining.
#
#
# Start Scraping: Filippo Volandri
# Serve Page: 1070
# Return Page: 1070
# Raw Page: 1070
# Finish Scraping 317 players.
# 31180 players remaining.
#
#
# Start Scraping: Yen Hsun Lu
# Serve Page: 1077
# Return Page: 1077
# Raw Page: 1077
# Finish Scraping 318 players.
# 31179 players remaining.
#
#
# Start Scraping: Tak Khunn Wang
# Serve Page: 540
# Return Page: 540
# Raw Page: 540
# Finish Scraping 319 players.
# 31178 players remaining.
#
#
# Start Scraping: Cameron Norrie
# Serve Page: 584
# Return Page: 584
# Raw Page: 584
# Finish Scraping 320 players.
# 31177 players remaining.
#
#
# Start Scraping: Javier Marti
# Serve Page: 539
# Return Page: 539
# Raw Page: 539
# Finish Scraping 321 players.
# 31176 players remaining.
#
#
# Start Scraping: Stefan Edberg
# Serve Page: 1077
# Return Page: 1077
# Raw Page: 1077
# Finish Scraping 322 players.
# 31175 players remaining.
#
#
# Start Scraping: Michael Geerts
# Serve Page: 629
# Return Page: 629
# Raw Page: 629
# Finish Scraping 323 players.
# 31174 players remaining.
#
#
# Start Scraping: Enzo Couacaud
# Serve Page: 582
# Return Page: 582
# Raw Page: 582
# Finish Scraping 324 players.
# 31173 players remaining.
#
#
# Start Scraping: Sebastian Fanselow
# Serve Page: 587
# Return Page: 587
# Raw Page: 587
# Finish Scraping 325 players.
# 31172 players remaining.
#
#
# Start Scraping: John Alexander
# Serve Page: 1065
# Return Page: 1065
# Raw Page: 1065
# Finish Scraping 326 players.
# 31171 players remaining.
#
#
# Start Scraping: Ti Chen
# Serve Page: 1068
# Return Page: 1068
# Raw Page: 1068
# Finish Scraping 327 players.
# 31170 players remaining.
#
#
# Start Scraping: Albert Montanes
# Serve Page: 1060
# Return Page: 1060
# Raw Page: 1060
# Finish Scraping 328 players.
# 31169 players remaining.
#
#
# Start Scraping: Vit Kopriva
# Serve Page: 608
# Return Page: 608
# Raw Page: 608
# Finish Scraping 329 players.
# 31168 players remaining.
#
#
# Start Scraping: Elmar Ejupovic
# Serve Page: 597
# Return Page: 597
# Raw Page: 597
# Finish Scraping 330 players.
# 31167 players remaining.
#
#
# Start Scraping: Cedrik Marcel Stebe
# Serve Page: 538
# Return Page: 538
# Raw Page: 538
# Finish Scraping 331 players.
# 31166 players remaining.
#
#
# Start Scraping: Marcel Granollers
# Serve Page: 1063
# Return Page: 1063
# Raw Page: 1063
# Finish Scraping 332 players.
# 31165 players remaining.
#
#
# Start Scraping: Jan Mertl
# Serve Page: 1058
# Return Page: 1058
# Raw Page: 1058
# Finish Scraping 333 players.
# 31164 players remaining.
#
#
# Start Scraping: Jelle Sels
# Serve Page: 609
# Return Page: 609
# Raw Page: 609
# Finish Scraping 334 players.
# 31163 players remaining.
#
#
# Start Scraping: Daniel Gimeno Traver
# Serve Page: 1058
# Return Page: 1058
# Raw Page: 1058
# Finish Scraping 335 players.
# 31162 players remaining.
#
#
# Start Scraping: Yannick Maden
# Serve Page: 522
# Return Page: 522
# Raw Page: 522
# Finish Scraping 336 players.
# 31161 players remaining.
#
#
# Start Scraping: Brian Gottfried
# Serve Page: 1034
# Return Page: 1034
# Raw Page: 1034
# Finish Scraping 337 players.
# 31160 players remaining.
#
#
# Start Scraping: Franco Agamenone
# Serve Page: 591
# Return Page: 591
# Raw Page: 591
# Finish Scraping 338 players.
# 31159 players remaining.
#
#
# Start Scraping: Dominik Hrbaty
# Serve Page: 1051
# Return Page: 1051
# Raw Page: 1051
# Finish Scraping 339 players.
# 31158 players remaining.
#
#
# Start Scraping: Jules Marie
# Serve Page: 577
# Return Page: 577
# Raw Page: 577
# Finish Scraping 340 players.
# 31157 players remaining.
#
#
# Start Scraping: Kyle Edmund
# Serve Page: 569
# Return Page: 569
# Raw Page: 569
# Finish Scraping 341 players.
# 31156 players remaining.
#
#
# Start Scraping: Andres Gimeno
# Serve Page: 1163
# Return Page: 1163
# Raw Page: 1163
# Finish Scraping 342 players.
# 31155 players remaining.
#
#
# Start Scraping: Lucas Miedler
# Serve Page: 531
# Return Page: 531
# Raw Page: 531
# Finish Scraping 343 players.
# 31154 players remaining.
#
#
# Start Scraping: Jeremy Jahn
# Serve Page: 523
# Return Page: 523
# Raw Page: 523
# Finish Scraping 344 players.
# 31153 players remaining.
#
#
# Start Scraping: Eduard Esteve Lobato
# Serve Page: 522
# Return Page: 522
# Raw Page: 522
# Finish Scraping 345 players.
# 31152 players remaining.
#
#
# Start Scraping: Carlos Gomez Herrera
# Serve Page: 521
# Return Page: 521
# Raw Page: 521
# Finish Scraping 346 players.
# 31151 players remaining.
#
#
# Start Scraping: N Sriram Balaji
# Serve Page: 522
# Return Page: 522
# Raw Page: 522
# Finish Scraping 347 players.
# 31150 players remaining.
#
#
# Start Scraping: Geoffrey Blancaneaux
# Serve Page: 582
# Return Page: 582
# Raw Page: 582
# Finish Scraping 348 players.
# 31149 players remaining.
#
#
# Start Scraping: Juan Ignacio Galarza
# Serve Page: 515
# Return Page: 515
# Raw Page: 515
# Finish Scraping 349 players.
# 31148 players remaining.
#
#
# Start Scraping: Vaclav Safranek
# Serve Page: 516
# Return Page: 516
# Raw Page: 516
# Finish Scraping 350 players.
# 31147 players remaining.
#
#
# Start Scraping: Jan Satral
# Serve Page: 516
# Return Page: 516
# Raw Page: 516
# Finish Scraping 351 players.
# 31146 players remaining.
#
#
# Start Scraping: Prajnesh Gunneswaran
# Serve Page: 509
# Return Page: 509
# Raw Page: 509
# Finish Scraping 352 players.
# 31145 players remaining.
#
#
# Start Scraping: Nicolas Mahut
# Finish Scraping 353 players.
# 31144 players remaining.
#
#
# Start Scraping: Fred Stolle
# Finish Scraping 354 players.
# 31143 players remaining.
#
#
# Start Scraping: Alex De Minaur
# Finish Scraping 355 players.
# 31142 players remaining.
#
#
# Start Scraping: Lucas Catarina
# Finish Scraping 356 players.
# 31141 players remaining.
#
#
# Start Scraping: Roger Taylor
# Serve Page: 1007
# Return Page: 1007
# Raw Page: 1007
# Finish Scraping 357 players.
# 31140 players remaining.
#
#
# Start Scraping: Oscar Jose Gutierrez
# Serve Page: 558
# Return Page: 558
# Raw Page: 558
# Finish Scraping 358 players.
# 31139 players remaining.
#
#
# Start Scraping: Sumit Nagal
# Serve Page: 564
# Return Page: 564
# Raw Page: 564
# Finish Scraping 359 players.
# 31138 players remaining.
#
#
# Start Scraping: Alexander Lazov
# Serve Page: 511
# Return Page: 511
# Raw Page: 511
# Finish Scraping 360 players.
# 31137 players remaining.
#
#
# Start Scraping: Jarkko Nieminen
# Serve Page: 1019
# Return Page: 1019
# Raw Page: 1019
# Finish Scraping 361 players.
# 31136 players remaining.
#
#
# Start Scraping: John Patrick Smith
# Serve Page: 510
# Return Page: 510
# Raw Page: 510
# Finish Scraping 362 players.
# 31135 players remaining.
#
#
# Start Scraping: Aziz Dougaz
# Serve Page: 601
# Return Page: 601
# Raw Page: 601
# Finish Scraping 363 players.
# 31134 players remaining.
#
#
# Start Scraping: Matias Zukas
# Serve Page: 508
# Return Page: 508
# Raw Page: 508
# Finish Scraping 364 players.
# 31133 players remaining.
#
#
# Start Scraping: Rainer Schuettler
# Serve Page: 1013
# Return Page: 1013
# Raw Page: 1013
# Finish Scraping 365 players.
# 31132 players remaining.
#
#
# Start Scraping: Manuel Santana
# Serve Page: 1051
# Return Page: 1051
# Raw Page: 1051
# Finish Scraping 366 players.
# ...
# Finish Scraping 8382 players.
# 23115 players remaining.
#
#
# Start Scraping: Chad Andrews
# Finish Scraping 8383 players.
# 23114 players remaining.
#
#
# Start Scraping: Andres Filimonov
# Finish Scraping 8384 players.
# 23113 players remaining.
#
#
# Start Scraping: Kevin Jordi
# Finish Scraping 8385 players.
# 23112 players remaining.
#
#
# Start Scraping: Claude Benz
# Finish Scraping 8386 players.
# 23111 players remaining.
#
#
# Start Scraping: Jamie Whiteford
# Finish Scraping 8387 players.
# 23110 players remaining.
#
#
# Start Scraping: Sebastien Vidal
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 8388 players.
# 23109 players remaining.
#
#
# Start Scraping: Mehdi Bouras
# Finish Scraping 8389 players.
# 23108 players remaining.
#
#
# Start Scraping: Nathaniel Gorham
# Finish Scraping 8390 players.
# 23107 players remaining.
#
#
# Start Scraping: Julian Morosi
# Finish Scraping 8391 players.
# 23106 players remaining.
#
#
# Start Scraping: Mark Mccook
# Finish Scraping 8392 players.
# 23105 players remaining.
#
#
# Start Scraping: Christophe Lenzi
# Finish Scraping 8393 players.
# 23104 players remaining.
#
#
# Start Scraping: Jakub Praibis
# Finish Scraping 8394 players.
# 23103 players remaining.
#
#
# Start Scraping: Milan Smejda
# Finish Scraping 8395 players.
# 23102 players remaining.
#
#
# Start Scraping: Daniel Steinhilber
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8396 players.
# 23101 players remaining.
#
#
# Start Scraping: Sam Schroerlucke
# Finish Scraping 8397 players.
# 23100 players remaining.
#
#
# Start Scraping: Mauro Barman
# Finish Scraping 8398 players.
# 23099 players remaining.
#
#
# Start Scraping: Eduardo Morones
# Finish Scraping 8399 players.
# 23098 players remaining.
#
#
# Start Scraping: Nicolas Guillaume
# Finish Scraping 8400 players.
# 23097 players remaining.
#
#
# Start Scraping: Gunter Kummermehr
# Finish Scraping 8401 players.
# 23096 players remaining.
#
#
# Start Scraping: Guido Van Rompaey
# Finish Scraping 8402 players.
# 23095 players remaining.
#
#
# Start Scraping: Darren Kirk
# Finish Scraping 8403 players.
# 23094 players remaining.
#
#
# Start Scraping: Shigeru Ota
# Finish Scraping 8404 players.
# 23093 players remaining.
#
#
# Start Scraping: Greg Van Emburgh
# Finish Scraping 8405 players.
# 23092 players remaining.
#
#
# Start Scraping: Helmar Stiegler
# Finish Scraping 8406 players.
# 23091 players remaining.
#
#
# Start Scraping: Vallis Wilder
# Finish Scraping 8407 players.
# 23090 players remaining.
#
#
# Start Scraping: Vincent Marysko
# Finish Scraping 8408 players.
# 23089 players remaining.
#
#
# Start Scraping: Grigory Shebekin
# Finish Scraping 8409 players.
# 23088 players remaining.
#
#
# Start Scraping: Zoran Ludoski
# Serve Page: 28
# Return Page: 28
# Raw Page: 28
# Finish Scraping 8410 players.
# 23087 players remaining.
#
#
# Start Scraping: Kabir Hans
# Serve Page: 27
# Return Page: 27
# Raw Page: 27
# Finish Scraping 8411 players.
# 23086 players remaining.
#
#
# Start Scraping: Rudy Quan
# Serve Page: 38
# Return Page: 38
# Raw Page: 38
# Finish Scraping 8412 players.
# 23085 players remaining.
#
#
# Start Scraping: Andrej Radojicic
# Finish Scraping 8413 players.
# 23084 players remaining.
#
#
# Start Scraping: Alexander Orlov
# Finish Scraping 8414 players.
# 23083 players remaining.
#
#
# Start Scraping: Matthew Summers
# Serve Page: 49
# Return Page: 49
# Raw Page: 49
# Finish Scraping 8415 players.
# 23082 players remaining.
#
#
# Start Scraping: Braden Shick
# Serve Page: 19
# Return Page: 19
# Raw Page: 19
# Finish Scraping 8416 players.
# 23081 players remaining.
#
#
# Start Scraping: Marc Antoine Gaillard
# Serve Page: 17
# Return Page: 17
# Raw Page: 17
# Finish Scraping 8417 players.
# 23080 players remaining.
#
#
# Start Scraping: Filip Apltauer
# Serve Page: 20
# Return Page: 20
# Raw Page: 20
# Finish Scraping 8418 players.
# 23079 players remaining.
#
#
# Start Scraping: Gunawan Trismuwantara
# Finish Scraping 8419 players.
# 23078 players remaining.
#
#
# Start Scraping: Jason Morton
# Finish Scraping 8420 players.
# 23077 players remaining.
#
#
# Start Scraping: William Jucha
# Finish Scraping 8421 players.
# 23076 players remaining.
#
#
# Start Scraping: Jiayang Dong
# Finish Scraping 8422 players.
# 23075 players remaining.
#
#
# Start Scraping: John Chin
# Finish Scraping 8423 players.
# 23074 players remaining.
#
#
# Start Scraping: Ha Minh Duc Vu
# Serve Page: 16
# Return Page: 16
# Raw Page: 16
# Finish Scraping 8424 players.
# 23073 players remaining.
#
#
# Start Scraping: Luis Francisco
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 8425 players.
# 23072 players remaining.
#
#
# Start Scraping: Radomir Tomic
# Finish Scraping 8426 players.
# 23071 players remaining.
#
#
# Start Scraping: Rayan Ghedjemis
# Finish Scraping 8427 players.
# 23070 players remaining.
#
#
# Start Scraping: Sebastian Gorzny
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 8428 players.
# 23069 players remaining.
#
#
# Start Scraping: Vojtech Petr
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 8429 players.
# 23068 players remaining.
#
#
# Start Scraping: Matheus Amorim De Lima
# Finish Scraping 8430 players.
# 23067 players remaining.
#
#
# Start Scraping: Vivien Versier
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 8431 players.
# 23066 players remaining.
#
#
# Start Scraping: Marcel Kamrowski
# Finish Scraping 8432 players.
# 23065 players remaining.
#
#
# Start Scraping: DUPE Bruno Kuzuhara
# Finish Scraping 8433 players.
# 23064 players remaining.
#
#
# Start Scraping: Rohan Mehra
# Finish Scraping 8434 players.
# 23063 players remaining.
#
#
# Start Scraping: Nishant Dabas
# Finish Scraping 8435 players.
# 23062 players remaining.
#
#
# Start Scraping: Sai Karteek Reddy Ganta
# Finish Scraping 8436 players.
# 23061 players remaining.
#
#
# Start Scraping: Alan Bojarski
# Serve Page: 35
# Return Page: 35
# Raw Page: 35
# Finish Scraping 8437 players.
# 23060 players remaining.
#
#
# Start Scraping: Vesa Ahti
# Finish Scraping 8438 players.
# 23059 players remaining.
#
#
# Start Scraping: Alfredo Casso
# Finish Scraping 8439 players.
# 23058 players remaining.
#
#
# Start Scraping: Luca Sanchez
# Finish Scraping 8440 players.
# 23057 players remaining.
#
#
# Start Scraping: Andrey Uvarov
# Finish Scraping 8441 players.
# 23056 players remaining.
#
#
# Start Scraping: Jan Jermar
# Finish Scraping 8442 players.
# 23055 players remaining.
#
#
# Start Scraping: Razvan Baiant
# Finish Scraping 8443 players.
# 23054 players remaining.
#
#
# Start Scraping: Robert Cash
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 8444 players.
# 23053 players remaining.
#
#
# Start Scraping: Jordan Chiu
# Serve Page: 23
# Return Page: 23
# Raw Page: 23
# Finish Scraping 8445 players.
# 23052 players remaining.
#
#
# Start Scraping: Yusuf Khamis
# Serve Page: 25
# Return Page: 25
# Raw Page: 25
# Finish Scraping 8446 players.
# 23051 players remaining.
#
#
# Start Scraping: Jacob Bullard
# Finish Scraping 8447 players.
# 23050 players remaining.
#
#
# Start Scraping: Jagmeet Singh
# Finish Scraping 8448 players.
# 23049 players remaining.
#
#
# Start Scraping: Piotr Galus
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 8449 players.
# 23048 players remaining.
#
#
# Start Scraping: Alessandro Coppini
# Serve Page: 28
# Return Page: 28
# Raw Page: 28
# Finish Scraping 8450 players.
# 23047 players remaining.
#
#
# Start Scraping: Hugo Maia
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 8451 players.
# 23046 players remaining.
#
#
# Start Scraping: Tomas Almeida
# Finish Scraping 8452 players.
# 23045 players remaining.
#
#
# Start Scraping: Cyril Respaut
# Serve Page: 17
# Return Page: 17
# Raw Page: 17
# Finish Scraping 8453 players.
# 23044 players remaining.
#
#
# Start Scraping: Simon Reveniau
# Serve Page: 24
# Return Page: 24
# Raw Page: 24
# Finish Scraping 8454 players.
# 23043 players remaining.
#
#
# Start Scraping: Jordi Walder
# Finish Scraping 8455 players.
# 23042 players remaining.
#
#
# Start Scraping: Brian Cernoch
# Finish Scraping 8456 players.
# 23041 players remaining.
#
#
# Start Scraping: Sid Donarski
# Finish Scraping 8457 players.
# 23040 players remaining.
#
#
# Start Scraping: Vasisht Cheruku
# Finish Scraping 8458 players.
# 23039 players remaining.
#
#
# Start Scraping: Toufik Sahtali
# Finish Scraping 8459 players.
# 23038 players remaining.
#
#
# Start Scraping: John Melhuish
# Serve Page: 14
# Return Page: 14
# Raw Page: 14
# Finish Scraping 8460 players.
# 23037 players remaining.
#
#
# Start Scraping: Agustin Riquelme
# Serve Page: 28
# Return Page: 28
# Raw Page: 28
# Finish Scraping 8461 players.
# 23036 players remaining.
#
#
# Start Scraping: Bhavesh Gour
# Finish Scraping 8462 players.
# 23035 players remaining.
#
#
# Start Scraping: Stefan Skadarka
# Serve Page: 28
# Return Page: 28
# Raw Page: 28
# Finish Scraping 8463 players.
# 23034 players remaining.
#
#
# Start Scraping: Luke Oakley
# Finish Scraping 8464 players.
# 23033 players remaining.
#
#
# Start Scraping: Sharmal Dissanayake
# Finish Scraping 8465 players.
# 23032 players remaining.
#
#
# Start Scraping: Irakli Metreveli
# Finish Scraping 8466 players.
# 23031 players remaining.
#
#
# Start Scraping: Robin Lang
# Finish Scraping 8467 players.
# 23030 players remaining.
#
#
# Start Scraping: Stefan Frljanic
# Finish Scraping 8468 players.
# 23029 players remaining.
#
#
# Start Scraping: Trevor Allen Johnson
# Finish Scraping 8469 players.
# 23028 players remaining.
#
#
# Start Scraping: Nikolas Walterscheid Tukic
# Finish Scraping 8470 players.
# 23027 players remaining.
#
#
# Start Scraping: Bernd Haberleitner
# Serve Page: 4
# Return Page: 4
# Raw Page: 4
# Finish Scraping 8471 players.
# 23026 players remaining.
#
#
# Start Scraping: Miguel Puig Tibbs
# Finish Scraping 8472 players.
# 23025 players remaining.
#
#
# Start Scraping: Andras Szekely
# Finish Scraping 8473 players.
# 23024 players remaining.
#
#
# Start Scraping: Hichem Yasri
# Finish Scraping 8474 players.
# 23023 players remaining.
#
#
# Start Scraping: Antoine Leduc
# Finish Scraping 8475 players.
# 23022 players remaining.
#
#
# Start Scraping: Andrew Ochotta
# Finish Scraping 8476 players.
# 23021 players remaining.
#
#
# Start Scraping: Marco Mokrzycki
# Serve Page: 16
# Return Page: 16
# Raw Page: 16
# Finish Scraping 8477 players.
# 23020 players remaining.
#
#
# Start Scraping: Santos Sanchez Patino
# Finish Scraping 8478 players.
# 23019 players remaining.
#
#
# Start Scraping: Cristobal Aguirre
# Finish Scraping 8479 players.
# 23018 players remaining.
#
#
# Start Scraping: Luis Ramon Osio De Freita
# Finish Scraping 8480 players.
# 23017 players remaining.
#
#
# Start Scraping: Tomaz Berendijas
# Finish Scraping 8481 players.
# 23016 players remaining.
#
#
# Start Scraping: Christian Requeni Sivera
# Finish Scraping 8482 players.
# 23015 players remaining.
#
#
# Start Scraping: Cesare Guerci Lena
# Finish Scraping 8483 players.
# 23014 players remaining.
#
#
# Start Scraping: Daniel Sanders
# Finish Scraping 8484 players.
# 23013 players remaining.
#
#
# Start Scraping: Bhee Witoonpanich
# Finish Scraping 8485 players.
# 23012 players remaining.
#
#
# Start Scraping: Remzi Aydin
# Finish Scraping 8486 players.
# 23011 players remaining.
#
#
# Start Scraping: Sultan Aman Azman
# Finish Scraping 8487 players.
# 23010 players remaining.
#
#
# Start Scraping: Andrey Yakovlev
# Finish Scraping 8488 players.
# 23009 players remaining.
#
#
# Start Scraping: Bob Puddicombe
# Serve Page: 28
# Return Page: 28
# Raw Page: 28
# Finish Scraping 8489 players.
# 23008 players remaining.
#
#
# Start Scraping: Steve Cornell
# Serve Page: 25
# Return Page: 25
# Raw Page: 25
# Finish Scraping 8490 players.
# 23007 players remaining.
#
#
# Start Scraping: Julian Krinsky
# Finish Scraping 8491 players.
# 23006 players remaining.
#
#
# Start Scraping: Alexander Karpenko
# Finish Scraping 8492 players.
# 23005 players remaining.
#
#
# Start Scraping: Pawel Syrewicz
# Finish Scraping 8493 players.
# 23004 players remaining.
#
#
# Start Scraping: Issam Jellali
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 8494 players.
# 23003 players remaining.
#
#
# Start Scraping: Antonio Martin Velez
# Finish Scraping 8495 players.
# 23002 players remaining.
#
#
# Start Scraping: Sergio Rojas
# Finish Scraping 8496 players.
# 23001 players remaining.
#
#
# Start Scraping: Frederick Sundsten
# Finish Scraping 8497 players.
# 23000 players remaining.
#
#
# Start Scraping: Shahzad Khan
# Finish Scraping 8498 players.
# 22999 players remaining.
#
#
# Start Scraping: Tsolak Gevorgyan
# Finish Scraping 8499 players.
# 22998 players remaining.
#
#
# Start Scraping: Tetsu Kuramitsu
# Finish Scraping 8500 players.
# 22997 players remaining.
#
#
# Start Scraping: Stefan Dallwitz
# Finish Scraping 8501 players.
# 22996 players remaining.
#
#
# Start Scraping: Sergio Rico
# Finish Scraping 8502 players.
# 22995 players remaining.
#
#
# Start Scraping: Ralph Kok
# Finish Scraping 8503 players.
# 22994 players remaining.
#
#
# Start Scraping: Michael Penman
# Finish Scraping 8504 players.
# 22993 players remaining.
#
#
# Start Scraping: Marco Alciati
# Serve Page: 11
# Return Page: 11
# Raw Page: 11
# Finish Scraping 8505 players.
# 22992 players remaining.
#
#
# Start Scraping: Joe Meyers
# Finish Scraping 8506 players.
# 22991 players remaining.
#
#
# Start Scraping: Jack Griffin
# Finish Scraping 8507 players.
# 22990 players remaining.
#
#
# Start Scraping: Gerd Albiez
# Finish Scraping 8508 players.
# 22989 players remaining.
#
#
# Start Scraping: Fabio Di Mauro
# Finish Scraping 8509 players.
# 22988 players remaining.
#
#
# Start Scraping: Di Lin
# Finish Scraping 8510 players.
# 22987 players remaining.
#
#
# Start Scraping: Cyril Mokaiesh
# Finish Scraping 8511 players.
# 22986 players remaining.
#
#
# Start Scraping: Bruce Haddad
# Finish Scraping 8512 players.
# 22985 players remaining.
#
#
# Start Scraping: Ante Andric
# Finish Scraping 8513 players.
# 22984 players remaining.
#
#
# Start Scraping: Alfonso Perez Penate
# Finish Scraping 8514 players.
# 22983 players remaining.
#
#
# Start Scraping: Alessandro Fornaro
# Finish Scraping 8515 players.
# 22982 players remaining.
#
#
# Start Scraping: Arnau Dachs
# Finish Scraping 8516 players.
# 22981 players remaining.
#
#
# Start Scraping: Batyr Sapaev
# Finish Scraping 8517 players.
# 22980 players remaining.
#
#
# Start Scraping: Dmitri Perevoshchikov
# Finish Scraping 8518 players.
# 22979 players remaining.
#
#
# Start Scraping: Armando Javier Boschetti
# Finish Scraping 8519 players.
# 22978 players remaining.
#
#
# Start Scraping: Thomas Shubert
# Finish Scraping 8520 players.
# 22977 players remaining.
#
#
# Start Scraping: Spencer Feldman
# Finish Scraping 8521 players.
# 22976 players remaining.
#
#
# Start Scraping: Patrick Jozwik
# Finish Scraping 8522 players.
# 22975 players remaining.
#
#
# Start Scraping: Kabelo Maleka
# Finish Scraping 8523 players.
# 22974 players remaining.
#
#
# Start Scraping: Nicolas Tholozan
# Finish Scraping 8524 players.
# 22973 players remaining.
#
#
# Start Scraping: Attapol Rithiwattanapong
# Finish Scraping 8525 players.
# 22972 players remaining.
#
#
# Start Scraping: Patrick Mayr
# Finish Scraping 8526 players.
# 22971 players remaining.
#
#
# Start Scraping: Wojtek Stasiak
# Finish Scraping 8527 players.
# 22970 players remaining.
#
#
# Start Scraping: Ivan Lukacs
# Serve Page: 5
# Return Page: 5
# Raw Page: 5
# Finish Scraping 8528 players.
# 22969 players remaining.
#
#
# Start Scraping: Almos Toth
# Finish Scraping 8529 players.
# 22968 players remaining.
#
#
# Start Scraping: Masaki Komura
# Finish Scraping 8530 players.
# 22967 players remaining.
#
#
# Start Scraping: Georgi Arabov
# Finish Scraping 8531 players.
# 22966 players remaining.
#
#
# Start Scraping: Peter Petrovsky
# Finish Scraping 8532 players.
# 22965 players remaining.
#
#
# Start Scraping: Oliver Mayo
# Finish Scraping 8533 players.
# 22964 players remaining.
#
#
# Start Scraping: Alfonso Fernandez Fermoselle
# Finish Scraping 8534 players.
# 22963 players remaining.
#
#
# Start Scraping: Michael Leonard
# Finish Scraping 8535 players.
# 22962 players remaining.
#
#
# Start Scraping: Donni Leaycraft
# Finish Scraping 8536 players.
# 22961 players remaining.
#
#
# Start Scraping: Brent Haygarth
# Finish Scraping 8537 players.
# 22960 players remaining.
#
#
# Start Scraping: Robert Pellizzi
# Finish Scraping 8538 players.
# 22959 players remaining.
#
#
# Start Scraping: Jacques Hervet
# Finish Scraping 8539 players.
# 22958 players remaining.
#
#
# Start Scraping: Lorenzo Fargas
# Finish Scraping 8540 players.
# 22957 players remaining.
#
#
# Start Scraping: Bhanu Nunna
# Finish Scraping 8541 players.
# 22956 players remaining.
#
#
# Start Scraping: Gonzalo Nunez
# Finish Scraping 8542 players.
# 22955 players remaining.
#
#
# Start Scraping: Matei Adrian Georgescu
# Finish Scraping 8543 players.
# 22954 players remaining.
#
#
# Start Scraping: James Ibrahim
# Serve Page: 27
# Return Page: 27
# Raw Page: 27
# Finish Scraping 8544 players.
# 22953 players remaining.
#
#
# Start Scraping: Agustin Suarez Gonzalez
# Finish Scraping 8545 players.
# 22952 players remaining.
#
#
# Start Scraping: Franco Moral
