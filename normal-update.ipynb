# %% [markdown]
# # Normal Updates - Last Update: 2025-01-06

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from geopy.geocoders import Nominatim
import time

# %% [markdown]
# ## 1. Update ATP Ranking

# %% [markdown]
# ### Single Date Update

# %%
# Load txt files
def load_txt(file):
    with open(file, 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    f.close()
    return df

# %%
# The webdesign may change over time!

def scrape_a_date_rank(date, previous):
    # scrape a particular date
    prefix = 'https://www.atptour.com/en/rankings/singles?RankRange=0-100&DateWeek='  # subject to change
    img_pre = 'https://www.atptour.com/en/~/media/images/flags/'

    # open chrome window
    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=1500, height=800)

    # get url
    driver.get(prefix + date)
    # driver.refresh()   # Refreshing can be detected by blockers

    # get content
    print('Start scraping:', date)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    trs = soup.find('table', {'class':'mega-table desktop-table non-live'}).find_all('tr')

    # set attrs
    attrs = ['Date', 'Rank', 'Country', 'Image', 'Player', 'Points']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # date
    dict['Date'] = [date for i in range(100)]

    for tr in trs:
        
        tds = tr.find_all('td')

        if len(tds) == 8: # check error
            # rank
            dict['Rank'].append(tds[0].text.strip())

            # country, image, player name
            lis = tds[1].find_all('li')
            country_abbr = (lis[1].svg.use.get('href', None))[-3:]
            dict['Country'].append(country_abbr.upper())
            dict['Image'].append(img_pre + country_abbr + '.svg')
            dict['Player'].append(lis[2].text.strip())

            # points
            dict['Points'].append(tds[3].text.strip().replace(',', ''))

    # save to txt
    df = pd.DataFrame(dict)
    df.to_csv('m/rank/dates/' + date + '.txt', index = False, sep = ',', encoding='utf-8-sig')
    print('Finished:', date)

    # open the ranking file
    dict_r = load_txt('m/rank/atpranking_20000110_'+previous.replace('-', '')+'.txt').to_dict('list')
    dict_r[date] = []

    # first get points for existing players
    for p in dict_r['Player']:
        found = False
        for i in range(len(dict['Player'])):
            if p == dict['Player'][i]:
                # add new point
                dict_r[date].append(dict['Points'][i])
                found = True
                break
        if not found:
            dict_r[date].append(0)

    # add new player if any
    for p in dict['Player']:
        if p not in dict_r['Player']:
            # add player
            dict_r['Player'].append(p)
            for i in range(len(dict['Player'])):
                if p == dict['Player'][i]:
                    # add country
                    dict_r['Country'].append(dict['Country'][i])
                    # add image
                    dict_r['Country_Image'].append(dict['Image'][i])
                    # add point
                    dict_r[date].append(dict['Points'][i])
                    break
            # add previous points, all 0
            for d in [key for key in dict_r.keys()][3:-1]:
                dict_r[d].append(0)

    # save to txt
    df_new = pd.DataFrame(dict_r)
    df_new.to_csv('m/rank/atpranking_20000110_'+date.replace('-', '')+'.txt', index = False, sep = ',', encoding='utf-8-sig')

# %%
scrape_a_date_rank('2025-01-06', '2024-12-30')
# Out:
# Start scraping: 2025-01-06
# Finished: 2025-01-06

# %% [markdown]
# Remember to add the new dates to dates.txt

# %% [markdown]
# Remember to update rank file in Flourish

# %% [markdown]
# ## 2. Update ATP Links According to New Ranks

# %%
# Define the function to update ATP profile links by ATP Top 100 ranks
def update_link_by_new_rank(dates):
    '''
    dates: a list of dates text
    '''
    # update links according to atp ranking

    prefix = 'https://www.atptour.com/en/rankings/singles?RankRange=0-100&DateWeek='
    head = 'https://www.atptour.com'

    # open txt
    df = load_txt('m/basics/atpprofilebasics.txt')
    pl = [p for p in df['Player']]

    with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
        links = [line[:-1] for line in f]
    f.close()

    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=1500, height=800)

    # date list
    for date in dates:
        driver.get(prefix + date)
        # driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        trs = soup.find('table', {'class':'mega-table desktop-table non-live'}).find_all('tr')
        for tr in trs[1:]:
            tds = tr.find_all('td')
            if len(tds) == 8:
                lis = tds[1].find_all('li')
                if lis[2].text.strip().replace('-', ' ') not in pl:
                    # add new link
                    links.append(head+lis[2].a.get('href'))
                    pl.append(lis[2].text.strip().replace('-', ' '))
                    print('Found:', lis[2].text.strip().replace('-', ' '))
        print('Finish:', date)
    f.close()

    # update links
    with open('m/basics/atpprofilelinks.txt', 'w', encoding='utf-8-sig') as f:
        for link in set(links):
            if link != '':
                f.write(link)
                f.write('\n')
    f.close()

# %%
update_link_by_new_rank(["2025-01-06"])
# Out:
# Finish: 2025-01-06

# %% [markdown]
# ## 3. Update ATP Profile Information

# %%
# Update new basics based on new links in atprofilelinks
# Website design may change

with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
    links = [line[:-1] for line in f]
f.close()

dict = load_txt('m/basics/atpprofilebasics.txt').to_dict('list')

chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)

for i, link in enumerate(links):
    if link not in dict['ATP Link']:
        driver.get(link)
        # driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        # add name
        try:
            dict['Player'].append(soup.find('div', {'class': 'player_name'}).text.strip().replace('-', ' '))
        except:
            print(link, 'not found')
            break
        # add link
        dict['ATP Link'].append(link)
        # add birthday
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Birthday'].append(lis[0].find_all('span')[1].text.split('(')[1][:-1].replace('.', '-'))
        except:
            dict['Birthday'].append('')
        # add birthplace
        try:
            lis = soup.find('ul', {'class': 'pd_right'}).find_all('li')
            birthplace = lis[1].find_all('span')[1].text.replace(', ', ' - ')
        except:
            birthplace = ''
        dict['Birthplace'].append(birthplace)
        # add plays
        try:
            lis = soup.find('ul', {'class': 'pd_right'}).find_all('li')
            dict['Plays'].append(lis[2].find_all('span')[1].text.replace(', ', ' - '))
        except:
            dict['Plays'].append('')
        # add turned pro
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Turned Pro'].append(lis[3].find_all('span')[1].text)
        except:
            dict['Turned Pro'].append('')
        # add weight
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Weight (kg)'].append(lis[1].find_all('span')[1].text.split('(')[1][:-3])
        except:
            dict['Weight (kg)'].append('')
        # add height
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Height (cm)'].append(lis[2].find_all('span')[1].text.split('(')[1][:-3])
        except:
            dict['Height (cm)'].append('')
        print('Finished:', i+1)

        # add birthplace details, matched region, lat, lon
        geolocator = Nominatim(user_agent='tennis-vis')
        try:
            location = geolocator.geocode(birthplace)
            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
            dict['Birthplace_lat'].append(location.latitude)
            dict['Birthplace_lon'].append(location.longitude)
            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
        except:
            try:
                location = geolocator.geocode(birthplace.split(',')[0]+','+birthplace.split(',')[1])
                dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                dict['Birthplace_lat'].append(location.latitude)
                dict['Birthplace_lon'].append(location.longitude)
                print(location.address.replace(',', ' -'), location.latitude, location.longitude)
            except:
                try:
                    location = geolocator.geocode(birthplace.split(',')[0])
                    dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                    dict['Birthplace_lat'].append(location.latitude)
                    dict['Birthplace_lon'].append(location.longitude)
                    print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                except:
                    try:
                        location = geolocator.geocode(birthplace.split(',')[1])
                        dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                        dict['Birthplace_lat'].append(location.latitude)
                        dict['Birthplace_lon'].append(location.longitude)
                        print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                    except:
                        try:
                            location = geolocator.geocode(birthplace.split(',')[2])
                            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                            dict['Birthplace_lat'].append(location.latitude)
                            dict['Birthplace_lon'].append(location.longitude)
                            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                        except:
                            dict['Birthplace_matched'].append('')
                            dict['Birthplace_lat'].append('')
                            dict['Birthplace_lon'].append('')
                            print('','','')

df = pd.DataFrame(dict)
df.to_csv('m/basics/atpprofilebasics.txt', index = False, sep = ',', encoding='utf-8-sig')
# Out:
# Finished: 1513
# Busto Arsizio - Varese - Lombardia - 21052 - Italia 45.611932 8.8518269

# %% [markdown]
# ## 4. Update ATP TOP 100 Distribution

# %%
# Define the function to update Geo distribution of ATP Top 100 players
def update_geo_atp100(date,num):
    # get basics
    df_basics = load_txt('m/basics/atpprofilebasics.txt')

    # set basic dict
    attrs = ['Start', 'End', 'Player', 'Rank', 'Points', 'Birthplace', 'Lat', 'Lon']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # get dates
    dates = []
    with open('m/rank/dates.txt', 'r') as f:
        for date in f:
            dates.append(date[:-1])
    f.close()

    # Start looping
    for k, date in enumerate([dates[num - i - 1] for i in range(num)]):
        df_rank = load_txt('m/rank/dates/'+date+'.txt')
        for i, p in enumerate(df_rank['Player']):
            for j, r in enumerate(df_basics['Player']):
                if p.replace('-', ' ') == r and k != (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append(dates[num - k - 2])
                    except:
                        pass
                    break
                if p.replace('-', ' ') == r and k == (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append('')
                    except:
                        pass
                    break

        print('Finished:', date)

    df = pd.DataFrame(dict)

    # Save csv
    df.to_csv('m/rank/atp100geo20000110_'+date.replace("-","")+'.txt', index = False, sep = ',', encoding = 'utf-8-sig')

# %%
# num = Row Number of "2000-01-10" in date.txt file
update_geo_atp100("2025-01-06", 1198)
# Out:
# Finished: 2000-01-10
# Finished: 2000-01-17
# Finished: 2000-01-24
# Finished: 2000-01-31
# Finished: 2000-02-07
# Finished: 2000-02-14
# Finished: 2000-02-21
# Finished: 2000-02-28
# Finished: 2000-03-06
# Finished: 2000-03-13
# Finished: 2000-03-20
# Finished: 2000-03-27
# Finished: 2000-04-03
# Finished: 2000-04-10
# Finished: 2000-04-17
# Finished: 2000-04-24
# Finished: 2000-05-01
# Finished: 2000-05-08
# Finished: 2000-05-15
# Finished: 2000-05-22
# Finished: 2000-05-29
# Finished: 2000-06-05
# Finished: 2000-06-12
# Finished: 2000-06-19
# Finished: 2000-06-26
# Finished: 2000-07-03
# Finished: 2000-07-10
# Finished: 2000-07-17
# Finished: 2000-07-24
# Finished: 2000-07-31
# Finished: 2000-08-07
# Finished: 2000-08-14
# Finished: 2000-08-21
# Finished: 2000-08-28
# Finished: 2000-09-04
# Finished: 2000-09-11
# Finished: 2000-09-18
# Finished: 2000-09-25
# Finished: 2000-10-02
# Finished: 2000-10-09
# Finished: 2000-10-16
# Finished: 2000-10-23
# Finished: 2000-10-30
# Finished: 2000-11-06
# Finished: 2000-11-13
# Finished: 2000-11-20
# Finished: 2000-11-27
# Finished: 2000-12-04
# Finished: 2000-12-11
# Finished: 2000-12-18
# Finished: 2000-12-25
# Finished: 2001-01-01
# Finished: 2001-01-08
# Finished: 2001-01-15
# Finished: 2001-01-22
# Finished: 2001-01-29
# Finished: 2001-02-05
# Finished: 2001-02-12
# Finished: 2001-02-19
# Finished: 2001-02-26
# Finished: 2001-03-05
# Finished: 2001-03-12
# Finished: 2001-03-19
# Finished: 2001-03-26
# Finished: 2001-04-02
# Finished: 2001-04-09
# Finished: 2001-04-16
# Finished: 2001-04-23
# Finished: 2001-04-30
# Finished: 2001-05-07
# Finished: 2001-05-14
# Finished: 2001-05-21
# Finished: 2001-05-28
# Finished: 2001-06-04
# Finished: 2001-06-11
# Finished: 2001-06-18
# Finished: 2001-06-25
# Finished: 2001-07-02
# Finished: 2001-07-09
# Finished: 2001-07-16
# Finished: 2001-07-23
# Finished: 2001-07-30
# Finished: 2001-08-06
# Finished: 2001-08-13
# Finished: 2001-08-20
# Finished: 2001-08-27
# Finished: 2001-09-03
# Finished: 2001-09-10
# Finished: 2001-09-17
# Finished: 2001-09-24
# Finished: 2001-10-01
# Finished: 2001-10-08
# Finished: 2001-10-15
# Finished: 2001-10-22
# Finished: 2001-10-29
# Finished: 2001-11-05
# Finished: 2001-11-12
# Finished: 2001-11-19
# Finished: 2001-11-26
# Finished: 2001-12-03
# Finished: 2001-12-10
# Finished: 2001-12-17
# Finished: 2001-12-24
# Finished: 2001-12-31
# Finished: 2002-01-07
# Finished: 2002-01-14
# Finished: 2002-01-21
# Finished: 2002-01-28
# Finished: 2002-02-04
# Finished: 2002-02-11
# Finished: 2002-02-18
# Finished: 2002-02-25
# Finished: 2002-03-04
# Finished: 2002-03-11
# Finished: 2002-03-18
# Finished: 2002-03-25
# Finished: 2002-04-01
# Finished: 2002-04-08
# Finished: 2002-04-15
# Finished: 2002-04-22
# Finished: 2002-04-29
# Finished: 2002-05-06
# Finished: 2002-05-13
# Finished: 2002-05-20
# Finished: 2002-05-27
# Finished: 2002-06-03
# Finished: 2002-06-10
# Finished: 2002-06-17
# Finished: 2002-06-24
# Finished: 2002-07-01
# Finished: 2002-07-08
# Finished: 2002-07-15
# Finished: 2002-07-22
# Finished: 2002-07-29
# Finished: 2002-08-05
# Finished: 2002-08-12
# Finished: 2002-08-19
# Finished: 2002-08-26
# Finished: 2002-09-02
# Finished: 2002-09-09
# Finished: 2002-09-16
# Finished: 2002-09-23
# Finished: 2002-09-30
# Finished: 2002-10-07
# Finished: 2002-10-14
# Finished: 2002-10-21
# Finished: 2002-10-28
# Finished: 2002-11-04
# Finished: 2002-11-11
# Finished: 2002-11-18
# Finished: 2002-11-25
# Finished: 2002-12-02
# Finished: 2002-12-09
# Finished: 2002-12-16
# Finished: 2002-12-23
# Finished: 2002-12-30
# Finished: 2003-01-06
# Finished: 2003-01-13
# Finished: 2003-01-20
# Finished: 2003-01-27
# Finished: 2003-02-03
# Finished: 2003-02-10
# Finished: 2003-02-17
# Finished: 2003-02-24
# Finished: 2003-03-03
# Finished: 2003-03-10
# Finished: 2003-03-17
# Finished: 2003-03-24
# Finished: 2003-03-31
# Finished: 2003-04-07
# Finished: 2003-04-14
# Finished: 2003-04-21
# Finished: 2003-04-28
# Finished: 2003-05-05
# Finished: 2003-05-12
# Finished: 2003-05-19
# Finished: 2003-05-26
# Finished: 2003-06-02
# Finished: 2003-06-09
# Finished: 2003-06-16
# Finished: 2003-06-23
# Finished: 2003-06-30
# Finished: 2003-07-07
# Finished: 2003-07-14
# Finished: 2003-07-21
# Finished: 2003-07-28
# Finished: 2003-08-04
# Finished: 2003-08-11
# Finished: 2003-08-18
# Finished: 2003-08-25
# Finished: 2003-09-01
# Finished: 2003-09-08
# Finished: 2003-09-15
# Finished: 2003-09-22
# Finished: 2003-09-29
# Finished: 2003-10-06
# Finished: 2003-10-13
# Finished: 2003-10-20
# Finished: 2003-10-27
# Finished: 2003-11-03
# Finished: 2003-11-10
# Finished: 2003-11-17
# Finished: 2003-11-24
# Finished: 2003-12-01
# Finished: 2003-12-08
# Finished: 2003-12-15
# Finished: 2003-12-22
# Finished: 2003-12-29
# Finished: 2004-01-05
# Finished: 2004-01-12
# Finished: 2004-01-19
# Finished: 2004-01-26
# Finished: 2004-02-02
# Finished: 2004-02-09
# Finished: 2004-02-16
# Finished: 2004-02-23
# Finished: 2004-03-01
# Finished: 2004-03-08
# Finished: 2004-03-15
# Finished: 2004-03-22
# Finished: 2004-03-29
# Finished: 2004-04-05
# Finished: 2004-04-12
# Finished: 2004-04-19
# Finished: 2004-04-26
# Finished: 2004-05-03
# Finished: 2004-05-10
# Finished: 2004-05-17
# Finished: 2004-05-24
# Finished: 2004-05-31
# Finished: 2004-06-07
# Finished: 2004-06-14
# Finished: 2004-06-21
# Finished: 2004-06-28
# Finished: 2004-07-05
# Finished: 2004-07-12
# Finished: 2004-07-19
# Finished: 2004-07-26
# Finished: 2004-08-02
# Finished: 2004-08-09
# Finished: 2004-08-16
# Finished: 2004-08-23
# Finished: 2004-08-30
# Finished: 2004-09-06
# Finished: 2004-09-13
# Finished: 2004-09-20
# Finished: 2004-09-27
# Finished: 2004-10-04
# Finished: 2004-10-11
# Finished: 2004-10-18
# Finished: 2004-10-25
# Finished: 2004-11-01
# Finished: 2004-11-08
# Finished: 2004-11-15
# Finished: 2004-11-22
# Finished: 2004-11-29
# Finished: 2004-12-06
# Finished: 2004-12-13
# Finished: 2004-12-20
# Finished: 2004-12-27
# Finished: 2005-01-03
# Finished: 2005-01-10
# Finished: 2005-01-17
# Finished: 2005-01-24
# Finished: 2005-01-31
# Finished: 2005-02-07
# Finished: 2005-02-14
# Finished: 2005-02-21
# Finished: 2005-02-28
# Finished: 2005-03-07
# Finished: 2005-03-14
# Finished: 2005-03-21
# Finished: 2005-03-28
# Finished: 2005-04-04
# Finished: 2005-04-11
# Finished: 2005-04-18
# Finished: 2005-04-25
# Finished: 2005-05-02
# Finished: 2005-05-09
# Finished: 2005-05-16
# Finished: 2005-05-23
# Finished: 2005-05-30
# Finished: 2005-06-06
# Finished: 2005-06-13
# Finished: 2005-06-20
# Finished: 2005-06-27
# Finished: 2005-07-04
# Finished: 2005-07-11
# Finished: 2005-07-18
# Finished: 2005-07-25
# Finished: 2005-08-01
# Finished: 2005-08-08
# Finished: 2005-08-15
# Finished: 2005-08-22
# Finished: 2005-08-29
# Finished: 2005-09-05
# Finished: 2005-09-12
# Finished: 2005-09-19
# Finished: 2005-09-26
# Finished: 2005-10-03
# Finished: 2005-10-10
# Finished: 2005-10-17
# Finished: 2005-10-24
# Finished: 2005-10-31
# Finished: 2005-11-07
# Finished: 2005-11-14
# Finished: 2005-11-21
# Finished: 2005-11-28
# Finished: 2005-12-05
# Finished: 2005-12-12
# Finished: 2005-12-19
# Finished: 2005-12-26
# Finished: 2006-01-02
# Finished: 2006-01-09
# Finished: 2006-01-16
# Finished: 2006-01-23
# Finished: 2006-01-30
# Finished: 2006-02-06
# Finished: 2006-02-13
# Finished: 2006-02-20
# Finished: 2006-02-27
# Finished: 2006-03-06
# Finished: 2006-03-13
# Finished: 2006-03-20
# Finished: 2006-03-27
# Finished: 2006-04-03
# Finished: 2006-04-10
# Finished: 2006-04-17
# Finished: 2006-04-24
# Finished: 2006-05-01
# Finished: 2006-05-08
# Finished: 2006-05-15
# Finished: 2006-05-22
# Finished: 2006-05-29
# Finished: 2006-06-05
# Finished: 2006-06-12
# Finished: 2006-06-19
# Finished: 2006-06-26
# Finished: 2006-07-03
# Finished: 2006-07-10
# Finished: 2006-07-17
# Finished: 2006-07-24
# Finished: 2006-07-31
# Finished: 2006-08-07
# Finished: 2006-08-14
# Finished: 2006-08-21
# Finished: 2006-08-28
# Finished: 2006-09-04
# Finished: 2006-09-11
# Finished: 2006-09-18
# Finished: 2006-09-25
# Finished: 2006-10-02
# Finished: 2006-10-09
# Finished: 2006-10-16
# Finished: 2006-10-23
# Finished: 2006-10-30
# Finished: 2006-11-06
# Finished: 2006-11-13
# Finished: 2006-11-20
# Finished: 2006-11-27
# Finished: 2006-12-04
# Finished: 2006-12-11
# Finished: 2006-12-18
# Finished: 2006-12-25
# Finished: 2007-01-01
# Finished: 2007-01-08
# Finished: 2007-01-15
# Finished: 2007-01-22
# Finished: 2007-01-29
# Finished: 2007-02-05
# Finished: 2007-02-12
# Finished: 2007-02-19
# Finished: 2007-02-26
# Finished: 2007-03-05
# Finished: 2007-03-12
# Finished: 2007-03-19
# Finished: 2007-03-26
# Finished: 2007-04-02
# Finished: 2007-04-09
# Finished: 2007-04-16
# Finished: 2007-04-23
# Finished: 2007-04-30
# Finished: 2007-05-07
# Finished: 2007-05-14
# Finished: 2007-05-21
# Finished: 2007-05-28
# Finished: 2007-06-04
# Finished: 2007-06-11
# Finished: 2007-06-18
# Finished: 2007-06-25
# Finished: 2007-07-02
# Finished: 2007-07-09
# Finished: 2007-07-16
# Finished: 2007-07-23
# Finished: 2007-07-30
# Finished: 2007-08-06
# Finished: 2007-08-13
# Finished: 2007-08-20
# Finished: 2007-08-27
# Finished: 2007-09-03
# Finished: 2007-09-10
# Finished: 2007-09-17
# Finished: 2007-09-24
# Finished: 2007-10-01
# Finished: 2007-10-08
# Finished: 2007-10-15
# Finished: 2007-10-22
# Finished: 2007-10-29
# Finished: 2007-11-05
# Finished: 2007-11-12
# Finished: 2007-11-19
# Finished: 2007-11-26
# Finished: 2007-12-03
# Finished: 2007-12-10
# Finished: 2007-12-17
# Finished: 2007-12-24
# Finished: 2007-12-31
# Finished: 2008-01-07
# Finished: 2008-01-14
# Finished: 2008-01-21
# Finished: 2008-01-28
# Finished: 2008-02-04
# Finished: 2008-02-11
# Finished: 2008-02-18
# Finished: 2008-02-25
# Finished: 2008-03-03
# Finished: 2008-03-10
# Finished: 2008-03-17
# Finished: 2008-03-24
# Finished: 2008-03-31
# Finished: 2008-04-07
# Finished: 2008-04-14
# Finished: 2008-04-21
# Finished: 2008-04-28
# Finished: 2008-05-05
# Finished: 2008-05-12
# Finished: 2008-05-19
# Finished: 2008-05-26
# Finished: 2008-06-02
# Finished: 2008-06-09
# Finished: 2008-06-16
# Finished: 2008-06-23
# Finished: 2008-06-30
# Finished: 2008-07-07
# Finished: 2008-07-14
# Finished: 2008-07-21
# Finished: 2008-07-28
# Finished: 2008-08-04
# Finished: 2008-08-11
# Finished: 2008-08-18
# Finished: 2008-08-25
# Finished: 2008-09-01
# Finished: 2008-09-08
# Finished: 2008-09-15
# Finished: 2008-09-22
# Finished: 2008-09-29
# Finished: 2008-10-06
# Finished: 2008-10-13
# Finished: 2008-10-20
# Finished: 2008-10-27
# Finished: 2008-11-03
# Finished: 2008-11-10
# Finished: 2008-11-17
# Finished: 2008-11-24
# Finished: 2008-12-01
# Finished: 2008-12-08
# Finished: 2008-12-15
# Finished: 2008-12-22
# Finished: 2008-12-29
# Finished: 2009-01-05
# Finished: 2009-01-12
# Finished: 2009-01-19
# Finished: 2009-01-26
# Finished: 2009-02-02
# Finished: 2009-02-09
# Finished: 2009-02-16
# Finished: 2009-02-23
# Finished: 2009-03-02
# Finished: 2009-03-09
# Finished: 2009-03-16
# Finished: 2009-03-23
# Finished: 2009-03-30
# Finished: 2009-04-06
# Finished: 2009-04-13
# Finished: 2009-04-20
# Finished: 2009-04-27
# Finished: 2009-05-04
# Finished: 2009-05-11
# Finished: 2009-05-18
# Finished: 2009-05-25
# Finished: 2009-06-01
# Finished: 2009-06-08
# Finished: 2009-06-15
# Finished: 2009-06-22
# Finished: 2009-06-29
# Finished: 2009-07-06
# Finished: 2009-07-13
# Finished: 2009-07-20
# Finished: 2009-07-27
# Finished: 2009-08-03
# Finished: 2009-08-10
# Finished: 2009-08-17
# Finished: 2009-08-24
# Finished: 2009-08-31
# Finished: 2009-09-07
# Finished: 2009-09-14
# Finished: 2009-09-21
# Finished: 2009-09-28
# Finished: 2009-10-05
# Finished: 2009-10-12
# Finished: 2009-10-19
# Finished: 2009-10-26
# Finished: 2009-11-02
# Finished: 2009-11-09
# Finished: 2009-11-16
# Finished: 2009-11-23
# Finished: 2009-11-30
# Finished: 2009-12-07
# Finished: 2009-12-14
# Finished: 2009-12-21
# Finished: 2009-12-28
# Finished: 2010-01-04
# Finished: 2010-01-11
# Finished: 2010-01-18
# Finished: 2010-01-25
# Finished: 2010-02-01
# Finished: 2010-02-08
# Finished: 2010-02-15
# Finished: 2010-02-22
# Finished: 2010-03-01
# Finished: 2010-03-08
# Finished: 2010-03-15
# Finished: 2010-03-22
# Finished: 2010-03-29
# Finished: 2010-04-05
# Finished: 2010-04-12
# Finished: 2010-04-19
# Finished: 2010-04-26
# Finished: 2010-05-03
# Finished: 2010-05-10
# Finished: 2010-05-17
# Finished: 2010-05-24
# Finished: 2010-05-31
# Finished: 2010-06-07
# Finished: 2010-06-14
# Finished: 2010-06-21
# Finished: 2010-06-28
# Finished: 2010-07-05
# Finished: 2010-07-12
# Finished: 2010-07-19
# Finished: 2010-07-26
# Finished: 2010-08-02
# Finished: 2010-08-09
# Finished: 2010-08-16
# Finished: 2010-08-23
# Finished: 2010-08-30
# Finished: 2010-09-06
# Finished: 2010-09-13
# Finished: 2010-09-20
# Finished: 2010-09-27
# Finished: 2010-10-04
# Finished: 2010-10-11
# Finished: 2010-10-18
# Finished: 2010-10-25
# Finished: 2010-11-01
# Finished: 2010-11-08
# Finished: 2010-11-15
# Finished: 2010-11-22
# Finished: 2010-11-29
# Finished: 2010-12-06
# Finished: 2010-12-13
# Finished: 2010-12-20
# Finished: 2010-12-27
# Finished: 2011-01-03
# Finished: 2011-01-10
# Finished: 2011-01-17
# Finished: 2011-01-31
# Finished: 2011-02-07
# Finished: 2011-02-14
# Finished: 2011-02-21
# Finished: 2011-02-28
# Finished: 2011-03-07
# Finished: 2011-03-21
# Finished: 2011-04-04
# Finished: 2011-04-11
# Finished: 2011-04-18
# Finished: 2011-04-25
# Finished: 2011-05-02
# Finished: 2011-05-09
# Finished: 2011-05-16
# Finished: 2011-05-23
# Finished: 2011-06-06
# Finished: 2011-06-13
# Finished: 2011-06-20
# Finished: 2011-07-04
# Finished: 2011-07-11
# Finished: 2011-07-18
# Finished: 2011-07-25
# Finished: 2011-08-01
# Finished: 2011-08-08
# Finished: 2011-08-15
# Finished: 2011-08-22
# Finished: 2011-08-29
# Finished: 2011-09-12
# Finished: 2011-09-19
# Finished: 2011-09-26
# Finished: 2011-10-03
# Finished: 2011-10-10
# Finished: 2011-10-17
# Finished: 2011-10-24
# Finished: 2011-10-31
# Finished: 2011-11-07
# Finished: 2011-11-14
# Finished: 2011-11-21
# Finished: 2011-11-28
# Finished: 2011-12-05
# Finished: 2011-12-12
# Finished: 2011-12-19
# Finished: 2011-12-26
# Finished: 2012-01-02
# Finished: 2012-01-09
# Finished: 2012-01-16
# Finished: 2012-01-30
# Finished: 2012-02-06
# Finished: 2012-02-13
# Finished: 2012-02-20
# Finished: 2012-02-27
# Finished: 2012-03-05
# Finished: 2012-03-19
# Finished: 2012-04-02
# Finished: 2012-04-09
# Finished: 2012-04-16
# Finished: 2012-04-23
# Finished: 2012-04-30
# Finished: 2012-05-07
# Finished: 2012-05-14
# Finished: 2012-05-21
# Finished: 2012-05-28
# Finished: 2012-06-11
# Finished: 2012-06-18
# Finished: 2012-06-25
# Finished: 2012-07-09
# Finished: 2012-07-16
# Finished: 2012-07-23
# Finished: 2012-07-30
# Finished: 2012-08-06
# Finished: 2012-08-13
# Finished: 2012-08-20
# Finished: 2012-08-27
# Finished: 2012-09-10
# Finished: 2012-09-17
# Finished: 2012-09-24
# Finished: 2012-10-01
# Finished: 2012-10-08
# Finished: 2012-10-15
# Finished: 2012-10-22
# Finished: 2012-10-29
# Finished: 2012-11-05
# Finished: 2012-11-12
# Finished: 2012-11-19
# Finished: 2012-11-26
# Finished: 2012-12-03
# Finished: 2012-12-10
# Finished: 2012-12-17
# Finished: 2012-12-24
# Finished: 2012-12-31
# Finished: 2013-01-07
# Finished: 2013-01-14
# Finished: 2013-01-28
# Finished: 2013-02-04
# Finished: 2013-02-11
# Finished: 2013-02-18
# Finished: 2013-02-25
# Finished: 2013-03-04
# Finished: 2013-03-18
# Finished: 2013-04-01
# Finished: 2013-04-08
# Finished: 2013-04-15
# Finished: 2013-04-22
# Finished: 2013-04-29
# Finished: 2013-05-06
# Finished: 2013-05-13
# Finished: 2013-05-20
# Finished: 2013-05-27
# Finished: 2013-06-10
# Finished: 2013-06-17
# Finished: 2013-06-24
# Finished: 2013-07-08
# Finished: 2013-07-15
# Finished: 2013-07-22
# Finished: 2013-07-29
# Finished: 2013-08-05
# Finished: 2013-08-12
# Finished: 2013-08-19
# Finished: 2013-08-26
# Finished: 2013-09-09
# Finished: 2013-09-16
# Finished: 2013-09-23
# Finished: 2013-09-30
# Finished: 2013-10-07
# Finished: 2013-10-14
# Finished: 2013-10-21
# Finished: 2013-10-28
# Finished: 2013-11-04
# Finished: 2013-11-11
# Finished: 2013-11-18
# Finished: 2013-11-25
# Finished: 2013-12-02
# Finished: 2013-12-09
# Finished: 2013-12-16
# Finished: 2013-12-23
# Finished: 2013-12-30
# Finished: 2014-01-06
# Finished: 2014-01-13
# Finished: 2014-01-27
# Finished: 2014-02-03
# Finished: 2014-02-10
# Finished: 2014-02-17
# Finished: 2014-02-24
# Finished: 2014-03-03
# Finished: 2014-03-17
# Finished: 2014-03-31
# Finished: 2014-04-07
# Finished: 2014-04-14
# Finished: 2014-04-21
# Finished: 2014-04-28
# Finished: 2014-05-05
# Finished: 2014-05-12
# Finished: 2014-05-19
# Finished: 2014-05-26
# Finished: 2014-06-09
# Finished: 2014-06-16
# Finished: 2014-06-23
# Finished: 2014-07-07
# Finished: 2014-07-14
# Finished: 2014-07-21
# Finished: 2014-07-28
# Finished: 2014-08-04
# Finished: 2014-08-11
# Finished: 2014-08-18
# Finished: 2014-08-25
# Finished: 2014-09-08
# Finished: 2014-09-15
# Finished: 2014-09-22
# Finished: 2014-09-29
# Finished: 2014-10-06
# Finished: 2014-10-13
# Finished: 2014-10-20
# Finished: 2014-10-27
# Finished: 2014-11-03
# Finished: 2014-11-10
# Finished: 2014-11-17
# Finished: 2014-11-24
# Finished: 2014-12-01
# Finished: 2014-12-08
# Finished: 2014-12-15
# Finished: 2014-12-22
# Finished: 2014-12-29
# Finished: 2015-01-05
# Finished: 2015-01-12
# Finished: 2015-01-19
# Finished: 2015-02-02
# Finished: 2015-02-09
# Finished: 2015-02-16
# Finished: 2015-02-23
# Finished: 2015-03-02
# Finished: 2015-03-09
# Finished: 2015-03-23
# Finished: 2015-04-06
# Finished: 2015-04-13
# Finished: 2015-04-20
# Finished: 2015-04-27
# Finished: 2015-05-04
# Finished: 2015-05-11
# Finished: 2015-05-18
# Finished: 2015-05-25
# Finished: 2015-06-08
# Finished: 2015-06-15
# Finished: 2015-06-22
# Finished: 2015-06-29
# Finished: 2015-07-13
# Finished: 2015-07-20
# Finished: 2015-07-27
# Finished: 2015-08-03
# Finished: 2015-08-10
# Finished: 2015-08-17
# Finished: 2015-08-24
# Finished: 2015-08-31
# Finished: 2015-09-14
# Finished: 2015-09-21
# Finished: 2015-09-28
# Finished: 2015-10-05
# Finished: 2015-10-12
# Finished: 2015-10-19
# Finished: 2015-10-26
# Finished: 2015-11-02
# Finished: 2015-11-09
# Finished: 2015-11-16
# Finished: 2015-11-23
# Finished: 2015-11-30
# Finished: 2015-12-07
# Finished: 2015-12-14
# Finished: 2015-12-21
# Finished: 2015-12-28
# Finished: 2016-01-04
# Finished: 2016-01-11
# Finished: 2016-01-18
# Finished: 2016-02-01
# Finished: 2016-02-08
# Finished: 2016-02-15
# Finished: 2016-02-22
# Finished: 2016-02-29
# Finished: 2016-03-07
# Finished: 2016-03-21
# Finished: 2016-04-04
# Finished: 2016-04-11
# Finished: 2016-04-18
# Finished: 2016-04-25
# Finished: 2016-05-02
# Finished: 2016-05-09
# Finished: 2016-05-16
# Finished: 2016-05-23
# Finished: 2016-06-06
# Finished: 2016-06-13
# Finished: 2016-06-20
# Finished: 2016-06-27
# Finished: 2016-07-11
# Finished: 2016-07-18
# Finished: 2016-07-25
# Finished: 2016-08-01
# Finished: 2016-08-08
# Finished: 2016-08-15
# Finished: 2016-08-22
# Finished: 2016-08-29
# Finished: 2016-09-12
# Finished: 2016-09-19
# Finished: 2016-09-26
# Finished: 2016-10-03
# Finished: 2016-10-10
# Finished: 2016-10-17
# Finished: 2016-10-24
# Finished: 2016-10-31
# Finished: 2016-11-07
# Finished: 2016-11-14
# Finished: 2016-11-21
# Finished: 2016-11-28
# Finished: 2016-12-05
# Finished: 2016-12-12
# Finished: 2016-12-19
# Finished: 2016-12-26
# Finished: 2017-01-02
# Finished: 2017-01-09
# Finished: 2017-01-16
# Finished: 2017-01-30
# Finished: 2017-02-06
# Finished: 2017-02-13
# Finished: 2017-02-20
# Finished: 2017-02-27
# Finished: 2017-03-06
# Finished: 2017-03-20
# Finished: 2017-04-03
# Finished: 2017-04-10
# Finished: 2017-04-17
# Finished: 2017-04-24
# Finished: 2017-05-01
# Finished: 2017-05-08
# Finished: 2017-05-15
# Finished: 2017-05-22
# Finished: 2017-05-29
# Finished: 2017-06-12
# Finished: 2017-06-19
# Finished: 2017-06-26
# Finished: 2017-07-03
# Finished: 2017-07-10
# Finished: 2017-07-17
# Finished: 2017-07-24
# Finished: 2017-07-31
# Finished: 2017-08-07
# Finished: 2017-08-14
# Finished: 2017-08-21
# Finished: 2017-08-28
# Finished: 2017-09-11
# Finished: 2017-09-18
# Finished: 2017-09-25
# Finished: 2017-10-02
# Finished: 2017-10-09
# Finished: 2017-10-16
# Finished: 2017-10-23
# Finished: 2017-10-30
# Finished: 2017-11-06
# Finished: 2017-11-13
# Finished: 2017-11-20
# Finished: 2017-11-27
# Finished: 2017-12-04
# Finished: 2017-12-11
# Finished: 2017-12-18
# Finished: 2017-12-25
# Finished: 2018-01-01
# Finished: 2018-01-08
# Finished: 2018-01-15
# Finished: 2018-01-29
# Finished: 2018-02-05
# Finished: 2018-02-12
# Finished: 2018-02-19
# Finished: 2018-02-26
# Finished: 2018-03-05
# Finished: 2018-03-19
# Finished: 2018-04-02
# Finished: 2018-04-09
# Finished: 2018-04-16
# Finished: 2018-04-23
# Finished: 2018-04-30
# Finished: 2018-05-07
# Finished: 2018-05-14
# Finished: 2018-05-21
# Finished: 2018-05-28
# Finished: 2018-06-11
# Finished: 2018-06-18
# Finished: 2018-06-25
# Finished: 2018-07-02
# Finished: 2018-07-16
# Finished: 2018-07-23
# Finished: 2018-07-30
# Finished: 2018-08-06
# Finished: 2018-08-13
# Finished: 2018-08-20
# Finished: 2018-08-27
# Finished: 2018-09-10
# Finished: 2018-09-17
# Finished: 2018-09-24
# Finished: 2018-10-01
# Finished: 2018-10-08
# Finished: 2018-10-15
# Finished: 2018-10-22
# Finished: 2018-10-29
# Finished: 2018-11-05
# Finished: 2018-11-12
# Finished: 2018-11-19
# Finished: 2018-11-26
# Finished: 2018-12-03
# Finished: 2018-12-10
# Finished: 2018-12-17
# Finished: 2018-12-24
# Finished: 2018-12-31
# Finished: 2019-01-07
# Finished: 2019-01-14
# Finished: 2019-01-28
# Finished: 2019-02-04
# Finished: 2019-02-11
# Finished: 2019-02-18
# Finished: 2019-02-25
# Finished: 2019-03-04
# Finished: 2019-03-11
# Finished: 2019-03-18
# Finished: 2019-04-01
# Finished: 2019-04-08
# Finished: 2019-04-15
# Finished: 2019-04-22
# Finished: 2019-04-29
# Finished: 2019-05-06
# Finished: 2019-05-13
# Finished: 2019-05-20
# Finished: 2019-05-27
# Finished: 2019-06-10
# Finished: 2019-06-17
# Finished: 2019-06-24
# Finished: 2019-07-01
# Finished: 2019-07-15
# Finished: 2019-07-22
# Finished: 2019-07-29
# Finished: 2019-08-05
# Finished: 2019-08-12
# Finished: 2019-08-19
# Finished: 2019-08-26
# Finished: 2019-09-09
# Finished: 2019-09-16
# Finished: 2019-09-23
# Finished: 2019-09-30
# Finished: 2019-10-07
# Finished: 2019-10-14
# Finished: 2019-10-21
# Finished: 2019-10-28
# Finished: 2019-11-04
# Finished: 2019-11-11
# Finished: 2019-11-18
# Finished: 2019-11-25
# Finished: 2019-12-02
# Finished: 2019-12-09
# Finished: 2019-12-16
# Finished: 2019-12-23
# Finished: 2019-12-30
# Finished: 2020-01-06
# Finished: 2020-01-13
# Finished: 2020-01-20
# Finished: 2020-02-03
# Finished: 2020-02-10
# Finished: 2020-02-17
# Finished: 2020-02-24
# Finished: 2020-03-02
# Finished: 2020-03-09
# Finished: 2020-03-16
# Finished: 2020-08-24
# Finished: 2020-08-31
# Finished: 2020-09-14
# Finished: 2020-09-21
# Finished: 2020-09-28
# Finished: 2020-10-12
# Finished: 2020-10-19
# Finished: 2020-10-26
# Finished: 2020-11-02
# Finished: 2020-11-09
# Finished: 2020-11-16
# Finished: 2020-11-23
# Finished: 2020-11-30
# Finished: 2020-12-07
# Finished: 2020-12-14
# Finished: 2020-12-21
# Finished: 2020-12-28
# Finished: 2021-01-04
# Finished: 2021-01-11
# Finished: 2021-01-18
# Finished: 2021-01-25
# Finished: 2021-02-01
# Finished: 2021-02-08
# Finished: 2021-02-22
# Finished: 2021-03-01
# Finished: 2021-03-08
# Finished: 2021-03-15
# Finished: 2021-03-22
# Finished: 2021-04-05
# Finished: 2021-04-12
# Finished: 2021-04-19
# Finished: 2021-04-26
# Finished: 2021-05-03
# Finished: 2021-05-10
# Finished: 2021-05-17
# Finished: 2021-05-24
# Finished: 2021-05-31
# Finished: 2021-06-14
# Finished: 2021-06-21
# Finished: 2021-06-28
# Finished: 2021-07-12
# Finished: 2021-07-19
# Finished: 2021-07-26
# Finished: 2021-08-02
# Finished: 2021-08-09
# Finished: 2021-08-16
# Finished: 2021-08-23
# Finished: 2021-08-30
# Finished: 2021-09-13
# Finished: 2021-09-20
# Finished: 2021-09-27
# Finished: 2021-10-04
# Finished: 2021-10-18
# Finished: 2021-10-25
# Finished: 2021-11-01
# Finished: 2021-11-08
# Finished: 2021-11-15
# Finished: 2021-11-22
# Finished: 2021-11-29
# Finished: 2021-12-06
# Finished: 2021-12-13
# Finished: 2021-12-20
# Finished: 2021-12-27
# Finished: 2022-01-03
# Finished: 2022-01-10
# Finished: 2022-01-17
# Finished: 2022-01-31
# Finished: 2022-02-07
# Finished: 2022-02-14
# Finished: 2022-02-21
# Finished: 2022-02-28
# Finished: 2022-03-07
# Finished: 2022-03-21
# Finished: 2022-04-04
# Finished: 2022-04-11
# Finished: 2022-04-18
# Finished: 2022-04-25
# Finished: 2022-05-02
# Finished: 2022-05-09
# Finished: 2022-05-16
# Finished: 2022-05-23
# Finished: 2022-06-06
# Finished: 2022-06-13
# Finished: 2022-06-20
# Finished: 2022-06-27
# Finished: 2022-07-11
# Finished: 2022-07-18
# Finished: 2022-07-25
# Finished: 2022-08-01
# Finished: 2022-08-08
# Finished: 2022-08-15
# Finished: 2022-08-22
# Finished: 2022-08-29
# Finished: 2022-09-12
# Finished: 2022-09-19
# Finished: 2022-09-26
# Finished: 2022-10-03
# Finished: 2022-10-10
# Finished: 2022-10-17
# Finished: 2022-10-24
# Finished: 2022-10-31
# Finished: 2022-11-07
# Finished: 2022-11-14
# Finished: 2022-11-21
# Finished: 2022-11-28
# Finished: 2022-12-05
# Finished: 2022-12-12
# Finished: 2022-12-19
# Finished: 2022-12-26
# Finished: 2023-01-02
# Finished: 2023-01-09
# Finished: 2023-01-16
# Finished: 2023-01-30
# Finished: 2023-02-06
# Finished: 2023-02-13
# Finished: 2023-02-20
# Finished: 2023-02-27
# Finished: 2023-03-06
# Finished: 2023-03-20
# Finished: 2023-04-03
# Finished: 2023-04-10
# Finished: 2023-04-17
# Finished: 2023-04-24
# Finished: 2023-05-08
# Finished: 2023-05-22
# Finished: 2023-05-29
# Finished: 2023-06-12
# Finished: 2023-06-19
# Finished: 2023-06-26
# Finished: 2023-07-03
# Finished: 2023-07-17
# Finished: 2023-07-24
# Finished: 2023-07-31
# Finished: 2023-08-07
# Finished: 2023-08-14
# Finished: 2023-08-21
# Finished: 2023-08-28
# Finished: 2023-09-11
# Finished: 2023-09-18
# Finished: 2023-09-25
# Finished: 2023-10-02
# Finished: 2023-10-16
# Finished: 2023-10-23
# Finished: 2023-10-30
# Finished: 2023-11-06
# Finished: 2023-11-13
# Finished: 2023-11-20
# Finished: 2023-11-27
# Finished: 2023-12-04
# Finished: 2023-12-11
# Finished: 2023-12-18
# Finished: 2023-12-25
# Finished: 2024-01-01
# Finished: 2024-01-08
# Finished: 2024-01-15
# Finished: 2024-01-29
# Finished: 2024-02-05
# Finished: 2024-02-12
# Finished: 2024-02-19
# Finished: 2024-02-26
# Finished: 2024-03-04
# Finished: 2024-03-18
# Finished: 2024-04-01
# Finished: 2024-04-08
# Finished: 2024-04-15
# Finished: 2024-04-22
# Finished: 2024-05-06
# Finished: 2024-05-20
# Finished: 2024-05-27
# Finished: 2024-06-10
# Finished: 2024-06-17
# Finished: 2024-06-24
# Finished: 2024-07-01
# Finished: 2024-07-15
# Finished: 2024-07-22
# Finished: 2024-07-29
# Finished: 2024-08-05
# Finished: 2024-08-12
# Finished: 2024-08-19
# Finished: 2024-08-26
# Finished: 2024-09-09
# Finished: 2024-09-16
# Finished: 2024-09-23
# Finished: 2024-09-30
# Finished: 2024-10-14
# Finished: 2024-10-21
# Finished: 2024-10-28
# Finished: 2024-11-04
# Finished: 2024-11-11
# Finished: 2024-11-18
# Finished: 2024-11-25
# Finished: 2024-12-02
# Finished: 2024-12-09
# Finished: 2024-12-16
# Finished: 2024-12-23
# Finished: 2024-12-30
# Finished: 2025-01-06

# %% [markdown]
# Remember to update geo file in Flourish

# %% [markdown]
# ## 5. Update All Matches Player by Player
#
# The website started to block me but it seems for most important players I can scrape them.

# %%
# define functions to get all players' names and scrape all matches data
def get_names(sex = ''):
    names = []
    if sex == 'm':
        with open('mp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    elif sex == 'w':
        with open('wp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    else:
        with open('mwplayerlist_processed.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    return names

# define a function to scrape for a single man player's matches
def scrape_matches(name, driver):
    try:
        # set attributes
        attributes_m = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'TP', 'Aces', 'DFs', 'SP', 
                        '1SP', '2SP', 'vA', 'Time']

        attributes_w = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'Time']

        # get cleaned name
        sex = name[1]
        name_cleaned = name[4:].replace(' ', '')

        # set url prefix and types of webpages
        if sex == 'M':
            url = "https://www.tennisabstract.com/cgi-bin/player-classic.cgi?p=" 
        #   types = ["&f=ACareerqq", "&f=ACareerqqr1", "&f=ACareerqqw1"]
        else:
            url = "https://www.tennisabstract.com/cgi-bin/wplayer-classic.cgi?p="

        # Start of Scraping
        print('Start Scraping:', name[4:])
        
        # Man and woman pages are different
        if sex == 'M':

            # For man players
            # Set dictionary
            dic = {}
            for attr in attributes_m:
                dic[attr] = []

            # For serve page
            driver.get(url + name_cleaned.replace(' ', '') + "&f=ACareerqq")
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
            # driver.quit()

            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # For return page
                show_return = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Return"]')))
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[1])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # For raw page
                show_raw = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Raw"]')))
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[2])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

            else:
                # Serve page
                driver.get(url + name_cleaned.replace(' ', ''))
                driver.refresh()
                # Show career
                try:
                    show_career = driver.find_element(By.ID, 'careerclick')
                except:
                    return None
                show_career.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # Return page
                show_return = driver.find_element(By.XPATH, '//span[text()="Return"]')
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # raw page
                show_raw = driver.find_element(By.XPATH, '//span[text()="Raw"]')
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
              # driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

        else:

            # For woman players
            # set dictionary
            dic = {}
            for attr in attributes_w:
                dic[attr] = []

            # For serve page
            driver.get(url + name_cleaned.replace(' ', '') + '&f=ACareerqq')
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')

            # Check whether it is empty
            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_w[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_w[1]].append(tds[1].text)
                        # sets
                        dic[attributes_w[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_w[3]].append(tds[2].text)
                        # round
                        dic[attributes_w[4]].append(tds[3].text)
                        # rank
                        dic[attributes_w[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_w[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_w[7]].append(1)
                            # winner
                            dic[attributes_w[10]].append(name[4:])
                            # loser
                            dic[attributes_w[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_w[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_w[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_w[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_w[9]].append('')
                        else:
                            # win?
                            dic[attributes_w[7]].append(0)
                            # winner
                            dic[attributes_w[10]].append(spans[1].text)
                            # loser
                            dic[attributes_w[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_w[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_w[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_w[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_w[9]].append('')
                        # score
                        dic[attributes_w[12]].append(tds[7].text.replace(" (ch)", ""))
                        # DR
                        dic[attributes_w[13]].append(tds[8].text)
                        # A%
                        dic[attributes_w[14]].append(tds[9].text)
                        # DF%
                        dic[attributes_w[15]].append(tds[10].text)
                        # 1stIn
                        dic[attributes_w[16]].append(tds[11].text)
                        # 1st%
                        dic[attributes_w[17]].append(tds[12].text)
                        # 2rd%
                        dic[attributes_w[18]].append(tds[13].text)
                        # BPSvd
                        dic[attributes_w[19]].append(tds[14].text)

                print('Serve Page:', len(dic['Date']))

                # For return page
                page_return = driver.find_element(By.XPATH, '//span[text()="Show Return Stats"]')
                page_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
            #   driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_w[20]].append(tds[9].text)
                        # RPW
                        dic[attributes_w[21]].append(tds[10].text)
                        # vA%
                        dic[attributes_w[22]].append(tds[11].text)
                        # v1st%
                        dic[attributes_w[23]].append(tds[12].text)
                        # v2rd%
                        dic[attributes_w[24]].append(tds[13].text)
                        # BPCvt
                        dic[attributes_w[25]].append(tds[14].text)
                        # Time
                        dic[attributes_w[26]].append(tds[15].text)

                print('Return Page:', len(dic['TPW']))

        # save to text, separated by gender
        df = pd.DataFrame(dic)
        df.to_csv(sex.lower() + '/matches/txt/' + name[4:] + '.txt', index = False, sep = ',', encoding='utf-8-sig')

    except (IndexError, AttributeError) as e:
        pass
    
# define a loop function to scrape players from a given index
def scrape_from(idx, sex, driver):
    names = get_names(sex)
    for i in range(idx, len(names)):
        try:

            # Scrape the player matches
            scrape_matches(names[i], driver)

            # Print out progress
            print('Finish Scraping', i + 1, 'players.')
            print(len(names) - (i + 1), 'players remaining.')
            print('\n')

            # Sleep for second
            # time.sleep(5)

        except:

            # Sleep for second
            # time.sleep(5)
            
            continue
        
# load txt files
def load_txt(name):
    with open(name[1].lower() + '/matches/txt/' + name[4:] + '.txt', 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    return df

# %%
# UPDATE MATCHES DATA!!!
# set up chromdriver
chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)
scrape_from(0, 'm', driver)
# Out:
# Start Scraping: Rafael Nadal
# Serve Page: 1431
# Return Page: 1431
# Raw Page: 1431
# Finish Scraping 1 players.
# 31496 players remaining.
#
#
# Start Scraping: Novak Djokovic
# Serve Page: 1447
# Return Page: 1447
# Raw Page: 1447
# Finish Scraping 2 players.
# 31495 players remaining.
#
#
# Start Scraping: Feliciano Lopez
# Serve Page: 1279
# Return Page: 1279
# Raw Page: 1279
# Finish Scraping 3 players.
# 31494 players remaining.
#
#
# Start Scraping: Fernando Verdasco
# Serve Page: 1254
# Return Page: 1254
# Raw Page: 1254
# Finish Scraping 4 players.
# 31493 players remaining.
#
#
# Start Scraping: Tommy Robredo
# Serve Page: 1197
# Return Page: 1197
# Raw Page: 1197
# Finish Scraping 5 players.
# 31492 players remaining.
#
#
# Start Scraping: Andreas Seppi
# Serve Page: 1202
# Return Page: 1202
# Raw Page: 1202
# Finish Scraping 6 players.
# 31491 players remaining.
#
#
# Start Scraping: Richard Gasquet
# Finish Scraping 7 players.
# 31490 players remaining.
#
#
# Start Scraping: Teymuraz Gabashvili
# Finish Scraping 8 players.
# 31489 players remaining.
#
#
# Start Scraping: Lukas Rosol
# Finish Scraping 9 players.
# 31488 players remaining.
#
#
# Start Scraping: Gilles Simon
# Finish Scraping 10 players.
# 31487 players remaining.
#
#
# Start Scraping: Adrian Mannarino
# Finish Scraping 11 players.
# 31486 players remaining.
#
#
# Start Scraping: Albert Ramos
# Finish Scraping 12 players.
# 31485 players remaining.
#
#
# Start Scraping: Philipp Kohlschreiber
# Finish Scraping 13 players.
# 31484 players remaining.
#
#
# Start Scraping: Andy Murray
# Finish Scraping 14 players.
# 31483 players remaining.
#
#
# Start Scraping: Sergiy Stakhovsky
# Serve Page: 1117
# Return Page: 1117
# Raw Page: 1117
# Finish Scraping 15 players.
# 31482 players remaining.
#
#
# Start Scraping: Go Soeda
# Serve Page: 1117
# Return Page: 1117
# Raw Page: 1117
# Finish Scraping 16 players.
# 31481 players remaining.
#
#
# Start Scraping: Roberto Bautista Agut
# Serve Page: 1174
# Return Page: 1174
# Raw Page: 1174
# Finish Scraping 17 players.
# 31480 players remaining.
#
#
# Start Scraping: Fabio Fognini
# Finish Scraping 18 players.
# 31479 players remaining.
#
#
# Start Scraping: Aldin Setkic
# Serve Page: 1129
# Return Page: 1129
# Raw Page: 1129
# Finish Scraping 19 players.
# 31478 players remaining.
#
#
# Start Scraping: Andrea Arnaboldi
# Serve Page: 1078
# Return Page: 1078
# Raw Page: 1078
# Finish Scraping 20 players.
# 31477 players remaining.
#
#
# Start Scraping: Stan Wawrinka
# Serve Page: 1107
# Return Page: 1107
# Raw Page: 1107
# Finish Scraping 21 players.
# 31476 players remaining.
#
#
# Start Scraping: Denis Istomin
# Serve Page: 1069
# Return Page: 1069
# Raw Page: 1069
# Finish Scraping 22 players.
# 31475 players remaining.
#
#
# Start Scraping: Yannick Mertens
# Serve Page: 1037
# Return Page: 1037
# Raw Page: 1037
# Finish Scraping 23 players.
# 31474 players remaining.
#
#
# Start Scraping: Malek Jaziri
# Serve Page: 1035
# Return Page: 1035
# Raw Page: 1035
# Finish Scraping 24 players.
# 31473 players remaining.
#
#
# Start Scraping: Facundo Bagnis
# Serve Page: 1039
# Return Page: 1039
# Raw Page: 1039
# Finish Scraping 25 players.
# 31472 players remaining.
#
#
# Start Scraping: Lukas Lacko
# Serve Page: 1025
# Return Page: 1025
# Raw Page: 1025
# Finish Scraping 26 players.
# 31471 players remaining.
#
#
# Start Scraping: Adrian Menendez Maceiras
# Serve Page: 1027
# Return Page: 1027
# Raw Page: 1027
# Finish Scraping 27 players.
# 31470 players remaining.
#
#
# Start Scraping: Benoit Paire
# Serve Page: 1056
# Return Page: 1056
# Raw Page: 1056
# Finish Scraping 28 players.
# 31469 players remaining.
#
#
# Start Scraping: Jaroslav Pospisil
# Serve Page: 1022
# Return Page: 1022
# Raw Page: 1022
# Finish Scraping 29 players.
# 31468 players remaining.
#
#
# Start Scraping: Radu Albot
# Serve Page: 1067
# Return Page: 1067
# Raw Page: 1067
# Finish Scraping 30 players.
# 31467 players remaining.
#
#
# Start Scraping: Marin Cilic
# Serve Page: 1039
# Return Page: 1039
# Raw Page: 1039
# Finish Scraping 31 players.
# 31466 players remaining.
#
#
# Start Scraping: Matteo Viola
# Serve Page: 1011
# Return Page: 1011
# Raw Page: 1011
# Finish Scraping 32 players.
# 31465 players remaining.
#
#
# Start Scraping: Mikhail Kukushkin
# Serve Page: 1061
# Return Page: 1061
# Raw Page: 1061
# Finish Scraping 33 players.
# 31464 players remaining.
#
#
# Start Scraping: Joao Sousa
# Serve Page: 1004
# Return Page: 1004
# Raw Page: 1004
# Finish Scraping 34 players.
# 31463 players remaining.
#
#
# Start Scraping: Marsel Ilhan
# Serve Page: 1012
# Return Page: 1012
# Raw Page: 1012
# Finish Scraping 35 players.
# 31462 players remaining.
#
#
# Start Scraping: Dudi Sela
# Serve Page: 1003
# Return Page: 1003
# Raw Page: 1003
# Finish Scraping 36 players.
# 31461 players remaining.
#
#
# Start Scraping: Matthias Bachinger
# Serve Page: 997
# Return Page: 997
# Raw Page: 997
# Finish Scraping 37 players.
# 31460 players remaining.
#
#
# Start Scraping: Steven Diez
# Serve Page: 1008
# Return Page: 1008
# Raw Page: 1008
# Finish Scraping 38 players.
# 31459 players remaining.
#
#
# Start Scraping: Mohamed Safwat
# Finish Scraping 39 players.
# 31458 players remaining.
#
#
# Start Scraping: Gael Monfils
# Finish Scraping 40 players.
# 31457 players remaining.
#
#
# Start Scraping: Ivan Nedelko
# Finish Scraping 41 players.
# 31456 players remaining.
#
#
# Start Scraping: Tobias Kamke
# Finish Scraping 42 players.
# 31455 players remaining.
#
#
# Start Scraping: Tatsuma Ito
# Finish Scraping 43 players.
# 31454 players remaining.
#
#
# Start Scraping: Mischa Zverev
# Finish Scraping 44 players.
# 31453 players remaining.
#
#
# Start Scraping: David Goffin
# Finish Scraping 45 players.
# 31452 players remaining.
#
#
# Start Scraping: Robin Haase
# Finish Scraping 46 players.
# 31451 players remaining.
#
#
# Start Scraping: Illya Marchenko
# Finish Scraping 47 players.
# 31450 players remaining.
#
#
# Start Scraping: Jo Wilfried Tsonga
# Finish Scraping 48 players.
# 31449 players remaining.
#
#
# Start Scraping: Evgeny Donskoy
# Finish Scraping 49 players.
# 31448 players remaining.
#
#
# Start Scraping: Konstantin Kravchuk
# Serve Page: 947
# Return Page: 947
# Raw Page: 947
# Finish Scraping 50 players.
# 31447 players remaining.
#
#
# Start Scraping: Pablo Cuevas
# Serve Page: 940
# Return Page: 940
# Raw Page: 940
# Finish Scraping 51 players.
# 31446 players remaining.
#
#
# Start Scraping: Hiroki Moriya
# Serve Page: 992
# Return Page: 992
# Raw Page: 992
# Finish Scraping 52 players.
# 31445 players remaining.
#
#
# Start Scraping: Ruben Bemelmans
# Serve Page: 937
# Return Page: 937
# Raw Page: 937
# Finish Scraping 53 players.
# 31444 players remaining.
#
#
# Start Scraping: Pablo Andujar
# Serve Page: 940
# Return Page: 940
# Raw Page: 940
# Finish Scraping 54 players.
# 31443 players remaining.
#
#
# Start Scraping: Federico Coria
# Serve Page: 985
# Return Page: 985
# Raw Page: 985
# Finish Scraping 55 players.
# 31442 players remaining.
#
#
# Start Scraping: Miljan Zekic
# Serve Page: 953
# Return Page: 953
# Raw Page: 953
# Finish Scraping 56 players.
# 31441 players remaining.
#
#
# Start Scraping: Daniel Dutra Da Silva
# Serve Page: 1007
# Return Page: 1007
# Raw Page: 1007
# Finish Scraping 57 players.
# 31440 players remaining.
#
#
# Start Scraping: Jose Rubin Statham
# Serve Page: 944
# Return Page: 944
# Raw Page: 944
# Finish Scraping 58 players.
# 31439 players remaining.
#
#
# Start Scraping: Taro Daniel
# Serve Page: 965
# Return Page: 965
# Raw Page: 965
# Finish Scraping 59 players.
# 31438 players remaining.
#
#
# Start Scraping: Peter Gojowczyk
# Serve Page: 916
# Return Page: 916
# Raw Page: 916
# Finish Scraping 60 players.
# 31437 players remaining.
#
#
# Start Scraping: Jan Lennard Struff
# Serve Page: 965
# Return Page: 965
# Raw Page: 965
# Finish Scraping 61 players.
# 31436 players remaining.
#
#
# Start Scraping: Stephane Robert
# Serve Page: 915
# Return Page: 915
# Raw Page: 915
# Finish Scraping 62 players.
# 31435 players remaining.
#
#
# Start Scraping: Roberto Carballes Baena
# Serve Page: 969
# Return Page: 969
# Raw Page: 969
# Finish Scraping 63 players.
# 31434 players remaining.
#
#
# Start Scraping: Dusan Lajovic
# Serve Page: 941
# Return Page: 941
# Raw Page: 941
# Finish Scraping 64 players.
# 31433 players remaining.
#
#
# Start Scraping: Diego Schwartzman
# Finish Scraping 65 players.
# 31432 players remaining.
#
#
# Start Scraping: Andrej Martin
# Finish Scraping 66 players.
# 31431 players remaining.
#
#
# Start Scraping: Rod Laver
# Finish Scraping 67 players.
# 31430 players remaining.
#
#
# Start Scraping: Federico Gaio
# Finish Scraping 68 players.
# 31429 players remaining.
#
#
# Start Scraping: Uladzimir Ignatik
# Finish Scraping 69 players.
# 31428 players remaining.
#
#
# Start Scraping: Peter Polansky
# Finish Scraping 70 players.
# 31427 players remaining.
#
#
# Start Scraping: Kevin Anderson
# Finish Scraping 71 players.
# 31426 players remaining.
#
#
# Start Scraping: John Isner
# Finish Scraping 72 players.
# 31425 players remaining.
#
#
# Start Scraping: Damir Dzumhur
# Finish Scraping 73 players.
# 31424 players remaining.
#
#
# Start Scraping: Grigor Dimitrov
# Finish Scraping 74 players.
# 31423 players remaining.
#
#
# Start Scraping: Yuichi Sugita
# Finish Scraping 75 players.
# 31422 players remaining.
#
#
# Start Scraping: Jeremy Chardy
# Serve Page: 885
# Return Page: 885
# Raw Page: 885
# Finish Scraping 76 players.
# 31421 players remaining.
#
#
# Start Scraping: Ricardas Berankis
# Serve Page: 933
# Return Page: 933
# Raw Page: 933
# Finish Scraping 77 players.
# 31420 players remaining.
#
#
# Start Scraping: Marius Copil
# Serve Page: 887
# Return Page: 887
# Raw Page: 887
# Finish Scraping 78 players.
# 31419 players remaining.
#
#
# Start Scraping: Thomaz Bellucci
# Serve Page: 883
# Return Page: 883
# Raw Page: 883
# Finish Scraping 79 players.
# 31418 players remaining.
#
#
# Start Scraping: Oriol Roca Batalla
# Finish Scraping 80 players.
# 31417 players remaining.
#
#
# Start Scraping: Kenny De Schepper
# Finish Scraping 81 players.
# 31416 players remaining.
#
#
# Start Scraping: Gastao Elias
# Finish Scraping 82 players.
# 31415 players remaining.
#
#
# Start Scraping: Norbert Gombos
# Finish Scraping 83 players.
# 31414 players remaining.
#
#
# Start Scraping: Donald Young
# Finish Scraping 84 players.
# 31413 players remaining.
#
#
# Start Scraping: Ernests Gulbis
# Finish Scraping 85 players.
# 31412 players remaining.
#
#
# Start Scraping: Denis Kudla
# Finish Scraping 86 players.
# 31411 players remaining.
#
#
# Start Scraping: Daniel Evans
# Finish Scraping 87 players.
# 31410 players remaining.
#
#
# Start Scraping: Lorenzo Giustino
# Finish Scraping 88 players.
# 31409 players remaining.
#
#
# Start Scraping: Vasek Pospisil
# Finish Scraping 89 players.
# 31408 players remaining.
#
#
# Start Scraping: Federico Delbonis
# Finish Scraping 90 players.
# 31407 players remaining.
#
#
# Start Scraping: Thomas Fabbiano
# Finish Scraping 91 players.
# 31406 players remaining.
#
#
# Start Scraping: Pablo Carreno Busta
# Finish Scraping 92 players.
# 31405 players remaining.
#
#
# Start Scraping: Sam Querrey
# Serve Page: 846
# Return Page: 846
# Raw Page: 846
# Finish Scraping 93 players.
# 31404 players remaining.
#
#
# Start Scraping: Alejandro Gonzalez
# Serve Page: 845
# Return Page: 845
# Raw Page: 845
# Finish Scraping 94 players.
# 31403 players remaining.
#
#
# Start Scraping: Igor Sijsling
# Serve Page: 830
# Return Page: 830
# Raw Page: 830
# Finish Scraping 95 players.
# 31402 players remaining.
#
#
# Start Scraping: Lamine Ouahab
# Serve Page: 828
# Return Page: 828
# Raw Page: 828
# Finish Scraping 96 players.
# 31401 players remaining.
#
#
# Start Scraping: Stefano Travaglia
# Finish Scraping 97 players.
# 31400 players remaining.
#
#
# Start Scraping: Andrea Collarini
# Finish Scraping 98 players.
# 31399 players remaining.
#
#
# Start Scraping: Marco Trungelliti
# Finish Scraping 99 players.
# 31398 players remaining.
#
#
# Start Scraping: Matthew Ebden
# Finish Scraping 100 players.
# 31397 players remaining.
#
#
# Start Scraping: Alexey Vatutin
# Finish Scraping 101 players.
# 31396 players remaining.
#
#
# Start Scraping: Alessandro Giannessi
# Finish Scraping 102 players.
# 31395 players remaining.
#
#
# Start Scraping: Andrey Golubev
# Finish Scraping 103 players.
# 31394 players remaining.
#
#
# Start Scraping: Marco Cecchinato
# Finish Scraping 104 players.
# 31393 players remaining.
#
#
# Start Scraping: Jimmy Connors
# Finish Scraping 105 players.
# 31392 players remaining.
#
#
# Start Scraping: Renzo Olivo
# Finish Scraping 106 players.
# 31391 players remaining.
#
#
# Start Scraping: Roger Federer
# Finish Scraping 107 players.
# 31390 players remaining.
#
#
# Start Scraping: Kei Nishikori
# Serve Page: 837
# Return Page: 837
# Raw Page: 837
# Finish Scraping 108 players.
# 31389 players remaining.
#
#
# Start Scraping: Liam Broady
# Serve Page: 809
# Return Page: 809
# Raw Page: 809
# Finish Scraping 109 players.
# 31388 players remaining.
#
#
# Start Scraping: Ramkumar Ramanathan
# Serve Page: 818
# Return Page: 818
# Raw Page: 818
# Finish Scraping 110 players.
# 31387 players remaining.
#
#
# Start Scraping: Guido Pella
# Serve Page: 785
# Return Page: 785
# Raw Page: 785
# Finish Scraping 111 players.
# 31386 players remaining.
#
#
# Start Scraping: Martin Klizan
# Serve Page: 838
# Return Page: 838
# Raw Page: 838
# Finish Scraping 112 players.
# 31385 players remaining.
#
#
# Start Scraping: Jonathan Eysseric
# Serve Page: 783
# Return Page: 783
# Raw Page: 783
# Finish Scraping 113 players.
# 31384 players remaining.
#
#
# Start Scraping: Jozef Kovalik
# Serve Page: 815
# Return Page: 815
# Raw Page: 815
# Finish Scraping 114 players.
# 31383 players remaining.
#
#
# Start Scraping: Ilie Nastase
# Serve Page: 1443
# Return Page: 1443
# Raw Page: 1443
# Finish Scraping 115 players.
# 31382 players remaining.
#
#
# Start Scraping: Thiago Monteiro
# Serve Page: 825
# Return Page: 825
# Raw Page: 825
# Finish Scraping 116 players.
# 31381 players remaining.
#
#
# Start Scraping: Arthur Ashe
# Serve Page: 1532
# Return Page: 1532
# Raw Page: 1532
# Finish Scraping 117 players.
# 31380 players remaining.
#
#
# Start Scraping: Nikoloz Basilashvili
# Serve Page: 838
# Return Page: 838
# Raw Page: 838
# Finish Scraping 118 players.
# 31379 players remaining.
#
#
# Start Scraping: Henri Laaksonen
# Serve Page: 775
# Return Page: 775
# Raw Page: 775
# Finish Scraping 119 players.
# 31378 players remaining.
#
#
# Start Scraping: Marton Fucsovics
# Serve Page: 800
# Return Page: 800
# Raw Page: 800
# Finish Scraping 120 players.
# 31377 players remaining.
#
#
# Start Scraping: John Millman
# Serve Page: 769
# Return Page: 769
# Raw Page: 769
# Finish Scraping 121 players.
# 31376 players remaining.
#
#
# Start Scraping: Kento Takeuchi
# Serve Page: 766
# Return Page: 766
# Raw Page: 766
# Finish Scraping 122 players.
# 31375 players remaining.
#
#
# Start Scraping: Zhe Li
# Serve Page: 768
# Return Page: 768
# Raw Page: 768
# Finish Scraping 123 players.
# 31374 players remaining.
#
#
# Start Scraping: Dimitar Kuzmanov
# Finish Scraping 124 players.
# 31373 players remaining.
#
#
# Start Scraping: Mirza Basic
# Finish Scraping 125 players.
# 31372 players remaining.
#
#
# Start Scraping: Facundo Mena
# Finish Scraping 126 players.
# 31371 players remaining.
#
#
# Start Scraping: Juan Martin Del Potro
# Finish Scraping 127 players.
# 31370 players remaining.
#
#
# Start Scraping: Goncalo Oliveira
# Finish Scraping 128 players.
# 31369 players remaining.
#
#
# Start Scraping: Tsung Hua Yang
# Finish Scraping 129 players.
# 31368 players remaining.
#
#
# Start Scraping: Pierre Hugues Herbert
# Finish Scraping 130 players.
# 31367 players remaining.
#
#
# Start Scraping: Antoine Escoffier
# Finish Scraping 131 players.
# 31366 players remaining.
#
#
# Start Scraping: Denis Yevseyev
# Finish Scraping 132 players.
# 31365 players remaining.
#
#
# Start Scraping: Dennis Novak
# Finish Scraping 133 players.
# 31364 players remaining.
#
#
# Start Scraping: Salvatore Caruso
# Finish Scraping 134 players.
# 31363 players remaining.
#
#
# Start Scraping: Pedro Sousa
# Finish Scraping 135 players.
# 31362 players remaining.
#
#
# Start Scraping: James Duckworth
# Finish Scraping 136 players.
# 31361 players remaining.
#
#
# Start Scraping: Roberto Marcora
# Finish Scraping 137 players.
# 31360 players remaining.
#
#
# Start Scraping: Dominic Thiem
# Finish Scraping 138 players.
# 31359 players remaining.
#
#
# Start Scraping: Yasutaka Uchiyama
# Serve Page: 768
# Return Page: 768
# Raw Page: 768
# Finish Scraping 139 players.
# 31358 players remaining.
#
#
# Start Scraping: Gregoire Barrere
# Serve Page: 772
# Return Page: 772
# Raw Page: 772
# Finish Scraping 140 players.
# 31357 players remaining.
#
#
# Start Scraping: Constant Lestienne
# Serve Page: 765
# Return Page: 765
# Raw Page: 765
# Finish Scraping 141 players.
# 31356 players remaining.
#
#
# Start Scraping: Jordan Thompson
# Serve Page: 764
# Return Page: 764
# Raw Page: 764
# Finish Scraping 142 players.
# 31355 players remaining.
#
#
# Start Scraping: Kimmer Coppejans
# Finish Scraping 143 players.
# 31354 players remaining.
#
#
# Start Scraping: Laurynas Grigelis
# Finish Scraping 144 players.
# 31353 players remaining.
#
#
# Start Scraping: Tennys Sandgren
# Serve Page: 724
# Return Page: 724
# Raw Page: 724
# Finish Scraping 145 players.
# 31352 players remaining.
#
#
# Start Scraping: Thiemo De Bakker
# Serve Page: 721
# Return Page: 721
# Raw Page: 721
# Finish Scraping 146 players.
# 31351 players remaining.
#
#
# Start Scraping: Guido Andreozzi
# Serve Page: 735
# Return Page: 735
# Raw Page: 735
# Finish Scraping 147 players.
# 31350 players remaining.
#
#
# Start Scraping: Blaz Rola
# Serve Page: 737
# Return Page: 737
# Raw Page: 737
# Finish Scraping 148 players.
# 31349 players remaining.
#
#
# Start Scraping: Jiri Vesely
# Serve Page: 752
# Return Page: 752
# Raw Page: 752
# Finish Scraping 149 players.
# 31348 players remaining.
#
#
# Start Scraping: Riccardo Bonadio
# Serve Page: 743
# Return Page: 743
# Raw Page: 743
# Finish Scraping 150 players.
# 31347 players remaining.
#
#
# Start Scraping: Tristan Lamasine
# Serve Page: 748
# Return Page: 748
# Raw Page: 748
# Finish Scraping 151 players.
# 31346 players remaining.
#
#
# Start Scraping: Milos Raonic
# Serve Page: 720
# Return Page: 720
# Raw Page: 720
# Finish Scraping 152 players.
# 31345 players remaining.
#
#
# Start Scraping: Mathias Bourgue
# Finish Scraping 153 players.
# 31344 players remaining.
#
#
# Start Scraping: John Newcombe
# Finish Scraping 154 players.
# 31343 players remaining.
#
#
# Start Scraping: Hugo Dellien
# Finish Scraping 155 players.
# 31342 players remaining.
#
#
# Start Scraping: Ken Rosewall
# Finish Scraping 156 players.
# 31341 players remaining.
#
#
# Start Scraping: Filip Horansky
# Finish Scraping 157 players.
# 31340 players remaining.
#
#
# Start Scraping: Filip Krajinovic
# Serve Page: 714
# Return Page: 714
# Raw Page: 714
# Finish Scraping 158 players.
# 31339 players remaining.
#
#
# Start Scraping: Alexander Zverev
# Serve Page: 776
# Return Page: 776
# Raw Page: 776
# Finish Scraping 159 players.
# 31338 players remaining.
#
#
# Start Scraping: Juan Pablo Paz
# Finish Scraping 160 players.
# 31337 players remaining.
#
#
# Start Scraping: Dmitry Popko
# Serve Page: 755
# Return Page: 755
# Raw Page: 755
# Finish Scraping 161 players.
# 31336 players remaining.
#
#
# Start Scraping: Emilio Gomez
# Serve Page: 711
# Return Page: 711
# Raw Page: 711
# Finish Scraping 162 players.
# 31335 players remaining.
#
#
# Start Scraping: Roy Emerson
# Serve Page: 1578
# Return Page: 1578
# Raw Page: 1578
# Finish Scraping 163 players.
# 31334 players remaining.
#
#
# Start Scraping: Gerald Melzer
# Serve Page: 718
# Return Page: 718
# Raw Page: 718
# Finish Scraping 164 players.
# 31333 players remaining.
#
#
# Start Scraping: Daniil Medvedev
# Serve Page: 741
# Return Page: 741
# Raw Page: 741
# Finish Scraping 165 players.
# 31332 players remaining.
#
#
# Start Scraping: Frederico Ferreira Silva
# Serve Page: 767
# Return Page: 767
# Raw Page: 767
# Finish Scraping 166 players.
# 31331 players remaining.
#
#
# Start Scraping: Bernard Tomic
# Serve Page: 756
# Return Page: 756
# Raw Page: 756
# Finish Scraping 167 players.
# 31330 players remaining.
#
#
# Start Scraping: Jose Pereira
# Serve Page: 746
# Return Page: 746
# Raw Page: 746
# Finish Scraping 168 players.
# 31329 players remaining.
#
#
# Start Scraping: Ivan Gakhov
# Serve Page: 752
# Return Page: 752
# Raw Page: 752
# Finish Scraping 169 players.
# 31328 players remaining.
#
#
# Start Scraping: Jason Jung
# Serve Page: 679
# Return Page: 679
# Raw Page: 679
# Finish Scraping 170 players.
# 31327 players remaining.
#
#
# Start Scraping: David Perez Sanz
# Serve Page: 691
# Return Page: 691
# Raw Page: 691
# Finish Scraping 171 players.
# 31326 players remaining.
#
#
# Start Scraping: Andrey Rublev
# Serve Page: 730
# Return Page: 730
# Raw Page: 730
# Finish Scraping 172 players.
# 31325 players remaining.
#
#
# Start Scraping: Juan Ignacio Londero
# Serve Page: 691
# Return Page: 691
# Raw Page: 691
# Finish Scraping 173 players.
# 31324 players remaining.
#
#
# Start Scraping: Maxime Chazal
# Serve Page: 742
# Return Page: 742
# Raw Page: 742
# Finish Scraping 174 players.
# 31323 players remaining.
#
#
# Start Scraping: Inigo Cervantes Huegun
# Finish Scraping 175 players.
# 31322 players remaining.
#
#
# Start Scraping: Guillermo Vilas
# Finish Scraping 176 players.
# 31321 players remaining.
#
#
# Start Scraping: Wilson Leite
# Finish Scraping 177 players.
# 31320 players remaining.
#
#
# Start Scraping: Hernan Casanova
# Finish Scraping 178 players.
# 31319 players remaining.
#
#
# Start Scraping: Mitchell Krueger
# Finish Scraping 179 players.
# 31318 players remaining.
#
#
# Start Scraping: Pedro Cachin
# Finish Scraping 180 players.
# 31317 players remaining.
#
#
# Start Scraping: Toshihide Matsui
# Finish Scraping 181 players.
# 31316 players remaining.
#
#
# Start Scraping: Ricardo Rodriguez
# Finish Scraping 182 players.
# 31315 players remaining.
#
#
# Start Scraping: Paolo Lorenzi
# Finish Scraping 183 players.
# 31314 players remaining.
#
#
# Start Scraping: Steve Johnson
# Finish Scraping 184 players.
# 31313 players remaining.
#
#
# Start Scraping: Cem Ilkel
# Serve Page: 699
# Return Page: 699
# Raw Page: 699
# Finish Scraping 185 players.
# 31312 players remaining.
#
#
# Start Scraping: Filip Peliwo
# Serve Page: 722
# Return Page: 722
# Raw Page: 722
# Finish Scraping 186 players.
# 31311 players remaining.
#
#
# Start Scraping: Aljaz Bedene
# Finish Scraping 187 players.
# 31310 players remaining.
#
#
# Start Scraping: Stan Smith
# Finish Scraping 188 players.
# 31309 players remaining.
#
#
# Start Scraping: Maximilian Neuchrist
# Finish Scraping 189 players.
# 31308 players remaining.
#
#
# Start Scraping: Dayne Kelly
# Finish Scraping 190 players.
# 31307 players remaining.
#
#
# Start Scraping: Stefanos Tsitsipas
# Finish Scraping 191 players.
# 31306 players remaining.
#
#
# Start Scraping: Egor Gerasimov
# Finish Scraping 192 players.
# 31305 players remaining.
#
#
# Start Scraping: David Ferrer
# Finish Scraping 193 players.
# 31304 players remaining.
#
#
# Start Scraping: Ivan Lendl
# Finish Scraping 194 players.
# 31303 players remaining.
#
#
# Start Scraping: Ryan Harrison
# Finish Scraping 195 players.
# 31302 players remaining.
#
#
# Start Scraping: Daniel Cox
# Finish Scraping 196 players.
# 31301 players remaining.
#
#
# Start Scraping: Elias Ymer
# Finish Scraping 197 players.
# 31300 players remaining.
#
#
# Start Scraping: Pedro Martinez
# Finish Scraping 198 players.
# 31299 players remaining.
#
#
# Start Scraping: Peter Heller
# Finish Scraping 199 players.
# 31298 players remaining.
#
#
# Start Scraping: Aslan Karatsev
# Finish Scraping 200 players.
# 31297 players remaining.
#
#
# Start Scraping: Evgeny Karlovskiy
# Finish Scraping 201 players.
# 31296 players remaining.
#
#
# Start Scraping: Quentin Halys
# Finish Scraping 202 players.
# 31295 players remaining.
#
#
# Start Scraping: Matwe Middelkoop
# Serve Page: 648
# Return Page: 648
# Raw Page: 648
# Finish Scraping 203 players.
# 31294 players remaining.
#
#
# Start Scraping: Gianluca Mager
# Serve Page: 687
# Return Page: 687
# Raw Page: 687
# Finish Scraping 204 players.
# 31293 players remaining.
#
#
# Start Scraping: Luke Saville
# Serve Page: 660
# Return Page: 660
# Raw Page: 660
# Finish Scraping 205 players.
# 31292 players remaining.
#
#
# Start Scraping: Bjorn Fratangelo
# Serve Page: 642
# Return Page: 642
# Raw Page: 642
# Finish Scraping 206 players.
# 31291 players remaining.
#
#
# Start Scraping: Laslo Djere
# Finish Scraping 207 players.
# 31290 players remaining.
#
#
# Start Scraping: Kaichi Uchida
# Finish Scraping 208 players.
# 31289 players remaining.
#
#
# Start Scraping: Tom Okker
# Finish Scraping 209 players.
# 31288 players remaining.
#
#
# Start Scraping: Attila Balazs
# Finish Scraping 210 players.
# 31287 players remaining.
#
#
# Start Scraping: Zdenek Kolar
# Finish Scraping 211 players.
# 31286 players remaining.
#
#
# Start Scraping: Denys Molchanov
# Finish Scraping 212 players.
# 31285 players remaining.
#
#
# Start Scraping: Joao Domingues
# Finish Scraping 213 players.
# 31284 players remaining.
#
#
# Start Scraping: Hugo Grenier
# Finish Scraping 214 players.
# 31283 players remaining.
#
#
# Start Scraping: Andrey Kuznetsov
# Finish Scraping 215 players.
# 31282 players remaining.
#
#
# Start Scraping: Daniel Masur
# Finish Scraping 216 players.
# 31281 players remaining.
#
#
# Start Scraping: Maxime Janvier
# Finish Scraping 217 players.
# 31280 players remaining.
#
#
# Start Scraping: Oscar Otte
# Finish Scraping 218 players.
# 31279 players remaining.
#
#
# Start Scraping: Alexandre Muller
# Finish Scraping 219 players.
# 31278 players remaining.
#
#
# Start Scraping: Yoshihito Nishioka
# Finish Scraping 220 players.
# 31277 players remaining.
#
#
# Start Scraping: Nicolas Jarry
# Serve Page: 658
# Return Page: 658
# Raw Page: 658
# Finish Scraping 221 players.
# 31276 players remaining.
#
#
# Start Scraping: Sekou Bangoura
# Serve Page: 637
# Return Page: 637
# Raw Page: 637
# Finish Scraping 222 players.
# 31275 players remaining.
#
#
# Start Scraping: Alex Bolt
# Finish Scraping 223 players.
# 31274 players remaining.
#
#
# Start Scraping: Guilherme Clezar
# Finish Scraping 224 players.
# 31273 players remaining.
#
#
# Start Scraping: Bernabe Zapata Miralles
# Serve Page: 661
# Return Page: 661
# Raw Page: 661
# Finish Scraping 225 players.
# 31272 players remaining.
#
#
# Start Scraping: Shuichi Sekiguchi
# Serve Page: 627
# Return Page: 627
# Raw Page: 627
# Finish Scraping 226 players.
# 31271 players remaining.
#
#
# Start Scraping: Ruben Ramirez Hidalgo
# Serve Page: 1244
# Return Page: 1244
# Raw Page: 1244
# Finish Scraping 227 players.
# 31270 players remaining.
#
#
# Start Scraping: Martin Cuevas
# Serve Page: 623
# Return Page: 623
# Raw Page: 623
# Finish Scraping 228 players.
# 31269 players remaining.
#
#
# Start Scraping: Ze Zhang
# Serve Page: 622
# Return Page: 622
# Raw Page: 622
# Finish Scraping 229 players.
# 31268 players remaining.
#
#
# Start Scraping: Gleb Sakharov
# Finish Scraping 230 players.
# 31267 players remaining.
#
#
# Start Scraping: Benjamin Bonzi
# Finish Scraping 231 players.
# 31266 players remaining.
#
#
# Start Scraping: Maximilian Marterer
# Finish Scraping 232 players.
# 31265 players remaining.
#
#
# Start Scraping: Karim Mohamed Maamoun
# Finish Scraping 233 players.
# 31264 players remaining.
#
#
# Start Scraping: Daniel Elahi Galan
# Finish Scraping 234 players.
# 31263 players remaining.
#
#
# Start Scraping: Juan Pablo Varillas
# Finish Scraping 235 players.
# 31262 players remaining.
#
#
# Start Scraping: Karen Khachanov
# Finish Scraping 236 players.
# 31261 players remaining.
#
#
# Start Scraping: Gonzalo Lama
# Finish Scraping 237 players.
# 31260 players remaining.
#
#
# Start Scraping: Marco Bortolotti
# Finish Scraping 238 players.
# 31259 players remaining.
#
#
# Start Scraping: Antoine Hoang
# Finish Scraping 239 players.
# 31258 players remaining.
#
#
# Start Scraping: Cristian Garin
# Finish Scraping 240 players.
# 31257 players remaining.
#
#
# Start Scraping: Darian King
# Finish Scraping 241 players.
# 31256 players remaining.
#
#
# Start Scraping: Nino Serdarusic
# Finish Scraping 242 players.
# 31255 players remaining.
#
#
# Start Scraping: Aisam Ul Haq Qureshi
# Finish Scraping 243 players.
# 31254 players remaining.
#
#
# Start Scraping: Marcelo Arevalo
# Serve Page: 610
# Return Page: 610
# Raw Page: 610
# Finish Scraping 244 players.
# 31253 players remaining.
#
#
# Start Scraping: Aleksandr Nedovyesov
# Serve Page: 605
# Return Page: 605
# Raw Page: 605
# Finish Scraping 245 players.
# 31252 players remaining.
#
#
# Start Scraping: Takuto Niki
# Serve Page: 604
# Return Page: 604
# Raw Page: 604
# Finish Scraping 246 players.
# 31251 players remaining.
#
#
# Start Scraping: Federico Zeballos
# Finish Scraping 247 players.
# 31250 players remaining.
#
#
# Start Scraping: Joris De Loore
# Finish Scraping 248 players.
# 31249 players remaining.
#
#
# Start Scraping: Jaume Munar
# Finish Scraping 249 players.
# 31248 players remaining.
#
#
# Start Scraping: Gonzalo Villanueva
# Finish Scraping 250 players.
# 31247 players remaining.
#
#
# Start Scraping: Tomas Lipovsek Puches
# Finish Scraping 251 players.
# 31246 players remaining.
#
#
# Start Scraping: David Marrero
# Finish Scraping 252 players.
# 31245 players remaining.
#
#
# Start Scraping: Nikola Milojevic
# Finish Scraping 253 players.
# 31244 players remaining.
#
#
# Start Scraping: Pedro Sakamoto
# Finish Scraping 254 players.
# 31243 players remaining.
#
#
# Start Scraping: Pol Toledo Bague
# Finish Scraping 255 players.
# 31242 players remaining.
#
#
# Start Scraping: Sebastian Ofner
# Finish Scraping 256 players.
# 31241 players remaining.
#
#
# Start Scraping: Marcos Giron
# Finish Scraping 257 players.
# 31240 players remaining.
#
#
# Start Scraping: Jerzy Janowicz
# Finish Scraping 258 players.
# 31239 players remaining.
#
#
# Start Scraping: Fernando Romboli
# Finish Scraping 259 players.
# 31238 players remaining.
#
#
# Start Scraping: Vishnu Vardhan
# Finish Scraping 260 players.
# 31237 players remaining.
#
#
# Start Scraping: Andre Agassi
# Finish Scraping 261 players.
# 31236 players remaining.
#
#
# Start Scraping: Tommy Paul
# Finish Scraping 262 players.
# 31235 players remaining.
#
#
# Start Scraping: Sasi Kumar Mukund
# Finish Scraping 263 players.
# 31234 players remaining.
#
#
# Start Scraping: Jason Kubler
# Serve Page: 587
# Return Page: 587
# Raw Page: 587
# Finish Scraping 264 players.
# 31233 players remaining.
#
#
# Start Scraping: Carlos Taberner
# Serve Page: 639
# Return Page: 639
# Raw Page: 639
# Finish Scraping 265 players.
# 31232 players remaining.
#
#
# Start Scraping: Matias Franco Descotte
# Finish Scraping 266 players.
# 31231 players remaining.
#
#
# Start Scraping: Lucas Pouille
# Finish Scraping 267 players.
# 31230 players remaining.
#
#
# Start Scraping: Calvin Hemery
# Finish Scraping 268 players.
# 31229 players remaining.
#
#
# Start Scraping: Taylor Fritz
# Finish Scraping 269 players.
# 31228 players remaining.
#
#
# Start Scraping: Tiago Lopes
# Finish Scraping 270 players.
# 31227 players remaining.
#
#
# Start Scraping: Manuel Orantes
# Finish Scraping 271 players.
# 31226 players remaining.
#
#
# Start Scraping: Maximiliano Estevez
# Finish Scraping 272 players.
# 31225 players remaining.
#
#
# Start Scraping: Ilya Ivashka
# Finish Scraping 273 players.
# 31224 players remaining.
#
#
# Start Scraping: Christopher Oconnell
# Finish Scraping 274 players.
# 31223 players remaining.
#
#
# Start Scraping: Jan Choinski
# Finish Scraping 275 players.
# 31222 players remaining.
#
#
# Start Scraping: Stefano Napolitano
# Finish Scraping 276 players.
# 31221 players remaining.
#
#
# Start Scraping: Marty Riessen
# Finish Scraping 277 players.
# 31220 players remaining.
#
#
# Start Scraping: Viktor Durasovic
# Finish Scraping 278 players.
# 31219 players remaining.
#
#
# Start Scraping: Nicolas Kicker
# Serve Page: 586
# Return Page: 586
# Raw Page: 586
# Finish Scraping 279 players.
# 31218 players remaining.
#
#
# Start Scraping: Pedja Krstin
# Finish Scraping 280 players.
# 31217 players remaining.
#
#
# Start Scraping: Jack Sock
# Finish Scraping 281 players.
# 31216 players remaining.
#
#
# Start Scraping: Laurent Lokoli
# Finish Scraping 282 players.
# 31215 players remaining.
#
#
# Start Scraping: Vladyslav Manafov
# Finish Scraping 283 players.
# 31214 players remaining.
#
#
# Start Scraping: Alexis Musialek
# Finish Scraping 284 players.
# 31213 players remaining.
#
#
# Start Scraping: Lorenzo Sonego
# Finish Scraping 285 players.
# 31212 players remaining.
#
#
# Start Scraping: Hubert Hurkacz
# Finish Scraping 286 players.
# 31211 players remaining.
#
#
# Start Scraping: Mats Moraing
# Finish Scraping 287 players.
# 31210 players remaining.
#
#
# Start Scraping: Tomas Berdych
# Finish Scraping 288 players.
# 31209 players remaining.
#
#
# Start Scraping: Ivo Karlovic
# Finish Scraping 289 players.
# 31208 players remaining.
#
#
# Start Scraping: Alexander Bublik
# Finish Scraping 290 players.
# 31207 players remaining.
#
#
# Start Scraping: Frances Tiafoe
# Finish Scraping 291 players.
# 31206 players remaining.
#
#
# Start Scraping: Lloyd Harris
# Finish Scraping 292 players.
# 31205 players remaining.
#
#
# Start Scraping: Benjamin Lock
# Serve Page: 635
# Return Page: 635
# Raw Page: 635
# Finish Scraping 293 players.
# 31204 players remaining.
#
#
# Start Scraping: John Mcenroe
# Serve Page: 1113
# Return Page: 1113
# Raw Page: 1113
# Finish Scraping 294 players.
# 31203 players remaining.
#
#
# Start Scraping: Mikhail Youzhny
# Serve Page: 1112
# Return Page: 1112
# Raw Page: 1112
# Finish Scraping 295 players.
# 31202 players remaining.
#
#
# Start Scraping: Cheong Eui Kim
# Serve Page: 557
# Return Page: 557
# Raw Page: 557
# Finish Scraping 296 players.
# 31201 players remaining.
#
#
# Start Scraping: Francesco Vilardo
# Serve Page: 557
# Return Page: 557
# Raw Page: 557
# Finish Scraping 297 players.
# 31200 players remaining.
#
#
# Start Scraping: Fabrice Santoro
# Serve Page: 1113
# Return Page: 1113
# Raw Page: 1113
# Finish Scraping 298 players.
# 31199 players remaining.
#
#
# Start Scraping: Carlos Berlocq
# Serve Page: 1109
# Return Page: 1109
# Raw Page: 1109
# Finish Scraping 299 players.
# 31198 players remaining.
#
#
# Start Scraping: Daniel Altmaier
# Serve Page: 606
# Return Page: 606
# Raw Page: 606
# Finish Scraping 300 players.
# 31197 players remaining.
#
#
# Start Scraping: Tony Roche
# Serve Page: 1083
# Return Page: 1083
# Raw Page: 1083
# Finish Scraping 301 players.
# 31196 players remaining.
#
#
# Start Scraping: Duck Hee Lee
# Serve Page: 577
# Return Page: 577
# Raw Page: 577
# Finish Scraping 302 players.
# 31195 players remaining.
#
#
# Start Scraping: Casper Ruud
# Serve Page: 612
# Return Page: 612
# Raw Page: 612
# Finish Scraping 303 players.
# 31194 players remaining.
#
#
# Start Scraping: Altug Celikbilek
# Serve Page: 599
# Return Page: 599
# Raw Page: 599
# Finish Scraping 304 players.
# 31193 players remaining.
#
#
# Start Scraping: Marc Polmans
# Serve Page: 584
# Return Page: 584
# Raw Page: 584
# Finish Scraping 305 players.
# 31192 players remaining.
#
#
# Start Scraping: Guillermo Garcia Lopez
# Serve Page: 1097
# Return Page: 1097
# Raw Page: 1097
# Finish Scraping 306 players.
# 31191 players remaining.
#
#
# Start Scraping: Juan Pablo Ficovich
# Serve Page: 609
# Return Page: 609
# Raw Page: 609
# Finish Scraping 307 players.
# 31190 players remaining.
#
#
# Start Scraping: Nerman Fatic
# Serve Page: 588
# Return Page: 588
# Raw Page: 588
# Finish Scraping 308 players.
# 31189 players remaining.
#
#
# Start Scraping: Tallon Griekspoor
# Serve Page: 593
# Return Page: 593
# Raw Page: 593
# Finish Scraping 309 players.
# 31188 players remaining.
#
#
# Start Scraping: Roman Safiullin
# Serve Page: 595
# Return Page: 595
# Raw Page: 595
# Finish Scraping 310 players.
# 31187 players remaining.
#
#
# Start Scraping: David Pichler
# Serve Page: 573
# Return Page: 573
# Raw Page: 573
# Finish Scraping 311 players.
# 31186 players remaining.
#
#
# Start Scraping: Yannick Hanfmann
# Serve Page: 584
# Return Page: 584
# Raw Page: 584
# Finish Scraping 312 players.
# 31185 players remaining.
#
#
# Start Scraping: Kamil Majchrzak
# Serve Page: 595
# Return Page: 595
# Raw Page: 595
# Finish Scraping 313 players.
# 31184 players remaining.
#
#
# Start Scraping: Yan Bai
# Serve Page: 604
# Return Page: 604
# Raw Page: 604
# Finish Scraping 314 players.
# 31183 players remaining.
#
#
# Start Scraping: Borna Coric
# Serve Page: 574
# Return Page: 574
# Raw Page: 574
# Finish Scraping 315 players.
# 31182 players remaining.
#
#
# Start Scraping: Corentin Denolly
# Serve Page: 605
# Return Page: 605
# Raw Page: 605
# Finish Scraping 316 players.
# 31181 players remaining.
#
#
# Start Scraping: Filippo Volandri
# Serve Page: 1070
# Return Page: 1070
# Raw Page: 1070
# Finish Scraping 317 players.
# 31180 players remaining.
#
#
# Start Scraping: Yen Hsun Lu
# Serve Page: 1077
# Return Page: 1077
# Raw Page: 1077
# Finish Scraping 318 players.
# 31179 players remaining.
#
#
# Start Scraping: Tak Khunn Wang
# Serve Page: 540
# Return Page: 540
# Raw Page: 540
# Finish Scraping 319 players.
# 31178 players remaining.
#
#
# Start Scraping: Cameron Norrie
# Serve Page: 569
# Return Page: 569
# Raw Page: 569
# Finish Scraping 320 players.
# 31177 players remaining.
#
#
# Start Scraping: Javier Marti
# Serve Page: 539
# Return Page: 539
# Raw Page: 539
# Finish Scraping 321 players.
# 31176 players remaining.
#
#
# Start Scraping: Stefan Edberg
# Serve Page: 1077
# Return Page: 1077
# Raw Page: 1077
# Finish Scraping 322 players.
# 31175 players remaining.
#
#
# Start Scraping: Michael Geerts
# Serve Page: 605
# Return Page: 605
# Raw Page: 605
# Finish Scraping 323 players.
# 31174 players remaining.
#
#
# Start Scraping: Enzo Couacaud
# Serve Page: 572
# Return Page: 572
# Raw Page: 572
# Finish Scraping 324 players.
# 31173 players remaining.
#
#
# Start Scraping: Sebastian Fanselow
# Serve Page: 584
# Return Page: 584
# Raw Page: 584
# Finish Scraping 325 players.
# 31172 players remaining.
#
#
# Start Scraping: John Alexander
# Serve Page: 1065
# Return Page: 1065
# Raw Page: 1065
# Finish Scraping 326 players.
# 31171 players remaining.
#
#
# Start Scraping: Ti Chen
# Serve Page: 1068
# Return Page: 1068
# Raw Page: 1068
# Finish Scraping 327 players.
# 31170 players remaining.
#
#
# Start Scraping: Albert Montanes
# Serve Page: 1060
# Return Page: 1060
# Raw Page: 1060
# Finish Scraping 328 players.
# 31169 players remaining.
#
#
# Start Scraping: Vit Kopriva
# Serve Page: 589
# Return Page: 589
# Raw Page: 589
# Finish Scraping 329 players.
# 31168 players remaining.
#
#
# Start Scraping: Elmar Ejupovic
# Serve Page: 582
# Return Page: 582
# Raw Page: 582
# Finish Scraping 330 players.
# 31167 players remaining.
#
#
# Start Scraping: Cedrik Marcel Stebe
# Serve Page: 531
# Return Page: 531
# Raw Page: 531
# Finish Scraping 331 players.
# 31166 players remaining.
#
#
# Start Scraping: Marcel Granollers
# Serve Page: 1063
# Return Page: 1063
# Raw Page: 1063
# Finish Scraping 332 players.
# 31165 players remaining.
#
#
# Start Scraping: Jan Mertl
# Serve Page: 1058
# Return Page: 1058
# Raw Page: 1058
# Finish Scraping 333 players.
# 31164 players remaining.
#
#
# Start Scraping: Jelle Sels
# Serve Page: 592
# Return Page: 592
# Raw Page: 592
# Finish Scraping 334 players.
# 31163 players remaining.
#
#
# Start Scraping: Daniel Gimeno Traver
# Serve Page: 1058
# Return Page: 1058
# Raw Page: 1058
# Finish Scraping 335 players.
# 31162 players remaining.
#
#
# Start Scraping: Yannick Maden
# Serve Page: 522
# Return Page: 522
# Raw Page: 522
# Finish Scraping 336 players.
# 31161 players remaining.
#
#
# Start Scraping: Brian Gottfried
# Serve Page: 1034
# Return Page: 1034
# Raw Page: 1034
# Finish Scraping 337 players.
# 31160 players remaining.
#
#
# Start Scraping: Franco Agamenone
# Serve Page: 572
# Return Page: 572
# Raw Page: 572
# Finish Scraping 338 players.
# 31159 players remaining.
#
#
# Start Scraping: Dominik Hrbaty
# Serve Page: 1051
# Return Page: 1051
# Raw Page: 1051
# Finish Scraping 339 players.
# 31158 players remaining.
#
#
# Start Scraping: Jules Marie
# Serve Page: 575
# Return Page: 575
# Raw Page: 575
# Finish Scraping 340 players.
# 31157 players remaining.
#
#
# Start Scraping: Kyle Edmund
# Serve Page: 568
# Return Page: 568
# Raw Page: 568
# Finish Scraping 341 players.
# 31156 players remaining.
#
#
# Start Scraping: Andres Gimeno
# Serve Page: 1163
# Return Page: 1163
# Raw Page: 1163
# Finish Scraping 342 players.
# 31155 players remaining.
#
#
# Start Scraping: Lucas Miedler
# Serve Page: 529
# Return Page: 529
# Raw Page: 529
# Finish Scraping 343 players.
# 31154 players remaining.
#
#
# Start Scraping: Jeremy Jahn
# Serve Page: 523
# Return Page: 523
# Raw Page: 523
# Finish Scraping 344 players.
# 31153 players remaining.
#
#
# Start Scraping: Eduard Esteve Lobato
# Serve Page: 522
# Return Page: 522
# Raw Page: 522
# Finish Scraping 345 players.
# 31152 players remaining.
#
#
# Start Scraping: Carlos Gomez Herrera
# Finish Scraping 346 players.
# 31151 players remaining.
#
#
# Start Scraping: N Sriram Balaji
# Finish Scraping 347 players.
# 31150 players remaining.
#
#
# Start Scraping: Geoffrey Blancaneaux
# Finish Scraping 348 players.
# 31149 players remaining.
#
#
# Start Scraping: Juan Ignacio Galarza
# Finish Scraping 349 players.
# 31148 players remaining.
#
#
# Start Scraping: Vaclav Safranek
# Finish Scraping 350 players.
# 31147 players remaining.
#
#
# Start Scraping: Jan Satral
# Finish Scraping 351 players.
# 31146 players remaining.
#
#
# Start Scraping: Prajnesh Gunneswaran
# Serve Page: 509
# Return Page: 509
# Raw Page: 509
# Finish Scraping 352 players.
# 31145 players remaining.
#
#
# Start Scraping: Nicolas Mahut
# Serve Page: 1023
# Return Page: 1023
# Raw Page: 1023
# Finish Scraping 353 players.
# 31144 players remaining.
#
#
# Start Scraping: Fred Stolle
# Serve Page: 1048
# Return Page: 1048
# Raw Page: 1048
# Finish Scraping 354 players.
# 31143 players remaining.
#
#
# Start Scraping: Alex De Minaur
# Serve Page: 564
# Return Page: 564
# Raw Page: 564
# Finish Scraping 355 players.
# 31142 players remaining.
#
#
# Start Scraping: Lucas Catarina
# Serve Page: 521
# Return Page: 521
# Raw Page: 521
# Finish Scraping 356 players.
# 31141 players remaining.
#
#
# Start Scraping: Roger Taylor
# Serve Page: 1007
# Return Page: 1007
# Raw Page: 1007
# Finish Scraping 357 players.
# 31140 players remaining.
#
#
# Start Scraping: Oscar Jose Gutierrez
# Serve Page: 548
# Return Page: 548
# Raw Page: 548
# Finish Scraping 358 players.
# 31139 players remaining.
#
#
# Start Scraping: Sumit Nagal
# Serve Page: 550
# Return Page: 550
# Raw Page: 550
# Finish Scraping 359 players.
# 31138 players remaining.
#
#
# Start Scraping: Alexander Lazov
# Serve Page: 511
# Return Page: 511
# Raw Page: 511
# Finish Scraping 360 players.
# 31137 players remaining.
#
#
# Start Scraping: Jarkko Nieminen
# Serve Page: 1019
# Return Page: 1019
# Raw Page: 1019
# Finish Scraping 361 players.
# 31136 players remaining.
#
#
# Start Scraping: John Patrick Smith
# Serve Page: 510
# Return Page: 510
# Raw Page: 510
# Finish Scraping 362 players.
# 31135 players remaining.
#
#
# Start Scraping: Aziz Dougaz
# Serve Page: 580
# Return Page: 580
# Raw Page: 580
# Finish Scraping 363 players.
# 31134 players remaining.
#
#
# Start Scraping: Matias Zukas
# Serve Page: 508
# Return Page: 508
# Raw Page: 508
# Finish Scraping 364 players.
# 31133 players remaining.
#
#
# Start Scraping: Rainer Schuettler
# Serve Page: 1013
# Return Page: 1013
# Raw Page: 1013
# Finish Scraping 365 players.
# 31132 players remaining.
#
#
# Start Scraping: Manuel Santana
# Serve Page: 1051
# Return Page: 1051
# Raw Page: 1051
# Finish Scraping 366 players.
# 31131 players remaining.
#
#
# Start Scraping: David Guez
# Serve Page: 1009
# Return Page: 1009
# Raw Page: 1009
# Finish Scraping 367 players.
# 31130 players remaining.
#
#
# Start Scraping: Radek Stepanek
# Serve Page: 970
# Return Page: 970
# Raw Page: 970
# Finish Scraping 368 players.
# 31129 players remaining.
#
#
# Start Scraping: Mariano Kestelboim
# Serve Page: 546
# Return Page: 546
# Raw Page: 546
# Finish Scraping 369 players.
# 31128 players remaining.
#
#
# Start Scraping: Ernesto Escobedo
# Serve Page: 551
# Return Page: 551
# Raw Page: 551
# Finish Scraping 370 players.
# 31127 players remaining.
#
#
# Start Scraping: Stefan Kozlov
# Serve Page: 541
# Return Page: 541
# Raw Page: 541
# Finish Scraping 371 players.
# 31126 players remaining.
#
#
# Start Scraping: Michael Chang
# Serve Page: 1010
# Return Page: 1010
# Raw Page: 1010
# Finish Scraping 372 players.
# 31125 players remaining.
#
#
# Start Scraping: Jan Kodes
# Serve Page: 1004
# Return Page: 1004
# Raw Page: 1004
# Finish Scraping 373 players.
# 31124 players remaining.
#
#
# Start Scraping: Roberto Quiroz
# Serve Page: 506
# Return Page: 506
# Raw Page: 506
# Finish Scraping 374 players.
# 31123 players remaining.
#
#
# Start Scraping: Tobias Simon
# Serve Page: 505
# Return Page: 505
# Raw Page: 505
# Finish Scraping 375 players.
# 31122 players remaining.
#
#
# Start Scraping: Yuki Bhambri
# Serve Page: 503
# Return Page: 503
# Raw Page: 503
# Finish Scraping 376 players.
# 31121 players remaining.
#
#
# Start Scraping: Carlos Moya
# Serve Page: 1006
# Return Page: 1006
# Raw Page: 1006
# Finish Scraping 377 players.
# 31120 players remaining.
#
#
# Start Scraping: Cliff Richey
# Serve Page: 980
# Return Page: 980
# Raw Page: 980
# Finish Scraping 378 players.
# 31119 players remaining.
#
#
# Start Scraping: Nikolay Davydenko
# Serve Page: 998
# Return Page: 998
# Raw Page: 998
# Finish Scraping 379 players.
# 31118 players remaining.
#
#
# Start Scraping: Alexey Kedryuk
# Serve Page: 497
# Return Page: 497
# Raw Page: 497
# Finish Scraping 380 players.
# 31117 players remaining.
#
#
# Start Scraping: Pete Sampras
# Serve Page: 1000
# Return Page: 1000
# Raw Page: 1000
# Finish Scraping 381 players.
# 31116 players remaining.
#
#
# Start Scraping: Jaime Fillol
# Serve Page: 22
# Return Page: 22
# Raw Page: 22
# Finish Scraping 382 players.
# 31115 players remaining.
#
#
# Start Scraping: Mackenzie Mcdonald
# Finish Scraping 383 players.
# 31114 players remaining.
#
#
# Start Scraping: Michael Russell
# Finish Scraping 384 players.
# 31113 players remaining.
#
#
# Start Scraping: Tomas Barrios Vera
# Finish Scraping 385 players.
# 31112 players remaining.
#
#
# Start Scraping: Frederico Gil
# Finish Scraping 386 players.
# 31111 players remaining.
#
#
# Start Scraping: Dustin Brown
# Finish Scraping 387 players.
# 31110 players remaining.
#
#
# Start Scraping: Alessio Di Mauro
# Finish Scraping 388 players.
# 31109 players remaining.
#
#
# Start Scraping: Yevgeny Kafelnikov
# Serve Page: 991
# Return Page: 991
# Raw Page: 991
# Finish Scraping 389 players.
# 31108 players remaining.
#
#
# Start Scraping: Evan King
# Serve Page: 497
# Return Page: 497
# Raw Page: 497
# Finish Scraping 390 players.
# 31107 players remaining.
#
#
# Start Scraping: Thomas Muster
# Serve Page: 986
# Return Page: 986
# Raw Page: 986
# Finish Scraping 391 players.
# 31106 players remaining.
#
#
# Start Scraping: Bogdan Bobrov
# Serve Page: 549
# Return Page: 549
# Raw Page: 549
# Finish Scraping 392 players.
# 31105 players remaining.
#
#
# Start Scraping: Michael Mmoh
# Serve Page: 491
# Return Page: 491
# Raw Page: 491
# Finish Scraping 393 players.
# 31104 players remaining.
#
#
# Start Scraping: Artem Sitak
# Serve Page: 492
# Return Page: 492
# Raw Page: 492
# Finish Scraping 394 players.
# 31103 players remaining.
#
#
# Start Scraping: Sidharth Rawat
# Serve Page: 513
# Return Page: 513
# Raw Page: 513
# Finish Scraping 395 players.
# 31102 players remaining.
#
#
# Start Scraping: Roman Jebavy
# Serve Page: 487
# Return Page: 487
# Raw Page: 487
# Finish Scraping 396 players.
# 31101 players remaining.
#
#
# Start Scraping: Ugo Humbert
# Serve Page: 535
# Return Page: 535
# Raw Page: 535
# Finish Scraping 397 players.
# 31100 players remaining.
#
#
# Start Scraping: Felix Auger Aliassime
# Serve Page: 535
# Return Page: 535
# Raw Page: 535
# Finish Scraping 398 players.
# 31099 players remaining.
#
#
# Start Scraping: David Poljak
# Serve Page: 509
# Return Page: 509
# Raw Page: 509
# Finish Scraping 399 players.
# 31098 players remaining.
#
#
# Start Scraping: Ranjeet Virali Murugesan
# Serve Page: 488
# Return Page: 488
# Raw Page: 488
# Finish Scraping 400 players.
# 31097 players remaining.
#
#
# Start Scraping: Tommy Haas
# Serve Page: 975
# Return Page: 975
# Raw Page: 975
# Finish Scraping 401 players.
# 31096 players remaining.
#
#
# Start Scraping: Vincent Spadea
# Serve Page: 969
# Return Page: 969
# Raw Page: 969
# Finish Scraping 402 players.
# 31095 players remaining.
#
#
# Start Scraping: Harold Solomon
# Serve Page: 957
# Return Page: 957
# Raw Page: 957
# Finish Scraping 403 players.
# 31094 players remaining.
#
#
# Start Scraping: Cliff Drysdale
# Serve Page: 948
# Return Page: 948
# Raw Page: 948
# Finish Scraping 404 players.
# 31093 players remaining.
#
#
# Start Scraping: Antoine Bellier
# Serve Page: 517
# Return Page: 517
# Raw Page: 517
# Finish Scraping 405 players.
# 31092 players remaining.
#
#
# Start Scraping: Albano Olivetti
# Serve Page: 487
# Return Page: 487
# Raw Page: 487
# Finish Scraping 406 players.
# 31091 players remaining.
#
#
# Start Scraping: Yann Marti
# Serve Page: 486
# Return Page: 486
# Raw Page: 486
# Finish Scraping 407 players.
# 31090 players remaining.
#
#
# Start Scraping: Alejandro Tabilo
# Finish Scraping 408 players.
# 31089 players remaining.
#
#
# Start Scraping: Christopher Heyman
# Finish Scraping 409 players.
# 31088 players remaining.
#
#
# Start Scraping: Bob Hewitt
# Finish Scraping 410 players.
# 31087 players remaining.
#
#
# Start Scraping: Omar Giacalone
# Finish Scraping 411 players.
# 31086 players remaining.
#
#
# Start Scraping: Michael Berrer
# Finish Scraping 412 players.
# 31085 players remaining.
#
#
# Start Scraping: Edan Leshem
# Finish Scraping 413 players.
# 31084 players remaining.
#
#
# Start Scraping: Botic Van De Zandschulp
# Serve Page: 535
# Return Page: 535
# Raw Page: 535
# Finish Scraping 414 players.
# 31083 players remaining.
#
#
# Start Scraping: Adam Pavlasek
# Serve Page: 482
# Return Page: 482
# Raw Page: 482
# Finish Scraping 415 players.
# 31082 players remaining.
#
#
# Start Scraping: Nicolas Lapentti
# Serve Page: 958
# Return Page: 958
# Raw Page: 958
# Finish Scraping 416 players.
# 31081 players remaining.
#
#
# Start Scraping: Gilles Muller
# Serve Page: 960
# Return Page: 960
# Raw Page: 960
# Finish Scraping 417 players.
# 31080 players remaining.
#
#
# Start Scraping: Charlie Pasarell
# Serve Page: 937
# Return Page: 937
# Raw Page: 937
# Finish Scraping 418 players.
# 31079 players remaining.
#
#
# Start Scraping: Danai Udomchoke
# Serve Page: 907
# Return Page: 907
# Raw Page: 907
# Finish Scraping 419 players.
# 31078 players remaining.
#
#
# Start Scraping: Tim Henman
# Serve Page: 959
# Return Page: 959
# Raw Page: 959
# Finish Scraping 420 players.
# 31077 players remaining.
#
#
# Start Scraping: Moez Echargui
# Serve Page: 520
# Return Page: 520
# Raw Page: 520
# Finish Scraping 421 players.
# 31076 players remaining.
#
#
# Start Scraping: Bob Lutz
# Serve Page: 947
# Return Page: 947
# Raw Page: 947
# Finish Scraping 422 players.
# 31075 players remaining.
#
#
# Start Scraping: Akira Santillan
# Serve Page: 480
# Return Page: 480
# Raw Page: 480
# Finish Scraping 423 players.
# 31074 players remaining.
#
#
# Start Scraping: Nick Chappell
# Serve Page: 513
# Return Page: 513
# Raw Page: 513
# Finish Scraping 424 players.
# 31073 players remaining.
#
#
# Start Scraping: Mario Vilella Martinez
# Finish Scraping 425 players.
# 31072 players remaining.
#
#
# Start Scraping: Jurgen Melzer
# Finish Scraping 426 players.
# 31071 players remaining.
#
#
# ...
# Finish Scraping 6427 players.
# 25070 players remaining.
#
#
# Start Scraping: Theo Arribage
# Finish Scraping 6428 players.
# 25069 players remaining.
#
#
# Start Scraping: Brandon Murphy
# Finish Scraping 6429 players.
# 25068 players remaining.
#
#
# Start Scraping: Raghav Jaisinghani
# Finish Scraping 6430 players.
# 25067 players remaining.
#
#
# Start Scraping: Dominik Langmajer
# Finish Scraping 6431 players.
# 25066 players remaining.
#
#
# Start Scraping: Bharath Nishok Kumaran
# Finish Scraping 6432 players.
# 25065 players remaining.
#
#
# Start Scraping: Miguel Fernando Pereira
# Finish Scraping 6433 players.
# 25064 players remaining.
#
#
# Start Scraping: Arjun Mehrotra
# Finish Scraping 6434 players.
# 25063 players remaining.
#
#
# Start Scraping: Alberto Lim
# Finish Scraping 6435 players.
# 25062 players remaining.
#
#
# Start Scraping: Christian Lakoseljac
# Finish Scraping 6436 players.
# 25061 players remaining.
#
#
# Start Scraping: Yair Sarouk
# Finish Scraping 6437 players.
# 25060 players remaining.
#
#
# Start Scraping: Jannik Opitz
# Finish Scraping 6438 players.
# 25059 players remaining.
#
#
# Start Scraping: Felipe Derdoy
# Finish Scraping 6439 players.
# 25058 players remaining.
#
#
# Start Scraping: Mats Hermans
# Finish Scraping 6440 players.
# 25057 players remaining.
#
#
# Start Scraping: Hugo Largo
# Finish Scraping 6441 players.
# 25056 players remaining.
#
#
# Start Scraping: Horst Rieder
# Finish Scraping 6442 players.
# 25055 players remaining.
#
#
# Start Scraping: Stephanos Schinas
# Finish Scraping 6443 players.
# 25054 players remaining.
#
#
# Start Scraping: Joachim Bjerke
# Finish Scraping 6444 players.
# 25053 players remaining.
#
#
# Start Scraping: Hao Yuan Ng
# Finish Scraping 6445 players.
# 25052 players remaining.
#
#
# Start Scraping: Carlos Cirne Lima
# Finish Scraping 6446 players.
# 25051 players remaining.
#
#
# Start Scraping: Alfonso Ochoa
# Finish Scraping 6447 players.
# 25050 players remaining.
#
#
# Start Scraping: Pancho Contreras
# Finish Scraping 6448 players.
# 25049 players remaining.
#
#
# Start Scraping: Fausto Gardini
# Finish Scraping 6449 players.
# 25048 players remaining.
#
#
# Start Scraping: Shotaro Goto
# Finish Scraping 6450 players.
# 25047 players remaining.
#
#
# Start Scraping: Ron Goldman
# Finish Scraping 6451 players.
# 25046 players remaining.
#
#
# Start Scraping: Brian Cheney
# Finish Scraping 6452 players.
# 25045 players remaining.
#
#
# Start Scraping: John De Mendoza
# Finish Scraping 6453 players.
# 25044 players remaining.
#
#
# Start Scraping: Pavel Tsoy
# Finish Scraping 6454 players.
# 25043 players remaining.
#
#
# Start Scraping: Jae Min Seol
# Finish Scraping 6455 players.
# 25042 players remaining.
#
#
# Start Scraping: Bill Durham
# Finish Scraping 6456 players.
# 25041 players remaining.
#
#
# Start Scraping: Thomas Breuninger
# Finish Scraping 6457 players.
# 25040 players remaining.
#
#
# Start Scraping: Sebastien Mattieu
# Finish Scraping 6458 players.
# 25039 players remaining.
#
#
# Start Scraping: Sebastian Soresini
# Finish Scraping 6459 players.
# 25038 players remaining.
#
#
# Start Scraping: Robert Kresberg
# Finish Scraping 6460 players.
# 25037 players remaining.
#
#
# Start Scraping: Pietro Marzano
# Finish Scraping 6461 players.
# 25036 players remaining.
#
#
# Start Scraping: Geza Varga
# Finish Scraping 6462 players.
# 25035 players remaining.
#
#
# Start Scraping: Guillermo Nunez
# Finish Scraping 6463 players.
# 25034 players remaining.
#
#
# Start Scraping: Marcelo Plaza
# Finish Scraping 6464 players.
# 25033 players remaining.
#
#
# Start Scraping: Lucas Jovita
# Finish Scraping 6465 players.
# 25032 players remaining.
#
#
# Start Scraping: Miles Bugby
# Finish Scraping 6466 players.
# 25031 players remaining.
#
#
# Start Scraping: Matias Niemiz
# Finish Scraping 6467 players.
# 25030 players remaining.
#
#
# Start Scraping: Morgan Wilson
# Finish Scraping 6468 players.
# 25029 players remaining.
#
#
# Start Scraping: Aleksandar Maric
# Finish Scraping 6469 players.
# 25028 players remaining.
#
#
# Start Scraping: Rouzbeh Kamran
# Finish Scraping 6470 players.
# 25027 players remaining.
#
#
# Start Scraping: Sebastian Linda
# Finish Scraping 6471 players.
# 25026 players remaining.
#
#
# Start Scraping: Nathan Price
# Finish Scraping 6472 players.
# 25025 players remaining.
#
#
# Start Scraping: Daniel Schalen
# Finish Scraping 6473 players.
# 25024 players remaining.
#
#
# Start Scraping: Kane Dewhurst
# Finish Scraping 6474 players.
# 25023 players remaining.
#
#
# Start Scraping: Dmitri Kourilovich
# Finish Scraping 6475 players.
# 25022 players remaining.
#
#
# Start Scraping: Clinton Snell
# Finish Scraping 6476 players.
# 25021 players remaining.
#
#
# Start Scraping: Michael Flanagan
# Finish Scraping 6477 players.
# 25020 players remaining.
#
#
# Start Scraping: Brandon Coupe
# Finish Scraping 6478 players.
# 25019 players remaining.
#
#
# Start Scraping: Krister Wedenby
# Finish Scraping 6479 players.
# 25018 players remaining.
#
#
# Start Scraping: Jan Willem Lodder
# Finish Scraping 6480 players.
# 25017 players remaining.
#
#
# Start Scraping: Stephen Botfield
# Finish Scraping 6481 players.
# 25016 players remaining.
#
#
# Start Scraping: John Letts
# Finish Scraping 6482 players.
# 25015 players remaining.
#
#
# Start Scraping: Tjahjono Tjahjono
# Finish Scraping 6483 players.
# 25014 players remaining.
#
#
# Start Scraping: Jean Marc Piacentile
# Finish Scraping 6484 players.
# 25013 players remaining.
#
#
# Start Scraping: Thierry Pham
# Finish Scraping 6485 players.
# 25012 players remaining.
#
#
# Start Scraping: Mark Vines
# Finish Scraping 6486 players.
# 25011 players remaining.
#
#
# Start Scraping: Junie Chatman
# Finish Scraping 6487 players.
# 25010 players remaining.
#
#
# Start Scraping: Ian Harris
# Finish Scraping 6488 players.
# 25009 players remaining.
#
#
# Start Scraping: Stanley Pasarell
# Finish Scraping 6489 players.
# 25008 players remaining.
#
#
# Start Scraping: Matteo Tinelli
# Finish Scraping 6490 players.
# 25007 players remaining.
#
#
# Start Scraping: Quim Sorni Chavarria
# Finish Scraping 6491 players.
# 25006 players remaining.
#
#
# Start Scraping: Juan Montes
# Finish Scraping 6492 players.
# 25005 players remaining.
#
#
# Start Scraping: Jin Ho Lee
# Finish Scraping 6493 players.
# 25004 players remaining.
#
#
# Start Scraping: Sagar Ahuja
# Finish Scraping 6494 players.
# 25003 players remaining.
#
#
# Start Scraping: Mike Franks
# Finish Scraping 6495 players.
# 25002 players remaining.
#
#
# Start Scraping: Anders Haseth
# Finish Scraping 6496 players.
# 25001 players remaining.
#
#
# Start Scraping: Tejas Chaukulkar
# Finish Scraping 6497 players.
# 25000 players remaining.
#
#
# Start Scraping: Mathias Werren
# Finish Scraping 6498 players.
# 24999 players remaining.
#
#
# Start Scraping: Vittorio Crotta
# Finish Scraping 6499 players.
# 24998 players remaining.
#
#
# Start Scraping: Worapol Thongkamcho
# Finish Scraping 6500 players.
# 24997 players remaining.
#
#
# Start Scraping: Reto Staubli
# Finish Scraping 6501 players.
# 24996 players remaining.
#
#
# Start Scraping: Levente Baratosi
# Finish Scraping 6502 players.
# 24995 players remaining.
#
#
# Start Scraping: Naoki Takeda
# Finish Scraping 6503 players.
# 24994 players remaining.
#
#
# Start Scraping: Ilija Martinoski
# Finish Scraping 6504 players.
# 24993 players remaining.
#
#
# Start Scraping: Dylan Sessagesimi
# Finish Scraping 6505 players.
# 24992 players remaining.
#
#
# Start Scraping: Francisco Franco
# Finish Scraping 6506 players.
# 24991 players remaining.
#
#
# Start Scraping: Lukas Weinhandl
# Finish Scraping 6507 players.
# 24990 players remaining.
#
#
# Start Scraping: Dmytro Petrov
# Finish Scraping 6508 players.
# 24989 players remaining.
#
#
# Start Scraping: Ryan Rowe
# Finish Scraping 6509 players.
# 24988 players remaining.
#
#
# Start Scraping: Jamie Murray
# Finish Scraping 6510 players.
# 24987 players remaining.
#
#
# Start Scraping: Rudolf Siwy
# Finish Scraping 6511 players.
# 24986 players remaining.
#
#
# Start Scraping: Rafael Farias
# Finish Scraping 6512 players.
# 24985 players remaining.
#
#
# Start Scraping: David Stojan
# Finish Scraping 6513 players.
# 24984 players remaining.
#
#
# Start Scraping: Johny De Leon
# Finish Scraping 6514 players.
# 24983 players remaining.
#
#
# Start Scraping: Andrea Fava
# Finish Scraping 6515 players.
# 24982 players remaining.
#
#
# Start Scraping: Sung Kyun Kang
# Finish Scraping 6516 players.
# 24981 players remaining.
#
#
# Start Scraping: Diego Acuna
# Finish Scraping 6517 players.
# 24980 players remaining.
#
#
# Start Scraping: Daniel Casquero
# Finish Scraping 6518 players.
# 24979 players remaining.
#
#
# Start Scraping: Krystian Pfeiffer
# Finish Scraping 6519 players.
# 24978 players remaining.
#
#
# Start Scraping: Ramsey Smith
# Finish Scraping 6520 players.
# 24977 players remaining.
#
#
# Start Scraping: Anton Klaric
# Finish Scraping 6521 players.
# 24976 players remaining.
#
#
# Start Scraping: Peter Madarassy
# Finish Scraping 6522 players.
# 24975 players remaining.
#
#
# Start Scraping: Herwig Ribitsch
# Finish Scraping 6523 players.
# 24974 players remaining.
#
#
# Start Scraping: Thomas Perchtold
# Finish Scraping 6524 players.
# 24973 players remaining.
#
#
# Start Scraping: Ashley Fisher
# Finish Scraping 6525 players.
# 24972 players remaining.
#
#
# Start Scraping: Alberto Brause
# Finish Scraping 6526 players.
# 24971 players remaining.
#
#
# Start Scraping: Fernando Samayoa
# Finish Scraping 6527 players.
# 24970 players remaining.
#
#
# Start Scraping: Patrick Nestler
# Finish Scraping 6528 players.
# 24969 players remaining.
#
#
# Start Scraping: Razvan Itu
# Finish Scraping 6529 players.
# 24968 players remaining.
#
#
# Start Scraping: Eduardo Velez
# Finish Scraping 6530 players.
# 24967 players remaining.
#
#
# Start Scraping: Fredrik Perman
# Finish Scraping 6531 players.
# 24966 players remaining.
#
#
# Start Scraping: Scott Warner
# Finish Scraping 6532 players.
# 24965 players remaining.
#
#
# Start Scraping: Ian Aler
# Finish Scraping 6533 players.
# 24964 players remaining.
#
#
# Start Scraping: Henri De Wet
# Finish Scraping 6534 players.
# 24963 players remaining.
#
#
# Start Scraping: Ahmed El Mehelmy
# Finish Scraping 6535 players.
# 24962 players remaining.
#
#
# Start Scraping: Hugo Nunez
# Finish Scraping 6536 players.
# 24961 players remaining.
#
#
# Start Scraping: Jeff Turpin
# Finish Scraping 6537 players.
# 24960 players remaining.
#
#
# Start Scraping: Mike Brunnberg
# Finish Scraping 6538 players.
# 24959 players remaining.
#
#
# Start Scraping: Mike Wayman
# Finish Scraping 6539 players.
# 24958 players remaining.
#
#
# Start Scraping: Tony Bardsley
# Finish Scraping 6540 players.
# 24957 players remaining.
#
#
# Start Scraping: Yanis Ghazouani Durand
# Finish Scraping 6541 players.
# 24956 players remaining.
#
#
# Start Scraping: Ethan Cook
# Finish Scraping 6542 players.
# 24955 players remaining.
#
#
# Start Scraping: Antoine Vincent
# Finish Scraping 6543 players.
# 24954 players remaining.
#
#
# Start Scraping: Bruno Fernandez
# Finish Scraping 6544 players.
# 24953 players remaining.
#
#
# Start Scraping: Aleksander Orlikowski
# Finish Scraping 6545 players.
# 24952 players remaining.
#
#
# Start Scraping: Fons Van Sambeek
# Finish Scraping 6546 players.
# 24951 players remaining.
#
#
# Start Scraping: Luc Koenig
# Finish Scraping 6547 players.
# 24950 players remaining.
#
#
# Start Scraping: Stefano Dagostino
# Finish Scraping 6548 players.
# 24949 players remaining.
#
#
# Start Scraping: Nikita Volonski
# Finish Scraping 6549 players.
# 24948 players remaining.
#
#
# Start Scraping: Muzammil Murtaza
# Finish Scraping 6550 players.
# 24947 players remaining.
#
#
# Start Scraping: Martins Rocens
# Finish Scraping 6551 players.
# 24946 players remaining.
#
#
# Start Scraping: Michalis Sakellaridis
# Finish Scraping 6552 players.
# 24945 players remaining.
#
#
# Start Scraping: Pasquale De Giorgio
# Finish Scraping 6553 players.
# 24944 players remaining.
#
#
# Start Scraping: Loris Pourroy
# Finish Scraping 6554 players.
# 24943 players remaining.
#
#
# Start Scraping: Lazar Vojinovic
# Finish Scraping 6555 players.
# 24942 players remaining.
#
#
# Start Scraping: Linus Frost
# Finish Scraping 6556 players.
# 24941 players remaining.
#
#
# Start Scraping: Bill Moss
# Finish Scraping 6557 players.
# 24940 players remaining.
#
#
# Start Scraping: Hugo Pierre
# Finish Scraping 6558 players.
# 24939 players remaining.
#
#
# Start Scraping: Huixin Wang
# Finish Scraping 6559 players.
# 24938 players remaining.
#
#
# Start Scraping: Dmitry Mnushkin
# Finish Scraping 6560 players.
# 24937 players remaining.
#
#
# Start Scraping: Tim Kopinski
# Finish Scraping 6561 players.
# 24936 players remaining.
#
#
# Start Scraping: Henrique Sousa
# Finish Scraping 6562 players.
# 24935 players remaining.
#
#
# Start Scraping: Thomas Prerovsky
# Finish Scraping 6563 players.
# 24934 players remaining.
#
#
# Start Scraping: Ruslon Rainov
# Finish Scraping 6564 players.
# 24933 players remaining.
#
#
# Start Scraping: Joost Wijnhoud
# Finish Scraping 6565 players.
# 24932 players remaining.
#
#
# Start Scraping: Jan Hordijk
# Finish Scraping 6566 players.
# 24931 players remaining.
#
#
# Start Scraping: Hernan Colombo Russel
# Finish Scraping 6567 players.
# 24930 players remaining.
#
#
# Start Scraping: Bernard Balleret
# Finish Scraping 6568 players.
# 24929 players remaining.
#
#
# Start Scraping: Nebojsa Peric
# Finish Scraping 6569 players.
# 24928 players remaining.
#
#
# Start Scraping: Serizhan Yessenbekov
# Finish Scraping 6570 players.
# 24927 players remaining.
#
#
# Start Scraping: Aaron Leeder Chard
# Finish Scraping 6571 players.
# 24926 players remaining.
#
#
# Start Scraping: Louis Cant
# Finish Scraping 6572 players.
# 24925 players remaining.
#
#
# Start Scraping: Jae Won Choi
# Finish Scraping 6573 players.
# 24924 players remaining.
#
#
# Start Scraping: Alejandro Moreno Figueroa
# Finish Scraping 6574 players.
# 24923 players remaining.
#
#
# Start Scraping: Marcus Weiglhofer
# Finish Scraping 6575 players.
# 24922 players remaining.
#
#
# Start Scraping: Philip Orno
# Finish Scraping 6576 players.
# 24921 players remaining.
#
#
# Start Scraping: Ajai Selvaraj
# Finish Scraping 6577 players.
# 24920 players remaining.
#
#
# Start Scraping: Nikolai Soloviev
# Finish Scraping 6578 players.
# 24919 players remaining.
#
#
# Start Scraping: Valentine Kassatkine
# Finish Scraping 6579 players.
# 24918 players remaining.
#
#
# Start Scraping: Joel Kielbowicz
# Finish Scraping 6580 players.
# 24917 players remaining.
#
#
# Start Scraping: Mario Monroy
# Start Scraping: John Mcgahon
# Finish Scraping 6582 players.
# 24915 players remaining.
#
#
# Start Scraping: Raimonds Sproga
# Finish Scraping 6583 players.
# 24914 players remaining.
#
#
# Start Scraping: Alejandro Asta
# Finish Scraping 6584 players.
# 24913 players remaining.
#
#
# Start Scraping: Masashi Tokumaru
# Finish Scraping 6585 players.
# 24912 players remaining.
#
#
# Start Scraping: Shahab Hassani Nafez
# Finish Scraping 6586 players.
# 24911 players remaining.
#
#
# Start Scraping: Michal Chmela
# Finish Scraping 6587 players.
# 24910 players remaining.
#
#
# Start Scraping: Borut Martincevic
# Finish Scraping 6588 players.
# 24909 players remaining.
#
#
# Start Scraping: Rodolfo Varela
# Finish Scraping 6589 players.
# 24908 players remaining.
#
#
# Start Scraping: Alexander Gietl
# Finish Scraping 6590 players.
# 24907 players remaining.
#
#
# Start Scraping: Muhammad Khaliq Siddiq
# Finish Scraping 6591 players.
# 24906 players remaining.
#
#
# Start Scraping: Jesse Walter
# Finish Scraping 6592 players.
# 24905 players remaining.
#
#
# Start Scraping: Brivael Maillet
# Finish Scraping 6593 players.
# 24904 players remaining.
#
#
# Start Scraping: Chris Mahony
# Finish Scraping 6594 players.
# 24903 players remaining.
#
#
# Start Scraping: Ryan Clark
# Finish Scraping 6595 players.
# 24902 players remaining.
#
#
# Start Scraping: Mark Booras
# Finish Scraping 6596 players.
# 24901 players remaining.
#
#
# Start Scraping: Rudiger Haas
# Finish Scraping 6597 players.
# 24900 players remaining.
#
#
# Start Scraping: Axel Hornung
# Finish Scraping 6598 players.
# 24899 players remaining.
#
#
# Start Scraping: Mark Avedikian
# Finish Scraping 6599 players.
# 24898 players remaining.
#
#
# Start Scraping: Tom Mercer
# Finish Scraping 6600 players.
# 24897 players remaining.
#
#
# Start Scraping: Hugo Chapacu
# Finish Scraping 6601 players.
# 24896 players remaining.
#
#
# Start Scraping: Marco Armellini
# Finish Scraping 6602 players.
# 24895 players remaining.
#
#
# Start Scraping: Noel Phillips
# Finish Scraping 6603 players.
# 24894 players remaining.
#
#
# Start Scraping: Felipe Martinez Sarrasague
# Finish Scraping 6604 players.
# 24893 players remaining.
#
#
# Start Scraping: Alexander Ovcharov
# Finish Scraping 6605 players.
# 24892 players remaining.
#
#
# Start Scraping: Rainer Marzenell
# Finish Scraping 6606 players.
# 24891 players remaining.
#
#
# Start Scraping: Robert Constantinovici
# Finish Scraping 6607 players.
# 24890 players remaining.
#
#
# Start Scraping: Hunter Reese
# Finish Scraping 6608 players.
# 24889 players remaining.
#
#
# Start Scraping: Andras Szikszay
