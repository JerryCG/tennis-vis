# %% [markdown]
# # Normal Updates - Last Update: 2024-09-09

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from geopy.geocoders import Nominatim

# %% [markdown]
# ## 1. Update ATP Ranking

# %% [markdown]
# ### Single Date Update

# %%
# Load txt files
def load_txt(file):
    with open(file, 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    f.close()
    return df

# %%
# The webdesign may change over time!

def scrape_a_date_rank(date, previous):
    # scrape a particular date
    prefix = 'https://www.atptour.com/en/rankings/singles?RankRange=0-100&DateWeek='  # subject to change
    img_pre = 'https://www.atptour.com/en/~/media/images/flags/'

    # open chrome window
    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=1500, height=800)

    # get url
    driver.get(prefix + date)
    # driver.refresh()   # Refreshing can be detected by blockers

    # get content
    print('Start scraping:', date)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    trs = soup.find('table', {'class':'mega-table desktop-table non-live'}).find_all('tr')

    # set attrs
    attrs = ['Date', 'Rank', 'Country', 'Image', 'Player', 'Points']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # date
    dict['Date'] = [date for i in range(100)]

    for tr in trs:
        
        tds = tr.find_all('td')

        if len(tds) == 8: # check error
            # rank
            dict['Rank'].append(tds[0].text.strip())

            # country, image, player name
            lis = tds[1].find_all('li')
            country_abbr = (lis[1].svg.use.get('href', None))[-3:]
            dict['Country'].append(country_abbr.upper())
            dict['Image'].append(img_pre + country_abbr + '.svg')
            dict['Player'].append(lis[2].text.strip())

            # points
            dict['Points'].append(tds[3].text.strip().replace(',', ''))

    # save to txt
    df = pd.DataFrame(dict)
    df.to_csv('m/rank/dates/' + date + '.txt', index = False, sep = ',', encoding='utf-8-sig')
    print('Finished:', date)

    # open the ranking file
    dict_r = load_txt('m/rank/atpranking_20000110_'+previous.replace('-', '')+'.txt').to_dict('list')
    dict_r[date] = []

    # first get points for existing players
    for p in dict_r['Player']:
        found = False
        for i in range(len(dict['Player'])):
            if p == dict['Player'][i]:
                # add new point
                dict_r[date].append(dict['Points'][i])
                found = True
                break
        if not found:
            dict_r[date].append(0)

    # add new player if any
    for p in dict['Player']:
        if p not in dict_r['Player']:
            # add player
            dict_r['Player'].append(p)
            for i in range(len(dict['Player'])):
                if p == dict['Player'][i]:
                    # add country
                    dict_r['Country'].append(dict['Country'][i])
                    # add image
                    dict_r['Country_Image'].append(dict['Image'][i])
                    # add point
                    dict_r[date].append(dict['Points'][i])
                    break
            # add previous points, all 0
            for d in [key for key in dict_r.keys()][3:-1]:
                dict_r[d].append(0)

    # save to txt
    df_new = pd.DataFrame(dict_r)
    df_new.to_csv('m/rank/atpranking_20000110_'+date.replace('-', '')+'.txt', index = False, sep = ',', encoding='utf-8-sig')

# %%
scrape_a_date_rank('2024-09-09', '2024-08-26')
# Out:
# Start scraping: 2024-09-09
# Finished: 2024-09-09

# %% [markdown]
# Remember to add the new dates to dates.txt

# %% [markdown]
# Remember to update rank file in Flourish

# %% [markdown]
# ## 2. Update ATP Links According to New Ranks

# %%
# Define the function to update ATP profile links by ATP Top 100 ranks
def update_link_by_new_rank(dates):
    '''
    dates: a list of dates text
    '''
    # update links according to atp ranking

    prefix = 'https://www.atptour.com/en/rankings/singles?RankRange=0-100&DateWeek='
    head = 'https://www.atptour.com'

    # open txt
    df = load_txt('m/basics/atpprofilebasics.txt')
    pl = [p for p in df['Player']]

    with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
        links = [line[:-1] for line in f]
    f.close()

    chromedrive_path = "D:\chromedriver.exe"
    s = Service(chromedrive_path)
    driver = webdriver.Chrome(service=s)
    driver.set_window_rect(x=10, y=10, width=1500, height=800)

    # date list
    for date in dates:
        driver.get(prefix + date)
        # driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        trs = soup.find('table', {'class':'mega-table desktop-table non-live'}).find_all('tr')
        for tr in trs[1:]:
            tds = tr.find_all('td')
            if len(tds) == 8:
                lis = tds[1].find_all('li')
                if lis[2].text.strip().replace('-', ' ') not in pl:
                    # add new link
                    links.append(head+lis[2].a.get('href'))
                    pl.append(lis[2].text.strip().replace('-', ' '))
                    print('Found:', lis[2].text.strip().replace('-', ' '))
        print('Finish:', date)
    f.close()

    # update links
    with open('m/basics/atpprofilelinks.txt', 'w', encoding='utf-8-sig') as f:
        for link in set(links):
            if link != '':
                f.write(link)
                f.write('\n')
    f.close()

# %%
update_link_by_new_rank(["2024-09-09"])
# Out:
# Found: Juncheng  Shang
# Finish: 2024-09-09

# %% [markdown]
# ## 3. Update ATP Profile Information

# %%
# Update new basics based on new links in atprofilelinks
# Website design may change

with open('m/basics/atpprofilelinks.txt', 'r', encoding='utf-8-sig') as f:
    links = [line[:-1] for line in f]
f.close()

dict = load_txt('m/basics/atpprofilebasics.txt').to_dict('list')

chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)

for i, link in enumerate(links):
    if link not in dict['ATP Link']:
        driver.get(link)
        # driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        # add name
        try:
            dict['Player'].append(soup.find('div', {'class': 'player_name'}).text.strip().replace('-', ' '))
        except:
            print(link, 'not found')
            break
        # add link
        dict['ATP Link'].append(link)
        # add birthday
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Birthday'].append(lis[0].find_all('span')[1].text.split('(')[1][:-1].replace('.', '-'))
        except:
            dict['Birthday'].append('')
        # add birthplace
        try:
            lis = soup.find('ul', {'class': 'pd_right'}).find_all('li')
            birthplace = lis[1].find_all('span')[1].text.replace(', ', ' - ')
        except:
            birthplace = ''
        dict['Birthplace'].append(birthplace)
        # add plays
        try:
            lis = soup.find('ul', {'class': 'pd_right'}).find_all('li')
            dict['Plays'].append(lis[2].find_all('span')[1].text.replace(', ', ' - '))
        except:
            dict['Plays'].append('')
        # add turned pro
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Turned Pro'].append(lis[3].find_all('span')[1].text)
        except:
            dict['Turned Pro'].append('')
        # add weight
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Weight (kg)'].append(lis[1].find_all('span')[1].text.split('(')[1][:-3])
        except:
            dict['Weight (kg)'].append('')
        # add height
        try:
            lis = soup.find('ul', {'class': 'pd_left'}).find_all('li')
            dict['Height (cm)'].append(lis[2].find_all('span')[1].text.split('(')[1][:-3])
        except:
            dict['Height (cm)'].append('')
        print('Finished:', i+1)

        # add birthplace details, matched region, lat, lon
        geolocator = Nominatim(user_agent='tennis-vis')
        try:
            location = geolocator.geocode(birthplace)
            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
            dict['Birthplace_lat'].append(location.latitude)
            dict['Birthplace_lon'].append(location.longitude)
            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
        except:
            try:
                location = geolocator.geocode(birthplace.split(',')[0]+','+birthplace.split(',')[1])
                dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                dict['Birthplace_lat'].append(location.latitude)
                dict['Birthplace_lon'].append(location.longitude)
                print(location.address.replace(',', ' -'), location.latitude, location.longitude)
            except:
                try:
                    location = geolocator.geocode(birthplace.split(',')[0])
                    dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                    dict['Birthplace_lat'].append(location.latitude)
                    dict['Birthplace_lon'].append(location.longitude)
                    print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                except:
                    try:
                        location = geolocator.geocode(birthplace.split(',')[1])
                        dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                        dict['Birthplace_lat'].append(location.latitude)
                        dict['Birthplace_lon'].append(location.longitude)
                        print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                    except:
                        try:
                            location = geolocator.geocode(birthplace.split(',')[2])
                            dict['Birthplace_matched'].append(location.address.replace(',', ' -'))
                            dict['Birthplace_lat'].append(location.latitude)
                            dict['Birthplace_lon'].append(location.longitude)
                            print(location.address.replace(',', ' -'), location.latitude, location.longitude)
                        except:
                            dict['Birthplace_matched'].append('')
                            dict['Birthplace_lat'].append('')
                            dict['Birthplace_lon'].append('')
                            print('','','')

df = pd.DataFrame(dict)
df.to_csv('m/basics/atpprofilebasics.txt', index = False, sep = ',', encoding='utf-8-sig')
# Out:
# Finished: 1080
# La Plata - Partido de La Plata - Buenos Aires - Argentina -34.9206797 -57.9537638

# %% [markdown]
# ## 4. Update ATP TOP 100 Distribution

# %%
# Define the function to update Geo distribution of ATP Top 100 players
def update_geo_atp100(date,num):
    # get basics
    df_basics = load_txt('m/basics/atpprofilebasics.txt')

    # set basic dict
    attrs = ['Start', 'End', 'Player', 'Rank', 'Points', 'Birthplace', 'Lat', 'Lon']
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # get dates
    dates = []
    with open('m/rank/dates.txt', 'r') as f:
        for date in f:
            dates.append(date[:-1])
    f.close()

    # Start looping
    for k, date in enumerate([dates[num - i - 1] for i in range(num)]):
        df_rank = load_txt('m/rank/dates/'+date+'.txt')
        for i, p in enumerate(df_rank['Player']):
            for j, r in enumerate(df_basics['Player']):
                if p.replace('-', ' ') == r and k != (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append(dates[num - k - 2])
                    except:
                        pass
                    break
                if p.replace('-', ' ') == r and k == (num-1):
                    try:
                        player = p.replace('-', ' ')
                        rank = int(df_rank['Rank'][i])
                        points = int(df_rank['Points'][i])
                        birthplace = df_basics['Birthplace'][j]
                        birthplace_lat = float(df_basics['Birthplace_lat'][j])
                        birthplace_lon = float(df_basics['Birthplace_lon'][j])
                        dict['Player'].append(player)
                        dict['Rank'].append(rank)
                        dict['Points'].append(points)
                        dict['Birthplace'].append(birthplace)
                        dict['Lat'].append(birthplace_lat)
                        dict['Lon'].append(birthplace_lon)
                        dict['Start'].append(date)
                        dict['End'].append('')
                    except:
                        pass
                    break

        print('Finished:', date)

    df = pd.DataFrame(dict)

    # Save csv
    df.to_csv('m/rank/atp100geo20000110_'+date.replace("-","")+'.txt', index = False, sep = ',', encoding = 'utf-8-sig')

# %%
# num = Row Number of "2000-01-10" in date.txt file
update_geo_atp100("2024-09-09", 1182)
# Out:
# Finished: 2000-01-10
# Finished: 2000-01-17
# Finished: 2000-01-24
# Finished: 2000-01-31
# Finished: 2000-02-07
# Finished: 2000-02-14
# Finished: 2000-02-21
# Finished: 2000-02-28
# Finished: 2000-03-06
# Finished: 2000-03-13
# Finished: 2000-03-20
# Finished: 2000-03-27
# Finished: 2000-04-03
# Finished: 2000-04-10
# Finished: 2000-04-17
# Finished: 2000-04-24
# Finished: 2000-05-01
# Finished: 2000-05-08
# Finished: 2000-05-15
# Finished: 2000-05-22
# Finished: 2000-05-29
# Finished: 2000-06-05
# Finished: 2000-06-12
# Finished: 2000-06-19
# Finished: 2000-06-26
# Finished: 2000-07-03
# Finished: 2000-07-10
# Finished: 2000-07-17
# Finished: 2000-07-24
# Finished: 2000-07-31
# Finished: 2000-08-07
# Finished: 2000-08-14
# Finished: 2000-08-21
# Finished: 2000-08-28
# Finished: 2000-09-04
# Finished: 2000-09-11
# Finished: 2000-09-18
# Finished: 2000-09-25
# Finished: 2000-10-02
# Finished: 2000-10-09
# Finished: 2000-10-16
# Finished: 2000-10-23
# Finished: 2000-10-30
# Finished: 2000-11-06
# Finished: 2000-11-13
# Finished: 2000-11-20
# Finished: 2000-11-27
# Finished: 2000-12-04
# Finished: 2000-12-11
# Finished: 2000-12-18
# Finished: 2000-12-25
# Finished: 2001-01-01
# Finished: 2001-01-08
# Finished: 2001-01-15
# Finished: 2001-01-22
# Finished: 2001-01-29
# Finished: 2001-02-05
# Finished: 2001-02-12
# Finished: 2001-02-19
# Finished: 2001-02-26
# Finished: 2001-03-05
# Finished: 2001-03-12
# Finished: 2001-03-19
# Finished: 2001-03-26
# Finished: 2001-04-02
# Finished: 2001-04-09
# Finished: 2001-04-16
# Finished: 2001-04-23
# Finished: 2001-04-30
# Finished: 2001-05-07
# Finished: 2001-05-14
# Finished: 2001-05-21
# Finished: 2001-05-28
# Finished: 2001-06-04
# Finished: 2001-06-11
# Finished: 2001-06-18
# Finished: 2001-06-25
# Finished: 2001-07-02
# Finished: 2001-07-09
# Finished: 2001-07-16
# Finished: 2001-07-23
# Finished: 2001-07-30
# Finished: 2023-08-28
# Finished: 2023-09-11
# Finished: 2023-09-18
# Finished: 2023-09-25
# Finished: 2023-10-02
# Finished: 2023-10-16
# Finished: 2023-10-23
# Finished: 2023-10-30
# Finished: 2023-11-06
# Finished: 2023-11-13
# Finished: 2023-11-20
# Finished: 2023-11-27
# Finished: 2023-12-04
# Finished: 2023-12-11
# Finished: 2023-12-18
# Finished: 2023-12-25
# Finished: 2024-01-01
# Finished: 2024-01-08
# Finished: 2024-01-15
# Finished: 2024-01-29
# Finished: 2024-02-05
# Finished: 2024-02-12
# Finished: 2024-02-19
# Finished: 2024-02-26
# Finished: 2024-03-04
# Finished: 2024-03-18
# Finished: 2024-04-01
# Finished: 2024-04-08
# Finished: 2024-04-15
# Finished: 2024-04-22
# Finished: 2024-05-06
# Finished: 2024-05-20
# Finished: 2024-05-27
# Finished: 2024-06-10
# Finished: 2024-06-17
# Finished: 2024-06-24
# Finished: 2024-07-01
# Finished: 2024-07-15
# Finished: 2024-07-22
# Finished: 2024-07-29
# Finished: 2024-08-05
# Finished: 2024-08-12
# Finished: 2024-08-19
# Finished: 2024-08-26
# Finished: 2024-09-09

# %% [markdown]
# Remember to update geo file in Flourish

# %% [markdown]
# ## 5. Update All Matches Player by Player

# %%
# define functions to get all players' names and scrape all matches data
def get_names(sex = ''):
    names = []
    if sex == 'm':
        with open('mp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    elif sex == 'w':
        with open('wp.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    else:
        with open('mwplayerlist_processed.txt', 'r', encoding='utf-8-sig') as f:
            for line in f:
                names.append(line[:-1])
    return names

# define a function to scrape for a single man player's matches
def scrape_matches(name, driver):
    try:
        # set attributes
        attributes_m = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'TP', 'Aces', 'DFs', 'SP', 
                        '1SP', '2SP', 'vA', 'Time']

        attributes_w = ['Date', 'Tournament', 'Sets', 'Surface', 
                        'Rd', 'Rk', 'vRk', 'W', 'tRk', 'vtRk', 
                        'WP', 'LP', 'Score', 'DR', 'A%', 'DF%',
                        '1stIn', '1st%', '2nd%', 'BPSvd',
                        'TPW', 'RPW', 'vA%', 'v1st%', 'v2nd%',
                        'BPCnv', 'Time']

        # get cleaned name
        sex = name[1]
        name_cleaned = name[4:].replace(' ', '')

        # set url prefix and types of webpages
        if sex == 'M':
            url = "https://www.tennisabstract.com/cgi-bin/player-classic.cgi?p=" 
        #   types = ["&f=ACareerqq", "&f=ACareerqqr1", "&f=ACareerqqw1"]
        else:
            url = "https://www.tennisabstract.com/cgi-bin/wplayer-classic.cgi?p="

        # Start of Scraping
        print('Start Scraping:', name[4:])
        
        # Man and woman pages are different
        if sex == 'M':

            # For man players
            # Set dictionary
            dic = {}
            for attr in attributes_m:
                dic[attr] = []

            # For serve page
            driver.get(url + name_cleaned.replace(' ', '') + "&f=ACareerqq")
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')
        #   driver.quit()

            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # For return page
                show_return = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Return"]')))
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[1])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # For raw page
                show_raw = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//span[text()="Raw"]')))
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver = webdriver.Chrome(service=s)
          #     driver.get(url + name_cleaned.replace(' ', '') + types[2])
          #     soup = BeautifulSoup(driver.page_source, 'html.parser')
          #     matches = soup.find('table', {'id': 'matches'}).find_all('tr')
          #     driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

            else:
                # Serve page
                driver.get(url + name_cleaned.replace(' ', ''))
                driver.refresh()
                # Show career
                try:
                    show_career = driver.find_element(By.ID, 'careerclick')
                except:
                    return None
                show_career.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_m[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_m[1]].append(tds[1].text)
                        # sets
                        dic[attributes_m[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_m[3]].append(tds[2].text)
                        # round
                        dic[attributes_m[4]].append(tds[3].text)
                        # rank
                        dic[attributes_m[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_m[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_m[7]].append(1)
                            # winner
                            dic[attributes_m[10]].append(name[4:])
                            # loser
                            dic[attributes_m[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_m[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_m[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        else:
                            # win?
                            dic[attributes_m[7]].append(0)
                            # winner
                            dic[attributes_m[10]].append(spans[1].text)
                            # loser
                            dic[attributes_m[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_m[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_m[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_m[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_m[9]].append('')
                        # score
                        dic[attributes_m[12]].append(tds[7].text)
                        # DR
                        dic[attributes_m[13]].append(tds[9].text)
                        # A%
                        dic[attributes_m[14]].append(tds[10].text)
                        # DF%
                        dic[attributes_m[15]].append(tds[11].text)
                        # 1stIn
                        dic[attributes_m[16]].append(tds[12].text)
                        # 1st%
                        dic[attributes_m[17]].append(tds[13].text)
                        # 2rd%
                        dic[attributes_m[18]].append(tds[14].text)
                        # BPSvd
                        dic[attributes_m[19]].append(tds[15].text)

                print('Serve Page:', len(dic['Date']))

                # Return page
                show_return = driver.find_element(By.XPATH, '//span[text()="Return"]')
                show_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_m[20]].append(tds[10].text)
                        # RPW
                        dic[attributes_m[21]].append(tds[11].text)
                        # vA%
                        dic[attributes_m[22]].append(tds[12].text)
                        # v1st%
                        dic[attributes_m[23]].append(tds[13].text)
                        # v2rd%
                        dic[attributes_m[24]].append(tds[14].text)
                        # BPCvt
                        dic[attributes_m[25]].append(tds[15].text)
                
                print('Return Page:', len(dic['TPW']))

                # raw page
                show_raw = driver.find_element(By.XPATH, '//span[text()="Raw"]')
                show_raw.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
              # driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TP
                        dic[attributes_m[26]].append(tds[9].text)
                        # Aces
                        dic[attributes_m[27]].append(tds[10].text)
                        # DFs
                        dic[attributes_m[28]].append(tds[11].text)
                        # SP
                        dic[attributes_m[29]].append(tds[12].text)
                        # 1SP
                        dic[attributes_m[30]].append(tds[13].text)
                        # 2SP
                        dic[attributes_m[31]].append(tds[14].text)
                        # vA
                        dic[attributes_m[32]].append(tds[15].text)
                        # Time
                        dic[attributes_m[33]].append(tds[16].text)

                print('Raw Page:', len(dic['TP']))

        else:

            # For woman players
            # set dictionary
            dic = {}
            for attr in attributes_w:
                dic[attr] = []

            # For serve page
            driver.get(url + name_cleaned.replace(' ', '') + '&f=ACareerqq')
            driver.refresh()
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            matches = soup.find('table', {'id': 'matches'}).find_all('tr')

            # Check whether it is empty
            if matches != []:
                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # date, contain special character
                        date = tds[0].text.split('‑')
                        dic[attributes_w[0]].append('-'.join(date))
                        # tournament
                        dic[attributes_w[1]].append(tds[1].text)
                        # sets
                        dic[attributes_w[2]].append(5 if tds[1].text in ['Wimbledon', 'Roland Garros', 'US Open', 'Australian Open'] else 3)
                        # surface
                        dic[attributes_w[3]].append(tds[2].text)
                        # round
                        dic[attributes_w[4]].append(tds[3].text)
                        # rank
                        dic[attributes_w[5]].append(tds[4].text)
                        # opponent rank
                        dic[attributes_w[6]].append(tds[5].text)
                        # win?, tournament rank, opponent tournament rank, winner, loser
                        if spans[1].text in name:
                            # win?
                            dic[attributes_w[7]].append(1)
                            # winner
                            dic[attributes_w[10]].append(name[4:])
                            # loser
                            dic[attributes_w[11]].append(spans[6].text)
                            # tRk
                            if spans[0].text != '':
                                dic[attributes_w[8]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_w[8]].append('')
                            # vtRk
                            if spans[5].text != '':
                                dic[attributes_w[9]].append(spans[5].text[1:-1])
                            else:
                                dic[attributes_w[9]].append('')
                        else:
                            # win?
                            dic[attributes_w[7]].append(0)
                            # winner
                            dic[attributes_w[10]].append(spans[1].text)
                            # loser
                            dic[attributes_w[11]].append(name[4:])
                            # tRk
                            if spans[6].text != '':
                                dic[attributes_w[8]].append(spans[6].text[1:-1])
                            else:
                                dic[attributes_w[8]].append('')
                            # vtRk
                            if spans[0].text != '':
                                dic[attributes_w[9]].append(spans[0].text[1:-1])
                            else:
                                dic[attributes_w[9]].append('')
                        # score
                        dic[attributes_w[12]].append(tds[7].text.replace(" (ch)", ""))
                        # DR
                        dic[attributes_w[13]].append(tds[8].text)
                        # A%
                        dic[attributes_w[14]].append(tds[9].text)
                        # DF%
                        dic[attributes_w[15]].append(tds[10].text)
                        # 1stIn
                        dic[attributes_w[16]].append(tds[11].text)
                        # 1st%
                        dic[attributes_w[17]].append(tds[12].text)
                        # 2rd%
                        dic[attributes_w[18]].append(tds[13].text)
                        # BPSvd
                        dic[attributes_w[19]].append(tds[14].text)

                print('Serve Page:', len(dic['Date']))

                # For return page
                page_return = driver.find_element(By.XPATH, '//span[text()="Show Return Stats"]')
                page_return.click()
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                matches = soup.find('table', {'id': 'matches'}).find_all('tr')
            #   driver.quit()

                for match in matches[2:]:
                    tds = match.find_all('td')
                    # first check if it is ongoing match
                    spans = tds[6].find_all('span')
                    if spans[3].text != 'vs':
                        # TPW
                        dic[attributes_w[20]].append(tds[9].text)
                        # RPW
                        dic[attributes_w[21]].append(tds[10].text)
                        # vA%
                        dic[attributes_w[22]].append(tds[11].text)
                        # v1st%
                        dic[attributes_w[23]].append(tds[12].text)
                        # v2rd%
                        dic[attributes_w[24]].append(tds[13].text)
                        # BPCvt
                        dic[attributes_w[25]].append(tds[14].text)
                        # Time
                        dic[attributes_w[26]].append(tds[15].text)

                print('Return Page:', len(dic['TPW']))

        # save to text, separated by gender
        df = pd.DataFrame(dic)
        df.to_csv(sex.lower() + '/matches/txt/' + name[4:] + '.txt', index = False, sep = ',', encoding='utf-8-sig')

    except (IndexError, AttributeError) as e:
        pass
    
# define a loop function to scrape players from a given index
def scrape_from(idx, sex, driver):
    names = get_names(sex)
    for i in range(idx, len(names)):
        scrape_matches(names[i], driver)
        print('Finish Scraping', i + 1, 'players.')
        print(len(names) - (i + 1), 'players remaining.')
        print('\n')
        
# load txt files
def load_txt(name):
    with open(name[1].lower() + '/matches/txt/' + name[4:] + '.txt', 'r', encoding='utf-8-sig') as f:
        attributes = f.readline()[:-1].split(',')
        df = pd.DataFrame([line[:-1].split(',') for line in f], columns = attributes)
    return df

# %%
# UPDATE MATCHES DATA!!!
# set up chromdriver
chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service=s)
driver.set_window_rect(x=10, y=10, width=100, height=200)
scrape_from(29388, 'm', driver)
# Out:
# Start Scraping: Kevin Dessauer
# Finish Scraping 29389 players.
# 2108 players remaining.
#
#
# Start Scraping: Max Stevens
# Finish Scraping 29390 players.
# 2107 players remaining.
#
#
# Start Scraping: David Goodman
# Finish Scraping 29391 players.
# 2106 players remaining.
#
#
# Start Scraping: Sasha Ermakov
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 29392 players.
# 2105 players remaining.
#
#
# Start Scraping: Sean Maymi
# Finish Scraping 29393 players.
# 2104 players remaining.
#
#
# Start Scraping: Jordan Delass
# Finish Scraping 29394 players.
# 2103 players remaining.
#
#
# Start Scraping: William Mertz
# Finish Scraping 29395 players.
# 2102 players remaining.
#
#
# Start Scraping: Peter Marrack
# Finish Scraping 29396 players.
# 2101 players remaining.
#
#
# Start Scraping: Mauro Adrian Pesci
# Finish Scraping 29397 players.
# 2100 players remaining.
#
#
# Start Scraping: Nicolas Stegmann
# Finish Scraping 29398 players.
# 2099 players remaining.
#
#
# Start Scraping: Hui Jin Hong
# Finish Scraping 29399 players.
# 2098 players remaining.
#
#
# Start Scraping: Yasuyuki Akimoto
# Finish Scraping 29400 players.
# 2097 players remaining.
#
#
# Start Scraping: Junji Akagi
# Finish Scraping 29401 players.
# 2096 players remaining.
#
#
# Start Scraping: Toshiya Suzuki
# Finish Scraping 29402 players.
# 2095 players remaining.
#
#
# Start Scraping: Farhad Sane
# Finish Scraping 29403 players.
# 2094 players remaining.
#
#
# Start Scraping: Hamid Reza Al Yasin
# Finish Scraping 29404 players.
# 2093 players remaining.
#
#
# Start Scraping: Saeed Daroodi
# Finish Scraping 29405 players.
# 2092 players remaining.
#
#
# Start Scraping: Ganang Surya Atmaja
# Finish Scraping 29406 players.
# 2091 players remaining.
#
#
# Start Scraping: James Richardson
# Finish Scraping 29407 players.
# 2090 players remaining.
#
#
# Start Scraping: Mario Ziulu
# Finish Scraping 29408 players.
# 2089 players remaining.
#
#
# Start Scraping: Nikita Gostev
# Finish Scraping 29409 players.
# 2088 players remaining.
#
#
# Start Scraping: Matthew Curic
# Finish Scraping 29410 players.
# 2087 players remaining.
#
#
# Start Scraping: Nicolas Bilicki
# Finish Scraping 29411 players.
# 2086 players remaining.
#
#
# Start Scraping: Pavel Kunc
# Finish Scraping 29412 players.
# 2085 players remaining.
#
#
# Start Scraping: Irakli Dshandshgava
# Finish Scraping 29413 players.
# 2084 players remaining.
#
#
# Start Scraping: Yannic Wymann
# Finish Scraping 29414 players.
# 2083 players remaining.
#
#
# Start Scraping: Alain Zysset
# Finish Scraping 29415 players.
# 2082 players remaining.
#
#
# Start Scraping: Igor Ogrizek
# Finish Scraping 29416 players.
# 2081 players remaining.
#
#
# Start Scraping: Adrian Porowski
# Finish Scraping 29417 players.
# 2080 players remaining.
#
#
# Start Scraping: Julien Schindler
# Finish Scraping 29418 players.
# 2079 players remaining.
#
#
# Start Scraping: Oliver Diserens
# Finish Scraping 29419 players.
# 2078 players remaining.
#
#
# Start Scraping: Vanja Blazun
# Finish Scraping 29420 players.
# 2077 players remaining.
#
#
# Start Scraping: Diego Estrada Lumbreras
# Finish Scraping 29421 players.
# 2076 players remaining.
#
#
# Start Scraping: Gabriel Reina
# Finish Scraping 29422 players.
# 2075 players remaining.
#
#
# Start Scraping: Razvan Petru Copil
# Finish Scraping 29423 players.
# 2074 players remaining.
#
#
# Start Scraping: Sun Liang Lie
# Finish Scraping 29424 players.
# 2073 players remaining.
#
#
# Start Scraping: Artem Vlasenko
# Finish Scraping 29425 players.
# 2072 players remaining.
#
#
# Start Scraping: Wouter Koning
# Finish Scraping 29426 players.
# 2071 players remaining.
#
#
# Start Scraping: Marcel Pilat
# Finish Scraping 29427 players.
# 2070 players remaining.
#
#
# Start Scraping: Benedikt Lindheim
# Finish Scraping 29428 players.
# 2069 players remaining.
#
#
# Start Scraping: Ivan Horsky
# Finish Scraping 29429 players.
# 2068 players remaining.
#
#
# Start Scraping: Przemyslaw Centkowski
# Finish Scraping 29430 players.
# 2067 players remaining.
#
#
# Start Scraping: Alexander Zeller
# Finish Scraping 29431 players.
# 2066 players remaining.
#
#
# Start Scraping: Javier Corominas Navarrete
# Finish Scraping 29432 players.
# 2065 players remaining.
#
#
# Start Scraping: Djerald Oganezov
# Finish Scraping 29433 players.
# 2064 players remaining.
#
#
# Start Scraping: Robert Schulze
# Finish Scraping 29434 players.
# 2063 players remaining.
#
#
# Start Scraping: Lucian Ursu
# Finish Scraping 29435 players.
# 2062 players remaining.
#
#
# Start Scraping: Gregor Voigt
# Finish Scraping 29436 players.
# 2061 players remaining.
#
#
# Start Scraping: Riccardo Berton
# Finish Scraping 29437 players.
# 2060 players remaining.
#
#
# Start Scraping: Simon Kaufmann
# Finish Scraping 29438 players.
# 2059 players remaining.
#
#
# Start Scraping: Rainer Nachbauer
# Finish Scraping 29439 players.
# 2058 players remaining.
#
#
# Start Scraping: Julian Zganec
# Finish Scraping 29440 players.
# 2057 players remaining.
#
#
# Start Scraping: Christian Fuster
# Finish Scraping 29441 players.
# 2056 players remaining.
#
#
# Start Scraping: Octavian Avram
# Finish Scraping 29442 players.
# 2055 players remaining.
#
#
# Start Scraping: Gevork Kirakosyan
# Finish Scraping 29443 players.
# 2054 players remaining.
#
#
# Start Scraping: Nico Schinke
# Finish Scraping 29444 players.
# 2053 players remaining.
#
#
# Start Scraping: Philip Lageder
# Finish Scraping 29445 players.
# 2052 players remaining.
#
#
# Start Scraping: Massimiliano Costa
# Finish Scraping 29446 players.
# 2051 players remaining.
#
#
# Start Scraping: Octavian Stane
# Finish Scraping 29447 players.
# 2050 players remaining.
#
#
# Start Scraping: Fernando Tomas Navarro
# Finish Scraping 29448 players.
# 2049 players remaining.
#
#
# Start Scraping: Stefano Macioce
# Finish Scraping 29449 players.
# 2048 players remaining.
#
#
# Start Scraping: Ryad Benhabiles
# Finish Scraping 29450 players.
# 2047 players remaining.
#
#
# Start Scraping: Thipok Kunatippapong
# Finish Scraping 29451 players.
# 2046 players remaining.
#
#
# Start Scraping: Mark Zornosa
# Finish Scraping 29452 players.
# 2045 players remaining.
#
#
# Start Scraping: Justino Morales
# Finish Scraping 29453 players.
# 2044 players remaining.
#
#
# Start Scraping: Abdullah Abdul Mohsen
# Finish Scraping 29454 players.
# 2043 players remaining.
#
#
# Start Scraping: Hassan Hajaj
# Finish Scraping 29455 players.
# 2042 players remaining.
#
#
# Start Scraping: Richard Stera
# Finish Scraping 29456 players.
# 2041 players remaining.
#
#
# Start Scraping: Shiva Sangwan
# Finish Scraping 29457 players.
# 2040 players remaining.
#
#
# Start Scraping: Siddharth Raj
# Finish Scraping 29458 players.
# 2039 players remaining.
#
#
# Start Scraping: Adriano Bonilha Garcia
# Finish Scraping 29459 players.
# 2038 players remaining.
#
#
# Start Scraping: Matthias Martin
# Finish Scraping 29460 players.
# 2037 players remaining.
#
#
# Start Scraping: Kristian Marquart
# Finish Scraping 29461 players.
# 2036 players remaining.
#
#
# Start Scraping: Artem Chebotarev
# Finish Scraping 29462 players.
# 2035 players remaining.
#
#
# Start Scraping: Mitchell Lvovsky
# Finish Scraping 29463 players.
# 2034 players remaining.
#
#
# Start Scraping: Adam Olbrich
# Finish Scraping 29464 players.
# 2033 players remaining.
#
#
# Start Scraping: Andrew Mateljan
# Finish Scraping 29465 players.
# 2032 players remaining.
#
#
# Start Scraping: Daniel Cho
# Finish Scraping 29466 players.
# 2031 players remaining.
#
#
# Start Scraping: Kwang Il Park
# Finish Scraping 29467 players.
# 2030 players remaining.
#
#
# Start Scraping: Jason Ramski
# Finish Scraping 29468 players.
# 2029 players remaining.
#
#
# Start Scraping: Ondrej Vana
# Finish Scraping 29469 players.
# 2028 players remaining.
#
#
# Start Scraping: Kota Okazaki
# Finish Scraping 29470 players.
# 2027 players remaining.
#
#
# Start Scraping: Yasuhiro Furuki
# Finish Scraping 29471 players.
# 2026 players remaining.
#
#
# Start Scraping: Gregory Chin A Kwie
# Finish Scraping 29472 players.
# 2025 players remaining.
#
#
# Start Scraping: Theodor Eikeri
# Finish Scraping 29473 players.
# 2024 players remaining.
#
#
# Start Scraping: Mihaita Aldea
# Finish Scraping 29474 players.
# 2023 players remaining.
#
#
# Start Scraping: Pascal Chappat
# Finish Scraping 29475 players.
# 2022 players remaining.
#
#
# Start Scraping: Daniel Kostro
# Finish Scraping 29476 players.
# 2021 players remaining.
#
#
# Start Scraping: Nicola De Cesare
# Finish Scraping 29477 players.
# 2020 players remaining.
#
#
# Start Scraping: Giuseppe Casertano
# Finish Scraping 29478 players.
# 2019 players remaining.
#
#
# Start Scraping: Marco Picardi
# Finish Scraping 29479 players.
# 2018 players remaining.
#
#
# Start Scraping: Mads Melby
# Finish Scraping 29480 players.
# 2017 players remaining.
#
#
# Start Scraping: Pablo Illodo Lado
# Finish Scraping 29481 players.
# 2016 players remaining.
#
#
# Start Scraping: Zander Woodford Smith
# Finish Scraping 29482 players.
# 2015 players remaining.
#
#
# Start Scraping: Pablo Martin Velez
# Finish Scraping 29483 players.
# 2014 players remaining.
#
#
# Start Scraping: Shahe Avakian
# Finish Scraping 29484 players.
# 2013 players remaining.
#
#
# Start Scraping: Marc Rosslein
# Finish Scraping 29485 players.
# 2012 players remaining.
#
#
# Start Scraping: Mikhail Trukshanin
# Finish Scraping 29486 players.
# 2011 players remaining.
#
#
# Start Scraping: Anton Khadasevich
# Finish Scraping 29487 players.
# 2010 players remaining.
#
#
# Start Scraping: Robert Van Swelm
# Finish Scraping 29488 players.
# 2009 players remaining.
#
#
# Start Scraping: Kristof Golob
# Finish Scraping 29489 players.
# 2008 players remaining.
#
#
# Start Scraping: Marko Milovanovic
# Finish Scraping 29490 players.
# 2007 players remaining.
#
#
# Start Scraping: Thomas Van Cauter
# Finish Scraping 29491 players.
# 2006 players remaining.
#
#
# Start Scraping: Venedictos Politis
# Finish Scraping 29492 players.
# 2005 players remaining.
#
#
# Start Scraping: Mike Soyer
# Finish Scraping 29493 players.
# 2004 players remaining.
#
#
# Start Scraping: Kaloyan Kirilov
# Finish Scraping 29494 players.
# 2003 players remaining.
#
#
# Start Scraping: Victor Gracia Barcina
# Finish Scraping 29495 players.
# 2002 players remaining.
#
#
# Start Scraping: Enric Larregola Cortezon
# Finish Scraping 29496 players.
# 2001 players remaining.
#
#
# Start Scraping: Pablo Martinez Catalan
# Finish Scraping 29497 players.
# 2000 players remaining.
#
#
# Start Scraping: Armando Moya Grandal
# Finish Scraping 29498 players.
# 1999 players remaining.
#
#
# Start Scraping: Yvonnick Lhurriec
# Finish Scraping 29499 players.
# 1998 players remaining.
#
#
# Start Scraping: Alexandre Hervy
# Finish Scraping 29500 players.
# 1997 players remaining.
#
#
# Start Scraping: Dimitri Winderickx
# Finish Scraping 29501 players.
# 1996 players remaining.
#
#
# Start Scraping: Christopher Gruber
# Finish Scraping 29502 players.
# 1995 players remaining.
#
#
# Start Scraping: Godwin Omuta
# Finish Scraping 29503 players.
# 1994 players remaining.
#
#
# Start Scraping: Emanuele Thomas Sapio
# Finish Scraping 29504 players.
# 1993 players remaining.
#
#
# Start Scraping: Fernando Montes Gonzalez
# Finish Scraping 29505 players.
# 1992 players remaining.
#
#
# Start Scraping: Nadav Ruppin
# Finish Scraping 29506 players.
# 1991 players remaining.
#
#
# Start Scraping: Oriol Mirallas Vinas
# Finish Scraping 29507 players.
# 1990 players remaining.
#
#
# Start Scraping: Joao Simoes
# Finish Scraping 29508 players.
# 1989 players remaining.
#
#
# Start Scraping: Yassine Mechgoug
# Finish Scraping 29509 players.
# 1988 players remaining.
#
#
# Start Scraping: Akshay Bajoria
# Finish Scraping 29510 players.
# 1987 players remaining.
#
#
# Start Scraping: Nicholas Brotman
# Finish Scraping 29511 players.
# 1986 players remaining.
#
#
# Start Scraping: Fabrizio Golfin Guevara
# Finish Scraping 29512 players.
# 1985 players remaining.
#
#
# Start Scraping: David Rosenfeld
# Finish Scraping 29513 players.
# 1984 players remaining.
#
#
# Start Scraping: Juan Miguel Gonzalez
# Finish Scraping 29514 players.
# 1983 players remaining.
#
#
# Start Scraping: Luis Ernesto Bravo
# Finish Scraping 29515 players.
# 1982 players remaining.
#
#
# Start Scraping: Willi Wolfer
# Finish Scraping 29516 players.
# 1981 players remaining.
#
#
# Start Scraping: Yuri Mijic
# Finish Scraping 29517 players.
# 1980 players remaining.
#
#
# Start Scraping: Arnaud Barabe
# Finish Scraping 29518 players.
# 1979 players remaining.
#
#
# Start Scraping: Felipe Baptista
# Finish Scraping 29519 players.
# 1978 players remaining.
#
#
# Start Scraping: Lukas Kubiena
# Finish Scraping 29520 players.
# 1977 players remaining.
#
#
# Start Scraping: Bernardo Dias
# Finish Scraping 29521 players.
# 1976 players remaining.
#
#
# Start Scraping: Francisco Castello Branco
# Finish Scraping 29522 players.
# 1975 players remaining.
#
#
# Start Scraping: Federico Garufi
# Finish Scraping 29523 players.
# 1974 players remaining.
#
#
# Start Scraping: Juma Changawa
# Finish Scraping 29524 players.
# 1973 players remaining.
#
#
# Start Scraping: Jeffrey Fitch
# Finish Scraping 29525 players.
# 1972 players remaining.
#
#
# Start Scraping: Brian Coyle
# Finish Scraping 29526 players.
# 1971 players remaining.
#
#
# Start Scraping: Bibel Soudani
# Finish Scraping 29527 players.
# 1970 players remaining.
#
#
# Start Scraping: Hedi Nouri
# Finish Scraping 29528 players.
# 1969 players remaining.
#
#
# Start Scraping: Rodrigo Ferraez
# Finish Scraping 29529 players.
# 1968 players remaining.
#
#
# Start Scraping: Andres Gonzalez Elizondo
# Finish Scraping 29530 players.
# 1967 players remaining.
#
#
# Start Scraping: Roberto Ovallez
# Finish Scraping 29531 players.
# 1966 players remaining.
#
#
# Start Scraping: Mario Reyes
# Finish Scraping 29532 players.
# 1965 players remaining.
#
#
# Start Scraping: Lucas Farias
# Finish Scraping 29533 players.
# 1964 players remaining.
#
#
# Start Scraping: Edio Castanhel Filho
# Finish Scraping 29534 players.
# 1963 players remaining.
#
#
# Start Scraping: Yannick Yoshizawa
# Finish Scraping 29535 players.
# 1962 players remaining.
#
#
# Start Scraping: Guilherme Rebolo
# Finish Scraping 29536 players.
# 1961 players remaining.
#
#
# Start Scraping: Paulo Calabro
# Finish Scraping 29537 players.
# 1960 players remaining.
#
#
# Start Scraping: Henrique Norbiato
# Finish Scraping 29538 players.
# 1959 players remaining.
#
#
# Start Scraping: Mark Shanahan
# Finish Scraping 29539 players.
# 1958 players remaining.
#
#
# Start Scraping: Asaf Honig
# Finish Scraping 29540 players.
# 1957 players remaining.
#
#
# Start Scraping: Mario Navarro Bayo
# Finish Scraping 29541 players.
# 1956 players remaining.
#
#
# Start Scraping: Goncalo Ribeiro
# Finish Scraping 29542 players.
# 1955 players remaining.
#
#
# Start Scraping: Vasco Martins
# Finish Scraping 29543 players.
# 1954 players remaining.
#
#
# Start Scraping: Tetteh Nartey
# Finish Scraping 29544 players.
# 1953 players remaining.
#
#
# Start Scraping: Loic Le Panse
# Finish Scraping 29545 players.
# 1952 players remaining.
#
#
# Start Scraping: Ivan Lopez Munoz
# Finish Scraping 29546 players.
# 1951 players remaining.
#
#
# Start Scraping: Luca Piolanti
# Finish Scraping 29547 players.
# 1950 players remaining.
#
#
# Start Scraping: Jose Mario Ferreira
# Finish Scraping 29548 players.
# 1949 players remaining.
#
#
# Start Scraping: Fabio Minami
# Finish Scraping 29549 players.
# 1948 players remaining.
#
#
# Start Scraping: Rafael Madruga
# Finish Scraping 29550 players.
# 1947 players remaining.
#
#
# Start Scraping: Erick Sgambatti
# Finish Scraping 29551 players.
# 1946 players remaining.
#
#
# Start Scraping: Eduardo Saratt
# Finish Scraping 29552 players.
# 1945 players remaining.
#
#
# Start Scraping: Federico Contino
# Finish Scraping 29553 players.
# 1944 players remaining.
#
#
# Start Scraping: Juan Ignacio Benitez Elizeche
# Finish Scraping 29554 players.
# 1943 players remaining.
#
#
# Start Scraping: Adrien Gillming
# Finish Scraping 29555 players.
# 1942 players remaining.
#
#
# Start Scraping: Robert Iliev
# Finish Scraping 29556 players.
# 1941 players remaining.
#
#
# Start Scraping: Jan Hejtmanek
# Finish Scraping 29557 players.
# 1940 players remaining.
#
#
# Start Scraping: Andoni Kapnisakis
# Finish Scraping 29558 players.
# 1939 players remaining.
#
#
# Start Scraping: Tommaso Fiorelli
# Finish Scraping 29559 players.
# 1938 players remaining.
#
#
# Start Scraping: Till Marks
# Finish Scraping 29560 players.
# 1937 players remaining.
#
#
# Start Scraping: Aleksander Korzeniewicz
# Finish Scraping 29561 players.
# 1936 players remaining.
#
#
# Start Scraping: Christiaan Berkouwer
# Finish Scraping 29562 players.
# 1935 players remaining.
#
#
# Start Scraping: Tim Doan Dinh
# Finish Scraping 29563 players.
# 1934 players remaining.
#
#
# Start Scraping: Niko Grba
# Finish Scraping 29564 players.
# 1933 players remaining.
#
#
# Start Scraping: Fredi Voormann
# Finish Scraping 29565 players.
# 1932 players remaining.
#
#
# Start Scraping: Endika Villacorta Rollan
# Finish Scraping 29566 players.
# 1931 players remaining.
#
#
# Start Scraping: Nikola Kostic
# Finish Scraping 29567 players.
# 1930 players remaining.
#
#
# Start Scraping: Ivan Marevic
# Finish Scraping 29568 players.
# 1929 players remaining.
#
#
# Start Scraping: Jan Unger
# Finish Scraping 29569 players.
# 1928 players remaining.
#
#
# Start Scraping: Binh Bui
# Finish Scraping 29570 players.
# 1927 players remaining.
#
#
# Start Scraping: Vegerd Veskimagi
# Finish Scraping 29571 players.
# 1926 players remaining.
#
#
# Start Scraping: Nikolas Zogaj
# Finish Scraping 29572 players.
# 1925 players remaining.
#
#
# Start Scraping: Yashar Sheet
# Finish Scraping 29573 players.
# 1924 players remaining.
#
#
# Start Scraping: Hosam Osman
# Finish Scraping 29574 players.
# 1923 players remaining.
#
#
# Start Scraping: Hamid Mustafa
# Finish Scraping 29575 players.
# 1922 players remaining.
#
#
# Start Scraping: Angel Marquez
# Finish Scraping 29576 players.
# 1921 players remaining.
#
#
# Start Scraping: Jonathan Rondon
# Finish Scraping 29577 players.
# 1920 players remaining.
#
#
# Start Scraping: Jose Ordaz
# Finish Scraping 29578 players.
# 1919 players remaining.
#
#
# Start Scraping: Matias Howells
# Finish Scraping 29579 players.
# 1918 players remaining.
#
#
# Start Scraping: Alberto Chitty
# Finish Scraping 29580 players.
# 1917 players remaining.
#
#
# Start Scraping: Juan Carlos Nunez
# Finish Scraping 29581 players.
# 1916 players remaining.
#
#
# Start Scraping: Alexander Diaz
# Finish Scraping 29582 players.
# 1915 players remaining.
#
#
# Start Scraping: Gianfabrizio Esposito
# Finish Scraping 29583 players.
# 1914 players remaining.
#
#
# Start Scraping: Michael Moore
# Finish Scraping 29584 players.
# 1913 players remaining.
#
#
# Start Scraping: Thanarath Pongsathien
# Finish Scraping 29585 players.
# 1912 players remaining.
#
#
# Start Scraping: Putporn Chantawannop
# Finish Scraping 29586 players.
# 1911 players remaining.
#
#
# Start Scraping: Simon Castello Brunet
# Finish Scraping 29587 players.
# 1910 players remaining.
#
#
# Start Scraping: Sylvain Ruest
# Finish Scraping 29588 players.
# 1909 players remaining.
#
#
# Start Scraping: Rohan Williams
# Finish Scraping 29589 players.
# 1908 players remaining.
#
#
# Start Scraping: Adrian Garza
# Finish Scraping 29590 players.
# 1907 players remaining.
#
#
# Start Scraping: Gonzalo Rafael De Villa
# Finish Scraping 29591 players.
# 1906 players remaining.
#
#
# Start Scraping: Sergio Herrera
# Finish Scraping 29592 players.
# 1905 players remaining.
#
#
# Start Scraping: Jose Antonio Zarur Nemer
# Finish Scraping 29593 players.
# 1904 players remaining.
#
#
# Start Scraping: Hideki Kobayashi
# Finish Scraping 29594 players.
# 1903 players remaining.
#
#
# Start Scraping: Masashi Yoshida
# Finish Scraping 29595 players.
# 1902 players remaining.
#
#
# Start Scraping: Seiya Toyota
# Finish Scraping 29596 players.
# 1901 players remaining.
#
#
# Start Scraping: Hikaru Sano
# Finish Scraping 29597 players.
# 1900 players remaining.
#
#
# Start Scraping: Christian Carere
# Finish Scraping 29598 players.
# 1899 players remaining.
#
#
# Start Scraping: Ivan Regan
# Finish Scraping 29599 players.
# 1898 players remaining.
#
#
# Start Scraping: Luiz Gonzaga
# Finish Scraping 29600 players.
# 1897 players remaining.
#
#
# Start Scraping: Caio Piacentini
# Finish Scraping 29601 players.
# 1896 players remaining.
#
#
# Start Scraping: Bruno Silva
# Finish Scraping 29602 players.
# 1895 players remaining.
#
#
# Start Scraping: Divyanshu Singh
# Finish Scraping 29603 players.
# 1894 players remaining.
#
#
# Start Scraping: Vojtech Kunovsky
# Finish Scraping 29604 players.
# 1893 players remaining.
#
#
# Start Scraping: Alberton Richelieu
# Finish Scraping 29605 players.
# 1892 players remaining.
#
#
# Start Scraping: Marcos Fernandez Acanda
# Finish Scraping 29606 players.
# 1891 players remaining.
#
#
# Start Scraping: Matias Lieb
# Finish Scraping 29607 players.
# 1890 players remaining.
#
#
# Start Scraping: Andrzej Misiek
# Finish Scraping 29608 players.
# 1889 players remaining.
#
#
# Start Scraping: Michal Olejniczak
# Finish Scraping 29609 players.
# 1888 players remaining.
#
#
# Start Scraping: Pawel Glodkowski
# Finish Scraping 29610 players.
# 1887 players remaining.
#
#
# Start Scraping: Laurentiu Basarab
# Finish Scraping 29611 players.
# 1886 players remaining.
#
#
# Start Scraping: Sergey Melikhov
# Finish Scraping 29612 players.
# 1885 players remaining.
#
#
# Start Scraping: Michel Remino
# Finish Scraping 29613 players.
# 1884 players remaining.
#
#
# Start Scraping: Francisco Gonzalez Segura
# Finish Scraping 29614 players.
# 1883 players remaining.
#
#
# Start Scraping: Georgy Morgoev
# Finish Scraping 29615 players.
# 1882 players remaining.
#
#
# Start Scraping: Aleh Patapau
# Finish Scraping 29616 players.
# 1881 players remaining.
#
#
# Start Scraping: Dimitar Labudovik
# Finish Scraping 29617 players.
# 1880 players remaining.
#
#
# Start Scraping: Andrea Massimo Volta
# Finish Scraping 29618 players.
# 1879 players remaining.
#
#
# Start Scraping: Matthias Mazur
# Finish Scraping 29619 players.
# 1878 players remaining.
#
#
# Start Scraping: Antonio Ochoa Collado
# Finish Scraping 29620 players.
# 1877 players remaining.
#
#
# Start Scraping: Igor Nikitin
# Finish Scraping 29621 players.
# 1876 players remaining.
#
#
# Start Scraping: Aleksandr Mantrov
# Finish Scraping 29622 players.
# 1875 players remaining.
#
#
# Start Scraping: Dmitriy Kalenichenko
# Finish Scraping 29623 players.
# 1874 players remaining.
#
#
# Start Scraping: Robert Grygiel
# Finish Scraping 29624 players.
# 1873 players remaining.
#
#
# Start Scraping: Adrian Ionut Balota
# Finish Scraping 29625 players.
# 1872 players remaining.
#
#
# Start Scraping: Flaviu Simihaian
# Finish Scraping 29626 players.
# 1871 players remaining.
#
#
# Start Scraping: Erik Konig
# Finish Scraping 29627 players.
# 1870 players remaining.
#
#
# Start Scraping: Adrian Ludwikiewicz
# Finish Scraping 29628 players.
# 1869 players remaining.
#
#
# Start Scraping: Ioannis Stavridis
# Finish Scraping 29629 players.
# 1868 players remaining.
#
#
# Start Scraping: Gabriel Ionascu
# Finish Scraping 29630 players.
# 1867 players remaining.
#
#
# Start Scraping: Francesco Pagani
# Finish Scraping 29631 players.
# 1866 players remaining.
#
#
# Start Scraping: Luca Compagnucci
# Finish Scraping 29632 players.
# 1865 players remaining.
#
#
# Start Scraping: Alexander Konigsfeldt
# Finish Scraping 29633 players.
# 1864 players remaining.
#
#
# Start Scraping: Hasan Sharif Al Marzouqi
# Finish Scraping 29634 players.
# 1863 players remaining.
#
#
# Start Scraping: Gerardo Diaz
# Finish Scraping 29635 players.
# 1862 players remaining.
#
#
# Start Scraping: Jonas Mouly
# Finish Scraping 29636 players.
# 1861 players remaining.
#
#
# Start Scraping: Valentine Dunenkov
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 29637 players.
# 1860 players remaining.
#
#
# Start Scraping: Hector Garcia
# Finish Scraping 29638 players.
# 1859 players remaining.
#
#
# Start Scraping: Kohei Tani
# Finish Scraping 29639 players.
# 1858 players remaining.
#
#
# Start Scraping: Masato Matsuda
# Finish Scraping 29640 players.
# 1857 players remaining.
#
#
# Start Scraping: Mizuto Fujita
# Finish Scraping 29641 players.
# 1856 players remaining.
#
#
# Start Scraping: Ryo Nakagawa
# Finish Scraping 29642 players.
# 1855 players remaining.
#
#
# Start Scraping: Mohammed Abdullah Al Nuaimi
# Finish Scraping 29643 players.
# 1854 players remaining.
#
#
# Start Scraping: Hong Ryun Kim
# Finish Scraping 29644 players.
# 1853 players remaining.
#
#
# Start Scraping: Yong Ho Kwon
# Finish Scraping 29645 players.
# 1852 players remaining.
#
#
# Start Scraping: Ivo Salvador
# Finish Scraping 29646 players.
# 1851 players remaining.
#
#
# Start Scraping: Michelangelo Di Mauro
# Finish Scraping 29647 players.
# 1850 players remaining.
#
#
# Start Scraping: Jason Cole
# Finish Scraping 29648 players.
# 1849 players remaining.
#
#
# Start Scraping: Boi Benje Bruggen
# Finish Scraping 29649 players.
# 1848 players remaining.
#
#
# Start Scraping: Alessio Genovese
# Finish Scraping 29650 players.
# 1847 players remaining.
#
#
# Start Scraping: Giovanni Di Fraia
# Finish Scraping 29651 players.
# 1846 players remaining.
#
#
# Start Scraping: Hugo Le Coq
# Finish Scraping 29652 players.
# 1845 players remaining.
#
#
# Start Scraping: Maxime Adam
# Finish Scraping 29653 players.
# 1844 players remaining.
#
#
# Start Scraping: Carlos Previ Aliano
# Finish Scraping 29654 players.
# 1843 players remaining.
#
#
# Start Scraping: Alex Lane
# Finish Scraping 29655 players.
# 1842 players remaining.
#
#
# Start Scraping: Bjorn Van Muysewinkel
# Finish Scraping 29656 players.
# 1841 players remaining.
#
#
# Start Scraping: Jorge Molina De La Rosa
# Finish Scraping 29657 players.
# 1840 players remaining.
#
#
# Start Scraping: Nathan M Price
# Finish Scraping 29658 players.
# 1839 players remaining.
#
#
# Start Scraping: Sebastian Suarez
# Finish Scraping 29659 players.
# 1838 players remaining.
#
#
# Start Scraping: Martin Echandi
# Finish Scraping 29660 players.
# 1837 players remaining.
#
#
# Start Scraping: Jonathon Galyon
# Finish Scraping 29661 players.
# 1836 players remaining.
#
#
# Start Scraping: Gerardo Suarez
# Finish Scraping 29662 players.
# 1835 players remaining.
#
#
# Start Scraping: Luis Franzani
# Finish Scraping 29663 players.
# 1834 players remaining.
#
#
# Start Scraping: Kevin Casey
# Finish Scraping 29664 players.
# 1833 players remaining.
#
#
# Start Scraping: Damian Dario Iturriaga
# Finish Scraping 29665 players.
# 1832 players remaining.
#
#
# Start Scraping: Pedro Posselt
# Finish Scraping 29666 players.
# 1831 players remaining.
#
#
# Start Scraping: Vijit Sehgal
# Finish Scraping 29667 players.
# 1830 players remaining.
#
#
# Start Scraping: Guillaume St Maurice
# Finish Scraping 29668 players.
# 1829 players remaining.
#
#
# Start Scraping: Alfonso De La Pena
# Finish Scraping 29669 players.
# 1828 players remaining.
#
#
# Start Scraping: Luis David Viruega Diaz
# Finish Scraping 29670 players.
# 1827 players remaining.
#
#
# Start Scraping: Eduardo De La Paz
# Finish Scraping 29671 players.
# 1826 players remaining.
#
#
# Start Scraping: Yovanny Monroy
# Finish Scraping 29672 players.
# 1825 players remaining.
#
#
# Start Scraping: Jhon Bolivar
# Finish Scraping 29673 players.
# 1824 players remaining.
#
#
# Start Scraping: Mauricio Mejia
# Finish Scraping 29674 players.
# 1823 players remaining.
#
#
# Start Scraping: Arturo Santa
# Finish Scraping 29675 players.
# 1822 players remaining.
#
#
# Start Scraping: Daniel Robles
# Finish Scraping 29676 players.
# 1821 players remaining.
#
#
# Start Scraping: Gabriel Perez
# Finish Scraping 29677 players.
# 1820 players remaining.
#
#
# Start Scraping: Nikola Aracic
# Finish Scraping 29678 players.
# 1819 players remaining.
#
#
# Start Scraping: Daniel Hwang
# Finish Scraping 29679 players.
# 1818 players remaining.
#
#
# Start Scraping: Mpiloenhle Migogo
# Finish Scraping 29680 players.
# 1817 players remaining.
#
#
# Start Scraping: Serdarguly Mamedkuliyev
# Finish Scraping 29681 players.
# 1816 players remaining.
#
#
# Start Scraping: Yaseen Obaray
# Finish Scraping 29682 players.
# 1815 players remaining.
#
#
# Start Scraping: Tshepang Tangane
# Finish Scraping 29683 players.
# 1814 players remaining.
#
#
# Start Scraping: Michael Power
# Finish Scraping 29684 players.
# 1813 players remaining.
#
#
# Start Scraping: Nathaniel Horton
# Finish Scraping 29685 players.
# 1812 players remaining.
#
#
# Start Scraping: Alberto Rodriguez Gonzalez
# Finish Scraping 29686 players.
# 1811 players remaining.
#
#
# Start Scraping: Patxy Suarez Galinanes
# Finish Scraping 29687 players.
# 1810 players remaining.
#
#
# Start Scraping: Luca Dinoi
# Finish Scraping 29688 players.
# 1809 players remaining.
#
#
# Start Scraping: Nicolas Fynn
# Finish Scraping 29689 players.
# 1808 players remaining.
#
#
# Start Scraping: Mohammad Sadegh Jafarnezhad
# Finish Scraping 29690 players.
# 1807 players remaining.
#
#
# Start Scraping: Ramin Hajiyev
# Finish Scraping 29691 players.
# 1806 players remaining.
#
#
# Start Scraping: Saman Koohestani
# Finish Scraping 29692 players.
# 1805 players remaining.
#
#
# Start Scraping: Helmut Leyva Herrera
# Finish Scraping 29693 players.
# 1804 players remaining.
#
#
# Start Scraping: Libertino Camelo Neto
# Finish Scraping 29694 players.
# 1803 players remaining.
#
#
# Start Scraping: Mohammed Abdel Gird
# Finish Scraping 29695 players.
# 1802 players remaining.
#
#
# Start Scraping: Abuelgasim Al Kogali
# Finish Scraping 29696 players.
# 1801 players remaining.
#
#
# Start Scraping: Adbelhmed Mohammed
# Finish Scraping 29697 players.
# 1800 players remaining.
#
#
# Start Scraping: Hazim Sedahmed
# Finish Scraping 29698 players.
# 1799 players remaining.
#
#
# Start Scraping: Wael Noureldin
# Finish Scraping 29699 players.
# 1798 players remaining.
#
#
# Start Scraping: Murtada El Harith
# Finish Scraping 29700 players.
# 1797 players remaining.
#
#
# Start Scraping: Alphonse Rutagambwa
# Finish Scraping 29701 players.
# 1796 players remaining.
#
#
# Start Scraping: Daniel Rono
# Finish Scraping 29702 players.
# 1795 players remaining.
#
#
# Start Scraping: Alberto Diaz Petrilli
# Finish Scraping 29703 players.
# 1794 players remaining.
#
#
# Start Scraping: Marcelo Diaz Petrilli
# Finish Scraping 29704 players.
# 1793 players remaining.
#
#
# Start Scraping: Carlos Perez
# Finish Scraping 29705 players.
# 1792 players remaining.
#
#
# Start Scraping: Peter Paulenka
# Finish Scraping 29706 players.
# 1791 players remaining.
#
#
# Start Scraping: Andres Carrasco Carrasco
# Finish Scraping 29707 players.
# 1790 players remaining.
#
#
# Start Scraping: Carlos Velarde
# Finish Scraping 29708 players.
# 1789 players remaining.
#
#
# Start Scraping: Eliseo Dandrea
# Finish Scraping 29709 players.
# 1788 players remaining.
#
#
# Start Scraping: Matias Alberti
# Finish Scraping 29710 players.
# 1787 players remaining.
#
#
# Start Scraping: Mario Salinas
# Finish Scraping 29711 players.
# 1786 players remaining.
#
#
# Start Scraping: Nicolas Franco
# Finish Scraping 29712 players.
# 1785 players remaining.
#
#
# Start Scraping: Juan Pablo Arandia
# Finish Scraping 29713 players.
# 1784 players remaining.
#
#
# Start Scraping: Claude Gorjux
# Finish Scraping 29714 players.
# 1783 players remaining.
#
#
# Start Scraping: Gregory Chaine
# Finish Scraping 29715 players.
# 1782 players remaining.
#
#
# Start Scraping: Branimir Bozic
# Finish Scraping 29716 players.
# 1781 players remaining.
#
#
# Start Scraping: Csaba Nemeth
# Finish Scraping 29717 players.
# 1780 players remaining.
#
#
# Start Scraping: Levan Nanava
# Finish Scraping 29718 players.
# 1779 players remaining.
#
#
# Start Scraping: Andrey Esipov
# Finish Scraping 29719 players.
# 1778 players remaining.
#
#
# Start Scraping: Dan Adrian Chermaci
# Finish Scraping 29720 players.
# 1777 players remaining.
#
#
# Start Scraping: Mirko Blohm
# Finish Scraping 29721 players.
# 1776 players remaining.
#
#
# Start Scraping: Philip Therp
# Finish Scraping 29722 players.
# 1775 players remaining.
#
#
# Start Scraping: Nenad Maric
# Finish Scraping 29723 players.
# 1774 players remaining.
#
#
# Start Scraping: Luigi Giannuzzi
# Finish Scraping 29724 players.
# 1773 players remaining.
#
#
# Start Scraping: Francesco Trachsel
# Finish Scraping 29725 players.
# 1772 players remaining.
#
#
# Start Scraping: Till Jaekel
# Finish Scraping 29726 players.
# 1771 players remaining.
#
#
# Start Scraping: Martin Gloeggler
# Finish Scraping 29727 players.
# 1770 players remaining.
#
#
# Start Scraping: Christian Storhas
# Finish Scraping 29728 players.
# 1769 players remaining.
#
#
# Start Scraping: Daniel Jewitt
# Finish Scraping 29729 players.
# 1768 players remaining.
#
#
# Start Scraping: Gaetan Lepinoy
# Finish Scraping 29730 players.
# 1767 players remaining.
#
#
# Start Scraping: Dorian Sovic
# Finish Scraping 29731 players.
# 1766 players remaining.
#
#
# Start Scraping: Florian Treschnitzer
# Finish Scraping 29732 players.
# 1765 players remaining.
#
#
# Start Scraping: Tim Koniarski
# Finish Scraping 29733 players.
# 1764 players remaining.
#
#
# Start Scraping: Benjamin Potsch
# Finish Scraping 29734 players.
# 1763 players remaining.
#
#
# Start Scraping: Torben Wendt
# Finish Scraping 29735 players.
# 1762 players remaining.
#
#
# Start Scraping: Daniel Ceross
# Finish Scraping 29736 players.
# 1761 players remaining.
#
#
# Start Scraping: Josef Bauer
# Finish Scraping 29737 players.
# 1760 players remaining.
#
#
# Start Scraping: Manuel Garcia Barecelo
# Finish Scraping 29738 players.
# 1759 players remaining.
#
#
# Start Scraping: Alejandro Campillo Alonso
# Finish Scraping 29739 players.
# 1758 players remaining.
#
#
# Start Scraping: John Chesworth
# Finish Scraping 29740 players.
# 1757 players remaining.
#
#
# Start Scraping: Alejandro Alburquerque Urios
# Finish Scraping 29741 players.
# 1756 players remaining.
#
#
# Start Scraping: Yacine Habbouche
# Finish Scraping 29742 players.
# 1755 players remaining.
#
#
# Start Scraping: Sergey Ionov
# Finish Scraping 29743 players.
# 1754 players remaining.
#
#
# Start Scraping: Mounir Baba Aissa
# Finish Scraping 29744 players.
# 1753 players remaining.
#
#
# Start Scraping: Sami Mouline
# Finish Scraping 29745 players.
# 1752 players remaining.
#
#
# Start Scraping: Saeed Farah
# Finish Scraping 29746 players.
# 1751 players remaining.
#
#
# Start Scraping: Woo Whuk Choi
# Finish Scraping 29747 players.
# 1750 players remaining.
#
#
# Start Scraping: Fitrawan Syam
# Finish Scraping 29748 players.
# 1749 players remaining.
#
#
# Start Scraping: Georg Pirkebner
# Finish Scraping 29749 players.
# 1748 players remaining.
#
#
# Start Scraping: Mohsen Dehghani
# Finish Scraping 29750 players.
# 1747 players remaining.
#
#
# Start Scraping: Abdollah Moini
# Finish Scraping 29751 players.
# 1746 players remaining.
#
#
# Start Scraping: Vikram Chitkara
# Finish Scraping 29752 players.
# 1745 players remaining.
#
#
# Start Scraping: Armando Carrascosa
# Finish Scraping 29753 players.
# 1744 players remaining.
#
#
# Start Scraping: Juan Alfaro
# Finish Scraping 29754 players.
# 1743 players remaining.
#
#
# Start Scraping: Youssou Berthe
# Finish Scraping 29755 players.
# 1742 players remaining.
#
#
# Start Scraping: Uche Amajouyi
# Finish Scraping 29756 players.
# 1741 players remaining.
#
#
# Start Scraping: Yuval Klein
# Finish Scraping 29757 players.
# 1740 players remaining.
#
#
# Start Scraping: Brian Livingston
# Finish Scraping 29758 players.
# 1739 players remaining.
#
#
# Start Scraping: Inigo Ojer
# Finish Scraping 29759 players.
# 1738 players remaining.
#
#
# Start Scraping: Damir Lunic
# Finish Scraping 29760 players.
# 1737 players remaining.
#
#
# Start Scraping: Riadh Kallel
# Finish Scraping 29761 players.
# 1736 players remaining.
#
#
# Start Scraping: Abdel Kader Madani
# Finish Scraping 29762 players.
# 1735 players remaining.
#
#
# Start Scraping: Vladislav Shegai
# Finish Scraping 29763 players.
# 1734 players remaining.
#
#
# Start Scraping: Christopher Ross Da Silva
# Finish Scraping 29764 players.
# 1733 players remaining.
#
#
# Start Scraping: Sascha Ruckelshausen
# Finish Scraping 29765 players.
# 1732 players remaining.
#
#
# Start Scraping: Angel Lara
# Finish Scraping 29766 players.
# 1731 players remaining.
#
#
# Start Scraping: Cesar Ruiz Alvarez
# Finish Scraping 29767 players.
# 1730 players remaining.
#
#
# Start Scraping: Moon Kyun Kang
# Finish Scraping 29768 players.
# 1729 players remaining.
#
#
# Start Scraping: Yoji Masuoka
# Finish Scraping 29769 players.
# 1728 players remaining.
#
#
# Start Scraping: Shogo Kouno
# Finish Scraping 29770 players.
# 1727 players remaining.
#
#
# Start Scraping: Jae Hyung An
# Finish Scraping 29771 players.
# 1726 players remaining.
#
#
# Start Scraping: So Kusakabe
# Finish Scraping 29772 players.
# 1725 players remaining.
#
#
# Start Scraping: Yuichi Yoshioka
# Finish Scraping 29773 players.
# 1724 players remaining.
#
#
# Start Scraping: Kentaro Maehara
# Finish Scraping 29774 players.
# 1723 players remaining.
#
#
# Start Scraping: Mitsuhiko Hosaka
# Finish Scraping 29775 players.
# 1722 players remaining.
#
#
# Start Scraping: Bo Liu
# Finish Scraping 29776 players.
# 1721 players remaining.
#
#
# Start Scraping: Bruno Hertwig
# Finish Scraping 29777 players.
# 1720 players remaining.
#
#
# Start Scraping: Juan Carlos Castello
# Finish Scraping 29778 players.
# 1719 players remaining.
#
#
# Start Scraping: Cristian Damian Lucero
# Finish Scraping 29779 players.
# 1718 players remaining.
#
#
# Start Scraping: Salih Unsal
# Finish Scraping 29780 players.
# 1717 players remaining.
#
#
# Start Scraping: Marco Masci
# Finish Scraping 29781 players.
# 1716 players remaining.
#
#
# Start Scraping: Federico Placidilli
# Finish Scraping 29782 players.
# 1715 players remaining.
#
#
# Start Scraping: Shashank Vij
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 29783 players.
# 1714 players remaining.
#
#
# Start Scraping: Pablo Seijo Rodriguez
# Finish Scraping 29784 players.
# 1713 players remaining.
#
#
# Start Scraping: Amel Bisevac
# Finish Scraping 29785 players.
# 1712 players remaining.
#
#
# Start Scraping: Razvan George Porancea
# Finish Scraping 29786 players.
# 1711 players remaining.
#
#
# Start Scraping: Sebastian Plescan
# Finish Scraping 29787 players.
# 1710 players remaining.
#
#
# Start Scraping: Luka Culic
# Finish Scraping 29788 players.
# 1709 players remaining.
#
#
# Start Scraping: Filip Kricka
# Finish Scraping 29789 players.
# 1708 players remaining.
#
#
# Start Scraping: Gal Brzin
# Finish Scraping 29790 players.
# 1707 players remaining.
#
#
# Start Scraping: Pablo Pulido Rodriguez
# Finish Scraping 29791 players.
# 1706 players remaining.
#
#
# Start Scraping: Jaume Farreny Reyes
# Finish Scraping 29792 players.
# 1705 players remaining.
#
#
# Start Scraping: Xavier Colomina Farre
# Finish Scraping 29793 players.
# 1704 players remaining.
#
#
# Start Scraping: Dimitrios Iatropoulos
# Finish Scraping 29794 players.
# 1703 players remaining.
#
#
# Start Scraping: Tasos Korakas
# Finish Scraping 29795 players.
# 1702 players remaining.
#
#
# Start Scraping: Herbert Weirather
# Finish Scraping 29796 players.
# 1701 players remaining.
#
#
# Start Scraping: Amaury Auzou
# Finish Scraping 29797 players.
# 1700 players remaining.
#
#
# Start Scraping: Julien Bouetz
# Finish Scraping 29798 players.
# 1699 players remaining.
#
#
# Start Scraping: Gustave Diep
# Finish Scraping 29799 players.
# 1698 players remaining.
#
#
# Start Scraping: Christophe Ficot
# Finish Scraping 29800 players.
# 1697 players remaining.
#
#
# Start Scraping: Matthias Pawlik
# Finish Scraping 29801 players.
# 1696 players remaining.
#
#
# Start Scraping: Wasiu Ibrahim
# Finish Scraping 29802 players.
# 1695 players remaining.
#
#
# Start Scraping: Matthias Neubert
# Finish Scraping 29803 players.
# 1694 players remaining.
#
#
# Start Scraping: Diego Abreu
# Finish Scraping 29804 players.
# 1693 players remaining.
#
#
# Start Scraping: Natapong Pongkunsub
# Finish Scraping 29805 players.
# 1692 players remaining.
#
#
# Start Scraping: Oaitse Thipe
# Finish Scraping 29806 players.
# 1691 players remaining.
#
#
# Start Scraping: Paul Goode
# Finish Scraping 29807 players.
# 1690 players remaining.
#
#
# Start Scraping: Ken Buchanan
# Finish Scraping 29808 players.
# 1689 players remaining.
#
#
# Start Scraping: Andre Cervelatti
# Finish Scraping 29809 players.
# 1688 players remaining.
#
#
# Start Scraping: Michal Wronka
# Finish Scraping 29810 players.
# 1687 players remaining.
#
#
# Start Scraping: Radim Lapcik
# Finish Scraping 29811 players.
# 1686 players remaining.
#
#
# Start Scraping: Stanislav Burian
# Finish Scraping 29812 players.
# 1685 players remaining.
#
#
# Start Scraping: Derrick Lajola
# Finish Scraping 29813 players.
# 1684 players remaining.
#
#
# Start Scraping: Yevgeny Supeko
# Finish Scraping 29814 players.
# 1683 players remaining.
#
#
# Start Scraping: Jakob Paulsen
# Finish Scraping 29815 players.
# 1682 players remaining.
#
#
# Start Scraping: Saddam Hussain Kadhim
# Finish Scraping 29816 players.
# 1681 players remaining.
#
#
# Start Scraping: Julio Victoria
# Finish Scraping 29817 players.
# 1680 players remaining.
#
#
# Start Scraping: Jonathan Otero
# Finish Scraping 29818 players.
# 1679 players remaining.
#
#
# Start Scraping: Stefan Feddersen
# Finish Scraping 29819 players.
# 1678 players remaining.
#
#
# Start Scraping: Andre Moreira
# Finish Scraping 29820 players.
# 1677 players remaining.
#
#
# Start Scraping: Marcelo Paungartner
# Finish Scraping 29821 players.
# 1676 players remaining.
#
#
# Start Scraping: Brenton Bacon
# Finish Scraping 29822 players.
# 1675 players remaining.
#
#
# Start Scraping: Alberto Romea Gonzalez
# Finish Scraping 29823 players.
# 1674 players remaining.
#
#
# Start Scraping: Rafael Array Pareja
# Finish Scraping 29824 players.
# 1673 players remaining.
#
#
# Start Scraping: Cornelio Puye Sale
# Finish Scraping 29825 players.
# 1672 players remaining.
#
#
# Start Scraping: Roman Michalik
# Finish Scraping 29826 players.
# 1671 players remaining.
#
#
# Start Scraping: Cristian Garcia
# Finish Scraping 29827 players.
# 1670 players remaining.
#
#
# Start Scraping: Eduardo Pires Barbeta
# Finish Scraping 29828 players.
# 1669 players remaining.
#
#
# Start Scraping: Jorge Yunes
# Finish Scraping 29829 players.
# 1668 players remaining.
#
#
# Start Scraping: Boris Mosquera
# Finish Scraping 29830 players.
# 1667 players remaining.
#
#
# Start Scraping: Rafael Robles Sanchez
# Finish Scraping 29831 players.
# 1666 players remaining.
#
#
# Start Scraping: Ayite Aziadapou
# Finish Scraping 29832 players.
# 1665 players remaining.
#
#
# Start Scraping: Komlan Dziwonou
# Finish Scraping 29833 players.
# 1664 players remaining.
#
#
# Start Scraping: Dammian Barra
# Finish Scraping 29834 players.
# 1663 players remaining.
#
#
# Start Scraping: Kanfitine Lamboni
# Finish Scraping 29835 players.
# 1662 players remaining.
#
#
# Start Scraping: Olalekan Adebisi
# Finish Scraping 29836 players.
# 1661 players remaining.
#
#
# Start Scraping: Sebastian Vazquez
# Finish Scraping 29837 players.
# 1660 players remaining.
#
#
# Start Scraping: Alvise Pasqualetti
# Finish Scraping 29838 players.
# 1659 players remaining.
#
#
# Start Scraping: Alexander Tisch
# Finish Scraping 29839 players.
# 1658 players remaining.
#
#
# Start Scraping: Matthew Loucks
# Finish Scraping 29840 players.
# 1657 players remaining.
#
#
# Start Scraping: Robert Kurek
# Finish Scraping 29841 players.
# 1656 players remaining.
#
#
# Start Scraping: Nishendran Sivendran
# Finish Scraping 29842 players.
# 1655 players remaining.
#
#
# Start Scraping: Amrit Rupasinghe
# Finish Scraping 29843 players.
# 1654 players remaining.
#
#
# Start Scraping: Min Woo Shin
# Finish Scraping 29844 players.
# 1653 players remaining.
#
#
# Start Scraping: Karthik Raju
# Finish Scraping 29845 players.
# 1652 players remaining.
#
#
# Start Scraping: Harutyun Saringulyan
# Finish Scraping 29846 players.
# 1651 players remaining.
#
#
# Start Scraping: Seung Yong Shin
# Finish Scraping 29847 players.
# 1650 players remaining.
#
#
# Start Scraping: Yusfridar Sangkala
# Finish Scraping 29848 players.
# 1649 players remaining.
#
#
# Start Scraping: Ivo Souto
# Finish Scraping 29849 players.
# 1648 players remaining.
#
#
# Start Scraping: Hugo Simoes
# Finish Scraping 29850 players.
# 1647 players remaining.
#
#
# Start Scraping: Pablo Martin Platano
# Finish Scraping 29851 players.
# 1646 players remaining.
#
#
# Start Scraping: Machado Jean
# Finish Scraping 29852 players.
# 1645 players remaining.
#
#
# Start Scraping: Thiago Galdino Do Vale
# Finish Scraping 29853 players.
# 1644 players remaining.
#
#
# Start Scraping: Luis Otavio Pires
# Finish Scraping 29854 players.
# 1643 players remaining.
#
#
# Start Scraping: Rafael Weigand
# Finish Scraping 29855 players.
# 1642 players remaining.
#
#
# Start Scraping: Joao Carlos Santos
# Finish Scraping 29856 players.
# 1641 players remaining.
#
#
# Start Scraping: Angel Ramon Cupeiro Coto
# Finish Scraping 29857 players.
# 1640 players remaining.
#
#
# Start Scraping: Pablo Monterde Perez
# Finish Scraping 29858 players.
# 1639 players remaining.
#
#
# Start Scraping: Marko Jankovic
# Finish Scraping 29859 players.
# 1638 players remaining.
#
#
# Start Scraping: Nikola Miskovic
# Finish Scraping 29860 players.
# 1637 players remaining.
#
#
# Start Scraping: Andrei Enache
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 29861 players.
# 1636 players remaining.
#
#
# Start Scraping: Salvijus Davalga
# Finish Scraping 29862 players.
# 1635 players remaining.
#
#
# Start Scraping: Yari Natali
# Finish Scraping 29863 players.
# 1634 players remaining.
#
#
# Start Scraping: Gregorio Sgarlato
# Finish Scraping 29864 players.
# 1633 players remaining.
#
#
# Start Scraping: Milan Krivohlavek
# Finish Scraping 29865 players.
# 1632 players remaining.
#
#
# Start Scraping: Tim Richter
# Finish Scraping 29866 players.
# 1631 players remaining.
#
#
# Start Scraping: Richard Drazny
# Finish Scraping 29867 players.
# 1630 players remaining.
#
#
# Start Scraping: Thomas Guilloteau
# Finish Scraping 29868 players.
# 1629 players remaining.
#
#
# Start Scraping: Marco Hammerl
# Finish Scraping 29869 players.
# 1628 players remaining.
#
#
# Start Scraping: Florian Kiefer
# Finish Scraping 29870 players.
# 1627 players remaining.
#
#
# Start Scraping: Alexander Klec
# Finish Scraping 29871 players.
# 1626 players remaining.
#
#
# Start Scraping: Massimo Puci
# Finish Scraping 29872 players.
# 1625 players remaining.
#
#
# Start Scraping: Zachary Rath
# Finish Scraping 29873 players.
# 1624 players remaining.
#
#
# Start Scraping: Jakub Rutka
# Finish Scraping 29874 players.
# 1623 players remaining.
#
#
# Start Scraping: David Cardoso
# Finish Scraping 29875 players.
# 1622 players remaining.
#
#
# Start Scraping: Antonio Cannavacciuolo
# Finish Scraping 29876 players.
# 1621 players remaining.
#
#
# Start Scraping: Michal Mateasko
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 29877 players.
# 1620 players remaining.
#
#
# Start Scraping: Karel Jilek
# Finish Scraping 29878 players.
# 1619 players remaining.
#
#
# Start Scraping: Ian Sala Koperdraat
# Finish Scraping 29879 players.
# 1618 players remaining.
#
#
# Start Scraping: Jeff Stollberg
# Finish Scraping 29880 players.
# 1617 players remaining.
#
#
# Start Scraping: Jihad Ushaah
# Finish Scraping 29881 players.
# 1616 players remaining.
#
#
# Start Scraping: Michael Jetter
# Finish Scraping 29882 players.
# 1615 players remaining.
#
#
# Start Scraping: Tom Bender
# Finish Scraping 29883 players.
# 1614 players remaining.
#
#
# Start Scraping: Abdul Aziz Abu Rasheed
# Finish Scraping 29884 players.
# 1613 players remaining.
#
#
# Start Scraping: Hossam Al Daghfag
# Finish Scraping 29885 players.
# 1612 players remaining.
#
#
# Start Scraping: Abdul Aziz Al Abdulah
# Finish Scraping 29886 players.
# 1611 players remaining.
#
#
# Start Scraping: Baqer Abu Khulaif
# Finish Scraping 29887 players.
# 1610 players remaining.
#
#
# Start Scraping: Ali Hayat
# Finish Scraping 29888 players.
# 1609 players remaining.
#
#
# Start Scraping: Charbel Choucair
# Finish Scraping 29889 players.
# 1608 players remaining.
#
#
# Start Scraping: Mohamad Ataya
# Finish Scraping 29890 players.
# 1607 players remaining.
#
#
# Start Scraping: Kimihito Satake
# Finish Scraping 29891 players.
# 1606 players remaining.
#
#
# Start Scraping: Gen Vivien Horiguchi
# Finish Scraping 29892 players.
# 1605 players remaining.
#
#
# Start Scraping: Naotaka Katou
# Finish Scraping 29893 players.
# 1604 players remaining.
#
#
# Start Scraping: Tatsuya Arimatsu
# Finish Scraping 29894 players.
# 1603 players remaining.
#
#
# Start Scraping: Fabian Stockhaus
# Finish Scraping 29895 players.
# 1602 players remaining.
#
#
# Start Scraping: Christopher Amend
# Finish Scraping 29896 players.
# 1601 players remaining.
#
#
# Start Scraping: Madalin Ivan
# Finish Scraping 29897 players.
# 1600 players remaining.
#
#
# Start Scraping: Adrian Chirita
# Finish Scraping 29898 players.
# 1599 players remaining.
#
#
# Start Scraping: Alin Zorila
# Finish Scraping 29899 players.
# 1598 players remaining.
#
#
# Start Scraping: Victor Frunza
# Finish Scraping 29900 players.
# 1597 players remaining.
#
#
# Start Scraping: Lucian Budescu
# Finish Scraping 29901 players.
# 1596 players remaining.
#
#
# Start Scraping: Isaias Rodriguez Perez
# Finish Scraping 29902 players.
# 1595 players remaining.
#
#
# Start Scraping: Jose Ruiz Chaparro
# Finish Scraping 29903 players.
# 1594 players remaining.
#
#
# Start Scraping: David Lenar
# Finish Scraping 29904 players.
# 1593 players remaining.
#
#
# Start Scraping: Nies Henning Lampe
# Finish Scraping 29905 players.
# 1592 players remaining.
#
#
# Start Scraping: Ladislav Demeter
# Finish Scraping 29906 players.
# 1591 players remaining.
#
#
# Start Scraping: Clinton Lee
# Finish Scraping 29907 players.
# 1590 players remaining.
#
#
# Start Scraping: Robert Giltinan
# Finish Scraping 29908 players.
# 1589 players remaining.
#
#
# Start Scraping: James Cuthell
# Finish Scraping 29909 players.
# 1588 players remaining.
#
#
# Start Scraping: Cyrille Monet
# Finish Scraping 29910 players.
# 1587 players remaining.
#
#
# Start Scraping: Teddy Djabali
# Finish Scraping 29911 players.
# 1586 players remaining.
#
#
# Start Scraping: Andreas Laulund
# Finish Scraping 29912 players.
# 1585 players remaining.
#
#
# Start Scraping: Josimario Ferreira
# Finish Scraping 29913 players.
# 1584 players remaining.
#
#
# Start Scraping: Marzio Marella
# Finish Scraping 29914 players.
# 1583 players remaining.
#
#
# Start Scraping: Simon Pierre Weyreuter
# Finish Scraping 29915 players.
# 1582 players remaining.
#
#
# Start Scraping: Scott Blackmon
# Finish Scraping 29916 players.
# 1581 players remaining.
#
#
# Start Scraping: Kevin Jay
# Finish Scraping 29917 players.
# 1580 players remaining.
#
#
# Start Scraping: Sander Van Grinsven
# Finish Scraping 29918 players.
# 1579 players remaining.
#
#
# Start Scraping: Jonathan Hooper
# Finish Scraping 29919 players.
# 1578 players remaining.
#
#
# Start Scraping: Kevin Doh
# Finish Scraping 29920 players.
# 1577 players remaining.
#
#
# Start Scraping: Ricardo Fonseca
# Finish Scraping 29921 players.
# 1576 players remaining.
#
#
# Start Scraping: Matko Maravic
# Finish Scraping 29922 players.
# 1575 players remaining.
#
#
# Start Scraping: Leo Puhanic
# Finish Scraping 29923 players.
# 1574 players remaining.
#
#
# Start Scraping: Julian Svitolin
# Finish Scraping 29924 players.
# ...
#
#
# Start Scraping: Jose Maria Blasi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31338 players.
# 159 players remaining.
#
#
# Start Scraping: Jose Fontes
# Finish Scraping 31339 players.
# 158 players remaining.
#
#
# Start Scraping: Jose Fernandez
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 31340 players.
# 157 players remaining.
#
#
# Start Scraping: Jose Delafuente
# Finish Scraping 31341 players.
# 156 players remaining.
#
#
# Start Scraping: Jorge Cano
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31342 players.
# 155 players remaining.
#
#
# Start Scraping: Johnies Sauer
# Finish Scraping 31343 players.
# 154 players remaining.
#
#
# Start Scraping: John Werner
# Finish Scraping 31344 players.
# 153 players remaining.
#
#
# Start Scraping: John Kapakoglu
# Finish Scraping 31345 players.
# 152 players remaining.
#
#
# Start Scraping: Johan Sjogren
# Finish Scraping 31346 players.
# 151 players remaining.
#
#
# Start Scraping: Johan Milbrimk
# Finish Scraping 31347 players.
# 150 players remaining.
#
#
# Start Scraping: Joe Shaheen
# Finish Scraping 31348 players.
# 149 players remaining.
#
#
# Start Scraping: Joao Guedes
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31349 players.
# 148 players remaining.
#
#
# Start Scraping: Joao Coutinho
# Finish Scraping 31350 players.
# 147 players remaining.
#
#
# Start Scraping: Jin So Lee
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31351 players.
# 146 players remaining.
#
#
# Start Scraping: Jim Somerville
# Finish Scraping 31352 players.
# 145 players remaining.
#
#
# Start Scraping: Jeremy Grubi
# Finish Scraping 31353 players.
# 144 players remaining.
#
#
# Start Scraping: Jeff Player
# Finish Scraping 31354 players.
# 143 players remaining.
#
#
# Start Scraping: Jeff Hamilton
# Finish Scraping 31355 players.
# 142 players remaining.
#
#
# Start Scraping: Jeff Crowne
# Finish Scraping 31356 players.
# 141 players remaining.
#
#
# Start Scraping: Jean Francois Blain
# Finish Scraping 31357 players.
# 140 players remaining.
#
#
# Start Scraping: Javier Duarte
# Finish Scraping 31358 players.
# 139 players remaining.
#
#
# Start Scraping: Jason Wilkie
# Finish Scraping 31359 players.
# 138 players remaining.
#
#
# Start Scraping: James Ilako
# Finish Scraping 31360 players.
# 137 players remaining.
#
#
# Start Scraping: Jacques Bonnemaison
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31361 players.
# 136 players remaining.
#
#
# Start Scraping: Jack Kruger
# Serve Page: 2
# Return Page: 2
# Raw Page: 2
# Finish Scraping 31362 players.
# 135 players remaining.
#
#
# Start Scraping: J Spinnenweber
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31363 players.
# 134 players remaining.
#
#
# Start Scraping: J Potgieter
# Finish Scraping 31364 players.
# 133 players remaining.
#
#
# Start Scraping: Ilyas Ghouse
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31365 players.
# 132 players remaining.
#
#
# Start Scraping: Ian Duvenhage
# Finish Scraping 31366 players.
# 131 players remaining.
#
#
# Start Scraping: Ian Bersin
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31367 players.
# 130 players remaining.
#
#
# Start Scraping: Horacio Marin
# Finish Scraping 31368 players.
# 129 players remaining.
#
#
# Start Scraping: Holger Trahn
# Finish Scraping 31369 players.
# 128 players remaining.
#
#
# Start Scraping: Hiroshi Ito
# Finish Scraping 31370 players.
# 127 players remaining.
#
#
# Start Scraping: Herve Bardot
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31371 players.
# 126 players remaining.
#
#
# Start Scraping: Hernan Valenzuela
# Finish Scraping 31372 players.
# 125 players remaining.
#
#
# Start Scraping: Harvey Becker
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31373 players.
# 124 players remaining.
#
#
# Start Scraping: H Hsu
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31374 players.
# 123 players remaining.
#
#
# Start Scraping: Gustavo Merbilhaa
# Finish Scraping 31375 players.
# 122 players remaining.
#
#
# Start Scraping: Gustavo Espinosa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31376 players.
# 121 players remaining.
#
#
# Start Scraping: Gulio Melchiorre
# Finish Scraping 31377 players.
# 120 players remaining.
#
#
# Start Scraping: Guido Possamai
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31378 players.
# 119 players remaining.
#
#
# Start Scraping: Greg Muller
# Finish Scraping 31379 players.
# 118 players remaining.
#
#
# Start Scraping: Greg Ewansky
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31380 players.
# 117 players remaining.
#
#
# Start Scraping: Graziano Risi
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31381 players.
# 116 players remaining.
#
#
# Start Scraping: DUPE Graydon Garner
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31382 players.
# 115 players remaining.
#
#
# Start Scraping: Graham Epsley Jones
# Finish Scraping 31383 players.
# 114 players remaining.
#
#
# Start Scraping: Gerardo Hernandez
# Finish Scraping 31384 players.
# 113 players remaining.
#
#
# Start Scraping: George Obidiegwu
# Finish Scraping 31385 players.
# 112 players remaining.
#
#
# Start Scraping: George Goncalves
# Finish Scraping 31386 players.
# 111 players remaining.
#
#
# Start Scraping: Gavin Hewson
# Finish Scraping 31387 players.
# 110 players remaining.
#
#
# Start Scraping: Frank Apecehea
# Finish Scraping 31388 players.
# 109 players remaining.
#
#
# Start Scraping: Francis Ikosa
# Finish Scraping 31389 players.
# 108 players remaining.
#
#
# Start Scraping: Fernando Souza
# Finish Scraping 31390 players.
# 107 players remaining.
#
#
# Start Scraping: Evgeni Zhelyazkov
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31391 players.
# 106 players remaining.
#
#
# Start Scraping: Enno Van Veggel
# Finish Scraping 31392 players.
# 105 players remaining.
#
#
# Start Scraping: Emmanuel Brard
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31393 players.
# 104 players remaining.
#
#
# Start Scraping: Emeka Igbinebor
# Finish Scraping 31394 players.
# 103 players remaining.
#
#
# Start Scraping: Eduardo Bricio
# Finish Scraping 31395 players.
# 102 players remaining.
#
#
# Start Scraping: Eddie Siegenthaler
# Finish Scraping 31396 players.
# 101 players remaining.
#
#
# Start Scraping: Drazen Humar
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31397 players.
# 100 players remaining.
#
#
# Start Scraping: Donald England
# Finish Scraping 31398 players.
# 99 players remaining.
#
#
# Start Scraping: Didier Frantz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31399 players.
# 98 players remaining.
#
#
# Start Scraping: Delroy Reid
# Finish Scraping 31400 players.
# 97 players remaining.
#
#
# Start Scraping: Davn Santiago
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31401 players.
# 96 players remaining.
#
#
# Start Scraping: David Leveaux
# Finish Scraping 31402 players.
# 95 players remaining.
#
#
# Start Scraping: David Kacharava
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31403 players.
# 94 players remaining.
#
#
# Start Scraping: David Culley
# Finish Scraping 31404 players.
# 93 players remaining.
#
#
# Start Scraping: David Betous
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31405 players.
# 92 players remaining.
#
#
# Start Scraping: Daryl Greeves
# Finish Scraping 31406 players.
# 91 players remaining.
#
#
# Start Scraping: Darren Cole
# Finish Scraping 31407 players.
# 90 players remaining.
#
#
# Start Scraping: Daniel Garcia
# Finish Scraping 31408 players.
# 89 players remaining.
#
#
# Start Scraping: Dan Rastland
# Finish Scraping 31409 players.
# 88 players remaining.
#
#
# Start Scraping: Curtis Hollinger
# Finish Scraping 31410 players.
# 87 players remaining.
#
#
# Start Scraping: Cristofer Leberth
# Finish Scraping 31411 players.
# 86 players remaining.
#
#
# Start Scraping: Cris Herman
# Finish Scraping 31412 players.
# 85 players remaining.
#
#
# Start Scraping: Corey Wittenberg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31413 players.
# 84 players remaining.
#
#
# Start Scraping: Claudio Semmelmann
# Finish Scraping 31414 players.
# 83 players remaining.
#
#
# Start Scraping: Claudio Menna
# Finish Scraping 31415 players.
# 82 players remaining.
#
#
# Start Scraping: Claudio Fava
# Finish Scraping 31416 players.
# 81 players remaining.
#
#
# Start Scraping: Christopher Wolff
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31417 players.
# 80 players remaining.
#
#
# Start Scraping: Chris Kaskow
# Finish Scraping 31418 players.
# 79 players remaining.
#
#
# Start Scraping: Christoph Geukens
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31419 players.
# 78 players remaining.
#
#
# Start Scraping: Chris Vermeeren
# Finish Scraping 31420 players.
# 77 players remaining.
#
#
# Start Scraping: Chris Ellis
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31421 players.
# 76 players remaining.
#
#
# Start Scraping: Carlos Stocker
# Finish Scraping 31422 players.
# 75 players remaining.
#
#
# Start Scraping: Carlos Bravo
# Finish Scraping 31423 players.
# 74 players remaining.
#
#
# Start Scraping: Carl Williams
# Finish Scraping 31424 players.
# 73 players remaining.
#
#
# Start Scraping: Carey Brading
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31425 players.
# 72 players remaining.
#
#
# Start Scraping: Bunge Nahor
# Finish Scraping 31426 players.
# 71 players remaining.
#
#
# Start Scraping: Brett Hibbert
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31427 players.
# 70 players remaining.
#
#
# Start Scraping: Brendan Sharp
# Finish Scraping 31428 players.
# 69 players remaining.
#
#
# Start Scraping: Bosko Simundsa
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31429 players.
# 68 players remaining.
#
#
# Start Scraping: Bob Deller
# Finish Scraping 31430 players.
# 67 players remaining.
#
#
# Start Scraping: Bjorn Wahlstrom
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31431 players.
# 66 players remaining.
#
#
# Start Scraping: Bernardo Padilha
# Finish Scraping 31432 players.
# 65 players remaining.
#
#
# Start Scraping: Babatunde Akinola
# Finish Scraping 31433 players.
# 64 players remaining.
#
#
# Start Scraping: B Hochstadter
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31434 players.
# 63 players remaining.
#
#
# Start Scraping: Archie Adams
# Finish Scraping 31435 players.
# 62 players remaining.
#
#
# Start Scraping: Antti Eranne
# Finish Scraping 31436 players.
# 61 players remaining.
#
#
# Start Scraping: Antonio Zampieri
# Finish Scraping 31437 players.
# 60 players remaining.
#
#
# Start Scraping: Anthony Burke
# Finish Scraping 31438 players.
# 59 players remaining.
#
#
# Start Scraping: Andreas Fink
# Finish Scraping 31439 players.
# 58 players remaining.
#
#
# Start Scraping: Anders Rolfsen
# Finish Scraping 31440 players.
# 57 players remaining.
#
#
# Start Scraping: Alberto Kulmann
# Finish Scraping 31441 players.
# 56 players remaining.
#
#
# Start Scraping: Alan Tunik
# Finish Scraping 31442 players.
# 55 players remaining.
#
#
# Start Scraping: Alan Douglas
# Finish Scraping 31443 players.
# 54 players remaining.
#
#
# Start Scraping: A Noffat
# Finish Scraping 31444 players.
# 53 players remaining.
#
#
# Start Scraping: A Hall
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 31445 players.
# 52 players remaining.
#
#
# Start Scraping: Arkadiusz Kocyla Kd20
# Finish Scraping 31446 players.
# 51 players remaining.
#
#
# Start Scraping: Yoann Re
# Serve Page: 3
# Return Page: 3
# Raw Page: 3
# Finish Scraping 31447 players.
# 50 players remaining.
#
#
# Start Scraping: Antonio Ruiz
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31448 players.
# 49 players remaining.
#
#
# Start Scraping: Ravishankar Pathanjali
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31449 players.
# 48 players remaining.
#
#
# Start Scraping: Eduardo Magadan
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31450 players.
# 47 players remaining.
#
#
# Start Scraping: Will Farah
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31451 players.
# 46 players remaining.
#
#
# Start Scraping: Juri Margotto
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31452 players.
# 45 players remaining.
#
#
# Start Scraping: Emmanuel Marmillod
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31453 players.
# 44 players remaining.
#
#
# Start Scraping: Juan Olivert
# Finish Scraping 31454 players.
# 43 players remaining.
#
#
# Start Scraping: David Franco
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31455 players.
# 42 players remaining.
#
#
# Start Scraping: Alexander Lindholm L174
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31456 players.
# 41 players remaining.
#
#
# Start Scraping: Adi Kremer
# Finish Scraping 31457 players.
# 40 players remaining.
#
#
# Start Scraping: Paul Lord
# Finish Scraping 31458 players.
# 39 players remaining.
#
#
# Start Scraping: Glenn Solomon
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31459 players.
# 38 players remaining.
#
#
# Start Scraping: Alberto Gutierrez G230
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31460 players.
# 37 players remaining.
#
#
# Start Scraping: Glenn Dickerson
# Finish Scraping 31461 players.
# 36 players remaining.
#
#
# Start Scraping: Jochen Wolff
# Finish Scraping 31462 players.
# 35 players remaining.
#
#
# Start Scraping: Yann Drieux
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31463 players.
# 34 players remaining.
#
#
# Start Scraping: Peter Herrmann
# Finish Scraping 31464 players.
# 33 players remaining.
#
#
# Start Scraping: Trey Carter
# Finish Scraping 31465 players.
# 32 players remaining.
#
#
# Start Scraping: Doug Pielet
# Finish Scraping 31466 players.
# 31 players remaining.
#
#
# Start Scraping: Eric Rosenfeld
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31467 players.
# 30 players remaining.
#
#
# Start Scraping: Bill Stanley
# Finish Scraping 31468 players.
# 29 players remaining.
#
#
# Start Scraping: Dave Richmond
# Finish Scraping 31469 players.
# 28 players remaining.
#
#
# Start Scraping: Peter Smith
# Serve Page: 928
# Return Page: 928
# Raw Page: 928
# Finish Scraping 31470 players.
# 27 players remaining.
#
#
# Start Scraping: Jim Sharton
# Finish Scraping 31471 players.
# 26 players remaining.
#
#
# Start Scraping: Martin Fortun
# Finish Scraping 31472 players.
# 25 players remaining.
#
#
# Start Scraping: Tom Fontana
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31473 players.
# 24 players remaining.
#
#
# Start Scraping: Kai Niemi
# Finish Scraping 31474 players.
# 23 players remaining.
#
#
# Start Scraping: Rob Mitchell
# Finish Scraping 31475 players.
# 22 players remaining.
#
#
# Start Scraping: Hans Fredborg
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31476 players.
# 21 players remaining.
#
#
# Start Scraping: Leighton Alfred
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31477 players.
# 20 players remaining.
#
#
# Start Scraping: Fred Viancos
# Finish Scraping 31478 players.
# 19 players remaining.
#
#
# Start Scraping: Jean Luc Cotard
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31479 players.
# 18 players remaining.
#
#
# Start Scraping: Steven Matthews
# Finish Scraping 31480 players.
# 17 players remaining.
#
#
# Start Scraping: John Losito
# Finish Scraping 31481 players.
# 16 players remaining.
#
#
# Start Scraping: Darcy Carroll
# Finish Scraping 31482 players.
# 15 players remaining.
#
#
# Start Scraping: Mark Pinchoff
# Finish Scraping 31483 players.
# 14 players remaining.
#
#
# Start Scraping: Tracy Fenelon
# Finish Scraping 31484 players.
# 13 players remaining.
#
#
# Start Scraping: Tim Robson
# Finish Scraping 31485 players.
# 12 players remaining.
#
#
# Start Scraping: Tim Downey
# Finish Scraping 31486 players.
# 11 players remaining.
#
#
# Start Scraping: James Rubin
# Finish Scraping 31487 players.
# 10 players remaining.
#
#
# Start Scraping: Andy Gordon
# Finish Scraping 31488 players.
# 9 players remaining.
#
#
# Start Scraping: Larry Barnett
# Finish Scraping 31489 players.
# 8 players remaining.
#
#
# Start Scraping: Eduard Pana
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31490 players.
# 7 players remaining.
#
#
# Start Scraping: Tom Caine
# Finish Scraping 31491 players.
# 6 players remaining.
#
#
# Start Scraping: Doug Adler
# Finish Scraping 31492 players.
# 5 players remaining.
#
#
# Start Scraping: Renald Etienne
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31493 players.
# 4 players remaining.
#
#
# Start Scraping: Jochen Hierl
# Finish Scraping 31494 players.
# 3 players remaining.
#
#
# Start Scraping: Robert Baumgartner
# Serve Page: 1
# Return Page: 1
# Raw Page: 1
# Finish Scraping 31495 players.
# 2 players remaining.
#
#
# Start Scraping: George Glowa
# Finish Scraping 31496 players.
# 1 players remaining.
#
#
# Start Scraping: Zdenek Slizek
# Finish Scraping 31497 players.
# 0 players remaining.
